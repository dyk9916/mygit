# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('D:/김동영/11_Github/mygit-1/DAT/25-1프로젝트/최종데이터/1년 평균값+중앙값 조회수,댓글수_결측치포함ver.csv')
df2 = pd.read_csv('D:/김동영/11_Github/mygit-1/DAT/25-1프로젝트/최종데이터/첫영상날짜.csv')
df3 = pd.read_csv('D:/김동영/11_Github/mygit-1/DAT/25-1프로젝트/최종데이터/exolyt_result_retry_최종.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   username          290 non-null    object
#  1   median_views      275 non-null    object
#  2   median_comments   275 non-null    float64
#  3   average_views     275 non-null    object
#  4   average_comments  271 non-null    float64
# dtypes: float64(2), object(3)
# memory usage: 11.5+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291 entries, 0 to 290
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   username         291 non-null    object
#  1   last_video_date  281 non-null    object
# dtypes: object(2)
# memory usage: 4.7+ KB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   username      304 non-null    object
#  1   verified      303 non-null    object
#  2   top_hashtags  298 non-null    object
# dtypes: object(3)
# memory usage: 7.3+ KB

# %%
df_merged = pd.merge(df1, df2, on='username', how='outer')
df_merged = pd.merge(df_merged, df3, on='username', how='outer')
df_merged.head()
# Out:
#                username median_views  median_comments average_views  \
# 0          Hikarifleurr          987              6.0          6.5K
# 1       Rosemarie.loves          419              9.0           617
# 2         Thatbaileygal          NaN              NaN           NaN
# 3  __allaboutskincare__          311              2.0           275
# 4              _anjello          389             24.0           529
#
#    average_comments last_video_date verified  \
# 0              11.0      2020-01-31    False
# 1              10.0      2023-02-24    False
# 2               NaN      2023-12-10    False
# 3               3.0      2024-02-17    False
# 4              27.0      2024-01-14    False
#
#                                         top_hashtags
# 0  nostalgia, y2k, brendasong, ad, girlygirl, plu...
# 1  tiktokshop, tiktokmademebuyit, fashion, tiktok...
# 2                                                NaN
# 3  explore, tiktok, viral, kbeauty, douyinmakeup,...
# ...

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307 entries, 0 to 306
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   username          307 non-null    object
#  1   median_views      279 non-null    object
#  2   median_comments   279 non-null    float64
#  3   average_views     279 non-null    object
#  4   average_comments  275 non-null    float64
#  5   last_video_date   283 non-null    object
#  6   verified          306 non-null    object
#  7   top_hashtags      301 non-null    object
# dtypes: float64(2), object(6)
# memory usage: 19.3+ KB

# %%
df_merged.to_csv('D:/김동영/11_Github/mygit-1/DAT/25-1프로젝트/최종데이터/통합데이터.csv', index=False)

# %%
data = pd.read_csv('D:/김동영/11_Github/mygit-1/DAT/25-1프로젝트/최종데이터/PR시트의 사본 - 시트1 (2).csv', encoding='cp949')

# %%
data

data = data.drop(index=0).reset_index(drop=True)
data.columns = data.iloc[0]
data = data.drop(index=0).reset_index(drop=True)
data.head()
# Out:
# 0 Contents guide Guide 발송여부 Channel        Username  \
# 0            NaN      FALSE  Tiktok  skinjoyedbyana
# 1            NaN      FALSE      IG   buildyourskin
# 2            NaN      FALSE      IG      grasiapper
# 3            NaN      FALSE      IG    myfadingskin
# 4            NaN      FALSE      IG    ashleymeidaa
#
# 0                                  Social Link Followers  \
# 0    https://www.instagram.com/skinjoyedbyana/     29.6K
# 1     https://www.instagram.com/buildyourskin/     22.5K
# 2    https://www.instagram.com/grasiapper/?g=5     21.2K
# 3      https://www.instagram.com/myfadingskin/     5,949
# 4  https://www.instagram.com/ashleymeidaa/?g=5       118
#
# 0             Email address    컨택 진행상황 특이사항  ... Updated link Updated Date  \
# 0  skinjoyedbyana@gmail.com  TRUE  NaN  NaN  ...          NaN          NaN
# 1                        DM  TRUE  NaN  NaN  ...          NaN          NaN
# 2                        DM  TRUE  NaN  NaN  ...          NaN          NaN
# ...

# %%
data = data[data['Channel'] == 'Tiktok'].reset_index(drop=True)
data.head()
# Out:
# 0 Contents guide Guide 발송여부 Channel        Username  \
# 0            NaN      FALSE  Tiktok  skinjoyedbyana
# 1            NaN      FALSE  Tiktok   @keishasarah_
# 2            NaN      FALSE  Tiktok   @theonlyhaven
# 3            NaN      FALSE  Tiktok  @turquoise.dec
# 4            NaN      FALSE  Tiktok   @ttalgi.ellie
#
# 0                                Social Link Followers  \
# 0  https://www.instagram.com/skinjoyedbyana/     29.6K
# 1       https://www.tiktok.com/@keishasarah_     44.8K
# 2       https://www.tiktok.com/@theonlyhaven      1.3M
# 3      https://www.tiktok.com/@turquoise.dec    746.1K
# 4       https://www.tiktok.com/@ttalgi.ellie      1.4K
#
# 0              Email address     컨택                  진행상황      특이사항  ...  \
# 0   skinjoyedbyana@gmail.com   TRUE                   NaN       NaN  ...
# 1     keisha@teamwildent.com  FALSE                   NaN  메일 전송 실패  ...
# 2         ac@teamwildent.com   TRUE  waiting for content        NaN  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 633 entries, 0 to 632
# Data columns (total 31 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Contents guide  52 non-null     object
#  1   Guide 발송여부      633 non-null    object
#  2   Channel         633 non-null    object
#  3   Username        633 non-null    object
#  4   Social Link     633 non-null    object
#  5   Followers       633 non-null    object
#  6   Email address   633 non-null    object
#  7   컨택              633 non-null    object
#  8   진행상황            343 non-null    object
#  9   특이사항            51 non-null     object
#  10  제품발송            633 non-null    object
#  11  City            311 non-null    object
#  12  State/Province  306 non-null    object
#  13  Country         311 non-null    object
#  14  Ship date       313 non-null    object
#  15  Posted link     178 non-null    object
#  16  Posted Date     177 non-null    object
# ...

# %%
data['Username'] = data['Username'].str.replace('@', '', regex=False)

# %%
merged_data = pd.merge(data, df_merged, left_on='Username', right_on='username', how='left')
merged_data.head()
# Out:
#   Contents guide Guide 발송여부 Channel        Username  \
# 0            NaN      FALSE  Tiktok  skinjoyedbyana
# 1            NaN      FALSE  Tiktok    keishasarah_
# 2            NaN      FALSE  Tiktok    theonlyhaven
# 3            NaN      FALSE  Tiktok   turquoise.dec
# 4            NaN      FALSE  Tiktok    ttalgi.ellie
#
#                                  Social Link Followers  \
# 0  https://www.instagram.com/skinjoyedbyana/     29.6K
# 1       https://www.tiktok.com/@keishasarah_     44.8K
# 2       https://www.tiktok.com/@theonlyhaven      1.3M
# 3      https://www.tiktok.com/@turquoise.dec    746.1K
# 4       https://www.tiktok.com/@ttalgi.ellie      1.4K
#
#                Email address     컨택                  진행상황      특이사항  ...  NaN  \
# 0   skinjoyedbyana@gmail.com   TRUE                   NaN       NaN  ...  NaN
# 1     keisha@teamwildent.com  FALSE                   NaN  메일 전송 실패  ...  NaN
# 2         ac@teamwildent.com   TRUE  waiting for content        NaN  ...  NaN
# ...

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 641 entries, 0 to 640
# Data columns (total 39 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Contents guide    52 non-null     object
#  1   Guide 발송여부        641 non-null    object
#  2   Channel           641 non-null    object
#  3   Username          641 non-null    object
#  4   Social Link       641 non-null    object
#  5   Followers         641 non-null    object
#  6   Email address     641 non-null    object
#  7   컨택                641 non-null    object
#  8   진행상황              351 non-null    object
#  9   특이사항              51 non-null     object
#  10  제품발송              641 non-null    object
#  11  City              319 non-null    object
#  12  State/Province    314 non-null    object
#  13  Country           319 non-null    object
#  14  Ship date         321 non-null    object
#  15  Posted link       184 non-null    object
# ...

# %%
merged_data = merged_data.dropna(subset=['username']).reset_index(drop=True)
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284 entries, 0 to 283
# Data columns (total 39 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Contents guide    52 non-null     object
#  1   Guide 발송여부        284 non-null    object
#  2   Channel           284 non-null    object
#  3   Username          284 non-null    object
#  4   Social Link       284 non-null    object
#  5   Followers         284 non-null    object
#  6   Email address     284 non-null    object
#  7   컨택                284 non-null    object
#  8   진행상황              284 non-null    object
#  9   특이사항              20 non-null     object
#  10  제품발송              284 non-null    object
#  11  City              283 non-null    object
#  12  State/Province    278 non-null    object
#  13  Country           283 non-null    object
#  14  Ship date         284 non-null    object
#  15  Posted link       164 non-null    object
# ...

# %%
merged_data.to_csv('D:/김동영/11_Github/mygit-1/DAT/25-1프로젝트/최종데이터/통합데이터_틱톡2.csv', index=False)

# %%
data = pd.read_csv('D:/김동영/11_Github/mygit-1/DAT/25-1프로젝트/최종데이터/통합데이터_틱톡2.csv', encoding='cp949')

# %%
data.columns
# Out:
# Index(['Contents guide', 'Guide 발송여부', 'Channel', 'Username', 'Social Link',
#        'Followers', 'Email address', '컨택', '진행상황', '특이사항', '제품발송', 'City',
#        'State/Province', 'Country', 'Ship date', 'Posted link', 'Posted Date',
#        'List-up Date', 'Posted Month', 'view track', '특이사항_1', 'Updated link',
#        'Updated Date', 'view track_2', ' 쌀도우 link', 'Updated Date_3',
#        'view track_4', '특이사항_5', 'Column1', '_6', '프로모션 영상 개수', 'username.1',
#        'median_views', 'median_comments', 'average_views', 'average_comments',
#        'last_video_date', 'verified', 'top_hashtags'],
#       dtype='object')

# %%
# 사용할 열 선택
selected_columns = ['Channel', 'Username', '진행상황', 'City', 'Country', 'median_views', 'median_comments', 'average_views', 'average_comments',
'last_video_date', 'verified', 'top_hashtags']

# %%
selected_data = data[selected_columns]
selected_data.head()
# Out:
#   Channel       Username                  진행상황        City Country  \
# 0  Tiktok   theonlyhaven  waiting for content    Singapore      SG
# 1  Tiktok  turquoise.dec  waiting for content    Singapore      SG
# 2  Tiktok   ttalgi.ellie              uploaded     Sarzana   Italy
# 3  Tiktok      srsaskin_              uploaded  Birmingham      GB
# 4  Tiktok       _anjello              uploaded     Concord      US
#
#   median_views  median_comments average_views  average_comments  \
# 0        17.6K              8.0        134.6K              32.0
# 1       117.8K             34.0        341.6K             153.0
# 2          932              5.0          4.3K               6.0
# 3         1.1K             19.0          2.7K              28.0
# 4          389             24.0           529              27.0
#
#   last_video_date verified                                       top_hashtags
# 0      2019-12-19    False  rlholiday, poloralphlauren, rlholidaytree, ral...
# ...

# %%
file_path = 'D:/김동영/11_Github/mygit-1/DAT/25-1프로젝트/최종데이터/팔로워_팔로잉_계정생성일_최종.xls - follower_following_date.csv'
data = pd.read_csv(file_path, encoding='cp949')

# %%
data

data = data.rename(columns={'癤퓎sername': 'username'})

# %%
merged_account = pd.merge(data, selected_data, left_on='account', right_on='Username', how='left')
merged_account.head()
# Out:
#    Column1        account  follower  following first_upload_date Channel  \
# 0        0   keishasarah_     44700        161        2020-09-30     NaN
# 1        1   theonlyhaven   1200000         77        2019-12-19  Tiktok
# 2        2  turquoise.dec    755000        122        2021-02-14  Tiktok
# 3        3   ttalgi.ellie      1373        726               NaN  Tiktok
# 4        4      srsaskin_      1439        890        2024-02-03  Tiktok
#
#         Username                  진행상황        City Country median_views  \
# 0            NaN                   NaN         NaN     NaN          NaN
# 1   theonlyhaven  waiting for content    Singapore      SG        17.6K
# 2  turquoise.dec  waiting for content    Singapore      SG       117.8K
# 3   ttalgi.ellie              uploaded     Sarzana   Italy          932
# 4      srsaskin_              uploaded  Birmingham      GB         1.1K
#
#    median_comments average_views  average_comments last_video_date verified  \
# ...

# %%
columns= ['Column1', 'account', 'first_upload_date', 'Channel']
# columns 리스트 안의 컬럼들을 제거합니다.
merged_account = merged_account.drop(columns=columns, errors='ignore')

merged_account
# Out:
#      follower  following        Username                  진행상황        City  \
# 0       44700        161             NaN                   NaN         NaN
# 1     1200000         77    theonlyhaven  waiting for content    Singapore
# 2      755000        122   turquoise.dec  waiting for content    Singapore
# 3        1373        726    ttalgi.ellie              uploaded     Sarzana
# 4        1439        890       srsaskin_              uploaded  Birmingham
# ..        ...        ...             ...                   ...         ...
# 622        60         82  aglimpseofglow              uploaded    La Habra
# 623      2313       1075     mariana.ugc              uploaded   Green Bay
# 624      2313       1075     mariana.ugc              uploaded   Green Bay
# 625      1425        360     tashfia____              ship out       Dhaka
# 626      1425        360     tashfia____              ship out       Dhaka
#
# ...

# %%
merged_account = merged_account.dropna().reset_index(drop=True)
merged_account.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   follower          247 non-null    int64
#  1   following         247 non-null    int64
#  2   Username          247 non-null    object
#  3   진행상황              247 non-null    object
#  4   City              247 non-null    object
#  5   Country           247 non-null    object
#  6   median_views      247 non-null    object
#  7   median_comments   247 non-null    float64
#  8   average_views     247 non-null    object
#  9   average_comments  247 non-null    float64
#  10  last_video_date   247 non-null    object
#  11  verified          247 non-null    object
#  12  top_hashtags      247 non-null    object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 25.2+ KB

# %%
merged_account

cols = ['Username'] + [col for col in merged_account.columns if col != 'Username']
merged_account = merged_account[cols]
merged_account

cols_reordered = [col for col in merged_account.columns if col != '진행상황'] + ['진행상황']
merged_account = merged_account[cols_reordered]
merged_account
# Out:
#            Username  follower  following        City     Country median_views  \
# 0      theonlyhaven   1200000         77   Singapore          SG        17.6K
# 1     turquoise.dec    755000        122   Singapore          SG       117.8K
# 2      ttalgi.ellie      1373        726     Sarzana       Italy          932
# 3         srsaskin_      1439        890  Birmingham          GB         1.1K
# 4          _anjello       949        681     Concord          US          389
# ..              ...       ...        ...         ...         ...          ...
# 242  aglimpseofglow        60         82    La Habra          US          948
# 243     mariana.ugc      2313       1075   Green Bay          US          461
# 244     mariana.ugc      2313       1075   Green Bay          US          461
# 245     tashfia____      1425        360       Dhaka  Bangladesh         1.3K
# 246     tashfia____      1425        360       Dhaka  Bangladesh         1.3K
#
# ...

# %%
merged_account.to_csv('D:/김동영/11_Github/mygit-1/DAT/25-1프로젝트/최종데이터/final_data.csv', index=False)
