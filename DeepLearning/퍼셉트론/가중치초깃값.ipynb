# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
x = np.random.randn(1000, 100)  # 입력 데이터 1000개, 표준정규분포로 랜덤한 값 생성 
node_num = 100                  # 각 은닉층의 노드(뉴런) 수
hidden_layer_size = 5           # 은닉층이 5개
activations = {}

# %%
len(x)
# Out:
# 1000

# %%
# 활성화 함수로 시그모이드 함수 사용
for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1]
        
    # 가중치 초깃값 설정
    w = np.random.randn(node_num, node_num) * 1 # 표준정규분포(평균:0, 표준편차:1)로부터 생성된 난수를 배열을 생성 
    a = np.dot(x, w)
    z = sigmoid(a)
    activations[i] = z

# %%
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i+1) + "-layer")
    plt.hist(a.flatten(), 30, range=(0, 1))

# %%
# 활성화 함수로 시그모이드 함수 사용
for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1]
        
    # 가중치 초깃값 설정
    w = np.random.randn(node_num, node_num) * 0.01 # 정규분포(평균:0, 표준편차:0.01)로부터 생성된 난수를 배열을 생성 
    a = np.dot(x, w)
    z = sigmoid(a) # 가중합 a를 활성화 함수인 시그모이스 함수에 통과시켜 z를 계산
    activations[i] = z # z는 활성화 함수 출력값 
    
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i+1) + "-layer")
    plt.hist(a.flatten(), 30, range=(0, 1))

# %%
x = np.random.randn(10, 10)  # 입력 데이터 1000개, 표준정규분포로 랜덤한 값 생성 
node_num = 10                  # 각 은닉층의 노드(뉴런) 수

# 가중치 초깃값 설정
w = np.random.randn(node_num, node_num) * 1 # 표준정규분포(평균:0, 표준편차:1)로부터 생성된 난수를 배열을 생성 
a = np.dot(x, w)
z = sigmoid(a) # 가중합 a를 활성화 함수 sigmoid에 통과시킴
activations[i] = z

for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i+1) + "-layer")
    plt.hist(a.flatten(), 30, range=(0, 1))

# %%
# 활성화 함수로 시그모이드 함수 사용
for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1]
        
    # 가중치 초깃값 설정
    w = np.random.randn(node_num, node_num) * np.sqrt(1.0 / node_num) # Xavier 초깃값 
    a = np.dot(x, w)
    z = sigmoid(a) # 가중합 a를 활성화 함수인 시그모이스 함수에 통과시켜 z를 계산
    activations[i] = z # z는 활성화 함수 출력값 
    
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i+1) + "-layer")
    plt.hist(a.flatten(), 30, range=(0, 1))
