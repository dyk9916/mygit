# %%
import numpy as np

# %%
class MatMul:
    def __init__(self, W):
        self.params = [W]               # 가중치 W를 인스턴스 변수 params에 리스트로 저장
        self.grads = [np.zeros_like(W)] # 기울기를 인스턴스 변수 grads에 리스트로 저장
        self.x = None

    def forward(self, x):
        W, = self.params
        out = np.dot(x, W)
        self.x = x
        return out

    def backward(self, dout):
        W, = self.params
        dx = np.dot(dout, W.T)
        dW = np.dot(self.x.T, dout)
        self.grads[0][...] = dW
        return dx

# %%
C = np.array([[1, 0, 0, 0, 0, 0, 0]])
W = np.random.randn(7, 3) # 표준 정규분포로 가중치 초기화
layer = MatMul(W)
h = layer.forward(C)      # 순전파, C와 W의 행렬 곱은 가중치의 행벡터 하나를 선택하는 것과 같다.
print(h)
# Out:
# [[0.08557829 0.10231506 2.4549236 ]]

# %% [markdown]
# ### CBOW 모델 추론

# %%
c0 = np.array([1,0,0,0,0,0,0])
c1 = np.array([0,0,0,1,0,0,0])

# 가중치 초기화
W_in = np.random.randn(7, 3)
W_out = np.random.randn(3, 7)

# 계층 생성
in_layer0 = MatMul(W_in)
in_layer1 = MatMul(W_in)
out_layer = MatMul(W_out)

# 순전파
h0 = in_layer0.forward(c0)
h1 = in_layer1.forward(c1)
h = 0.5 * (h0 + h1) # h0과 h1을 더한 후 0.5를 곱해 평균을 구한다.
s = out_layer.forward(h) # score 계산

print(s) # score 출력
# Out:
# [ 0.955739   -2.40178924  1.68476464 -0.84936642  1.86714724  2.10195289
#   1.15460872]
