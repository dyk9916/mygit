# %%
import numpy as np
import collections
from functions import softmax, cross_entropy_error
from ptb import *
from util import create_contexts_target,to_cpu, to_gpu
from optimizer import Adam
from trainer import Trainer

# %% [markdown]
# ### Embedding 계층 구현

# %%
class Embedding:
  def __init__(self, W):
    self.params = [W]
    self.grads = [np.zeros_like(W)]
    self.idx = None
   
  # 순전파에서는 가중치 w의 특정 행을 추출 
  def forward(self, idx):
    W, = self.params
    self.idx = idx
    out = W[idx]     # idx에 해당하는 가중치 행렬의 행을 추출
    return out
  
  # 역전파에서는 가중치 기울기 dW를 꺼낸다음, dW의 원소를 0으로 설정한 후, idx에 해당하는 행에 dout을 더한다.-> idx의 원소가 중복될 수 있으므로 더해야함. 
  def backward(self, dout):
    dW, = self.grads
    dW[...] = 0
    np.add.at(dW, self.idx, dout)  # dW의 특정 행에 dout을 더함
    return None

# %% [markdown]
# ### Embedding dot 계층 구현

# %%
class EmbeddingDot:
  def __init__(self, W):
    self.embed = Embedding(W)
    self.params = self.embed.params
    self.grads = self.embed.grads
    self.cache = None                   # 순전파 시의 계산 결과를 담아두는 변수

  def forward(self, h, idx):            # h는 은닉층 뉴런의 출력, idx는 단어 ID 배열
    target_W = self.embed.forward(idx)  # Embedding 계층의 forward 메서드 호출, idx에 해당하는 가중치 행렬의 행을 추출, 여기서 idx는 정답 레이블의 단어 ID이다. 
    out = np.sum(target_W * h, axis=1)  # target_W와 h의 행렬 곱 계산

    self.cache = (h, target_W)        
    return out

  def backward(self, dout):
    h, target_W = self.cache
    dout = dout.reshape(dout.shape[0], 1)

    dtarget_W = dout * h
    self.embed.backward(dtarget_W)
    dh = dout * target_W
    return dh

# %% [markdown]
# ### 네거티브 샘플링 구현

# %%
# 단어 빈도 수를 구해 확률분포에 따라 샘플링하는 함수

words = ['you', 'say', 'goodbye', 'I', 'hello', '.']
np.random.choice(words, size=2, replace=False)  # words에서 무작위로 5개 선택, 중복 없음

# 확률분포에 따라 샘플링
p = [0.1, 0.05, 0.5, 0.2, 0.05, 0.1] # 합이 1인 확률분포
np.random.choice(words, p=p)  # words에서 확률분포 p에 따라 샘플링
# Out:
# 'hello'

# %%
# 네거티브 샘플링 구현
class UnigramSampler:
    def __init__(self, corpus, power, sample_size):
        self.sample_size = sample_size
        self.vocab_size = None
        self.word_p = None

        counts = collections.Counter()
        for word_id in corpus:
            counts[word_id] += 1

        vocab_size = len(counts)
        self.vocab_size = vocab_size

        self.word_p = np.zeros(vocab_size)
        for i in range(vocab_size):
            self.word_p[i] = counts[i]

        self.word_p = np.power(self.word_p, power)
        self.word_p /= np.sum(self.word_p)

    def get_negative_sample(self, target):
        batch_size = target.shape[0]

        if not GPU:
            negative_sample = np.zeros((batch_size, self.sample_size), dtype=np.int32)

            for i in range(batch_size):
                p = self.word_p.copy()
                target_idx = target[i]
                p[target_idx] = 0
                p /= p.sum()
                negative_sample[i, :] = np.random.choice(self.vocab_size, size=self.sample_size, replace=False, p=p)
        else:
            # GPU(cupy）로 계산할 때는 속도를 우선한다.
            # 부정적 예에 타깃이 포함될 수 있다.
            negative_sample = np.random.choice(self.vocab_size, size=(batch_size, self.sample_size),
                                               replace=True, p=self.word_p)

        return negative_sample

# %%
# GPU 사용 여부 설정
GPU = False

corpus = np.array([0, 1, 2, 3, 4, 1, 2, 3])
power = 0.75
sample_size = 2

sampler = UnigramSampler(corpus, power, sample_size) # UnigramSampler 클래스의 인스턴스 생성
target = np.array([1, 3, 0]) # 3개의 데이터를 미니배치로 묶어 처리한다고 가정, 긍정적 예
negative_sample = sampler.get_negative_sample(target) # 부정적 예 샘플링
print(negative_sample)
# Out:
# [[2 3]
#  [2 4]
#  [1 3]]

# %%
class SigmoidWithLoss:
    def __init__(self):
        self.params, self.grads = [], []
        self.loss = None
        self.y = None  # sigmoid의 출력
        self.t = None  # 정답 데이터

    def forward(self, x, t):
        self.t = t
        self.y = 1 / (1 + np.exp(-x))

        self.loss = cross_entropy_error(np.c_[1 - self.y, self.y], self.t)

        return self.loss

    def backward(self, dout=1):
        batch_size = self.t.shape[0]

        dx = (self.y - self.t) * dout / batch_size
        return dx

# %%
# 네거티브 샘플링을 수행하는 손실함수 구현
# NegativeSampling 클래스 내부에는 EmbeddingDot 계층과 SigmoidWithLoss 계층이 포함되어 있다.
class NegativeSamplingLoss:
  def __init__(self, W, corpus, power=0.75, sample_size=5):
    self.sample_size = sample_size                                          # 샘플링 수
    self.sampler = UnigramSampler(corpus, power, sample_size)               # UnigramSampler 클래스의 인스턴스 생성
    self.loss_layers = [SigmoidWithLoss() for _ in range(sample_size + 1)]  # 긍정적 예 1개 + 부정적 예 sample_size개, loss_layers[0]는 긍정적 예에 대한 손실을 구하는 계층이다.
    self.embed_dot_layers = [EmbeddingDot(W) for _ in range(sample_size + 1)] # 긍정적 예 1개 + 부정적 예 sample_size개, embed_dot_layers[0]는 긍정적 예에 대한 점수를 구하는 계층이다.
    
    self.params, self.grads = [], []                                        # 모든 가중치와 기울기를 리스트에 모은다.
    for layer in self.embed_dot_layers:
      self.params += layer.params
      self.grads += layer.grads
  
  # 순전파, 긍정적 예와 부정적 예의 점수를 구하고, 손실을 계산한다.
  def forward(self, h, target):
    batch_size = target.shape[0]
    negative_sample = self.sampler.get_negative_sample(target)  # 부정적 예 샘플링, UnigramSampler 클래스의 get_negative_sample 메서드 호출
    
    # 긍정적 예의 순전파
    score = self.embed_dot_layers[0].forward(h, target)          # 긍정적 예의 점수, EmbeddingDot 클래스의 forward 메서드 호출, h와 target 간의 내적을 계산. 
    correct_label = np.ones(batch_size, dtype=np.int32)          # 긍정적 예의 레이블은 1
    loss = self.loss_layers[0].forward(score, correct_label)      # 긍정적 예의 손실, SigmoidWithLoss 클래스의 forward 메서드 호출, score를 SigmoidWithLoss 계층에 입력하여 손실을 계산.
    
    # 부정적 예의 순전파
    negative_label = np.zeros(batch_size, dtype=np.int32)        # 부정적 예의 레이블은 0
    for i in range(self.sample_size):
      negative_target = negative_sample[:, i]                    # 부정적 예의 타깃
      score = self.embed_dot_layers[1 + i].forward(h, negative_target)  # 부정적 예의 점수, EmbeddingDot 클래스의 forward 메서드 호출, h와 negative_target 간의 내적을 계산.
      loss += self.loss_layers[1 + i].forward(score, negative_label)    # 부정적 예의 손실, SigmoidWithLoss 클래스의 forward 메서드 호출, score를 SigmoidWithLoss 계층에 입력하여 손실을 계산.
      
    return loss
  
  # 역전파
  def backward(self, dout=1):
    dh = 0
    for l0, l1 in zip(self.loss_layers, self.embed_dot_layers):
      dscore = l0.backward(dout)  # SigmoidWithLoss 계층의 역전파, SigmoidWithLoss 클래스의 backward 메서드 호출
      dh += l1.backward(dscore)   # EmbeddingDot 계층의 역전파, EmbeddingDot 클래스의 backward 메서드 호출
    return dh

# %% [markdown]
# ### SimpleCBOW 모델을 개선한 CBOW 모델, Embedding 계층과 Negative Sampling Loss 계층을 적용했다.

# %%
class CBOW:
  def __init__(self, vocab_size, hidden_size, window_size, corpus): # voab_size:어휘수, hidden_size:은닉층 뉴런 수, window_size:맥락의 크기, corpus:말뭉치
    V, H = vocab_size, hidden_size                  

    # 가중치 초기화
    W_in = 0.01 * np.random.randn(V, H).astype('f')
    W_out = 0.01 * np.random.randn(V, H).astype('f')

    # 계층 생성
    self.in_layers = []
    for i in range(2 * window_size):
      layer = Embedding(W_in)              # Embedding 계층 사용, 2*window_size만큼 생성, 예) window_size가 1이면 2개의 Embedding 계층 생성
      self.in_layers.append(layer)         # Embedding 계층을 인스턴스 변수 in_layers에 배열로 저장
    self.ns_loss = NegativeSamplingLoss(W_out, corpus, power=0.75, sample_size=5)  # NegativeSamplingLoss 계층을 인스턴스 변수 ns_loss에 저장

    # 모든 가중치와 기울기를 리스트에 모은다.
    layers = self.in_layers + [self.ns_loss]  # in_layers와 ns_loss를 합쳐 layers에 저장, 모든 계층을 리스트에 모은다.
    self.params, self.grads = [], []
    for layer in layers:
      self.params += layer.params             # params에 각 계층의 가중치를 저장
      self.grads += layer.grads               # grads에 각 계층의 기울기를 저장

    # 인스턴스 변수에 단어의 분산 표현을 저장한다.
    self.word_vecs = W_in   # 인스턴스 변수 word_vecs에 W_in을 저장해 단어의 분산 표현에 접근할 수 있게 한다. 사실상 word_vecs를 구하기 위해 필요한 것은 W_in이다.
    
  # 순전파
  def forward(self, contexts, target):     # contexts는 맥락, target은 타깃을 나타내는데 이 두 인수는 단어 ID의 배열이다.
    h = 0
    for i, layer in enumerate(self.in_layers):
      h += layer.forward(contexts[:, i])  # Embedding 계층의 forward 메서드 호출, contexts[:, i]는 각 맥락의 단어 ID를 추출
    h *= 1 / len(self.in_layers)           # 은닉층 노드 h의 값이 맥락의 수만큼 나눠서 평균값을 구한다. 

    loss = self.ns_loss.forward(h, target) # NegativeSamplingLoss 계층의 forward 메서드 호출, h와 target을 입력하여 손실을 계산
    return loss
  
  # 역전파
  def backward(self, dout=1):
    dout = self.ns_loss.backward(dout)  # NegativeSamplingLoss 계층의 역전파, NegativeSamplingLoss 클래스의 backward 메서드 호출
    dout *= 1 / len(self.in_layers)     # 은닉층 노드 h의 기울기를 맥락의 수만큼 나눠서 평균값을 구한다.

    for layer in self.in_layers:
      layer.backward(dout)              # Embedding 계층의 역전파, Embedding 클래스의 backward 메서드 호출

# %% [markdown]
# ### CBOW 모델 학습 코드

# %%
# 하이퍼 파라미터 설정
window_size = 1
hidden_size = 5
batch_size = 3 # 미니배치 크기
max_epoch = 2

# 데이터 읽기
corpus, word_to_id, id_to_word = load_data('train')
vocab_size = len(word_to_id)
vocab_size
contexts, target = create_contexts_target(corpus, window_size) # 맥락과 타깃 생성하는 함수 호출
if GPU:
    contexts, target = to_gpu(contexts), to_gpu(target)
    
# 모델 생성
model = CBOW(vocab_size, hidden_size, window_size, corpus)
optimizer = Adam()
trainer = Trainer(model, optimizer)

# 학습 시작
trainer.fit(contexts, target, max_epoch, batch_size)
trainer.plot()
# Out:
# | 에폭 1 |  반복 1 / 309862 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 21 / 309862 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 41 / 309862 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 61 / 309862 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 81 / 309862 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 101 / 309862 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 121 / 309862 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 141 / 309862 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 161 / 309862 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 181 / 309862 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 201 / 309862 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 221 / 309862 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 241 / 309862 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 261 / 309862 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 281 / 309862 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 301 / 309862 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 321 / 309862 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 341 / 309862 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 361 / 309862 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 381 / 309862 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 401 / 309862 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 421 / 309862 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 441 / 309862 | 시간 0[s] | 손실 4.15
# | 에폭 1 |  반복 461 / 309862 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 481 / 309862 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 501 / 309862 | 시간 0[s] | 손실 4.15
# | 에폭 1 |  반복 521 / 309862 | 시간 0[s] | 손실 4.15
# | 에폭 1 |  반복 541 / 309862 | 시간 0[s] | 손실 4.15
# | 에폭 1 |  반복 561 / 309862 | 시간 0[s] | 손실 4.15
# | 에폭 1 |  반복 581 / 309862 | 시간 0[s] | 손실 4.15
# | 에폭 1 |  반복 601 / 309862 | 시간 0[s] | 손실 4.15
# | 에폭 1 |  반복 621 / 309862 | 시간 0[s] | 손실 4.15
# | 에폭 1 |  반복 641 / 309862 | 시간 0[s] | 손실 4.15
# | 에폭 1 |  반복 661 / 309862 | 시간 0[s] | 손실 4.15
# | 에폭 1 |  반복 681 / 309862 | 시간 0[s] | 손실 4.15
# | 에폭 1 |  반복 701 / 309862 | 시간 0[s] | 손실 4.15
# | 에폭 1 |  반복 721 / 309862 | 시간 0[s] | 손실 4.14
# | 에폭 1 |  반복 741 / 309862 | 시간 0[s] | 손실 4.14
# | 에폭 1 |  반복 761 / 309862 | 시간 0[s] | 손실 4.14
# | 에폭 1 |  반복 781 / 309862 | 시간 0[s] | 손실 4.14
# | 에폭 1 |  반복 801 / 309862 | 시간 0[s] | 손실 4.14
# | 에폭 1 |  반복 821 / 309862 | 시간 0[s] | 손실 4.13
# | 에폭 1 |  반복 841 / 309862 | 시간 0[s] | 손실 4.13
# | 에폭 1 |  반복 861 / 309862 | 시간 0[s] | 손실 4.13
# | 에폭 1 |  반복 881 / 309862 | 시간 0[s] | 손실 4.12
# | 에폭 1 |  반복 901 / 309862 | 시간 1[s] | 손실 4.12
# | 에폭 1 |  반복 921 / 309862 | 시간 1[s] | 손실 4.11
# | 에폭 1 |  반복 941 / 309862 | 시간 1[s] | 손실 4.12
# | 에폭 1 |  반복 961 / 309862 | 시간 1[s] | 손실 4.11
# | 에폭 1 |  반복 981 / 309862 | 시간 1[s] | 손실 4.12
# | 에폭 1 |  반복 1001 / 309862 | 시간 1[s] | 손실 4.11
# | 에폭 1 |  반복 1021 / 309862 | 시간 1[s] | 손실 4.11
# | 에폭 1 |  반복 1041 / 309862 | 시간 1[s] | 손실 4.11
# | 에폭 1 |  반복 1061 / 309862 | 시간 1[s] | 손실 4.10
# | 에폭 1 |  반복 1081 / 309862 | 시간 1[s] | 손실 4.10
# | 에폭 1 |  반복 1101 / 309862 | 시간 1[s] | 손실 4.09
# | 에폭 1 |  반복 1121 / 309862 | 시간 1[s] | 손실 4.09
# | 에폭 1 |  반복 1141 / 309862 | 시간 1[s] | 손실 4.09
# | 에폭 1 |  반복 1161 / 309862 | 시간 1[s] | 손실 4.09
# | 에폭 1 |  반복 1181 / 309862 | 시간 1[s] | 손실 4.08
# | 에폭 1 |  반복 1201 / 309862 | 시간 1[s] | 손실 4.09
# | 에폭 1 |  반복 1221 / 309862 | 시간 1[s] | 손실 4.10
# | 에폭 1 |  반복 1241 / 309862 | 시간 1[s] | 손실 4.06
# | 에폭 1 |  반복 1261 / 309862 | 시간 1[s] | 손실 4.08
# | 에폭 1 |  반복 1281 / 309862 | 시간 1[s] | 손실 4.08
# | 에폭 1 |  반복 1301 / 309862 | 시간 1[s] | 손실 4.05
# | 에폭 1 |  반복 1321 / 309862 | 시간 1[s] | 손실 4.05
# | 에폭 1 |  반복 1341 / 309862 | 시간 1[s] | 손실 4.04
# | 에폭 1 |  반복 1361 / 309862 | 시간 1[s] | 손실 4.06
# | 에폭 1 |  반복 1381 / 309862 | 시간 1[s] | 손실 4.07
# | 에폭 1 |  반복 1401 / 309862 | 시간 1[s] | 손실 4.03
# | 에폭 1 |  반복 1421 / 309862 | 시간 1[s] | 손실 4.04
# | 에폭 1 |  반복 1441 / 309862 | 시간 1[s] | 손실 4.01
# | 에폭 1 |  반복 1461 / 309862 | 시간 1[s] | 손실 4.01
# | 에폭 1 |  반복 1481 / 309862 | 시간 1[s] | 손실 4.01
# | 에폭 1 |  반복 1501 / 309862 | 시간 1[s] | 손실 4.02
# | 에폭 1 |  반복 1521 / 309862 | 시간 1[s] | 손실 4.02
# | 에폭 1 |  반복 1541 / 309862 | 시간 1[s] | 손실 3.99
# | 에폭 1 |  반복 1561 / 309862 | 시간 1[s] | 손실 4.02
# | 에폭 1 |  반복 1581 / 309862 | 시간 1[s] | 손실 4.00
# | 에폭 1 |  반복 1601 / 309862 | 시간 1[s] | 손실 3.99
# | 에폭 1 |  반복 1621 / 309862 | 시간 1[s] | 손실 4.00
# | 에폭 1 |  반복 1641 / 309862 | 시간 1[s] | 손실 3.96
# | 에폭 1 |  반복 1661 / 309862 | 시간 1[s] | 손실 4.01
# | 에폭 1 |  반복 1681 / 309862 | 시간 1[s] | 손실 4.02
# | 에폭 1 |  반복 1701 / 309862 | 시간 1[s] | 손실 3.94
# | 에폭 1 |  반복 1721 / 309862 | 시간 1[s] | 손실 3.99
# | 에폭 1 |  반복 1741 / 309862 | 시간 1[s] | 손실 3.93
# | 에폭 1 |  반복 1761 / 309862 | 시간 1[s] | 손실 3.98
# | 에폭 1 |  반복 1781 / 309862 | 시간 1[s] | 손실 3.99
# | 에폭 1 |  반복 1801 / 309862 | 시간 1[s] | 손실 3.92
# | 에폭 1 |  반복 1821 / 309862 | 시간 1[s] | 손실 3.92
# | 에폭 1 |  반복 1841 / 309862 | 시간 2[s] | 손실 3.95
# | 에폭 1 |  반복 1861 / 309862 | 시간 2[s] | 손실 3.97
# | 에폭 1 |  반복 1881 / 309862 | 시간 2[s] | 손실 3.90
# | 에폭 1 |  반복 1901 / 309862 | 시간 2[s] | 손실 3.86
# | 에폭 1 |  반복 1921 / 309862 | 시간 2[s] | 손실 3.95
# | 에폭 1 |  반복 1941 / 309862 | 시간 2[s] | 손실 3.92
# | 에폭 1 |  반복 1961 / 309862 | 시간 2[s] | 손실 3.93
# | 에폭 1 |  반복 1981 / 309862 | 시간 2[s] | 손실 3.94
# | 에폭 1 |  반복 2001 / 309862 | 시간 2[s] | 손실 3.91
# | 에폭 1 |  반복 2021 / 309862 | 시간 2[s] | 손실 3.93
# | 에폭 1 |  반복 2041 / 309862 | 시간 2[s] | 손실 3.99
# | 에폭 1 |  반복 2061 / 309862 | 시간 2[s] | 손실 3.96
# | 에폭 1 |  반복 2081 / 309862 | 시간 2[s] | 손실 3.93
# | 에폭 1 |  반복 2101 / 309862 | 시간 2[s] | 손실 3.90
# | 에폭 1 |  반복 2121 / 309862 | 시간 2[s] | 손실 3.86
# | 에폭 1 |  반복 2141 / 309862 | 시간 2[s] | 손실 3.89
# | 에폭 1 |  반복 2161 / 309862 | 시간 2[s] | 손실 3.94
# | 에폭 1 |  반복 2181 / 309862 | 시간 2[s] | 손실 3.91
# | 에폭 1 |  반복 2201 / 309862 | 시간 2[s] | 손실 3.83
# | 에폭 1 |  반복 2221 / 309862 | 시간 2[s] | 손실 3.89
# | 에폭 1 |  반복 2241 / 309862 | 시간 2[s] | 손실 3.83
# | 에폭 1 |  반복 2261 / 309862 | 시간 2[s] | 손실 3.82
# | 에폭 1 |  반복 2281 / 309862 | 시간 2[s] | 손실 3.85
# | 에폭 1 |  반복 2301 / 309862 | 시간 2[s] | 손실 3.86
# | 에폭 1 |  반복 2321 / 309862 | 시간 2[s] | 손실 3.86
# | 에폭 1 |  반복 2341 / 309862 | 시간 2[s] | 손실 3.87
# | 에폭 1 |  반복 2361 / 309862 | 시간 2[s] | 손실 3.88
# | 에폭 1 |  반복 2381 / 309862 | 시간 2[s] | 손실 3.83
# | 에폭 1 |  반복 2401 / 309862 | 시간 2[s] | 손실 3.85
# | 에폭 1 |  반복 2421 / 309862 | 시간 2[s] | 손실 3.77
# | 에폭 1 |  반복 2441 / 309862 | 시간 2[s] | 손실 3.91
# | 에폭 1 |  반복 2461 / 309862 | 시간 2[s] | 손실 3.85
# | 에폭 1 |  반복 2481 / 309862 | 시간 2[s] | 손실 3.88
# | 에폭 1 |  반복 2501 / 309862 | 시간 2[s] | 손실 3.79
# | 에폭 1 |  반복 2521 / 309862 | 시간 2[s] | 손실 3.86
# | 에폭 1 |  반복 2541 / 309862 | 시간 2[s] | 손실 3.85
# | 에폭 1 |  반복 2561 / 309862 | 시간 2[s] | 손실 3.77
# | 에폭 1 |  반복 2581 / 309862 | 시간 2[s] | 손실 3.79
# | 에폭 1 |  반복 2601 / 309862 | 시간 2[s] | 손실 3.85
# | 에폭 1 |  반복 2621 / 309862 | 시간 2[s] | 손실 3.81
# | 에폭 1 |  반복 2641 / 309862 | 시간 2[s] | 손실 3.82
# | 에폭 1 |  반복 2661 / 309862 | 시간 2[s] | 손실 3.83
# | 에폭 1 |  반복 2681 / 309862 | 시간 2[s] | 손실 3.82
# | 에폭 1 |  반복 2701 / 309862 | 시간 3[s] | 손실 3.80
# | 에폭 1 |  반복 2721 / 309862 | 시간 3[s] | 손실 3.70
# | 에폭 1 |  반복 2741 / 309862 | 시간 3[s] | 손실 3.73
# | 에폭 1 |  반복 2761 / 309862 | 시간 3[s] | 손실 3.86
# | 에폭 1 |  반복 2781 / 309862 | 시간 3[s] | 손실 3.76
# | 에폭 1 |  반복 2801 / 309862 | 시간 3[s] | 손실 3.82
# | 에폭 1 |  반복 2821 / 309862 | 시간 3[s] | 손실 3.85
# | 에폭 1 |  반복 2841 / 309862 | 시간 3[s] | 손실 3.75
# | 에폭 1 |  반복 2861 / 309862 | 시간 3[s] | 손실 3.86
# | 에폭 1 |  반복 2881 / 309862 | 시간 3[s] | 손실 3.79
# | 에폭 1 |  반복 2901 / 309862 | 시간 3[s] | 손실 3.85
# | 에폭 1 |  반복 2921 / 309862 | 시간 3[s] | 손실 3.83
# | 에폭 1 |  반복 2941 / 309862 | 시간 3[s] | 손실 3.74
# | 에폭 1 |  반복 2961 / 309862 | 시간 3[s] | 손실 3.85
# | 에폭 1 |  반복 2981 / 309862 | 시간 3[s] | 손실 3.68
# | 에폭 1 |  반복 3001 / 309862 | 시간 3[s] | 손실 3.76
# | 에폭 1 |  반복 3021 / 309862 | 시간 3[s] | 손실 3.82
# | 에폭 1 |  반복 3041 / 309862 | 시간 3[s] | 손실 3.71
# | 에폭 1 |  반복 3061 / 309862 | 시간 3[s] | 손실 3.69
# | 에폭 1 |  반복 3081 / 309862 | 시간 3[s] | 손실 3.83
# | 에폭 1 |  반복 3101 / 309862 | 시간 3[s] | 손실 3.70
# | 에폭 1 |  반복 3121 / 309862 | 시간 3[s] | 손실 3.67
# | 에폭 1 |  반복 3141 / 309862 | 시간 3[s] | 손실 3.69
# | 에폭 1 |  반복 3161 / 309862 | 시간 3[s] | 손실 3.77
# | 에폭 1 |  반복 3181 / 309862 | 시간 3[s] | 손실 3.70
# | 에폭 1 |  반복 3201 / 309862 | 시간 3[s] | 손실 3.70
# | 에폭 1 |  반복 3221 / 309862 | 시간 3[s] | 손실 3.74
# | 에폭 1 |  반복 3241 / 309862 | 시간 3[s] | 손실 3.75
# | 에폭 1 |  반복 3261 / 309862 | 시간 3[s] | 손실 3.75
# | 에폭 1 |  반복 3281 / 309862 | 시간 3[s] | 손실 3.68
# | 에폭 1 |  반복 3301 / 309862 | 시간 3[s] | 손실 3.68
# | 에폭 1 |  반복 3321 / 309862 | 시간 3[s] | 손실 3.65
# | 에폭 1 |  반복 3341 / 309862 | 시간 3[s] | 손실 3.75
# | 에폭 1 |  반복 3361 / 309862 | 시간 3[s] | 손실 3.74
# | 에폭 1 |  반복 3381 / 309862 | 시간 3[s] | 손실 3.66
# | 에폭 1 |  반복 3401 / 309862 | 시간 3[s] | 손실 3.71
# | 에폭 1 |  반복 3421 / 309862 | 시간 3[s] | 손실 3.66
# | 에폭 1 |  반복 3441 / 309862 | 시간 3[s] | 손실 3.79
# | 에폭 1 |  반복 3461 / 309862 | 시간 3[s] | 손실 3.71
# | 에폭 1 |  반복 3481 / 309862 | 시간 3[s] | 손실 3.80
# | 에폭 1 |  반복 3501 / 309862 | 시간 3[s] | 손실 3.66
# | 에폭 1 |  반복 3521 / 309862 | 시간 3[s] | 손실 3.70
# | 에폭 1 |  반복 3541 / 309862 | 시간 3[s] | 손실 3.70
# | 에폭 1 |  반복 3561 / 309862 | 시간 3[s] | 손실 3.75
# | 에폭 1 |  반복 3581 / 309862 | 시간 3[s] | 손실 3.73
# | 에폭 1 |  반복 3601 / 309862 | 시간 3[s] | 손실 3.61
# | 에폭 1 |  반복 3621 / 309862 | 시간 3[s] | 손실 3.77
# | 에폭 1 |  반복 3641 / 309862 | 시간 4[s] | 손실 3.61
# | 에폭 1 |  반복 3661 / 309862 | 시간 4[s] | 손실 3.64
# | 에폭 1 |  반복 3681 / 309862 | 시간 4[s] | 손실 3.63
# | 에폭 1 |  반복 3701 / 309862 | 시간 4[s] | 손실 3.73
# | 에폭 1 |  반복 3721 / 309862 | 시간 4[s] | 손실 3.61
# | 에폭 1 |  반복 3741 / 309862 | 시간 4[s] | 손실 3.72
# | 에폭 1 |  반복 3761 / 309862 | 시간 4[s] | 손실 3.65
# | 에폭 1 |  반복 3781 / 309862 | 시간 4[s] | 손실 3.60
# | 에폭 1 |  반복 3801 / 309862 | 시간 4[s] | 손실 3.67
# | 에폭 1 |  반복 3821 / 309862 | 시간 4[s] | 손실 3.65
# | 에폭 1 |  반복 3841 / 309862 | 시간 4[s] | 손실 3.62
# | 에폭 1 |  반복 3861 / 309862 | 시간 4[s] | 손실 3.69
# | 에폭 1 |  반복 3881 / 309862 | 시간 4[s] | 손실 3.68
# | 에폭 1 |  반복 3901 / 309862 | 시간 4[s] | 손실 3.63
# | 에폭 1 |  반복 3921 / 309862 | 시간 4[s] | 손실 3.63
# | 에폭 1 |  반복 3941 / 309862 | 시간 4[s] | 손실 3.59
# | 에폭 1 |  반복 3961 / 309862 | 시간 4[s] | 손실 3.66
# | 에폭 1 |  반복 3981 / 309862 | 시간 4[s] | 손실 3.63
# | 에폭 1 |  반복 4001 / 309862 | 시간 4[s] | 손실 3.64
# | 에폭 1 |  반복 4021 / 309862 | 시간 4[s] | 손실 3.72
# | 에폭 1 |  반복 4041 / 309862 | 시간 4[s] | 손실 3.62
# | 에폭 1 |  반복 4061 / 309862 | 시간 4[s] | 손실 3.53
# | 에폭 1 |  반복 4081 / 309862 | 시간 4[s] | 손실 3.53
# | 에폭 1 |  반복 4101 / 309862 | 시간 4[s] | 손실 3.62
# | 에폭 1 |  반복 4121 / 309862 | 시간 4[s] | 손실 3.63
# | 에폭 1 |  반복 4141 / 309862 | 시간 4[s] | 손실 3.74
# | 에폭 1 |  반복 4161 / 309862 | 시간 4[s] | 손실 3.60
# | 에폭 1 |  반복 4181 / 309862 | 시간 4[s] | 손실 3.55
# | 에폭 1 |  반복 4201 / 309862 | 시간 4[s] | 손실 3.61
# | 에폭 1 |  반복 4221 / 309862 | 시간 4[s] | 손실 3.49
# | 에폭 1 |  반복 4241 / 309862 | 시간 4[s] | 손실 3.51
# | 에폭 1 |  반복 4261 / 309862 | 시간 4[s] | 손실 3.59
# | 에폭 1 |  반복 4281 / 309862 | 시간 4[s] | 손실 3.66
# | 에폭 1 |  반복 4301 / 309862 | 시간 4[s] | 손실 3.65
# | 에폭 1 |  반복 4321 / 309862 | 시간 4[s] | 손실 3.68
# | 에폭 1 |  반복 4341 / 309862 | 시간 4[s] | 손실 3.55
# | 에폭 1 |  반복 4361 / 309862 | 시간 4[s] | 손실 3.60
# | 에폭 1 |  반복 4381 / 309862 | 시간 4[s] | 손실 3.59
# | 에폭 1 |  반복 4401 / 309862 | 시간 4[s] | 손실 3.63
# | 에폭 1 |  반복 4421 / 309862 | 시간 4[s] | 손실 3.52
# | 에폭 1 |  반복 4441 / 309862 | 시간 4[s] | 손실 3.56
# | 에폭 1 |  반복 4461 / 309862 | 시간 4[s] | 손실 3.57
# | 에폭 1 |  반복 4481 / 309862 | 시간 4[s] | 손실 3.70
# | 에폭 1 |  반복 4501 / 309862 | 시간 4[s] | 손실 3.61
# | 에폭 1 |  반복 4521 / 309862 | 시간 4[s] | 손실 3.67
# | 에폭 1 |  반복 4541 / 309862 | 시간 4[s] | 손실 3.54
# | 에폭 1 |  반복 4561 / 309862 | 시간 4[s] | 손실 3.68
# | 에폭 1 |  반복 4581 / 309862 | 시간 5[s] | 손실 3.49
# | 에폭 1 |  반복 4601 / 309862 | 시간 5[s] | 손실 3.56
# | 에폭 1 |  반복 4621 / 309862 | 시간 5[s] | 손실 3.59
# | 에폭 1 |  반복 4641 / 309862 | 시간 5[s] | 손실 3.60
# | 에폭 1 |  반복 4661 / 309862 | 시간 5[s] | 손실 3.64
# | 에폭 1 |  반복 4681 / 309862 | 시간 5[s] | 손실 3.65
# | 에폭 1 |  반복 4701 / 309862 | 시간 5[s] | 손실 3.58
# | 에폭 1 |  반복 4721 / 309862 | 시간 5[s] | 손실 3.51
# | 에폭 1 |  반복 4741 / 309862 | 시간 5[s] | 손실 3.67
# | 에폭 1 |  반복 4761 / 309862 | 시간 5[s] | 손실 3.47
# | 에폭 1 |  반복 4781 / 309862 | 시간 5[s] | 손실 3.50
# | 에폭 1 |  반복 4801 / 309862 | 시간 5[s] | 손실 3.44
# | 에폭 1 |  반복 4821 / 309862 | 시간 5[s] | 손실 3.53
# | 에폭 1 |  반복 4841 / 309862 | 시간 5[s] | 손실 3.52
# | 에폭 1 |  반복 4861 / 309862 | 시간 5[s] | 손실 3.41
# | 에폭 1 |  반복 4881 / 309862 | 시간 5[s] | 손실 3.54
# | 에폭 1 |  반복 4901 / 309862 | 시간 5[s] | 손실 3.51
# | 에폭 1 |  반복 4921 / 309862 | 시간 5[s] | 손실 3.56
# | 에폭 1 |  반복 4941 / 309862 | 시간 5[s] | 손실 3.38
# | 에폭 1 |  반복 4961 / 309862 | 시간 5[s] | 손실 3.45
# | 에폭 1 |  반복 4981 / 309862 | 시간 5[s] | 손실 3.61
# | 에폭 1 |  반복 5001 / 309862 | 시간 5[s] | 손실 3.59
# | 에폭 1 |  반복 5021 / 309862 | 시간 5[s] | 손실 3.41
# | 에폭 1 |  반복 5041 / 309862 | 시간 5[s] | 손실 3.44
# | 에폭 1 |  반복 5061 / 309862 | 시간 5[s] | 손실 3.58
# | 에폭 1 |  반복 5081 / 309862 | 시간 5[s] | 손실 3.55
# | 에폭 1 |  반복 5101 / 309862 | 시간 5[s] | 손실 3.52
# | 에폭 1 |  반복 5121 / 309862 | 시간 5[s] | 손실 3.57
# | 에폭 1 |  반복 5141 / 309862 | 시간 5[s] | 손실 3.54
# | 에폭 1 |  반복 5161 / 309862 | 시간 5[s] | 손실 3.56
# | 에폭 1 |  반복 5181 / 309862 | 시간 5[s] | 손실 3.68
# | 에폭 1 |  반복 5201 / 309862 | 시간 5[s] | 손실 3.47
# | 에폭 1 |  반복 5221 / 309862 | 시간 5[s] | 손실 3.61
# | 에폭 1 |  반복 5241 / 309862 | 시간 5[s] | 손실 3.31
# | 에폭 1 |  반복 5261 / 309862 | 시간 5[s] | 손실 3.46
# | 에폭 1 |  반복 5281 / 309862 | 시간 5[s] | 손실 3.42
# | 에폭 1 |  반복 5301 / 309862 | 시간 5[s] | 손실 3.57
# | 에폭 1 |  반복 5321 / 309862 | 시간 5[s] | 손실 3.43
# | 에폭 1 |  반복 5341 / 309862 | 시간 5[s] | 손실 3.43
# | 에폭 1 |  반복 5361 / 309862 | 시간 5[s] | 손실 3.49
# | 에폭 1 |  반복 5381 / 309862 | 시간 5[s] | 손실 3.46
# | 에폭 1 |  반복 5401 / 309862 | 시간 5[s] | 손실 3.33
# | 에폭 1 |  반복 5421 / 309862 | 시간 5[s] | 손실 3.48
# | 에폭 1 |  반복 5441 / 309862 | 시간 5[s] | 손실 3.44
# | 에폭 1 |  반복 5461 / 309862 | 시간 5[s] | 손실 3.28
# | 에폭 1 |  반복 5481 / 309862 | 시간 5[s] | 손실 3.38
# | 에폭 1 |  반복 5501 / 309862 | 시간 6[s] | 손실 3.46
# | 에폭 1 |  반복 5521 / 309862 | 시간 6[s] | 손실 3.54
# | 에폭 1 |  반복 5541 / 309862 | 시간 6[s] | 손실 3.48
# | 에폭 1 |  반복 5561 / 309862 | 시간 6[s] | 손실 3.47
# | 에폭 1 |  반복 5581 / 309862 | 시간 6[s] | 손실 3.31
# | 에폭 1 |  반복 5601 / 309862 | 시간 6[s] | 손실 3.53
# | 에폭 1 |  반복 5621 / 309862 | 시간 6[s] | 손실 3.64
# | 에폭 1 |  반복 5641 / 309862 | 시간 6[s] | 손실 3.57
# | 에폭 1 |  반복 5661 / 309862 | 시간 6[s] | 손실 3.52
# | 에폭 1 |  반복 5681 / 309862 | 시간 6[s] | 손실 3.53
# | 에폭 1 |  반복 5701 / 309862 | 시간 6[s] | 손실 3.51
# | 에폭 1 |  반복 5721 / 309862 | 시간 6[s] | 손실 3.38
# | 에폭 1 |  반복 5741 / 309862 | 시간 6[s] | 손실 3.48
# | 에폭 1 |  반복 5761 / 309862 | 시간 6[s] | 손실 3.32
# | 에폭 1 |  반복 5781 / 309862 | 시간 6[s] | 손실 3.43
# | 에폭 1 |  반복 5801 / 309862 | 시간 6[s] | 손실 3.50
# | 에폭 1 |  반복 5821 / 309862 | 시간 6[s] | 손실 3.39
# | 에폭 1 |  반복 5841 / 309862 | 시간 6[s] | 손실 3.45
# | 에폭 1 |  반복 5861 / 309862 | 시간 6[s] | 손실 3.44
# | 에폭 1 |  반복 5881 / 309862 | 시간 6[s] | 손실 3.44
# | 에폭 1 |  반복 5901 / 309862 | 시간 6[s] | 손실 3.39
# | 에폭 1 |  반복 5921 / 309862 | 시간 6[s] | 손실 3.41
# | 에폭 1 |  반복 5941 / 309862 | 시간 6[s] | 손실 3.55
# | 에폭 1 |  반복 5961 / 309862 | 시간 6[s] | 손실 3.38
# | 에폭 1 |  반복 5981 / 309862 | 시간 6[s] | 손실 3.36
# | 에폭 1 |  반복 6001 / 309862 | 시간 6[s] | 손실 3.28
# | 에폭 1 |  반복 6021 / 309862 | 시간 6[s] | 손실 3.39
# | 에폭 1 |  반복 6041 / 309862 | 시간 6[s] | 손실 3.35
# | 에폭 1 |  반복 6061 / 309862 | 시간 6[s] | 손실 3.39
# | 에폭 1 |  반복 6081 / 309862 | 시간 6[s] | 손실 3.54
# | 에폭 1 |  반복 6101 / 309862 | 시간 6[s] | 손실 3.29
# | 에폭 1 |  반복 6121 / 309862 | 시간 6[s] | 손실 3.38
# | 에폭 1 |  반복 6141 / 309862 | 시간 6[s] | 손실 3.36
# | 에폭 1 |  반복 6161 / 309862 | 시간 6[s] | 손실 3.56
# | 에폭 1 |  반복 6181 / 309862 | 시간 6[s] | 손실 3.33
# | 에폭 1 |  반복 6201 / 309862 | 시간 6[s] | 손실 3.32
# | 에폭 1 |  반복 6221 / 309862 | 시간 6[s] | 손실 3.44
# | 에폭 1 |  반복 6241 / 309862 | 시간 6[s] | 손실 3.42
# | 에폭 1 |  반복 6261 / 309862 | 시간 6[s] | 손실 3.28
# | 에폭 1 |  반복 6281 / 309862 | 시간 6[s] | 손실 3.51
# | 에폭 1 |  반복 6301 / 309862 | 시간 6[s] | 손실 3.36
# | 에폭 1 |  반복 6321 / 309862 | 시간 6[s] | 손실 3.36
# | 에폭 1 |  반복 6341 / 309862 | 시간 6[s] | 손실 3.49
# | 에폭 1 |  반복 6361 / 309862 | 시간 6[s] | 손실 3.42
# | 에폭 1 |  반복 6381 / 309862 | 시간 6[s] | 손실 3.29
# | 에폭 1 |  반복 6401 / 309862 | 시간 6[s] | 손실 3.46
# | 에폭 1 |  반복 6421 / 309862 | 시간 6[s] | 손실 3.50
# | 에폭 1 |  반복 6441 / 309862 | 시간 7[s] | 손실 3.43
# | 에폭 1 |  반복 6461 / 309862 | 시간 7[s] | 손실 3.46
# | 에폭 1 |  반복 6481 / 309862 | 시간 7[s] | 손실 3.31
# | 에폭 1 |  반복 6501 / 309862 | 시간 7[s] | 손실 3.34
# | 에폭 1 |  반복 6521 / 309862 | 시간 7[s] | 손실 3.43
# | 에폭 1 |  반복 6541 / 309862 | 시간 7[s] | 손실 3.37
# | 에폭 1 |  반복 6561 / 309862 | 시간 7[s] | 손실 3.35
# | 에폭 1 |  반복 6581 / 309862 | 시간 7[s] | 손실 3.39
# | 에폭 1 |  반복 6601 / 309862 | 시간 7[s] | 손실 3.25
# | 에폭 1 |  반복 6621 / 309862 | 시간 7[s] | 손실 3.31
# | 에폭 1 |  반복 6641 / 309862 | 시간 7[s] | 손실 3.43
# | 에폭 1 |  반복 6661 / 309862 | 시간 7[s] | 손실 3.37
# | 에폭 1 |  반복 6681 / 309862 | 시간 7[s] | 손실 3.44
# | 에폭 1 |  반복 6701 / 309862 | 시간 7[s] | 손실 3.27
# | 에폭 1 |  반복 6721 / 309862 | 시간 7[s] | 손실 3.20
# | 에폭 1 |  반복 6741 / 309862 | 시간 7[s] | 손실 3.34
# | 에폭 1 |  반복 6761 / 309862 | 시간 7[s] | 손실 3.40
# | 에폭 1 |  반복 6781 / 309862 | 시간 7[s] | 손실 3.36
# | 에폭 1 |  반복 6801 / 309862 | 시간 7[s] | 손실 3.39
# | 에폭 1 |  반복 6821 / 309862 | 시간 7[s] | 손실 3.40
# | 에폭 1 |  반복 6841 / 309862 | 시간 7[s] | 손실 3.32
# | 에폭 1 |  반복 6861 / 309862 | 시간 7[s] | 손실 3.19
# | 에폭 1 |  반복 6881 / 309862 | 시간 7[s] | 손실 3.25
# | 에폭 1 |  반복 6901 / 309862 | 시간 7[s] | 손실 3.41
# | 에폭 1 |  반복 6921 / 309862 | 시간 7[s] | 손실 3.20
# | 에폭 1 |  반복 6941 / 309862 | 시간 7[s] | 손실 3.32
# | 에폭 1 |  반복 6961 / 309862 | 시간 7[s] | 손실 3.33
# | 에폭 1 |  반복 6981 / 309862 | 시간 7[s] | 손실 3.29
# | 에폭 1 |  반복 7001 / 309862 | 시간 7[s] | 손실 3.26
# | 에폭 1 |  반복 7021 / 309862 | 시간 7[s] | 손실 3.21
# | 에폭 1 |  반복 7041 / 309862 | 시간 7[s] | 손실 3.41
# | 에폭 1 |  반복 7061 / 309862 | 시간 7[s] | 손실 3.26
# | 에폭 1 |  반복 7081 / 309862 | 시간 7[s] | 손실 3.47
# | 에폭 1 |  반복 7101 / 309862 | 시간 7[s] | 손실 3.40
# | 에폭 1 |  반복 7121 / 309862 | 시간 7[s] | 손실 3.30
# | 에폭 1 |  반복 7141 / 309862 | 시간 7[s] | 손실 3.36
# | 에폭 1 |  반복 7161 / 309862 | 시간 7[s] | 손실 3.33
# | 에폭 1 |  반복 7181 / 309862 | 시간 7[s] | 손실 3.30
# | 에폭 1 |  반복 7201 / 309862 | 시간 7[s] | 손실 3.28
# | 에폭 1 |  반복 7221 / 309862 | 시간 7[s] | 손실 3.30
# | 에폭 1 |  반복 7241 / 309862 | 시간 7[s] | 손실 3.38
# | 에폭 1 |  반복 7261 / 309862 | 시간 7[s] | 손실 3.38
# | 에폭 1 |  반복 7281 / 309862 | 시간 7[s] | 손실 3.42
# | 에폭 1 |  반복 7301 / 309862 | 시간 7[s] | 손실 3.42
# | 에폭 1 |  반복 7321 / 309862 | 시간 7[s] | 손실 3.32
# | 에폭 1 |  반복 7341 / 309862 | 시간 7[s] | 손실 3.23
# | 에폭 1 |  반복 7361 / 309862 | 시간 7[s] | 손실 3.38
# | 에폭 1 |  반복 7381 / 309862 | 시간 8[s] | 손실 3.25
# | 에폭 1 |  반복 7401 / 309862 | 시간 8[s] | 손실 3.26
# | 에폭 1 |  반복 7421 / 309862 | 시간 8[s] | 손실 3.30
# | 에폭 1 |  반복 7441 / 309862 | 시간 8[s] | 손실 3.22
# | 에폭 1 |  반복 7461 / 309862 | 시간 8[s] | 손실 3.18
# | 에폭 1 |  반복 7481 / 309862 | 시간 8[s] | 손실 3.33
# | 에폭 1 |  반복 7501 / 309862 | 시간 8[s] | 손실 3.37
# | 에폭 1 |  반복 7521 / 309862 | 시간 8[s] | 손실 3.32
# | 에폭 1 |  반복 7541 / 309862 | 시간 8[s] | 손실 3.28
# | 에폭 1 |  반복 7561 / 309862 | 시간 8[s] | 손실 3.24
# | 에폭 1 |  반복 7581 / 309862 | 시간 8[s] | 손실 3.31
# | 에폭 1 |  반복 7601 / 309862 | 시간 8[s] | 손실 3.41
# | 에폭 1 |  반복 7621 / 309862 | 시간 8[s] | 손실 3.29
# | 에폭 1 |  반복 7641 / 309862 | 시간 8[s] | 손실 3.19
# | 에폭 1 |  반복 7661 / 309862 | 시간 8[s] | 손실 3.37
# | 에폭 1 |  반복 7681 / 309862 | 시간 8[s] | 손실 3.26
# | 에폭 1 |  반복 7701 / 309862 | 시간 8[s] | 손실 3.32
# | 에폭 1 |  반복 7721 / 309862 | 시간 8[s] | 손실 3.27
# | 에폭 1 |  반복 7741 / 309862 | 시간 8[s] | 손실 3.24
# | 에폭 1 |  반복 7761 / 309862 | 시간 8[s] | 손실 3.35
# | 에폭 1 |  반복 7781 / 309862 | 시간 8[s] | 손실 3.32
# | 에폭 1 |  반복 7801 / 309862 | 시간 8[s] | 손실 3.29
# | 에폭 1 |  반복 7821 / 309862 | 시간 8[s] | 손실 3.40
# | 에폭 1 |  반복 7841 / 309862 | 시간 8[s] | 손실 3.20
# | 에폭 1 |  반복 7861 / 309862 | 시간 8[s] | 손실 3.21
# | 에폭 1 |  반복 7881 / 309862 | 시간 8[s] | 손실 3.29
# | 에폭 1 |  반복 7901 / 309862 | 시간 8[s] | 손실 3.26
# | 에폭 1 |  반복 7921 / 309862 | 시간 8[s] | 손실 3.18
# | 에폭 1 |  반복 7941 / 309862 | 시간 8[s] | 손실 3.09
# | 에폭 1 |  반복 7961 / 309862 | 시간 8[s] | 손실 3.21
# | 에폭 1 |  반복 7981 / 309862 | 시간 8[s] | 손실 3.21
# | 에폭 1 |  반복 8001 / 309862 | 시간 8[s] | 손실 3.05
# | 에폭 1 |  반복 8021 / 309862 | 시간 8[s] | 손실 3.28
# | 에폭 1 |  반복 8041 / 309862 | 시간 8[s] | 손실 3.24
# | 에폭 1 |  반복 8061 / 309862 | 시간 8[s] | 손실 3.30
# | 에폭 1 |  반복 8081 / 309862 | 시간 8[s] | 손실 3.26
# | 에폭 1 |  반복 8101 / 309862 | 시간 8[s] | 손실 3.16
# | 에폭 1 |  반복 8121 / 309862 | 시간 8[s] | 손실 3.15
# | 에폭 1 |  반복 8141 / 309862 | 시간 8[s] | 손실 3.21
# | 에폭 1 |  반복 8161 / 309862 | 시간 8[s] | 손실 3.21
# | 에폭 1 |  반복 8181 / 309862 | 시간 8[s] | 손실 3.04
# | 에폭 1 |  반복 8201 / 309862 | 시간 8[s] | 손실 3.29
# | 에폭 1 |  반복 8221 / 309862 | 시간 8[s] | 손실 3.14
# | 에폭 1 |  반복 8241 / 309862 | 시간 8[s] | 손실 3.17
# | 에폭 1 |  반복 8261 / 309862 | 시간 8[s] | 손실 3.31
# | 에폭 1 |  반복 8281 / 309862 | 시간 8[s] | 손실 3.34
# | 에폭 1 |  반복 8301 / 309862 | 시간 9[s] | 손실 3.27
# | 에폭 1 |  반복 8321 / 309862 | 시간 9[s] | 손실 3.23
# | 에폭 1 |  반복 8341 / 309862 | 시간 9[s] | 손실 3.14
# | 에폭 1 |  반복 8361 / 309862 | 시간 9[s] | 손실 3.27
# | 에폭 1 |  반복 8381 / 309862 | 시간 9[s] | 손실 3.28
# | 에폭 1 |  반복 8401 / 309862 | 시간 9[s] | 손실 3.31
# | 에폭 1 |  반복 8421 / 309862 | 시간 9[s] | 손실 3.35
# | 에폭 1 |  반복 8441 / 309862 | 시간 9[s] | 손실 3.21
# | 에폭 1 |  반복 8461 / 309862 | 시간 9[s] | 손실 3.30
# | 에폭 1 |  반복 8481 / 309862 | 시간 9[s] | 손실 3.18
# | 에폭 1 |  반복 8501 / 309862 | 시간 9[s] | 손실 3.18
# | 에폭 1 |  반복 8521 / 309862 | 시간 9[s] | 손실 3.21
# | 에폭 1 |  반복 8541 / 309862 | 시간 9[s] | 손실 3.08
# | 에폭 1 |  반복 8561 / 309862 | 시간 9[s] | 손실 3.32
# | 에폭 1 |  반복 8581 / 309862 | 시간 9[s] | 손실 3.30
# | 에폭 1 |  반복 8601 / 309862 | 시간 9[s] | 손실 3.21
# | 에폭 1 |  반복 8621 / 309862 | 시간 9[s] | 손실 3.11
# | 에폭 1 |  반복 8641 / 309862 | 시간 9[s] | 손실 3.19
# | 에폭 1 |  반복 8661 / 309862 | 시간 9[s] | 손실 3.23
# | 에폭 1 |  반복 8681 / 309862 | 시간 9[s] | 손실 3.33
# | 에폭 1 |  반복 8701 / 309862 | 시간 9[s] | 손실 3.16
# | 에폭 1 |  반복 8721 / 309862 | 시간 9[s] | 손실 3.31
# | 에폭 1 |  반복 8741 / 309862 | 시간 9[s] | 손실 3.10
# | 에폭 1 |  반복 8761 / 309862 | 시간 9[s] | 손실 3.21
# | 에폭 1 |  반복 8781 / 309862 | 시간 9[s] | 손실 3.24
# | 에폭 1 |  반복 8801 / 309862 | 시간 9[s] | 손실 3.18
# | 에폭 1 |  반복 8821 / 309862 | 시간 9[s] | 손실 3.14
# | 에폭 1 |  반복 8841 / 309862 | 시간 9[s] | 손실 3.30
# | 에폭 1 |  반복 8861 / 309862 | 시간 9[s] | 손실 3.23
# | 에폭 1 |  반복 8881 / 309862 | 시간 9[s] | 손실 3.16
# | 에폭 1 |  반복 8901 / 309862 | 시간 9[s] | 손실 3.24
# | 에폭 1 |  반복 8921 / 309862 | 시간 9[s] | 손실 3.04
# | 에폭 1 |  반복 8941 / 309862 | 시간 9[s] | 손실 3.22
# | 에폭 1 |  반복 8961 / 309862 | 시간 9[s] | 손실 3.24
# | 에폭 1 |  반복 8981 / 309862 | 시간 9[s] | 손실 3.16
# | 에폭 1 |  반복 9001 / 309862 | 시간 9[s] | 손실 3.18
# | 에폭 1 |  반복 9021 / 309862 | 시간 9[s] | 손실 3.14
# | 에폭 1 |  반복 9041 / 309862 | 시간 9[s] | 손실 3.29
# | 에폭 1 |  반복 9061 / 309862 | 시간 9[s] | 손실 3.14
# | 에폭 1 |  반복 9081 / 309862 | 시간 9[s] | 손실 3.28
# | 에폭 1 |  반복 9101 / 309862 | 시간 9[s] | 손실 3.02
# | 에폭 1 |  반복 9121 / 309862 | 시간 9[s] | 손실 3.21
# | 에폭 1 |  반복 9141 / 309862 | 시간 9[s] | 손실 3.25
# | 에폭 1 |  반복 9161 / 309862 | 시간 9[s] | 손실 3.23
# | 에폭 1 |  반복 9181 / 309862 | 시간 9[s] | 손실 3.28
# | 에폭 1 |  반복 9201 / 309862 | 시간 9[s] | 손실 3.08
# | 에폭 1 |  반복 9221 / 309862 | 시간 9[s] | 손실 3.32
# | 에폭 1 |  반복 9241 / 309862 | 시간 10[s] | 손실 3.02
# | 에폭 1 |  반복 9261 / 309862 | 시간 10[s] | 손실 3.22
# | 에폭 1 |  반복 9281 / 309862 | 시간 10[s] | 손실 3.09
# | 에폭 1 |  반복 9301 / 309862 | 시간 10[s] | 손실 3.15
# | 에폭 1 |  반복 9321 / 309862 | 시간 10[s] | 손실 3.15
# | 에폭 1 |  반복 9341 / 309862 | 시간 10[s] | 손실 3.29
# | 에폭 1 |  반복 9361 / 309862 | 시간 10[s] | 손실 3.13
# | 에폭 1 |  반복 9381 / 309862 | 시간 10[s] | 손실 3.28
# | 에폭 1 |  반복 9401 / 309862 | 시간 10[s] | 손실 3.28
# | 에폭 1 |  반복 9421 / 309862 | 시간 10[s] | 손실 3.15
# | 에폭 1 |  반복 9441 / 309862 | 시간 10[s] | 손실 3.20
# | 에폭 1 |  반복 9461 / 309862 | 시간 10[s] | 손실 3.15
# | 에폭 1 |  반복 9481 / 309862 | 시간 10[s] | 손실 3.21
# | 에폭 1 |  반복 9501 / 309862 | 시간 10[s] | 손실 2.95
# | 에폭 1 |  반복 9521 / 309862 | 시간 10[s] | 손실 3.05
# | 에폭 1 |  반복 9541 / 309862 | 시간 10[s] | 손실 3.10
# | 에폭 1 |  반복 9561 / 309862 | 시간 10[s] | 손실 3.24
# | 에폭 1 |  반복 9581 / 309862 | 시간 10[s] | 손실 3.12
# | 에폭 1 |  반복 9601 / 309862 | 시간 10[s] | 손실 3.02
# | 에폭 1 |  반복 9621 / 309862 | 시간 10[s] | 손실 3.27
# | 에폭 1 |  반복 9641 / 309862 | 시간 10[s] | 손실 3.23
# | 에폭 1 |  반복 9661 / 309862 | 시간 10[s] | 손실 3.12
# | 에폭 1 |  반복 9681 / 309862 | 시간 10[s] | 손실 3.16
# | 에폭 1 |  반복 9701 / 309862 | 시간 10[s] | 손실 3.00
# | 에폭 1 |  반복 9721 / 309862 | 시간 10[s] | 손실 3.19
# | 에폭 1 |  반복 9741 / 309862 | 시간 10[s] | 손실 3.27
# | 에폭 1 |  반복 9761 / 309862 | 시간 10[s] | 손실 3.03
# | 에폭 1 |  반복 9781 / 309862 | 시간 10[s] | 손실 3.36
# | 에폭 1 |  반복 9801 / 309862 | 시간 10[s] | 손실 3.23
# | 에폭 1 |  반복 9821 / 309862 | 시간 10[s] | 손실 3.27
# | 에폭 1 |  반복 9841 / 309862 | 시간 10[s] | 손실 3.35
# | 에폭 1 |  반복 9861 / 309862 | 시간 10[s] | 손실 3.10
# | 에폭 1 |  반복 9881 / 309862 | 시간 10[s] | 손실 3.20
# | 에폭 1 |  반복 9901 / 309862 | 시간 10[s] | 손실 3.31
# | 에폭 1 |  반복 9921 / 309862 | 시간 10[s] | 손실 3.26
# | 에폭 1 |  반복 9941 / 309862 | 시간 10[s] | 손실 3.18
# | 에폭 1 |  반복 9961 / 309862 | 시간 10[s] | 손실 3.07
# | 에폭 1 |  반복 9981 / 309862 | 시간 10[s] | 손실 3.10
# | 에폭 1 |  반복 10001 / 309862 | 시간 10[s] | 손실 3.20
# | 에폭 1 |  반복 10021 / 309862 | 시간 10[s] | 손실 3.05
# | 에폭 1 |  반복 10041 / 309862 | 시간 10[s] | 손실 3.30
# | 에폭 1 |  반복 10061 / 309862 | 시간 10[s] | 손실 3.11
# | 에폭 1 |  반복 10081 / 309862 | 시간 10[s] | 손실 3.09
# | 에폭 1 |  반복 10101 / 309862 | 시간 10[s] | 손실 3.18
# | 에폭 1 |  반복 10121 / 309862 | 시간 10[s] | 손실 3.14
# | 에폭 1 |  반복 10141 / 309862 | 시간 10[s] | 손실 3.22
# | 에폭 1 |  반복 10161 / 309862 | 시간 10[s] | 손실 3.15
# | 에폭 1 |  반복 10181 / 309862 | 시간 11[s] | 손실 3.14
# | 에폭 1 |  반복 10201 / 309862 | 시간 11[s] | 손실 3.18
# | 에폭 1 |  반복 10221 / 309862 | 시간 11[s] | 손실 3.18
# | 에폭 1 |  반복 10241 / 309862 | 시간 11[s] | 손실 3.16
# | 에폭 1 |  반복 10261 / 309862 | 시간 11[s] | 손실 3.10
# | 에폭 1 |  반복 10281 / 309862 | 시간 11[s] | 손실 3.04
# | 에폭 1 |  반복 10301 / 309862 | 시간 11[s] | 손실 3.14
# | 에폭 1 |  반복 10321 / 309862 | 시간 11[s] | 손실 3.29
# | 에폭 1 |  반복 10341 / 309862 | 시간 11[s] | 손실 3.10
# | 에폭 1 |  반복 10361 / 309862 | 시간 11[s] | 손실 3.24
# | 에폭 1 |  반복 10381 / 309862 | 시간 11[s] | 손실 2.97
# | 에폭 1 |  반복 10401 / 309862 | 시간 11[s] | 손실 3.08
# | 에폭 1 |  반복 10421 / 309862 | 시간 11[s] | 손실 3.06
# | 에폭 1 |  반복 10441 / 309862 | 시간 11[s] | 손실 3.10
# | 에폭 1 |  반복 10461 / 309862 | 시간 11[s] | 손실 3.01
# | 에폭 1 |  반복 10481 / 309862 | 시간 11[s] | 손실 3.14
# | 에폭 1 |  반복 10501 / 309862 | 시간 11[s] | 손실 3.07
# | 에폭 1 |  반복 10521 / 309862 | 시간 11[s] | 손실 3.02
# | 에폭 1 |  반복 10541 / 309862 | 시간 11[s] | 손실 3.04
# | 에폭 1 |  반복 10561 / 309862 | 시간 11[s] | 손실 3.01
# | 에폭 1 |  반복 10581 / 309862 | 시간 11[s] | 손실 3.09
# | 에폭 1 |  반복 10601 / 309862 | 시간 11[s] | 손실 3.16
# | 에폭 1 |  반복 10621 / 309862 | 시간 11[s] | 손실 2.96
# | 에폭 1 |  반복 10641 / 309862 | 시간 11[s] | 손실 3.22
# | 에폭 1 |  반복 10661 / 309862 | 시간 11[s] | 손실 2.90
# | 에폭 1 |  반복 10681 / 309862 | 시간 11[s] | 손실 3.07
# | 에폭 1 |  반복 10701 / 309862 | 시간 11[s] | 손실 3.09
# | 에폭 1 |  반복 10721 / 309862 | 시간 11[s] | 손실 3.22
# | 에폭 1 |  반복 10741 / 309862 | 시간 11[s] | 손실 3.11
# | 에폭 1 |  반복 10761 / 309862 | 시간 11[s] | 손실 3.24
# | 에폭 1 |  반복 10781 / 309862 | 시간 11[s] | 손실 3.01
# | 에폭 1 |  반복 10801 / 309862 | 시간 11[s] | 손실 3.13
# | 에폭 1 |  반복 10821 / 309862 | 시간 11[s] | 손실 3.16
# | 에폭 1 |  반복 10841 / 309862 | 시간 11[s] | 손실 3.08
# | 에폭 1 |  반복 10861 / 309862 | 시간 11[s] | 손실 3.21
# | 에폭 1 |  반복 10881 / 309862 | 시간 11[s] | 손실 3.16
# | 에폭 1 |  반복 10901 / 309862 | 시간 11[s] | 손실 3.04
# | 에폭 1 |  반복 10921 / 309862 | 시간 11[s] | 손실 3.08
# | 에폭 1 |  반복 10941 / 309862 | 시간 11[s] | 손실 3.16
# | 에폭 1 |  반복 10961 / 309862 | 시간 11[s] | 손실 3.22
# | 에폭 1 |  반복 10981 / 309862 | 시간 11[s] | 손실 3.12
# | 에폭 1 |  반복 11001 / 309862 | 시간 11[s] | 손실 3.26
# | 에폭 1 |  반복 11021 / 309862 | 시간 11[s] | 손실 3.12
# | 에폭 1 |  반복 11041 / 309862 | 시간 11[s] | 손실 2.98
# | 에폭 1 |  반복 11061 / 309862 | 시간 11[s] | 손실 3.20
# | 에폭 1 |  반복 11081 / 309862 | 시간 11[s] | 손실 2.98
# | 에폭 1 |  반복 11101 / 309862 | 시간 11[s] | 손실 3.15
# | 에폭 1 |  반복 11121 / 309862 | 시간 11[s] | 손실 3.14
# | 에폭 1 |  반복 11141 / 309862 | 시간 12[s] | 손실 3.18
# | 에폭 1 |  반복 11161 / 309862 | 시간 12[s] | 손실 3.10
# | 에폭 1 |  반복 11181 / 309862 | 시간 12[s] | 손실 3.24
# | 에폭 1 |  반복 11201 / 309862 | 시간 12[s] | 손실 3.11
# | 에폭 1 |  반복 11221 / 309862 | 시간 12[s] | 손실 3.16
# | 에폭 1 |  반복 11241 / 309862 | 시간 12[s] | 손실 2.96
# | 에폭 1 |  반복 11261 / 309862 | 시간 12[s] | 손실 3.05
# | 에폭 1 |  반복 11281 / 309862 | 시간 12[s] | 손실 3.17
# | 에폭 1 |  반복 11301 / 309862 | 시간 12[s] | 손실 3.14
# | 에폭 1 |  반복 11321 / 309862 | 시간 12[s] | 손실 3.11
# | 에폭 1 |  반복 11341 / 309862 | 시간 12[s] | 손실 2.99
# | 에폭 1 |  반복 11361 / 309862 | 시간 12[s] | 손실 3.01
# | 에폭 1 |  반복 11381 / 309862 | 시간 12[s] | 손실 3.10
# | 에폭 1 |  반복 11401 / 309862 | 시간 12[s] | 손실 2.94
# | 에폭 1 |  반복 11421 / 309862 | 시간 12[s] | 손실 3.01
# | 에폭 1 |  반복 11441 / 309862 | 시간 12[s] | 손실 2.98
# | 에폭 1 |  반복 11461 / 309862 | 시간 12[s] | 손실 3.18
# | 에폭 1 |  반복 11481 / 309862 | 시간 12[s] | 손실 3.07
# | 에폭 1 |  반복 11501 / 309862 | 시간 12[s] | 손실 2.97
# | 에폭 1 |  반복 11521 / 309862 | 시간 12[s] | 손실 3.09
# | 에폭 1 |  반복 11541 / 309862 | 시간 12[s] | 손실 2.98
# | 에폭 1 |  반복 11561 / 309862 | 시간 12[s] | 손실 2.95
# | 에폭 1 |  반복 11581 / 309862 | 시간 12[s] | 손실 3.21
# | 에폭 1 |  반복 11601 / 309862 | 시간 12[s] | 손실 3.18
# | 에폭 1 |  반복 11621 / 309862 | 시간 12[s] | 손실 3.20
# | 에폭 1 |  반복 11641 / 309862 | 시간 12[s] | 손실 3.19
# | 에폭 1 |  반복 11661 / 309862 | 시간 12[s] | 손실 3.05
# | 에폭 1 |  반복 11681 / 309862 | 시간 12[s] | 손실 3.25
# | 에폭 1 |  반복 11701 / 309862 | 시간 12[s] | 손실 2.99
# | 에폭 1 |  반복 11721 / 309862 | 시간 12[s] | 손실 3.07
# | 에폭 1 |  반복 11741 / 309862 | 시간 12[s] | 손실 3.01
# | 에폭 1 |  반복 11761 / 309862 | 시간 12[s] | 손실 2.99
# | 에폭 1 |  반복 11781 / 309862 | 시간 12[s] | 손실 2.94
# | 에폭 1 |  반복 11801 / 309862 | 시간 12[s] | 손실 3.16
# | 에폭 1 |  반복 11821 / 309862 | 시간 12[s] | 손실 3.11
# | 에폭 1 |  반복 11841 / 309862 | 시간 12[s] | 손실 2.89
# | 에폭 1 |  반복 11861 / 309862 | 시간 12[s] | 손실 3.04
# | 에폭 1 |  반복 11881 / 309862 | 시간 12[s] | 손실 3.19
# | 에폭 1 |  반복 11901 / 309862 | 시간 12[s] | 손실 3.07
# | 에폭 1 |  반복 11921 / 309862 | 시간 12[s] | 손실 3.08
# | 에폭 1 |  반복 11941 / 309862 | 시간 12[s] | 손실 3.21
# | 에폭 1 |  반복 11961 / 309862 | 시간 12[s] | 손실 2.93
# | 에폭 1 |  반복 11981 / 309862 | 시간 12[s] | 손실 3.10
# | 에폭 1 |  반복 12001 / 309862 | 시간 12[s] | 손실 2.94
# | 에폭 1 |  반복 12021 / 309862 | 시간 12[s] | 손실 3.07
# | 에폭 1 |  반복 12041 / 309862 | 시간 13[s] | 손실 3.01
# | 에폭 1 |  반복 12061 / 309862 | 시간 13[s] | 손실 2.91
# | 에폭 1 |  반복 12081 / 309862 | 시간 13[s] | 손실 3.22
# | 에폭 1 |  반복 12101 / 309862 | 시간 13[s] | 손실 3.12
# | 에폭 1 |  반복 12121 / 309862 | 시간 13[s] | 손실 2.89
# | 에폭 1 |  반복 12141 / 309862 | 시간 13[s] | 손실 2.99
# | 에폭 1 |  반복 12161 / 309862 | 시간 13[s] | 손실 3.00
# | 에폭 1 |  반복 12181 / 309862 | 시간 13[s] | 손실 2.94
# | 에폭 1 |  반복 12201 / 309862 | 시간 13[s] | 손실 3.11
# | 에폭 1 |  반복 12221 / 309862 | 시간 13[s] | 손실 3.10
# | 에폭 1 |  반복 12241 / 309862 | 시간 13[s] | 손실 2.86
# | 에폭 1 |  반복 12261 / 309862 | 시간 13[s] | 손실 3.01
# | 에폭 1 |  반복 12281 / 309862 | 시간 13[s] | 손실 2.98
# | 에폭 1 |  반복 12301 / 309862 | 시간 13[s] | 손실 3.08
# | 에폭 1 |  반복 12321 / 309862 | 시간 13[s] | 손실 2.81
# | 에폭 1 |  반복 12341 / 309862 | 시간 13[s] | 손실 2.96
# | 에폭 1 |  반복 12361 / 309862 | 시간 13[s] | 손실 3.10
# | 에폭 1 |  반복 12381 / 309862 | 시간 13[s] | 손실 3.17
# | 에폭 1 |  반복 12401 / 309862 | 시간 13[s] | 손실 3.08
# | 에폭 1 |  반복 12421 / 309862 | 시간 13[s] | 손실 3.12
# | 에폭 1 |  반복 12441 / 309862 | 시간 13[s] | 손실 2.96
# | 에폭 1 |  반복 12461 / 309862 | 시간 13[s] | 손실 3.15
# | 에폭 1 |  반복 12481 / 309862 | 시간 13[s] | 손실 3.19
# | 에폭 1 |  반복 12501 / 309862 | 시간 13[s] | 손실 2.95
# | 에폭 1 |  반복 12521 / 309862 | 시간 13[s] | 손실 3.14
# | 에폭 1 |  반복 12541 / 309862 | 시간 13[s] | 손실 2.89
# | 에폭 1 |  반복 12561 / 309862 | 시간 13[s] | 손실 3.22
# | 에폭 1 |  반복 12581 / 309862 | 시간 13[s] | 손실 3.03
# | 에폭 1 |  반복 12601 / 309862 | 시간 13[s] | 손실 3.00
# | 에폭 1 |  반복 12621 / 309862 | 시간 13[s] | 손실 3.05
# | 에폭 1 |  반복 12641 / 309862 | 시간 13[s] | 손실 3.10
# | 에폭 1 |  반복 12661 / 309862 | 시간 13[s] | 손실 2.99
# | 에폭 1 |  반복 12681 / 309862 | 시간 13[s] | 손실 3.14
# | 에폭 1 |  반복 12701 / 309862 | 시간 13[s] | 손실 3.03
# | 에폭 1 |  반복 12721 / 309862 | 시간 13[s] | 손실 3.05
# | 에폭 1 |  반복 12741 / 309862 | 시간 13[s] | 손실 3.11
# | 에폭 1 |  반복 12761 / 309862 | 시간 13[s] | 손실 3.00
# | 에폭 1 |  반복 12781 / 309862 | 시간 13[s] | 손실 3.09
# | 에폭 1 |  반복 12801 / 309862 | 시간 13[s] | 손실 3.04
# | 에폭 1 |  반복 12821 / 309862 | 시간 13[s] | 손실 3.13
# | 에폭 1 |  반복 12841 / 309862 | 시간 13[s] | 손실 3.21
# | 에폭 1 |  반복 12861 / 309862 | 시간 13[s] | 손실 3.11
# | 에폭 1 |  반복 12881 / 309862 | 시간 13[s] | 손실 2.99
# | 에폭 1 |  반복 12901 / 309862 | 시간 13[s] | 손실 3.01
# | 에폭 1 |  반복 12921 / 309862 | 시간 13[s] | 손실 3.01
# | 에폭 1 |  반복 12941 / 309862 | 시간 13[s] | 손실 3.12
# | 에폭 1 |  반복 12961 / 309862 | 시간 13[s] | 손실 3.06
# | 에폭 1 |  반복 12981 / 309862 | 시간 13[s] | 손실 2.97
# | 에폭 1 |  반복 13001 / 309862 | 시간 14[s] | 손실 2.82
# | 에폭 1 |  반복 13021 / 309862 | 시간 14[s] | 손실 3.11
# | 에폭 1 |  반복 13041 / 309862 | 시간 14[s] | 손실 3.08
# | 에폭 1 |  반복 13061 / 309862 | 시간 14[s] | 손실 3.14
# | 에폭 1 |  반복 13081 / 309862 | 시간 14[s] | 손실 3.18
# | 에폭 1 |  반복 13101 / 309862 | 시간 14[s] | 손실 3.20
# | 에폭 1 |  반복 13121 / 309862 | 시간 14[s] | 손실 3.04
# | 에폭 1 |  반복 13141 / 309862 | 시간 14[s] | 손실 3.07
# | 에폭 1 |  반복 13161 / 309862 | 시간 14[s] | 손실 3.01
# | 에폭 1 |  반복 13181 / 309862 | 시간 14[s] | 손실 3.04
# | 에폭 1 |  반복 13201 / 309862 | 시간 14[s] | 손실 3.07
# | 에폭 1 |  반복 13221 / 309862 | 시간 14[s] | 손실 3.11
# | 에폭 1 |  반복 13241 / 309862 | 시간 14[s] | 손실 2.83
# | 에폭 1 |  반복 13261 / 309862 | 시간 14[s] | 손실 3.09
# | 에폭 1 |  반복 13281 / 309862 | 시간 14[s] | 손실 3.07
# | 에폭 1 |  반복 13301 / 309862 | 시간 14[s] | 손실 3.06
# | 에폭 1 |  반복 13321 / 309862 | 시간 14[s] | 손실 3.00
# | 에폭 1 |  반복 13341 / 309862 | 시간 14[s] | 손실 2.93
# | 에폭 1 |  반복 13361 / 309862 | 시간 14[s] | 손실 3.00
# | 에폭 1 |  반복 13381 / 309862 | 시간 14[s] | 손실 3.02
# | 에폭 1 |  반복 13401 / 309862 | 시간 14[s] | 손실 2.92
# | 에폭 1 |  반복 13421 / 309862 | 시간 14[s] | 손실 2.98
# | 에폭 1 |  반복 13441 / 309862 | 시간 14[s] | 손실 2.97
# | 에폭 1 |  반복 13461 / 309862 | 시간 14[s] | 손실 3.05
# | 에폭 1 |  반복 13481 / 309862 | 시간 14[s] | 손실 2.98
# | 에폭 1 |  반복 13501 / 309862 | 시간 14[s] | 손실 3.01
# | 에폭 1 |  반복 13521 / 309862 | 시간 14[s] | 손실 2.96
# | 에폭 1 |  반복 13541 / 309862 | 시간 14[s] | 손실 2.94
# | 에폭 1 |  반복 13561 / 309862 | 시간 14[s] | 손실 3.09
# | 에폭 1 |  반복 13581 / 309862 | 시간 14[s] | 손실 2.90
# | 에폭 1 |  반복 13601 / 309862 | 시간 14[s] | 손실 3.15
# | 에폭 1 |  반복 13621 / 309862 | 시간 14[s] | 손실 2.95
# | 에폭 1 |  반복 13641 / 309862 | 시간 14[s] | 손실 3.07
# | 에폭 1 |  반복 13661 / 309862 | 시간 14[s] | 손실 3.09
# | 에폭 1 |  반복 13681 / 309862 | 시간 14[s] | 손실 2.94
# | 에폭 1 |  반복 13701 / 309862 | 시간 14[s] | 손실 2.97
# | 에폭 1 |  반복 13721 / 309862 | 시간 14[s] | 손실 3.01
# | 에폭 1 |  반복 13741 / 309862 | 시간 14[s] | 손실 2.96
# | 에폭 1 |  반복 13761 / 309862 | 시간 14[s] | 손실 2.99
# | 에폭 1 |  반복 13781 / 309862 | 시간 14[s] | 손실 2.79
# | 에폭 1 |  반복 13801 / 309862 | 시간 14[s] | 손실 2.93
# | 에폭 1 |  반복 13821 / 309862 | 시간 14[s] | 손실 3.03
# | 에폭 1 |  반복 13841 / 309862 | 시간 14[s] | 손실 3.00
# | 에폭 1 |  반복 13861 / 309862 | 시간 14[s] | 손실 3.03
# | 에폭 1 |  반복 13881 / 309862 | 시간 14[s] | 손실 2.98
# | 에폭 1 |  반복 13901 / 309862 | 시간 14[s] | 손실 2.96
# | 에폭 1 |  반복 13921 / 309862 | 시간 14[s] | 손실 3.17
# | 에폭 1 |  반복 13941 / 309862 | 시간 15[s] | 손실 3.07
# | 에폭 1 |  반복 13961 / 309862 | 시간 15[s] | 손실 3.04
# | 에폭 1 |  반복 13981 / 309862 | 시간 15[s] | 손실 2.96
# | 에폭 1 |  반복 14001 / 309862 | 시간 15[s] | 손실 3.01
# | 에폭 1 |  반복 14021 / 309862 | 시간 15[s] | 손실 3.15
# | 에폭 1 |  반복 14041 / 309862 | 시간 15[s] | 손실 2.91
# | 에폭 1 |  반복 14061 / 309862 | 시간 15[s] | 손실 3.07
# | 에폭 1 |  반복 14081 / 309862 | 시간 15[s] | 손실 3.07
# | 에폭 1 |  반복 14101 / 309862 | 시간 15[s] | 손실 2.99
# | 에폭 1 |  반복 14121 / 309862 | 시간 15[s] | 손실 3.03
# | 에폭 1 |  반복 14141 / 309862 | 시간 15[s] | 손실 2.84
# | 에폭 1 |  반복 14161 / 309862 | 시간 15[s] | 손실 2.96
# | 에폭 1 |  반복 14181 / 309862 | 시간 15[s] | 손실 2.88
# | 에폭 1 |  반복 14201 / 309862 | 시간 15[s] | 손실 2.98
# | 에폭 1 |  반복 14221 / 309862 | 시간 15[s] | 손실 3.03
# | 에폭 1 |  반복 14241 / 309862 | 시간 15[s] | 손실 3.02
# | 에폭 1 |  반복 14261 / 309862 | 시간 15[s] | 손실 2.97
# | 에폭 1 |  반복 14281 / 309862 | 시간 15[s] | 손실 3.03
# | 에폭 1 |  반복 14301 / 309862 | 시간 15[s] | 손실 3.04
# | 에폭 1 |  반복 14321 / 309862 | 시간 15[s] | 손실 3.20
# | 에폭 1 |  반복 14341 / 309862 | 시간 15[s] | 손실 2.90
# | 에폭 1 |  반복 14361 / 309862 | 시간 15[s] | 손실 3.13
# | 에폭 1 |  반복 14381 / 309862 | 시간 15[s] | 손실 2.97
# | 에폭 1 |  반복 14401 / 309862 | 시간 15[s] | 손실 2.97
# | 에폭 1 |  반복 14421 / 309862 | 시간 15[s] | 손실 2.99
# | 에폭 1 |  반복 14441 / 309862 | 시간 15[s] | 손실 2.95
# | 에폭 1 |  반복 14461 / 309862 | 시간 15[s] | 손실 2.90
# | 에폭 1 |  반복 14481 / 309862 | 시간 15[s] | 손실 3.00
# | 에폭 1 |  반복 14501 / 309862 | 시간 15[s] | 손실 2.96
# | 에폭 1 |  반복 14521 / 309862 | 시간 15[s] | 손실 2.82
# | 에폭 1 |  반복 14541 / 309862 | 시간 15[s] | 손실 2.80
# | 에폭 1 |  반복 14561 / 309862 | 시간 15[s] | 손실 3.05
# | 에폭 1 |  반복 14581 / 309862 | 시간 15[s] | 손실 3.02
# | 에폭 1 |  반복 14601 / 309862 | 시간 15[s] | 손실 3.00
# | 에폭 1 |  반복 14621 / 309862 | 시간 15[s] | 손실 3.05
# | 에폭 1 |  반복 14641 / 309862 | 시간 15[s] | 손실 2.89
# | 에폭 1 |  반복 14661 / 309862 | 시간 15[s] | 손실 2.96
# | 에폭 1 |  반복 14681 / 309862 | 시간 15[s] | 손실 3.04
# | 에폭 1 |  반복 14701 / 309862 | 시간 15[s] | 손실 3.02
# | 에폭 1 |  반복 14721 / 309862 | 시간 15[s] | 손실 2.94
# | 에폭 1 |  반복 14741 / 309862 | 시간 15[s] | 손실 3.01
# | 에폭 1 |  반복 14761 / 309862 | 시간 15[s] | 손실 3.11
# | 에폭 1 |  반복 14781 / 309862 | 시간 15[s] | 손실 2.78
# | 에폭 1 |  반복 14801 / 309862 | 시간 15[s] | 손실 3.03
# | 에폭 1 |  반복 14821 / 309862 | 시간 15[s] | 손실 2.94
# | 에폭 1 |  반복 14841 / 309862 | 시간 15[s] | 손실 2.96
# | 에폭 1 |  반복 14861 / 309862 | 시간 16[s] | 손실 2.72
# | 에폭 1 |  반복 14881 / 309862 | 시간 16[s] | 손실 3.02
# | 에폭 1 |  반복 14901 / 309862 | 시간 16[s] | 손실 2.97
# | 에폭 1 |  반복 14921 / 309862 | 시간 16[s] | 손실 3.04
# | 에폭 1 |  반복 14941 / 309862 | 시간 16[s] | 손실 3.12
# | 에폭 1 |  반복 14961 / 309862 | 시간 16[s] | 손실 2.92
# | 에폭 1 |  반복 14981 / 309862 | 시간 16[s] | 손실 2.84
# | 에폭 1 |  반복 15001 / 309862 | 시간 16[s] | 손실 3.00
# | 에폭 1 |  반복 15021 / 309862 | 시간 16[s] | 손실 2.88
# | 에폭 1 |  반복 15041 / 309862 | 시간 16[s] | 손실 2.90
# | 에폭 1 |  반복 15061 / 309862 | 시간 16[s] | 손실 3.00
# | 에폭 1 |  반복 15081 / 309862 | 시간 16[s] | 손실 2.88
# | 에폭 1 |  반복 15101 / 309862 | 시간 16[s] | 손실 2.98
# | 에폭 1 |  반복 15121 / 309862 | 시간 16[s] | 손실 2.87
# | 에폭 1 |  반복 15141 / 309862 | 시간 16[s] | 손실 2.88
# | 에폭 1 |  반복 15161 / 309862 | 시간 16[s] | 손실 2.93
# | 에폭 1 |  반복 15181 / 309862 | 시간 16[s] | 손실 2.80
# | 에폭 1 |  반복 15201 / 309862 | 시간 16[s] | 손실 2.99
# | 에폭 1 |  반복 15221 / 309862 | 시간 16[s] | 손실 2.98
# | 에폭 1 |  반복 15241 / 309862 | 시간 16[s] | 손실 3.15
# | 에폭 1 |  반복 15261 / 309862 | 시간 16[s] | 손실 2.89
# | 에폭 1 |  반복 15281 / 309862 | 시간 16[s] | 손실 2.95
# | 에폭 1 |  반복 15301 / 309862 | 시간 16[s] | 손실 3.07
# | 에폭 1 |  반복 15321 / 309862 | 시간 16[s] | 손실 2.97
# | 에폭 1 |  반복 15341 / 309862 | 시간 16[s] | 손실 2.96
# | 에폭 1 |  반복 15361 / 309862 | 시간 16[s] | 손실 2.94
# | 에폭 1 |  반복 15381 / 309862 | 시간 16[s] | 손실 3.04
# | 에폭 1 |  반복 15401 / 309862 | 시간 16[s] | 손실 2.99
# | 에폭 1 |  반복 15421 / 309862 | 시간 16[s] | 손실 2.80
# | 에폭 1 |  반복 15441 / 309862 | 시간 16[s] | 손실 3.00
# | 에폭 1 |  반복 15461 / 309862 | 시간 16[s] | 손실 2.93
# | 에폭 1 |  반복 15481 / 309862 | 시간 16[s] | 손실 2.96
# | 에폭 1 |  반복 15501 / 309862 | 시간 16[s] | 손실 3.12
# | 에폭 1 |  반복 15521 / 309862 | 시간 16[s] | 손실 3.04
# | 에폭 1 |  반복 15541 / 309862 | 시간 16[s] | 손실 2.93
# | 에폭 1 |  반복 15561 / 309862 | 시간 16[s] | 손실 2.90
# | 에폭 1 |  반복 15581 / 309862 | 시간 16[s] | 손실 2.70
# | 에폭 1 |  반복 15601 / 309862 | 시간 16[s] | 손실 3.12
# | 에폭 1 |  반복 15621 / 309862 | 시간 16[s] | 손실 2.83
# | 에폭 1 |  반복 15641 / 309862 | 시간 16[s] | 손실 2.92
# | 에폭 1 |  반복 15661 / 309862 | 시간 16[s] | 손실 3.04
# | 에폭 1 |  반복 15681 / 309862 | 시간 16[s] | 손실 2.99
# | 에폭 1 |  반복 15701 / 309862 | 시간 16[s] | 손실 2.84
# | 에폭 1 |  반복 15721 / 309862 | 시간 16[s] | 손실 2.87
# | 에폭 1 |  반복 15741 / 309862 | 시간 16[s] | 손실 3.08
# | 에폭 1 |  반복 15761 / 309862 | 시간 16[s] | 손실 2.83
# | 에폭 1 |  반복 15781 / 309862 | 시간 16[s] | 손실 2.86
# | 에폭 1 |  반복 15801 / 309862 | 시간 17[s] | 손실 3.14
# | 에폭 1 |  반복 15821 / 309862 | 시간 17[s] | 손실 3.12
# | 에폭 1 |  반복 15841 / 309862 | 시간 17[s] | 손실 2.89
# | 에폭 1 |  반복 15861 / 309862 | 시간 17[s] | 손실 2.94
# | 에폭 1 |  반복 15881 / 309862 | 시간 17[s] | 손실 2.97
# | 에폭 1 |  반복 15901 / 309862 | 시간 17[s] | 손실 2.89
# | 에폭 1 |  반복 15921 / 309862 | 시간 17[s] | 손실 2.87
# | 에폭 1 |  반복 15941 / 309862 | 시간 17[s] | 손실 3.01
# | 에폭 1 |  반복 15961 / 309862 | 시간 17[s] | 손실 2.83
# | 에폭 1 |  반복 15981 / 309862 | 시간 17[s] | 손실 2.92
# | 에폭 1 |  반복 16001 / 309862 | 시간 17[s] | 손실 2.90
# | 에폭 1 |  반복 16021 / 309862 | 시간 17[s] | 손실 2.93
# | 에폭 1 |  반복 16041 / 309862 | 시간 17[s] | 손실 2.75
# | 에폭 1 |  반복 16061 / 309862 | 시간 17[s] | 손실 2.80
# | 에폭 1 |  반복 16081 / 309862 | 시간 17[s] | 손실 2.92
# | 에폭 1 |  반복 16101 / 309862 | 시간 17[s] | 손실 2.80
# | 에폭 1 |  반복 16121 / 309862 | 시간 17[s] | 손실 3.00
# | 에폭 1 |  반복 16141 / 309862 | 시간 17[s] | 손실 2.91
# | 에폭 1 |  반복 16161 / 309862 | 시간 17[s] | 손실 3.00
# | 에폭 1 |  반복 16181 / 309862 | 시간 17[s] | 손실 2.98
# | 에폭 1 |  반복 16201 / 309862 | 시간 17[s] | 손실 3.00
# | 에폭 1 |  반복 16221 / 309862 | 시간 17[s] | 손실 2.83
# | 에폭 1 |  반복 16241 / 309862 | 시간 17[s] | 손실 3.10
# | 에폭 1 |  반복 16261 / 309862 | 시간 17[s] | 손실 2.98
# | 에폭 1 |  반복 16281 / 309862 | 시간 17[s] | 손실 2.80
# | 에폭 1 |  반복 16301 / 309862 | 시간 17[s] | 손실 3.08
# | 에폭 1 |  반복 16321 / 309862 | 시간 17[s] | 손실 2.99
# | 에폭 1 |  반복 16341 / 309862 | 시간 17[s] | 손실 2.99
# | 에폭 1 |  반복 16361 / 309862 | 시간 17[s] | 손실 2.82
# | 에폭 1 |  반복 16381 / 309862 | 시간 17[s] | 손실 2.86
# | 에폭 1 |  반복 16401 / 309862 | 시간 17[s] | 손실 2.81
# | 에폭 1 |  반복 16421 / 309862 | 시간 17[s] | 손실 2.92
# | 에폭 1 |  반복 16441 / 309862 | 시간 17[s] | 손실 3.18
# | 에폭 1 |  반복 16461 / 309862 | 시간 17[s] | 손실 2.91
# | 에폭 1 |  반복 16481 / 309862 | 시간 17[s] | 손실 3.03
# | 에폭 1 |  반복 16501 / 309862 | 시간 17[s] | 손실 2.92
# | 에폭 1 |  반복 16521 / 309862 | 시간 17[s] | 손실 2.97
# | 에폭 1 |  반복 16541 / 309862 | 시간 17[s] | 손실 2.85
# | 에폭 1 |  반복 16561 / 309862 | 시간 17[s] | 손실 3.03
# | 에폭 1 |  반복 16581 / 309862 | 시간 17[s] | 손실 2.98
# | 에폭 1 |  반복 16601 / 309862 | 시간 17[s] | 손실 3.05
# | 에폭 1 |  반복 16621 / 309862 | 시간 17[s] | 손실 3.02
# | 에폭 1 |  반복 16641 / 309862 | 시간 17[s] | 손실 3.02
# | 에폭 1 |  반복 16661 / 309862 | 시간 17[s] | 손실 2.78
# | 에폭 1 |  반복 16681 / 309862 | 시간 18[s] | 손실 2.94
# | 에폭 1 |  반복 16701 / 309862 | 시간 18[s] | 손실 2.92
# | 에폭 1 |  반복 16721 / 309862 | 시간 18[s] | 손실 2.86
# | 에폭 1 |  반복 16741 / 309862 | 시간 18[s] | 손실 2.91
# | 에폭 1 |  반복 16761 / 309862 | 시간 18[s] | 손실 3.09
# | 에폭 1 |  반복 16781 / 309862 | 시간 18[s] | 손실 2.86
# | 에폭 1 |  반복 16801 / 309862 | 시간 18[s] | 손실 2.87
# | 에폭 1 |  반복 16821 / 309862 | 시간 18[s] | 손실 2.94
# | 에폭 1 |  반복 16841 / 309862 | 시간 18[s] | 손실 2.92
# | 에폭 1 |  반복 16861 / 309862 | 시간 18[s] | 손실 2.89
# | 에폭 1 |  반복 16881 / 309862 | 시간 18[s] | 손실 3.02
# | 에폭 1 |  반복 16901 / 309862 | 시간 18[s] | 손실 2.92
# | 에폭 1 |  반복 16921 / 309862 | 시간 18[s] | 손실 3.00
# | 에폭 1 |  반복 16941 / 309862 | 시간 18[s] | 손실 2.85
# | 에폭 1 |  반복 16961 / 309862 | 시간 18[s] | 손실 2.83
# | 에폭 1 |  반복 16981 / 309862 | 시간 18[s] | 손실 2.85
# | 에폭 1 |  반복 17001 / 309862 | 시간 18[s] | 손실 2.92
# | 에폭 1 |  반복 17021 / 309862 | 시간 18[s] | 손실 2.99
# | 에폭 1 |  반복 17041 / 309862 | 시간 18[s] | 손실 2.83
# | 에폭 1 |  반복 17061 / 309862 | 시간 18[s] | 손실 2.77
# | 에폭 1 |  반복 17081 / 309862 | 시간 18[s] | 손실 2.97
# | 에폭 1 |  반복 17101 / 309862 | 시간 18[s] | 손실 2.86
# | 에폭 1 |  반복 17121 / 309862 | 시간 18[s] | 손실 2.93
# | 에폭 1 |  반복 17141 / 309862 | 시간 18[s] | 손실 3.01
# | 에폭 1 |  반복 17161 / 309862 | 시간 18[s] | 손실 3.03
# | 에폭 1 |  반복 17181 / 309862 | 시간 18[s] | 손실 2.96
# | 에폭 1 |  반복 17201 / 309862 | 시간 18[s] | 손실 2.96
# | 에폭 1 |  반복 17221 / 309862 | 시간 18[s] | 손실 2.89
# | 에폭 1 |  반복 17241 / 309862 | 시간 18[s] | 손실 2.69
# | 에폭 1 |  반복 17261 / 309862 | 시간 18[s] | 손실 2.92
# | 에폭 1 |  반복 17281 / 309862 | 시간 18[s] | 손실 3.05
# | 에폭 1 |  반복 17301 / 309862 | 시간 18[s] | 손실 3.03
# | 에폭 1 |  반복 17321 / 309862 | 시간 18[s] | 손실 3.03
# | 에폭 1 |  반복 17341 / 309862 | 시간 18[s] | 손실 2.93
# | 에폭 1 |  반복 17361 / 309862 | 시간 18[s] | 손실 2.84
# | 에폭 1 |  반복 17381 / 309862 | 시간 18[s] | 손실 2.79
# | 에폭 1 |  반복 17401 / 309862 | 시간 18[s] | 손실 2.74
# | 에폭 1 |  반복 17421 / 309862 | 시간 18[s] | 손실 2.89
# | 에폭 1 |  반복 17441 / 309862 | 시간 18[s] | 손실 2.85
# | 에폭 1 |  반복 17461 / 309862 | 시간 18[s] | 손실 2.92
# | 에폭 1 |  반복 17481 / 309862 | 시간 18[s] | 손실 2.88
# | 에폭 1 |  반복 17501 / 309862 | 시간 18[s] | 손실 2.75
# | 에폭 1 |  반복 17521 / 309862 | 시간 18[s] | 손실 2.94
# | 에폭 1 |  반복 17541 / 309862 | 시간 18[s] | 손실 2.80
# | 에폭 1 |  반복 17561 / 309862 | 시간 18[s] | 손실 2.69
# | 에폭 1 |  반복 17581 / 309862 | 시간 18[s] | 손실 2.94
# | 에폭 1 |  반복 17601 / 309862 | 시간 18[s] | 손실 2.83
# | 에폭 1 |  반복 17621 / 309862 | 시간 19[s] | 손실 2.89
# | 에폭 1 |  반복 17641 / 309862 | 시간 19[s] | 손실 2.93
# | 에폭 1 |  반복 17661 / 309862 | 시간 19[s] | 손실 2.76
# | 에폭 1 |  반복 17681 / 309862 | 시간 19[s] | 손실 2.85
# | 에폭 1 |  반복 17701 / 309862 | 시간 19[s] | 손실 2.95
# | 에폭 1 |  반복 17721 / 309862 | 시간 19[s] | 손실 2.78
# | 에폭 1 |  반복 17741 / 309862 | 시간 19[s] | 손실 2.85
# | 에폭 1 |  반복 17761 / 309862 | 시간 19[s] | 손실 2.86
# | 에폭 1 |  반복 17781 / 309862 | 시간 19[s] | 손실 2.87
# | 에폭 1 |  반복 17801 / 309862 | 시간 19[s] | 손실 2.84
# | 에폭 1 |  반복 17821 / 309862 | 시간 19[s] | 손실 2.95
# | 에폭 1 |  반복 17841 / 309862 | 시간 19[s] | 손실 2.80
# | 에폭 1 |  반복 17861 / 309862 | 시간 19[s] | 손실 3.09
# | 에폭 1 |  반복 17881 / 309862 | 시간 19[s] | 손실 2.84
# | 에폭 1 |  반복 17901 / 309862 | 시간 19[s] | 손실 2.89
# | 에폭 1 |  반복 17921 / 309862 | 시간 19[s] | 손실 2.83
# | 에폭 1 |  반복 17941 / 309862 | 시간 19[s] | 손실 2.89
# | 에폭 1 |  반복 17961 / 309862 | 시간 19[s] | 손실 2.76
# | 에폭 1 |  반복 17981 / 309862 | 시간 19[s] | 손실 3.07
# | 에폭 1 |  반복 18001 / 309862 | 시간 19[s] | 손실 2.91
# | 에폭 1 |  반복 18021 / 309862 | 시간 19[s] | 손실 2.95
# | 에폭 1 |  반복 18041 / 309862 | 시간 19[s] | 손실 2.75
# | 에폭 1 |  반복 18061 / 309862 | 시간 19[s] | 손실 2.80
# | 에폭 1 |  반복 18081 / 309862 | 시간 19[s] | 손실 2.82
# | 에폭 1 |  반복 18101 / 309862 | 시간 19[s] | 손실 2.75
# | 에폭 1 |  반복 18121 / 309862 | 시간 19[s] | 손실 3.00
# | 에폭 1 |  반복 18141 / 309862 | 시간 19[s] | 손실 3.00
# | 에폭 1 |  반복 18161 / 309862 | 시간 19[s] | 손실 2.88
# | 에폭 1 |  반복 18181 / 309862 | 시간 19[s] | 손실 2.78
# | 에폭 1 |  반복 18201 / 309862 | 시간 19[s] | 손실 2.83
# | 에폭 1 |  반복 18221 / 309862 | 시간 19[s] | 손실 2.91
# | 에폭 1 |  반복 18241 / 309862 | 시간 19[s] | 손실 2.90
# | 에폭 1 |  반복 18261 / 309862 | 시간 19[s] | 손실 2.95
# | 에폭 1 |  반복 18281 / 309862 | 시간 19[s] | 손실 2.95
# | 에폭 1 |  반복 18301 / 309862 | 시간 19[s] | 손실 2.76
# | 에폭 1 |  반복 18321 / 309862 | 시간 19[s] | 손실 2.91
# | 에폭 1 |  반복 18341 / 309862 | 시간 19[s] | 손실 2.81
# | 에폭 1 |  반복 18361 / 309862 | 시간 19[s] | 손실 2.90
# | 에폭 1 |  반복 18381 / 309862 | 시간 19[s] | 손실 2.91
# | 에폭 1 |  반복 18401 / 309862 | 시간 19[s] | 손실 2.82
# | 에폭 1 |  반복 18421 / 309862 | 시간 19[s] | 손실 2.85
# | 에폭 1 |  반복 18441 / 309862 | 시간 19[s] | 손실 2.78
# | 에폭 1 |  반복 18461 / 309862 | 시간 19[s] | 손실 3.02
# | 에폭 1 |  반복 18481 / 309862 | 시간 19[s] | 손실 2.94
# | 에폭 1 |  반복 18501 / 309862 | 시간 20[s] | 손실 2.78
# | 에폭 1 |  반복 18521 / 309862 | 시간 20[s] | 손실 2.76
# | 에폭 1 |  반복 18541 / 309862 | 시간 20[s] | 손실 2.84
# | 에폭 1 |  반복 18561 / 309862 | 시간 20[s] | 손실 2.82
# | 에폭 1 |  반복 18581 / 309862 | 시간 20[s] | 손실 2.87
# | 에폭 1 |  반복 18601 / 309862 | 시간 20[s] | 손실 2.75
# | 에폭 1 |  반복 18621 / 309862 | 시간 20[s] | 손실 2.80
# | 에폭 1 |  반복 18641 / 309862 | 시간 20[s] | 손실 2.76
# | 에폭 1 |  반복 18661 / 309862 | 시간 20[s] | 손실 2.77
# | 에폭 1 |  반복 18681 / 309862 | 시간 20[s] | 손실 3.02
# | 에폭 1 |  반복 18701 / 309862 | 시간 20[s] | 손실 2.64
# | 에폭 1 |  반복 18721 / 309862 | 시간 20[s] | 손실 2.86
# | 에폭 1 |  반복 18741 / 309862 | 시간 20[s] | 손실 2.83
# | 에폭 1 |  반복 18761 / 309862 | 시간 20[s] | 손실 2.75
# | 에폭 1 |  반복 18781 / 309862 | 시간 20[s] | 손실 2.88
# | 에폭 1 |  반복 18801 / 309862 | 시간 20[s] | 손실 2.90
# | 에폭 1 |  반복 18821 / 309862 | 시간 20[s] | 손실 2.96
# | 에폭 1 |  반복 18841 / 309862 | 시간 20[s] | 손실 2.89
# | 에폭 1 |  반복 18861 / 309862 | 시간 20[s] | 손실 2.95
# | 에폭 1 |  반복 18881 / 309862 | 시간 20[s] | 손실 2.86
# | 에폭 1 |  반복 18901 / 309862 | 시간 20[s] | 손실 3.01
# | 에폭 1 |  반복 18921 / 309862 | 시간 20[s] | 손실 2.90
# | 에폭 1 |  반복 18941 / 309862 | 시간 20[s] | 손실 2.74
# | 에폭 1 |  반복 18961 / 309862 | 시간 20[s] | 손실 2.90
# | 에폭 1 |  반복 18981 / 309862 | 시간 20[s] | 손실 2.75
# | 에폭 1 |  반복 19001 / 309862 | 시간 20[s] | 손실 2.88
# | 에폭 1 |  반복 19021 / 309862 | 시간 20[s] | 손실 2.90
# | 에폭 1 |  반복 19041 / 309862 | 시간 20[s] | 손실 2.88
# | 에폭 1 |  반복 19061 / 309862 | 시간 20[s] | 손실 2.95
# | 에폭 1 |  반복 19081 / 309862 | 시간 20[s] | 손실 2.99
# | 에폭 1 |  반복 19101 / 309862 | 시간 20[s] | 손실 2.80
# | 에폭 1 |  반복 19121 / 309862 | 시간 20[s] | 손실 2.90
# | 에폭 1 |  반복 19141 / 309862 | 시간 20[s] | 손실 2.83
# | 에폭 1 |  반복 19161 / 309862 | 시간 20[s] | 손실 2.87
# | 에폭 1 |  반복 19181 / 309862 | 시간 20[s] | 손실 2.70
# | 에폭 1 |  반복 19201 / 309862 | 시간 20[s] | 손실 2.65
# | 에폭 1 |  반복 19221 / 309862 | 시간 20[s] | 손실 2.97
# | 에폭 1 |  반복 19241 / 309862 | 시간 20[s] | 손실 2.94
# | 에폭 1 |  반복 19261 / 309862 | 시간 20[s] | 손실 2.87
# | 에폭 1 |  반복 19281 / 309862 | 시간 20[s] | 손실 2.74
# | 에폭 1 |  반복 19301 / 309862 | 시간 20[s] | 손실 2.93
# | 에폭 1 |  반복 19321 / 309862 | 시간 20[s] | 손실 3.03
# | 에폭 1 |  반복 19341 / 309862 | 시간 20[s] | 손실 2.98
# | 에폭 1 |  반복 19361 / 309862 | 시간 20[s] | 손실 2.91
# | 에폭 1 |  반복 19381 / 309862 | 시간 20[s] | 손실 2.92
# | 에폭 1 |  반복 19401 / 309862 | 시간 21[s] | 손실 2.76
# | 에폭 1 |  반복 19421 / 309862 | 시간 21[s] | 손실 2.85
# | 에폭 1 |  반복 19441 / 309862 | 시간 21[s] | 손실 2.67
# | 에폭 1 |  반복 19461 / 309862 | 시간 21[s] | 손실 2.82
# | 에폭 1 |  반복 19481 / 309862 | 시간 21[s] | 손실 2.68
# | 에폭 1 |  반복 19501 / 309862 | 시간 21[s] | 손실 2.83
# | 에폭 1 |  반복 19521 / 309862 | 시간 21[s] | 손실 2.75
# | 에폭 1 |  반복 19541 / 309862 | 시간 21[s] | 손실 2.78
# | 에폭 1 |  반복 19561 / 309862 | 시간 21[s] | 손실 2.90
# | 에폭 1 |  반복 19581 / 309862 | 시간 21[s] | 손실 2.99
# | 에폭 1 |  반복 19601 / 309862 | 시간 21[s] | 손실 2.90
# | 에폭 1 |  반복 19621 / 309862 | 시간 21[s] | 손실 2.81
# | 에폭 1 |  반복 19641 / 309862 | 시간 21[s] | 손실 2.94
# | 에폭 1 |  반복 19661 / 309862 | 시간 21[s] | 손실 2.83
# | 에폭 1 |  반복 19681 / 309862 | 시간 21[s] | 손실 2.78
# | 에폭 1 |  반복 19701 / 309862 | 시간 21[s] | 손실 2.98
# | 에폭 1 |  반복 19721 / 309862 | 시간 21[s] | 손실 2.93
# | 에폭 1 |  반복 19741 / 309862 | 시간 21[s] | 손실 2.90
# | 에폭 1 |  반복 19761 / 309862 | 시간 21[s] | 손실 2.66
# | 에폭 1 |  반복 19781 / 309862 | 시간 21[s] | 손실 2.87
# | 에폭 1 |  반복 19801 / 309862 | 시간 21[s] | 손실 2.84
# | 에폭 1 |  반복 19821 / 309862 | 시간 21[s] | 손실 2.82
# | 에폭 1 |  반복 19841 / 309862 | 시간 21[s] | 손실 2.83
# | 에폭 1 |  반복 19861 / 309862 | 시간 21[s] | 손실 2.55
# | 에폭 1 |  반복 19881 / 309862 | 시간 21[s] | 손실 2.72
# | 에폭 1 |  반복 19901 / 309862 | 시간 21[s] | 손실 2.81
# | 에폭 1 |  반복 19921 / 309862 | 시간 21[s] | 손실 2.85
# | 에폭 1 |  반복 19941 / 309862 | 시간 21[s] | 손실 2.91
# | 에폭 1 |  반복 19961 / 309862 | 시간 21[s] | 손실 2.92
# | 에폭 1 |  반복 19981 / 309862 | 시간 21[s] | 손실 2.91
# ...
# | 에폭 2 |  반복 303621 / 309862 | 시간 680[s] | 손실 2.00
# | 에폭 2 |  반복 303641 / 309862 | 시간 680[s] | 손실 2.05
# | 에폭 2 |  반복 303661 / 309862 | 시간 680[s] | 손실 2.03
# | 에폭 2 |  반복 303681 / 309862 | 시간 680[s] | 손실 2.04
# | 에폭 2 |  반복 303701 / 309862 | 시간 680[s] | 손실 2.45
# | 에폭 2 |  반복 303721 / 309862 | 시간 680[s] | 손실 2.16
# | 에폭 2 |  반복 303741 / 309862 | 시간 680[s] | 손실 2.16
# | 에폭 2 |  반복 303761 / 309862 | 시간 680[s] | 손실 2.54
# | 에폭 2 |  반복 303781 / 309862 | 시간 680[s] | 손실 2.14
# | 에폭 2 |  반복 303801 / 309862 | 시간 680[s] | 손실 1.88
# | 에폭 2 |  반복 303821 / 309862 | 시간 680[s] | 손실 1.95
# | 에폭 2 |  반복 303841 / 309862 | 시간 680[s] | 손실 2.13
# | 에폭 2 |  반복 303861 / 309862 | 시간 680[s] | 손실 2.06
# | 에폭 2 |  반복 303881 / 309862 | 시간 680[s] | 손실 2.12
# | 에폭 2 |  반복 303901 / 309862 | 시간 680[s] | 손실 2.27
# | 에폭 2 |  반복 303921 / 309862 | 시간 680[s] | 손실 2.05
# | 에폭 2 |  반복 303941 / 309862 | 시간 680[s] | 손실 2.16
# | 에폭 2 |  반복 303961 / 309862 | 시간 680[s] | 손실 2.18
# | 에폭 2 |  반복 303981 / 309862 | 시간 680[s] | 손실 2.07
# | 에폭 2 |  반복 304001 / 309862 | 시간 680[s] | 손실 2.18
# | 에폭 2 |  반복 304021 / 309862 | 시간 680[s] | 손실 2.04
# | 에폭 2 |  반복 304041 / 309862 | 시간 680[s] | 손실 2.16
# | 에폭 2 |  반복 304061 / 309862 | 시간 680[s] | 손실 2.12
# | 에폭 2 |  반복 304081 / 309862 | 시간 680[s] | 손실 1.80
# | 에폭 2 |  반복 304101 / 309862 | 시간 680[s] | 손실 2.26
# | 에폭 2 |  반복 304121 / 309862 | 시간 680[s] | 손실 2.44
# | 에폭 2 |  반복 304141 / 309862 | 시간 680[s] | 손실 1.96
# | 에폭 2 |  반복 304161 / 309862 | 시간 680[s] | 손실 2.01
# | 에폭 2 |  반복 304181 / 309862 | 시간 680[s] | 손실 2.19
# | 에폭 2 |  반복 304201 / 309862 | 시간 680[s] | 손실 1.92
# | 에폭 2 |  반복 304221 / 309862 | 시간 680[s] | 손실 2.10
# | 에폭 2 |  반복 304241 / 309862 | 시간 680[s] | 손실 2.00
# | 에폭 2 |  반복 304261 / 309862 | 시간 680[s] | 손실 2.07
# | 에폭 2 |  반복 304281 / 309862 | 시간 680[s] | 손실 2.21
# | 에폭 2 |  반복 304301 / 309862 | 시간 680[s] | 손실 2.35
# | 에폭 2 |  반복 304321 / 309862 | 시간 680[s] | 손실 2.02
# | 에폭 2 |  반복 304341 / 309862 | 시간 680[s] | 손실 2.01
# | 에폭 2 |  반복 304361 / 309862 | 시간 680[s] | 손실 1.96
# | 에폭 2 |  반복 304381 / 309862 | 시간 680[s] | 손실 2.02
# | 에폭 2 |  반복 304401 / 309862 | 시간 680[s] | 손실 2.01
# | 에폭 2 |  반복 304421 / 309862 | 시간 681[s] | 손실 2.05
# | 에폭 2 |  반복 304441 / 309862 | 시간 681[s] | 손실 2.00
# | 에폭 2 |  반복 304461 / 309862 | 시간 681[s] | 손실 2.04
# | 에폭 2 |  반복 304481 / 309862 | 시간 681[s] | 손실 1.99
# | 에폭 2 |  반복 304501 / 309862 | 시간 681[s] | 손실 2.19
# | 에폭 2 |  반복 304521 / 309862 | 시간 681[s] | 손실 2.23
# | 에폭 2 |  반복 304541 / 309862 | 시간 681[s] | 손실 2.10
# | 에폭 2 |  반복 304561 / 309862 | 시간 681[s] | 손실 2.13
# | 에폭 2 |  반복 304581 / 309862 | 시간 681[s] | 손실 1.89
# | 에폭 2 |  반복 304601 / 309862 | 시간 681[s] | 손실 1.96
# | 에폭 2 |  반복 304621 / 309862 | 시간 681[s] | 손실 2.21
# | 에폭 2 |  반복 304641 / 309862 | 시간 681[s] | 손실 1.96
# | 에폭 2 |  반복 304661 / 309862 | 시간 681[s] | 손실 2.30
# | 에폭 2 |  반복 304681 / 309862 | 시간 681[s] | 손실 1.88
# | 에폭 2 |  반복 304701 / 309862 | 시간 681[s] | 손실 2.03
# | 에폭 2 |  반복 304721 / 309862 | 시간 681[s] | 손실 2.25
# | 에폭 2 |  반복 304741 / 309862 | 시간 681[s] | 손실 2.27
# | 에폭 2 |  반복 304761 / 309862 | 시간 681[s] | 손실 2.27
# | 에폭 2 |  반복 304781 / 309862 | 시간 681[s] | 손실 2.30
# | 에폭 2 |  반복 304801 / 309862 | 시간 681[s] | 손실 2.06
# | 에폭 2 |  반복 304821 / 309862 | 시간 681[s] | 손실 2.26
# | 에폭 2 |  반복 304841 / 309862 | 시간 681[s] | 손실 2.05
# | 에폭 2 |  반복 304861 / 309862 | 시간 681[s] | 손실 2.03
# | 에폭 2 |  반복 304881 / 309862 | 시간 681[s] | 손실 2.05
# | 에폭 2 |  반복 304901 / 309862 | 시간 681[s] | 손실 2.11
# | 에폭 2 |  반복 304921 / 309862 | 시간 681[s] | 손실 2.48
# | 에폭 2 |  반복 304941 / 309862 | 시간 681[s] | 손실 2.22
# | 에폭 2 |  반복 304961 / 309862 | 시간 681[s] | 손실 1.89
# | 에폭 2 |  반복 304981 / 309862 | 시간 681[s] | 손실 1.89
# | 에폭 2 |  반복 305001 / 309862 | 시간 681[s] | 손실 2.16
# | 에폭 2 |  반복 305021 / 309862 | 시간 681[s] | 손실 2.08
# | 에폭 2 |  반복 305041 / 309862 | 시간 681[s] | 손실 2.07
# | 에폭 2 |  반복 305061 / 309862 | 시간 681[s] | 손실 2.33
# | 에폭 2 |  반복 305081 / 309862 | 시간 681[s] | 손실 2.19
# | 에폭 2 |  반복 305101 / 309862 | 시간 681[s] | 손실 2.14
# | 에폭 2 |  반복 305121 / 309862 | 시간 681[s] | 손실 2.12
# | 에폭 2 |  반복 305141 / 309862 | 시간 681[s] | 손실 2.07
# | 에폭 2 |  반복 305161 / 309862 | 시간 681[s] | 손실 2.08
# | 에폭 2 |  반복 305181 / 309862 | 시간 681[s] | 손실 2.41
# | 에폭 2 |  반복 305201 / 309862 | 시간 681[s] | 손실 2.23
# | 에폭 2 |  반복 305221 / 309862 | 시간 681[s] | 손실 1.93
# | 에폭 2 |  반복 305241 / 309862 | 시간 681[s] | 손실 2.08
# | 에폭 2 |  반복 305261 / 309862 | 시간 681[s] | 손실 2.25
# | 에폭 2 |  반복 305281 / 309862 | 시간 681[s] | 손실 2.33
# | 에폭 2 |  반복 305301 / 309862 | 시간 682[s] | 손실 2.11
# | 에폭 2 |  반복 305321 / 309862 | 시간 682[s] | 손실 2.01
# | 에폭 2 |  반복 305341 / 309862 | 시간 682[s] | 손실 2.01
# | 에폭 2 |  반복 305361 / 309862 | 시간 682[s] | 손실 2.16
# | 에폭 2 |  반복 305381 / 309862 | 시간 682[s] | 손실 2.11
# | 에폭 2 |  반복 305401 / 309862 | 시간 682[s] | 손실 2.19
# | 에폭 2 |  반복 305421 / 309862 | 시간 682[s] | 손실 2.32
# | 에폭 2 |  반복 305441 / 309862 | 시간 682[s] | 손실 2.25
# | 에폭 2 |  반복 305461 / 309862 | 시간 682[s] | 손실 2.36
# | 에폭 2 |  반복 305481 / 309862 | 시간 682[s] | 손실 2.02
# | 에폭 2 |  반복 305501 / 309862 | 시간 682[s] | 손실 2.11
# | 에폭 2 |  반복 305521 / 309862 | 시간 682[s] | 손실 2.22
# | 에폭 2 |  반복 305541 / 309862 | 시간 682[s] | 손실 2.09
# | 에폭 2 |  반복 305561 / 309862 | 시간 682[s] | 손실 1.94
# | 에폭 2 |  반복 305581 / 309862 | 시간 682[s] | 손실 2.15
# | 에폭 2 |  반복 305601 / 309862 | 시간 682[s] | 손실 2.13
# | 에폭 2 |  반복 305621 / 309862 | 시간 682[s] | 손실 1.96
# | 에폭 2 |  반복 305641 / 309862 | 시간 682[s] | 손실 2.15
# | 에폭 2 |  반복 305661 / 309862 | 시간 682[s] | 손실 2.03
# | 에폭 2 |  반복 305681 / 309862 | 시간 682[s] | 손실 2.01
# | 에폭 2 |  반복 305701 / 309862 | 시간 682[s] | 손실 2.11
# | 에폭 2 |  반복 305721 / 309862 | 시간 682[s] | 손실 2.07
# | 에폭 2 |  반복 305741 / 309862 | 시간 682[s] | 손실 2.21
# | 에폭 2 |  반복 305761 / 309862 | 시간 682[s] | 손실 2.17
# | 에폭 2 |  반복 305781 / 309862 | 시간 682[s] | 손실 2.15
# | 에폭 2 |  반복 305801 / 309862 | 시간 682[s] | 손실 2.07
# | 에폭 2 |  반복 305821 / 309862 | 시간 682[s] | 손실 2.02
# | 에폭 2 |  반복 305841 / 309862 | 시간 682[s] | 손실 1.98
# | 에폭 2 |  반복 305861 / 309862 | 시간 682[s] | 손실 2.20
# | 에폭 2 |  반복 305881 / 309862 | 시간 682[s] | 손실 2.11
# | 에폭 2 |  반복 305901 / 309862 | 시간 682[s] | 손실 2.32
# | 에폭 2 |  반복 305921 / 309862 | 시간 682[s] | 손실 2.36
# | 에폭 2 |  반복 305941 / 309862 | 시간 682[s] | 손실 2.03
# | 에폭 2 |  반복 305961 / 309862 | 시간 682[s] | 손실 2.07
# | 에폭 2 |  반복 305981 / 309862 | 시간 682[s] | 손실 2.10
# | 에폭 2 |  반복 306001 / 309862 | 시간 682[s] | 손실 2.06
# | 에폭 2 |  반복 306021 / 309862 | 시간 682[s] | 손실 2.10
# | 에폭 2 |  반복 306041 / 309862 | 시간 682[s] | 손실 2.00
# | 에폭 2 |  반복 306061 / 309862 | 시간 682[s] | 손실 2.14
# | 에폭 2 |  반복 306081 / 309862 | 시간 682[s] | 손실 2.14
# | 에폭 2 |  반복 306101 / 309862 | 시간 682[s] | 손실 2.32
# | 에폭 2 |  반복 306121 / 309862 | 시간 682[s] | 손실 2.31
# | 에폭 2 |  반복 306141 / 309862 | 시간 682[s] | 손실 2.17
# | 에폭 2 |  반복 306161 / 309862 | 시간 682[s] | 손실 1.98
# | 에폭 2 |  반복 306181 / 309862 | 시간 683[s] | 손실 2.01
# | 에폭 2 |  반복 306201 / 309862 | 시간 683[s] | 손실 2.02
# | 에폭 2 |  반복 306221 / 309862 | 시간 683[s] | 손실 2.24
# | 에폭 2 |  반복 306241 / 309862 | 시간 683[s] | 손실 2.06
# | 에폭 2 |  반복 306261 / 309862 | 시간 683[s] | 손실 2.44
# | 에폭 2 |  반복 306281 / 309862 | 시간 683[s] | 손실 2.08
# | 에폭 2 |  반복 306301 / 309862 | 시간 683[s] | 손실 2.02
# | 에폭 2 |  반복 306321 / 309862 | 시간 683[s] | 손실 2.17
# | 에폭 2 |  반복 306341 / 309862 | 시간 683[s] | 손실 2.14
# | 에폭 2 |  반복 306361 / 309862 | 시간 683[s] | 손실 2.06
# | 에폭 2 |  반복 306381 / 309862 | 시간 683[s] | 손실 2.16
# | 에폭 2 |  반복 306401 / 309862 | 시간 683[s] | 손실 2.22
# | 에폭 2 |  반복 306421 / 309862 | 시간 683[s] | 손실 2.00
# | 에폭 2 |  반복 306441 / 309862 | 시간 683[s] | 손실 1.99
# | 에폭 2 |  반복 306461 / 309862 | 시간 683[s] | 손실 2.13
# | 에폭 2 |  반복 306481 / 309862 | 시간 683[s] | 손실 1.86
# | 에폭 2 |  반복 306501 / 309862 | 시간 683[s] | 손실 2.14
# | 에폭 2 |  반복 306521 / 309862 | 시간 683[s] | 손실 1.97
# | 에폭 2 |  반복 306541 / 309862 | 시간 683[s] | 손실 2.27
# | 에폭 2 |  반복 306561 / 309862 | 시간 683[s] | 손실 2.09
# | 에폭 2 |  반복 306581 / 309862 | 시간 683[s] | 손실 2.29
# | 에폭 2 |  반복 306601 / 309862 | 시간 683[s] | 손실 2.20
# | 에폭 2 |  반복 306621 / 309862 | 시간 683[s] | 손실 2.19
# | 에폭 2 |  반복 306641 / 309862 | 시간 683[s] | 손실 1.98
# | 에폭 2 |  반복 306661 / 309862 | 시간 683[s] | 손실 2.08
# | 에폭 2 |  반복 306681 / 309862 | 시간 683[s] | 손실 2.15
# | 에폭 2 |  반복 306701 / 309862 | 시간 683[s] | 손실 2.04
# | 에폭 2 |  반복 306721 / 309862 | 시간 683[s] | 손실 2.10
# | 에폭 2 |  반복 306741 / 309862 | 시간 683[s] | 손실 2.42
# | 에폭 2 |  반복 306761 / 309862 | 시간 683[s] | 손실 2.08
# | 에폭 2 |  반복 306781 / 309862 | 시간 683[s] | 손실 2.04
# | 에폭 2 |  반복 306801 / 309862 | 시간 683[s] | 손실 2.43
# | 에폭 2 |  반복 306821 / 309862 | 시간 683[s] | 손실 2.40
# | 에폭 2 |  반복 306841 / 309862 | 시간 683[s] | 손실 2.39
# | 에폭 2 |  반복 306861 / 309862 | 시간 683[s] | 손실 1.93
# | 에폭 2 |  반복 306881 / 309862 | 시간 683[s] | 손실 1.91
# | 에폭 2 |  반복 306901 / 309862 | 시간 683[s] | 손실 2.09
# | 에폭 2 |  반복 306921 / 309862 | 시간 683[s] | 손실 2.10
# | 에폭 2 |  반복 306941 / 309862 | 시간 683[s] | 손실 2.00
# | 에폭 2 |  반복 306961 / 309862 | 시간 683[s] | 손실 2.32
# | 에폭 2 |  반복 306981 / 309862 | 시간 683[s] | 손실 2.02
# | 에폭 2 |  반복 307001 / 309862 | 시간 683[s] | 손실 2.22
# | 에폭 2 |  반복 307021 / 309862 | 시간 684[s] | 손실 2.32
# | 에폭 2 |  반복 307041 / 309862 | 시간 684[s] | 손실 2.26
# | 에폭 2 |  반복 307061 / 309862 | 시간 684[s] | 손실 2.21
# | 에폭 2 |  반복 307081 / 309862 | 시간 684[s] | 손실 2.38
# | 에폭 2 |  반복 307101 / 309862 | 시간 684[s] | 손실 2.12
# | 에폭 2 |  반복 307121 / 309862 | 시간 684[s] | 손실 1.86
# | 에폭 2 |  반복 307141 / 309862 | 시간 684[s] | 손실 2.22
# | 에폭 2 |  반복 307161 / 309862 | 시간 684[s] | 손실 2.27
# | 에폭 2 |  반복 307181 / 309862 | 시간 684[s] | 손실 2.13
# | 에폭 2 |  반복 307201 / 309862 | 시간 684[s] | 손실 1.93
# | 에폭 2 |  반복 307221 / 309862 | 시간 684[s] | 손실 2.19
# | 에폭 2 |  반복 307241 / 309862 | 시간 684[s] | 손실 2.02
# | 에폭 2 |  반복 307261 / 309862 | 시간 684[s] | 손실 2.20
# | 에폭 2 |  반복 307281 / 309862 | 시간 684[s] | 손실 2.07
# | 에폭 2 |  반복 307301 / 309862 | 시간 684[s] | 손실 2.01
# | 에폭 2 |  반복 307321 / 309862 | 시간 684[s] | 손실 1.92
# | 에폭 2 |  반복 307341 / 309862 | 시간 684[s] | 손실 1.94
# | 에폭 2 |  반복 307361 / 309862 | 시간 684[s] | 손실 2.31
# | 에폭 2 |  반복 307381 / 309862 | 시간 684[s] | 손실 2.06
# | 에폭 2 |  반복 307401 / 309862 | 시간 684[s] | 손실 2.17
# | 에폭 2 |  반복 307421 / 309862 | 시간 684[s] | 손실 2.13
# | 에폭 2 |  반복 307441 / 309862 | 시간 684[s] | 손실 1.99
# | 에폭 2 |  반복 307461 / 309862 | 시간 684[s] | 손실 2.09
# | 에폭 2 |  반복 307481 / 309862 | 시간 684[s] | 손실 2.05
# | 에폭 2 |  반복 307501 / 309862 | 시간 684[s] | 손실 2.09
# | 에폭 2 |  반복 307521 / 309862 | 시간 684[s] | 손실 2.15
# | 에폭 2 |  반복 307541 / 309862 | 시간 684[s] | 손실 2.19
# | 에폭 2 |  반복 307561 / 309862 | 시간 684[s] | 손실 2.34
# | 에폭 2 |  반복 307581 / 309862 | 시간 684[s] | 손실 2.18
# | 에폭 2 |  반복 307601 / 309862 | 시간 684[s] | 손실 2.29
# | 에폭 2 |  반복 307621 / 309862 | 시간 684[s] | 손실 2.27
# | 에폭 2 |  반복 307641 / 309862 | 시간 684[s] | 손실 2.20
# | 에폭 2 |  반복 307661 / 309862 | 시간 684[s] | 손실 2.15
# | 에폭 2 |  반복 307681 / 309862 | 시간 684[s] | 손실 2.43
# | 에폭 2 |  반복 307701 / 309862 | 시간 684[s] | 손실 2.26
# | 에폭 2 |  반복 307721 / 309862 | 시간 684[s] | 손실 2.21
# | 에폭 2 |  반복 307741 / 309862 | 시간 684[s] | 손실 2.00
# | 에폭 2 |  반복 307761 / 309862 | 시간 684[s] | 손실 2.29
# | 에폭 2 |  반복 307781 / 309862 | 시간 684[s] | 손실 2.30
# | 에폭 2 |  반복 307801 / 309862 | 시간 684[s] | 손실 2.09
# | 에폭 2 |  반복 307821 / 309862 | 시간 684[s] | 손실 2.28
# | 에폭 2 |  반복 307841 / 309862 | 시간 684[s] | 손실 2.02
# | 에폭 2 |  반복 307861 / 309862 | 시간 685[s] | 손실 1.97
# | 에폭 2 |  반복 307881 / 309862 | 시간 685[s] | 손실 2.22
# | 에폭 2 |  반복 307901 / 309862 | 시간 685[s] | 손실 1.97
# | 에폭 2 |  반복 307921 / 309862 | 시간 685[s] | 손실 2.06
# | 에폭 2 |  반복 307941 / 309862 | 시간 685[s] | 손실 2.23
# | 에폭 2 |  반복 307961 / 309862 | 시간 685[s] | 손실 1.95
# | 에폭 2 |  반복 307981 / 309862 | 시간 685[s] | 손실 2.16
# | 에폭 2 |  반복 308001 / 309862 | 시간 685[s] | 손실 2.37
# | 에폭 2 |  반복 308021 / 309862 | 시간 685[s] | 손실 2.34
# | 에폭 2 |  반복 308041 / 309862 | 시간 685[s] | 손실 2.31
# | 에폭 2 |  반복 308061 / 309862 | 시간 685[s] | 손실 1.97
# | 에폭 2 |  반복 308081 / 309862 | 시간 685[s] | 손실 2.08
# | 에폭 2 |  반복 308101 / 309862 | 시간 685[s] | 손실 1.89
# | 에폭 2 |  반복 308121 / 309862 | 시간 685[s] | 손실 2.16
# | 에폭 2 |  반복 308141 / 309862 | 시간 685[s] | 손실 1.76
# | 에폭 2 |  반복 308161 / 309862 | 시간 685[s] | 손실 2.12
# | 에폭 2 |  반복 308181 / 309862 | 시간 685[s] | 손실 2.17
# | 에폭 2 |  반복 308201 / 309862 | 시간 685[s] | 손실 2.09
# | 에폭 2 |  반복 308221 / 309862 | 시간 685[s] | 손실 1.82
# | 에폭 2 |  반복 308241 / 309862 | 시간 685[s] | 손실 2.58
# | 에폭 2 |  반복 308261 / 309862 | 시간 685[s] | 손실 1.84
# | 에폭 2 |  반복 308281 / 309862 | 시간 685[s] | 손실 2.21
# | 에폭 2 |  반복 308301 / 309862 | 시간 685[s] | 손실 2.10
# | 에폭 2 |  반복 308321 / 309862 | 시간 685[s] | 손실 1.95
# | 에폭 2 |  반복 308341 / 309862 | 시간 685[s] | 손실 2.08
# | 에폭 2 |  반복 308361 / 309862 | 시간 685[s] | 손실 2.09
# | 에폭 2 |  반복 308381 / 309862 | 시간 685[s] | 손실 2.05
# | 에폭 2 |  반복 308401 / 309862 | 시간 685[s] | 손실 2.13
# | 에폭 2 |  반복 308421 / 309862 | 시간 685[s] | 손실 2.02
# | 에폭 2 |  반복 308441 / 309862 | 시간 685[s] | 손실 2.07
# | 에폭 2 |  반복 308461 / 309862 | 시간 685[s] | 손실 2.19
# | 에폭 2 |  반복 308481 / 309862 | 시간 685[s] | 손실 2.25
# | 에폭 2 |  반복 308501 / 309862 | 시간 685[s] | 손실 1.97
# | 에폭 2 |  반복 308521 / 309862 | 시간 685[s] | 손실 1.86
# | 에폭 2 |  반복 308541 / 309862 | 시간 685[s] | 손실 2.03
# | 에폭 2 |  반복 308561 / 309862 | 시간 685[s] | 손실 1.97
# | 에폭 2 |  반복 308581 / 309862 | 시간 685[s] | 손실 2.14
# | 에폭 2 |  반복 308601 / 309862 | 시간 685[s] | 손실 2.12
# | 에폭 2 |  반복 308621 / 309862 | 시간 685[s] | 손실 2.16
# | 에폭 2 |  반복 308641 / 309862 | 시간 685[s] | 손실 1.97
# | 에폭 2 |  반복 308661 / 309862 | 시간 686[s] | 손실 2.21
# | 에폭 2 |  반복 308681 / 309862 | 시간 686[s] | 손실 2.19
# | 에폭 2 |  반복 308701 / 309862 | 시간 686[s] | 손실 2.30
# | 에폭 2 |  반복 308721 / 309862 | 시간 686[s] | 손실 2.27
# | 에폭 2 |  반복 308741 / 309862 | 시간 686[s] | 손실 2.09
# | 에폭 2 |  반복 308761 / 309862 | 시간 686[s] | 손실 2.03
# | 에폭 2 |  반복 308781 / 309862 | 시간 686[s] | 손실 2.00
# | 에폭 2 |  반복 308801 / 309862 | 시간 686[s] | 손실 1.97
# | 에폭 2 |  반복 308821 / 309862 | 시간 686[s] | 손실 2.08
# | 에폭 2 |  반복 308841 / 309862 | 시간 686[s] | 손실 2.44
# | 에폭 2 |  반복 308861 / 309862 | 시간 686[s] | 손실 1.92
# | 에폭 2 |  반복 308881 / 309862 | 시간 686[s] | 손실 2.21
# | 에폭 2 |  반복 308901 / 309862 | 시간 686[s] | 손실 2.10
# | 에폭 2 |  반복 308921 / 309862 | 시간 686[s] | 손실 2.07
# | 에폭 2 |  반복 308941 / 309862 | 시간 686[s] | 손실 2.28
# | 에폭 2 |  반복 308961 / 309862 | 시간 686[s] | 손실 2.08
# | 에폭 2 |  반복 308981 / 309862 | 시간 686[s] | 손실 1.94
# | 에폭 2 |  반복 309001 / 309862 | 시간 686[s] | 손실 2.06
# | 에폭 2 |  반복 309021 / 309862 | 시간 686[s] | 손실 2.40
# | 에폭 2 |  반복 309041 / 309862 | 시간 686[s] | 손실 2.05
# | 에폭 2 |  반복 309061 / 309862 | 시간 686[s] | 손실 2.14
# | 에폭 2 |  반복 309081 / 309862 | 시간 686[s] | 손실 2.34
# | 에폭 2 |  반복 309101 / 309862 | 시간 686[s] | 손실 2.18
# | 에폭 2 |  반복 309121 / 309862 | 시간 686[s] | 손실 2.23
# | 에폭 2 |  반복 309141 / 309862 | 시간 686[s] | 손실 1.91
# | 에폭 2 |  반복 309161 / 309862 | 시간 686[s] | 손실 2.33
# | 에폭 2 |  반복 309181 / 309862 | 시간 686[s] | 손실 2.08
# | 에폭 2 |  반복 309201 / 309862 | 시간 686[s] | 손실 2.34
# | 에폭 2 |  반복 309221 / 309862 | 시간 686[s] | 손실 2.14
# | 에폭 2 |  반복 309241 / 309862 | 시간 686[s] | 손실 2.12
# | 에폭 2 |  반복 309261 / 309862 | 시간 686[s] | 손실 2.37
# | 에폭 2 |  반복 309281 / 309862 | 시간 686[s] | 손실 2.12
# | 에폭 2 |  반복 309301 / 309862 | 시간 686[s] | 손실 2.08
# | 에폭 2 |  반복 309321 / 309862 | 시간 686[s] | 손실 2.40
# | 에폭 2 |  반복 309341 / 309862 | 시간 686[s] | 손실 2.11
# | 에폭 2 |  반복 309361 / 309862 | 시간 686[s] | 손실 2.18
# | 에폭 2 |  반복 309381 / 309862 | 시간 686[s] | 손실 2.13
# | 에폭 2 |  반복 309401 / 309862 | 시간 686[s] | 손실 2.23
# | 에폭 2 |  반복 309421 / 309862 | 시간 686[s] | 손실 2.10
# | 에폭 2 |  반복 309441 / 309862 | 시간 686[s] | 손실 2.10
# | 에폭 2 |  반복 309461 / 309862 | 시간 686[s] | 손실 1.98
# | 에폭 2 |  반복 309481 / 309862 | 시간 686[s] | 손실 1.99
# | 에폭 2 |  반복 309501 / 309862 | 시간 686[s] | 손실 2.22
# | 에폭 2 |  반복 309521 / 309862 | 시간 687[s] | 손실 2.14
# | 에폭 2 |  반복 309541 / 309862 | 시간 687[s] | 손실 2.46
# | 에폭 2 |  반복 309561 / 309862 | 시간 687[s] | 손실 2.10
# | 에폭 2 |  반복 309581 / 309862 | 시간 687[s] | 손실 2.11
# | 에폭 2 |  반복 309601 / 309862 | 시간 687[s] | 손실 2.26
# | 에폭 2 |  반복 309621 / 309862 | 시간 687[s] | 손실 2.14
# | 에폭 2 |  반복 309641 / 309862 | 시간 687[s] | 손실 2.17
# | 에폭 2 |  반복 309661 / 309862 | 시간 687[s] | 손실 2.07
# | 에폭 2 |  반복 309681 / 309862 | 시간 687[s] | 손실 2.21
# | 에폭 2 |  반복 309701 / 309862 | 시간 687[s] | 손실 2.08
# | 에폭 2 |  반복 309721 / 309862 | 시간 687[s] | 손실 2.08
# | 에폭 2 |  반복 309741 / 309862 | 시간 687[s] | 손실 2.29
# | 에폭 2 |  반복 309761 / 309862 | 시간 687[s] | 손실 1.99
# | 에폭 2 |  반복 309781 / 309862 | 시간 687[s] | 손실 1.99
# | 에폭 2 |  반복 309801 / 309862 | 시간 687[s] | 손실 2.14
# | 에폭 2 |  반복 309821 / 309862 | 시간 687[s] | 손실 2.19
# | 에폭 2 |  반복 309841 / 309862 | 시간 687[s] | 손실 2.18
# | 에폭 2 |  반복 309861 / 309862 | 시간 687[s] | 손실 2.17

# %%
# 학습이 끝난 후 단어의 분산 표현을 추출
word_vecs = model.word_vecs
if GPU:
    word_vecs = to_cpu(word_vecs)

# 단어 별 분산 표현을 사전에 저장
params = {}
params['word_vecs'] = word_vecs.astype(np.float16)
params['word_to_id'] = word_to_id
params['id_to_word'] = id_to_word
pkl_file = 'cbow_params.pkl'
with open(pkl_file, 'wb') as f:
    pickle.dump(params, f, -1)
