# %% [markdown]
# ### 통계 기반 기법 vs. 추론 기반 기법

# %%
import sys
sys.path.append('C:/Users/KimDongyoung/Desktop/Github/my_git/mygit/DEEPLEARNING/밑바닥부터시작하는딥러닝2')
import numpy as np
# from common.util import most_similar, create_co_matrix, ppmi
from ptb import load_data

# %%
def cos_similarity(x, y, eps=1e-8):
    '''코사인 유사도 산출

    :param x: 벡터
    :param y: 벡터
    :param eps: '0으로 나누기'를 방지하기 위한 작은 값
    :return:
    '''
    nx = x / (np.sqrt(np.sum(x ** 2)) + eps)
    ny = y / (np.sqrt(np.sum(y ** 2)) + eps)
    return np.dot(nx, ny)


def most_similar(query, word_to_id, id_to_word, word_matrix, top=5):
    '''유사 단어 검색

    :param query: 쿼리(텍스트)
    :param word_to_id: 단어에서 단어 ID로 변환하는 딕셔너리
    :param id_to_word: 단어 ID에서 단어로 변환하는 딕셔너리
    :param word_matrix: 단어 벡터를 정리한 행렬. 각 행에 해당 단어 벡터가 저장되어 있다고 가정한다.
    :param top: 상위 몇 개까지 출력할 지 지정
    '''
    if query not in word_to_id:
        print('%s(을)를 찾을 수 없습니다.' % query)
        return

    print('\n[query] ' + query)
    query_id = word_to_id[query]
    query_vec = word_matrix[query_id]

    # 코사인 유사도 계산
    vocab_size = len(id_to_word)

    similarity = np.zeros(vocab_size)
    for i in range(vocab_size):
        similarity[i] = cos_similarity(word_matrix[i], query_vec)

    # 코사인 유사도를 기준으로 내림차순으로 출력
    count = 0
    for i in (-1 * similarity).argsort():
        if id_to_word[i] == query:
            continue
        print(' %s: %s' % (id_to_word[i], similarity[i]))

        count += 1
        if count >= top:
            return

def create_co_matrix(corpus, vocab_size, window_size=1):
    '''동시발생 행렬 생성

    :param corpus: 말뭉치(단어 ID 목록)
    :param vocab_size: 어휘 수
    :param window_size: 윈도우 크기(윈도우 크기가 1이면 타깃 단어 좌우 한 단어씩이 맥락에 포함)
    :return: 동시발생 행렬
    '''
    corpus_size = len(corpus)
    co_matrix = np.zeros((vocab_size, vocab_size), dtype=np.int32)

    for idx, word_id in enumerate(corpus):
        for i in range(1, window_size + 1):
            left_idx = idx - i
            right_idx = idx + i

            if left_idx >= 0:
                left_word_id = corpus[left_idx]
                co_matrix[word_id, left_word_id] += 1

            if right_idx < corpus_size:
                right_word_id = corpus[right_idx]
                co_matrix[word_id, right_word_id] += 1

    return co_matrix
  
def ppmi(C, verbose=False, eps = 1e-8):
    '''PPMI(점별 상호정보량) 생성

    :param C: 동시발생 행렬
    :param verbose: 진행 상황을 출력할지 여부
    :return:
    '''
    M = np.zeros_like(C, dtype=np.float32)
    N = np.sum(C)
    S = np.sum(C, axis=0)
    total = C.shape[0] * C.shape[1]
    cnt = 0

    for i in range(C.shape[0]):
        for j in range(C.shape[1]):
            pmi = np.log2(C[i, j] * N / (S[j]*S[i]) + eps)
            M[i, j] = max(0, pmi)

            if verbose:
                cnt += 1
                if cnt % (total//100 + 1) == 0:
                    print('%.1f%% 완료' % (100*cnt/total))
    return M

def normalize(x):
    if x.ndim == 2:
        s = np.sqrt((x * x).sum(1))
        x /= s.reshape((s.shape[0], 1))
    elif x.ndim == 1:
        s = np.sqrt((x * x).sum())
        x /= s
    return x


def analogy(a, b, c, word_to_id, id_to_word, word_matrix, top=5, answer=None):
    for word in (a, b, c):
        if word not in word_to_id:
            print('%s(을)를 찾을 수 없습니다.' % word)
            return

    print('\n[analogy] ' + a + ':' + b + ' = ' + c + ':?')
    a_vec, b_vec, c_vec = word_matrix[word_to_id[a]], word_matrix[word_to_id[b]], word_matrix[word_to_id[c]]
    query_vec = b_vec - a_vec + c_vec           # (b - a) + c   (b-a)는 a에서 b로 가는 벡터이다. 그래서 이 벡터에 c를 더하면 c에서 어디로 가는 벡터가 나온다.
    query_vec = normalize(query_vec)

    similarity = np.dot(word_matrix, query_vec)

    if answer is not None:
        print("==>" + answer + ":" + str(np.dot(word_matrix[word_to_id[answer]], query_vec)))

    count = 0
    for i in (-1 * similarity).argsort():
        if np.isnan(similarity[i]):
            continue
        if id_to_word[i] in (a, b, c):
            continue
        print(' {0}: {1}'.format(id_to_word[i], similarity[i]))

        count += 1
        if count >= top:
            return

# %%
window_size = 2
wordvec_size = 100

corpus, word_to_id, id_to_word = load_data('train')
vocab_size = len(word_to_id)
print('동시발생 수 계산 ...')
C = create_co_matrix(corpus, vocab_size, window_size)
print('PPMI 계산 ...')
W = ppmi(C, verbose=True)

print('calculating SVD ...')
try:
    # truncated SVD (빠르다!)
    from sklearn.utils.extmath import randomized_svd
    U, S, V = randomized_svd(W, n_components=wordvec_size, n_iter=5,
                             random_state=None)
except ImportError:
    # SVD (느리다)
    U, S, V = np.linalg.svd(W)

word_vecs = U[:, :wordvec_size]

querys = ['you', 'year', 'car', 'toyota']
for query in querys:
    most_similar(query, word_to_id, id_to_word, word_vecs, top=5)
# Out:
# 동시발생 수 계산 ...
# PPMI 계산 ...
# C:\Users\KimDongyoung\AppData\Local\Temp\ipykernel_6196\311581501.py:90: RuntimeWarning: overflow encountered in scalar multiply
#   pmi = np.log2(C[i, j] * N / (S[j]*S[i]) + eps)
# C:\Users\KimDongyoung\AppData\Local\Temp\ipykernel_6196\311581501.py:90: RuntimeWarning: invalid value encountered in log2
#   pmi = np.log2(C[i, j] * N / (S[j]*S[i]) + eps)
# 1.0% 완료
# 2.0% 완료
# 3.0% 완료
# 4.0% 완료
# 5.0% 완료
# 6.0% 완료
# 7.0% 완료
# 8.0% 완료
# 9.0% 완료
# 10.0% 완료
# 11.0% 완료
# 12.0% 완료
# 13.0% 완료
# 14.0% 완료
# 15.0% 완료
# 16.0% 완료
# 17.0% 완료
# 18.0% 완료
# 19.0% 완료
# 20.0% 완료
# 21.0% 완료
# 22.0% 완료
# 23.0% 완료
# 24.0% 완료
# 25.0% 완료
# 26.0% 완료
# 27.0% 완료
# 28.0% 완료
# 29.0% 완료
# 30.0% 완료
# 31.0% 완료
# 32.0% 완료
# 33.0% 완료
# 34.0% 완료
# 35.0% 완료
# 36.0% 완료
# 37.0% 완료
# 38.0% 완료
# 39.0% 완료
# 40.0% 완료
# 41.0% 완료
# 42.0% 완료
# 43.0% 완료
# 44.0% 완료
# 45.0% 완료
# 46.0% 완료
# 47.0% 완료
# 48.0% 완료
# 49.0% 완료
# 50.0% 완료
# 51.0% 완료
# 52.0% 완료
# 53.0% 완료
# 54.0% 완료
# 55.0% 완료
# 56.0% 완료
# 57.0% 완료
# 58.0% 완료
# 59.0% 완료
# 60.0% 완료
# 61.0% 완료
# 62.0% 완료
# 63.0% 완료
# 64.0% 완료
# 65.0% 완료
# 66.0% 완료
# 67.0% 완료
# 68.0% 완료
# 69.0% 완료
# 70.0% 완료
# 71.0% 완료
# 72.0% 완료
# 73.0% 완료
# 74.0% 완료
# 75.0% 완료
# 76.0% 완료
# 77.0% 완료
# 78.0% 완료
# 79.0% 완료
# 80.0% 완료
# 81.0% 완료
# 82.0% 완료
# 83.0% 완료
# 84.0% 완료
# 85.0% 완료
# 86.0% 완료
# 87.0% 완료
# 88.0% 완료
# 89.0% 완료
# 90.0% 완료
# 91.0% 완료
# 92.0% 완료
# 93.0% 완료
# 94.0% 완료
# 95.0% 완료
# 96.0% 완료
# 97.0% 완료
# 98.0% 완료
# 99.0% 완료
# calculating SVD ...
#
# [query] you
#  i: 0.6971861720085144
#  we: 0.6577469706535339
#  anybody: 0.5785029530525208
#  do: 0.5590694546699524
#  something: 0.5412172079086304
#
# [query] year
#  earlier: 0.680479109287262
#  month: 0.6613150835037231
#  quarter: 0.623519241809845
#  last: 0.6232503056526184
#  next: 0.5716107487678528
#
# [query] car
#  auto: 0.5820895433425903
#  luxury: 0.5069300532341003
#  corsica: 0.492815762758255
#  recreational: 0.4838029146194458
#  cars: 0.47470012307167053
#
# [query] toyota
#  motor: 0.7317621111869812
#  nissan: 0.6662983298301697
#  motors: 0.6388821005821228
#  mazda: 0.611629843711853
#  honda: 0.5881442427635193

# %% [markdown]
# ### 통계 기반 기법 평가

# %%
# 유추(analogy) 작업
print('-'*50)
print("통계 기반 기법 결과")
analogy('king', 'man', 'queen',  word_to_id, id_to_word, word_vecs)
analogy('take', 'took', 'go',  word_to_id, id_to_word, word_vecs)
analogy('car', 'cars', 'child',  word_to_id, id_to_word, word_vecs)
analogy('good', 'better', 'bad',  word_to_id, id_to_word, word_vecs)
analogy('dog', 'kennel', 'bird',  word_to_id, id_to_word, word_vecs)
analogy('teacher', 'school', 'doctor',  word_to_id, id_to_word, word_vecs)
analogy('ear', 'hear', 'eye',  word_to_id, id_to_word, word_vecs)
analogy('leg', 'walk', 'hand',  word_to_id, id_to_word, word_vecs)
analogy('leg', 'legs', 'hand',  word_to_id, id_to_word, word_vecs)
# Out:
# --------------------------------------------------
#
# [analogy] king:man = queen:?
#  who: 0.11196982860565186
#  she: 0.09461738169193268
#  among: 0.07201318442821503
#  ': 0.07159817218780518
#  young: 0.06765370815992355
#
# [analogy] take:took = go:?
#  says: 0.10150566697120667
#  into: 0.08729947358369827
#  mr.: 0.07824079692363739
#  went: 0.07464049011468887
#  back: 0.07279105484485626
#
# [analogy] car:cars = child:?
#  than: 0.11771439015865326
#  more: 0.11327702552080154
#  where: 0.09139949828386307
#  an: 0.09116490185260773
#  inc.: 0.08456432819366455
#
# [analogy] good:better = bad:?
#  more: 0.1075090765953064
#  than: 0.10305674374103546
#  often: 0.09605096280574799
#  whose: 0.07297506928443909
#  those: 0.06851065158843994

# %% [markdown]
# ### 추론 기반 기법

# %%
from common import config
# GPU에서 실행하려면 아래 주석을 해제하세요(CuPy 필요).
# ===============================================
# config.GPU = True
# ===============================================
import pickle
from common.trainer import Trainer
from common.optimizer import Adam
from ch04.cbow import CBOW
from common.util import create_contexts_target, to_cpu, to_gpu
from ptb import load_data

# %%
# 하이퍼파라미터 설정
window_size = 2
hidden_size = 100
batch_size = 100
max_epoch = 10

# 데이터 읽기
corpus, word_to_id, id_to_word = load_data('train')
vocab_size = len(word_to_id)

contexts, target = create_contexts_target(corpus, window_size)
if config.GPU:
    contexts, target = to_gpu(contexts), to_gpu(target)

# 모델 등 생성
model = CBOW(vocab_size, hidden_size, window_size, corpus)
optimizer = Adam()
trainer = Trainer(model, optimizer)

# 학습 시작
trainer.fit(contexts, target, max_epoch, batch_size)
trainer.plot()

# 나중에 사용할 수 있도록 필요한 데이터 저장
word_vecs = model.word_vecs
if config.GPU:
    word_vecs = to_cpu(word_vecs)
params = {}
params['word_vecs'] = word_vecs.astype(np.float16)
params['word_to_id'] = word_to_id
params['id_to_word'] = id_to_word
pkl_file = 'cbow_params.pkl'  # or 'skipgram_params.pkl'
with open(pkl_file, 'wb') as f:
    pickle.dump(params, f, -1)
# Out:
# | 에폭 1 |  반복 1 / 9295 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 21 / 9295 | 시간 1[s] | 손실 4.16
# | 에폭 1 |  반복 41 / 9295 | 시간 2[s] | 손실 4.16
# | 에폭 1 |  반복 61 / 9295 | 시간 3[s] | 손실 4.14
# | 에폭 1 |  반복 81 / 9295 | 시간 4[s] | 손실 4.10
# | 에폭 1 |  반복 101 / 9295 | 시간 6[s] | 손실 4.02
# | 에폭 1 |  반복 121 / 9295 | 시간 7[s] | 손실 3.90
# | 에폭 1 |  반복 141 / 9295 | 시간 8[s] | 손실 3.77
# | 에폭 1 |  반복 161 / 9295 | 시간 9[s] | 손실 3.63
# | 에폭 1 |  반복 181 / 9295 | 시간 10[s] | 손실 3.51
# | 에폭 1 |  반복 201 / 9295 | 시간 11[s] | 손실 3.40
# | 에폭 1 |  반복 221 / 9295 | 시간 12[s] | 손실 3.31
# | 에폭 1 |  반복 241 / 9295 | 시간 14[s] | 손실 3.22
# | 에폭 1 |  반복 261 / 9295 | 시간 15[s] | 손실 3.14
# | 에폭 1 |  반복 281 / 9295 | 시간 16[s] | 손실 3.10
# | 에폭 1 |  반복 301 / 9295 | 시간 17[s] | 손실 3.04
# | 에폭 1 |  반복 321 / 9295 | 시간 18[s] | 손실 2.98
# | 에폭 1 |  반복 341 / 9295 | 시간 20[s] | 손실 2.95
# | 에폭 1 |  반복 361 / 9295 | 시간 21[s] | 손실 2.91
# | 에폭 1 |  반복 381 / 9295 | 시간 22[s] | 손실 2.88
# | 에폭 1 |  반복 401 / 9295 | 시간 23[s] | 손실 2.85
# | 에폭 1 |  반복 421 / 9295 | 시간 25[s] | 손실 2.82
# | 에폭 1 |  반복 441 / 9295 | 시간 26[s] | 손실 2.79
# | 에폭 1 |  반복 461 / 9295 | 시간 28[s] | 손실 2.78
# | 에폭 1 |  반복 481 / 9295 | 시간 29[s] | 손실 2.77
# | 에폭 1 |  반복 501 / 9295 | 시간 31[s] | 손실 2.74
# | 에폭 1 |  반복 521 / 9295 | 시간 32[s] | 손실 2.75
# | 에폭 1 |  반복 541 / 9295 | 시간 33[s] | 손실 2.73
# | 에폭 1 |  반복 561 / 9295 | 시간 34[s] | 손실 2.73
# | 에폭 1 |  반복 581 / 9295 | 시간 35[s] | 손실 2.68
# | 에폭 1 |  반복 601 / 9295 | 시간 37[s] | 손실 2.68
# | 에폭 1 |  반복 621 / 9295 | 시간 38[s] | 손실 2.66
# | 에폭 1 |  반복 641 / 9295 | 시간 39[s] | 손실 2.66
# | 에폭 1 |  반복 661 / 9295 | 시간 40[s] | 손실 2.67
# | 에폭 1 |  반복 681 / 9295 | 시간 41[s] | 손실 2.62
# | 에폭 1 |  반복 701 / 9295 | 시간 43[s] | 손실 2.67
# | 에폭 1 |  반복 721 / 9295 | 시간 44[s] | 손실 2.63
# | 에폭 1 |  반복 741 / 9295 | 시간 45[s] | 손실 2.63
# | 에폭 1 |  반복 761 / 9295 | 시간 46[s] | 손실 2.62
# | 에폭 1 |  반복 781 / 9295 | 시간 47[s] | 손실 2.61
# | 에폭 1 |  반복 801 / 9295 | 시간 48[s] | 손실 2.60
# | 에폭 1 |  반복 821 / 9295 | 시간 49[s] | 손실 2.57
# | 에폭 1 |  반복 841 / 9295 | 시간 51[s] | 손실 2.62
# | 에폭 1 |  반복 861 / 9295 | 시간 52[s] | 손실 2.57
# | 에폭 1 |  반복 881 / 9295 | 시간 53[s] | 손실 2.57
# | 에폭 1 |  반복 901 / 9295 | 시간 54[s] | 손실 2.52
# | 에폭 1 |  반복 921 / 9295 | 시간 55[s] | 손실 2.58
# | 에폭 1 |  반복 941 / 9295 | 시간 56[s] | 손실 2.58
# | 에폭 1 |  반복 961 / 9295 | 시간 58[s] | 손실 2.59
# | 에폭 1 |  반복 981 / 9295 | 시간 59[s] | 손실 2.55
# | 에폭 1 |  반복 1001 / 9295 | 시간 60[s] | 손실 2.54
# | 에폭 1 |  반복 1021 / 9295 | 시간 62[s] | 손실 2.54
# | 에폭 1 |  반복 1041 / 9295 | 시간 63[s] | 손실 2.53
# | 에폭 1 |  반복 1061 / 9295 | 시간 64[s] | 손실 2.53
# | 에폭 1 |  반복 1081 / 9295 | 시간 65[s] | 손실 2.53
# | 에폭 1 |  반복 1101 / 9295 | 시간 66[s] | 손실 2.53
# | 에폭 1 |  반복 1121 / 9295 | 시간 67[s] | 손실 2.55
# | 에폭 1 |  반복 1141 / 9295 | 시간 68[s] | 손실 2.51
# | 에폭 1 |  반복 1161 / 9295 | 시간 69[s] | 손실 2.50
# | 에폭 1 |  반복 1181 / 9295 | 시간 71[s] | 손실 2.51
# | 에폭 1 |  반복 1201 / 9295 | 시간 72[s] | 손실 2.51
# | 에폭 1 |  반복 1221 / 9295 | 시간 73[s] | 손실 2.50
# | 에폭 1 |  반복 1241 / 9295 | 시간 74[s] | 손실 2.51
# | 에폭 1 |  반복 1261 / 9295 | 시간 75[s] | 손실 2.50
# | 에폭 1 |  반복 1281 / 9295 | 시간 76[s] | 손실 2.49
# | 에폭 1 |  반복 1301 / 9295 | 시간 77[s] | 손실 2.46
# | 에폭 1 |  반복 1321 / 9295 | 시간 79[s] | 손실 2.50
# | 에폭 1 |  반복 1341 / 9295 | 시간 80[s] | 손실 2.47
# | 에폭 1 |  반복 1361 / 9295 | 시간 81[s] | 손실 2.49
# | 에폭 1 |  반복 1381 / 9295 | 시간 82[s] | 손실 2.48
# | 에폭 1 |  반복 1401 / 9295 | 시간 83[s] | 손실 2.47
# | 에폭 1 |  반복 1421 / 9295 | 시간 84[s] | 손실 2.48
# | 에폭 1 |  반복 1441 / 9295 | 시간 85[s] | 손실 2.46
# | 에폭 1 |  반복 1461 / 9295 | 시간 86[s] | 손실 2.47
# | 에폭 1 |  반복 1481 / 9295 | 시간 88[s] | 손실 2.45
# | 에폭 1 |  반복 1501 / 9295 | 시간 89[s] | 손실 2.47
# | 에폭 1 |  반복 1521 / 9295 | 시간 90[s] | 손실 2.45
# | 에폭 1 |  반복 1541 / 9295 | 시간 91[s] | 손실 2.44
# | 에폭 1 |  반복 1561 / 9295 | 시간 92[s] | 손실 2.46
# | 에폭 1 |  반복 1581 / 9295 | 시간 93[s] | 손실 2.45
# | 에폭 1 |  반복 1601 / 9295 | 시간 94[s] | 손실 2.47
# | 에폭 1 |  반복 1621 / 9295 | 시간 95[s] | 손실 2.44
# | 에폭 1 |  반복 1641 / 9295 | 시간 97[s] | 손실 2.48
# | 에폭 1 |  반복 1661 / 9295 | 시간 98[s] | 손실 2.44
# | 에폭 1 |  반복 1681 / 9295 | 시간 99[s] | 손실 2.44
# | 에폭 1 |  반복 1701 / 9295 | 시간 100[s] | 손실 2.43
# | 에폭 1 |  반복 1721 / 9295 | 시간 101[s] | 손실 2.45
# | 에폭 1 |  반복 1741 / 9295 | 시간 102[s] | 손실 2.43
# | 에폭 1 |  반복 1761 / 9295 | 시간 103[s] | 손실 2.48
# | 에폭 1 |  반복 1781 / 9295 | 시간 105[s] | 손실 2.40
# | 에폭 1 |  반복 1801 / 9295 | 시간 106[s] | 손실 2.42
# | 에폭 1 |  반복 1821 / 9295 | 시간 107[s] | 손실 2.39
# | 에폭 1 |  반복 1841 / 9295 | 시간 108[s] | 손실 2.44
# | 에폭 1 |  반복 1861 / 9295 | 시간 109[s] | 손실 2.40
# | 에폭 1 |  반복 1881 / 9295 | 시간 110[s] | 손실 2.41
# | 에폭 1 |  반복 1901 / 9295 | 시간 112[s] | 손실 2.41
# | 에폭 1 |  반복 1921 / 9295 | 시간 113[s] | 손실 2.39
# | 에폭 1 |  반복 1941 / 9295 | 시간 114[s] | 손실 2.41
# | 에폭 1 |  반복 1961 / 9295 | 시간 115[s] | 손실 2.39
# | 에폭 1 |  반복 1981 / 9295 | 시간 116[s] | 손실 2.42
# | 에폭 1 |  반복 2001 / 9295 | 시간 117[s] | 손실 2.40
# | 에폭 1 |  반복 2021 / 9295 | 시간 118[s] | 손실 2.37
# | 에폭 1 |  반복 2041 / 9295 | 시간 119[s] | 손실 2.40
# | 에폭 1 |  반복 2061 / 9295 | 시간 120[s] | 손실 2.41
# | 에폭 1 |  반복 2081 / 9295 | 시간 121[s] | 손실 2.40
# | 에폭 1 |  반복 2101 / 9295 | 시간 122[s] | 손실 2.38
# | 에폭 1 |  반복 2121 / 9295 | 시간 123[s] | 손실 2.40
# | 에폭 1 |  반복 2141 / 9295 | 시간 125[s] | 손실 2.41
# | 에폭 1 |  반복 2161 / 9295 | 시간 126[s] | 손실 2.41
# | 에폭 1 |  반복 2181 / 9295 | 시간 127[s] | 손실 2.37
# | 에폭 1 |  반복 2201 / 9295 | 시간 128[s] | 손실 2.39
# | 에폭 1 |  반복 2221 / 9295 | 시간 129[s] | 손실 2.36
# | 에폭 1 |  반복 2241 / 9295 | 시간 130[s] | 손실 2.38
# | 에폭 1 |  반복 2261 / 9295 | 시간 131[s] | 손실 2.37
# | 에폭 1 |  반복 2281 / 9295 | 시간 132[s] | 손실 2.35
# | 에폭 1 |  반복 2301 / 9295 | 시간 133[s] | 손실 2.32
# | 에폭 1 |  반복 2321 / 9295 | 시간 134[s] | 손실 2.38
# | 에폭 1 |  반복 2341 / 9295 | 시간 135[s] | 손실 2.38
# | 에폭 1 |  반복 2361 / 9295 | 시간 136[s] | 손실 2.38
# | 에폭 1 |  반복 2381 / 9295 | 시간 137[s] | 손실 2.33
# | 에폭 1 |  반복 2401 / 9295 | 시간 139[s] | 손실 2.38
# | 에폭 1 |  반복 2421 / 9295 | 시간 140[s] | 손실 2.35
# | 에폭 1 |  반복 2441 / 9295 | 시간 141[s] | 손실 2.35
# | 에폭 1 |  반복 2461 / 9295 | 시간 142[s] | 손실 2.35
# | 에폭 1 |  반복 2481 / 9295 | 시간 143[s] | 손실 2.37
# | 에폭 1 |  반복 2501 / 9295 | 시간 144[s] | 손실 2.36
# | 에폭 1 |  반복 2521 / 9295 | 시간 145[s] | 손실 2.35
# | 에폭 1 |  반복 2541 / 9295 | 시간 146[s] | 손실 2.36
# | 에폭 1 |  반복 2561 / 9295 | 시간 147[s] | 손실 2.34
# | 에폭 1 |  반복 2581 / 9295 | 시간 148[s] | 손실 2.35
# | 에폭 1 |  반복 2601 / 9295 | 시간 149[s] | 손실 2.30
# | 에폭 1 |  반복 2621 / 9295 | 시간 150[s] | 손실 2.34
# | 에폭 1 |  반복 2641 / 9295 | 시간 151[s] | 손실 2.32
# | 에폭 1 |  반복 2661 / 9295 | 시간 152[s] | 손실 2.35
# | 에폭 1 |  반복 2681 / 9295 | 시간 153[s] | 손실 2.32
# | 에폭 1 |  반복 2701 / 9295 | 시간 155[s] | 손실 2.30
# | 에폭 1 |  반복 2721 / 9295 | 시간 156[s] | 손실 2.31
# | 에폭 1 |  반복 2741 / 9295 | 시간 157[s] | 손실 2.33
# | 에폭 1 |  반복 2761 / 9295 | 시간 158[s] | 손실 2.31
# | 에폭 1 |  반복 2781 / 9295 | 시간 159[s] | 손실 2.31
# | 에폭 1 |  반복 2801 / 9295 | 시간 160[s] | 손실 2.30
# | 에폭 1 |  반복 2821 / 9295 | 시간 161[s] | 손실 2.31
# | 에폭 1 |  반복 2841 / 9295 | 시간 162[s] | 손실 2.33
# | 에폭 1 |  반복 2861 / 9295 | 시간 163[s] | 손실 2.30
# | 에폭 1 |  반복 2881 / 9295 | 시간 164[s] | 손실 2.32
# | 에폭 1 |  반복 2901 / 9295 | 시간 165[s] | 손실 2.29
# | 에폭 1 |  반복 2921 / 9295 | 시간 167[s] | 손실 2.30
# | 에폭 1 |  반복 2941 / 9295 | 시간 168[s] | 손실 2.34
# | 에폭 1 |  반복 2961 / 9295 | 시간 169[s] | 손실 2.28
# | 에폭 1 |  반복 2981 / 9295 | 시간 170[s] | 손실 2.31
# | 에폭 1 |  반복 3001 / 9295 | 시간 171[s] | 손실 2.29
# | 에폭 1 |  반복 3021 / 9295 | 시간 172[s] | 손실 2.29
# | 에폭 1 |  반복 3041 / 9295 | 시간 173[s] | 손실 2.29
# | 에폭 1 |  반복 3061 / 9295 | 시간 174[s] | 손실 2.25
# | 에폭 1 |  반복 3081 / 9295 | 시간 175[s] | 손실 2.30
# | 에폭 1 |  반복 3101 / 9295 | 시간 176[s] | 손실 2.26
# | 에폭 1 |  반복 3121 / 9295 | 시간 177[s] | 손실 2.26
# | 에폭 1 |  반복 3141 / 9295 | 시간 178[s] | 손실 2.28
# | 에폭 1 |  반복 3161 / 9295 | 시간 180[s] | 손실 2.27
# | 에폭 1 |  반복 3181 / 9295 | 시간 181[s] | 손실 2.28
# | 에폭 1 |  반복 3201 / 9295 | 시간 182[s] | 손실 2.26
# | 에폭 1 |  반복 3221 / 9295 | 시간 183[s] | 손실 2.24
# | 에폭 1 |  반복 3241 / 9295 | 시간 184[s] | 손실 2.26
# | 에폭 1 |  반복 3261 / 9295 | 시간 186[s] | 손실 2.26
# | 에폭 1 |  반복 3281 / 9295 | 시간 187[s] | 손실 2.25
# | 에폭 1 |  반복 3301 / 9295 | 시간 188[s] | 손실 2.26
# | 에폭 1 |  반복 3321 / 9295 | 시간 189[s] | 손실 2.26
# | 에폭 1 |  반복 3341 / 9295 | 시간 190[s] | 손실 2.26
# | 에폭 1 |  반복 3361 / 9295 | 시간 192[s] | 손실 2.29
# | 에폭 1 |  반복 3381 / 9295 | 시간 193[s] | 손실 2.28
# | 에폭 1 |  반복 3401 / 9295 | 시간 194[s] | 손실 2.26
# | 에폭 1 |  반복 3421 / 9295 | 시간 196[s] | 손실 2.25
# | 에폭 1 |  반복 3441 / 9295 | 시간 197[s] | 손실 2.27
# | 에폭 1 |  반복 3461 / 9295 | 시간 198[s] | 손실 2.24
# | 에폭 1 |  반복 3481 / 9295 | 시간 199[s] | 손실 2.26
# | 에폭 1 |  반복 3501 / 9295 | 시간 200[s] | 손실 2.23
# | 에폭 1 |  반복 3521 / 9295 | 시간 201[s] | 손실 2.24
# | 에폭 1 |  반복 3541 / 9295 | 시간 202[s] | 손실 2.25
# | 에폭 1 |  반복 3561 / 9295 | 시간 204[s] | 손실 2.23
# | 에폭 1 |  반복 3581 / 9295 | 시간 205[s] | 손실 2.20
# | 에폭 1 |  반복 3601 / 9295 | 시간 206[s] | 손실 2.23
# | 에폭 1 |  반복 3621 / 9295 | 시간 207[s] | 손실 2.24
# | 에폭 1 |  반복 3641 / 9295 | 시간 208[s] | 손실 2.23
# | 에폭 1 |  반복 3661 / 9295 | 시간 210[s] | 손실 2.21
# | 에폭 1 |  반복 3681 / 9295 | 시간 211[s] | 손실 2.22
# | 에폭 1 |  반복 3701 / 9295 | 시간 212[s] | 손실 2.20
# | 에폭 1 |  반복 3721 / 9295 | 시간 213[s] | 손실 2.24
# | 에폭 1 |  반복 3741 / 9295 | 시간 214[s] | 손실 2.24
# | 에폭 1 |  반복 3761 / 9295 | 시간 215[s] | 손실 2.23
# | 에폭 1 |  반복 3781 / 9295 | 시간 216[s] | 손실 2.24
# | 에폭 1 |  반복 3801 / 9295 | 시간 218[s] | 손실 2.22
# | 에폭 1 |  반복 3821 / 9295 | 시간 219[s] | 손실 2.23
# | 에폭 1 |  반복 3841 / 9295 | 시간 220[s] | 손실 2.21
# | 에폭 1 |  반복 3861 / 9295 | 시간 221[s] | 손실 2.20
# | 에폭 1 |  반복 3881 / 9295 | 시간 222[s] | 손실 2.20
# | 에폭 1 |  반복 3901 / 9295 | 시간 223[s] | 손실 2.21
# | 에폭 1 |  반복 3921 / 9295 | 시간 225[s] | 손실 2.19
# | 에폭 1 |  반복 3941 / 9295 | 시간 226[s] | 손실 2.20
# | 에폭 1 |  반복 3961 / 9295 | 시간 227[s] | 손실 2.21
# | 에폭 1 |  반복 3981 / 9295 | 시간 228[s] | 손실 2.22
# | 에폭 1 |  반복 4001 / 9295 | 시간 229[s] | 손실 2.21
# | 에폭 1 |  반복 4021 / 9295 | 시간 230[s] | 손실 2.21
# | 에폭 1 |  반복 4041 / 9295 | 시간 231[s] | 손실 2.19
# | 에폭 1 |  반복 4061 / 9295 | 시간 232[s] | 손실 2.17
# | 에폭 1 |  반복 4081 / 9295 | 시간 233[s] | 손실 2.21
# | 에폭 1 |  반복 4101 / 9295 | 시간 234[s] | 손실 2.18
# | 에폭 1 |  반복 4121 / 9295 | 시간 236[s] | 손실 2.20
# | 에폭 1 |  반복 4141 / 9295 | 시간 237[s] | 손실 2.19
# | 에폭 1 |  반복 4161 / 9295 | 시간 238[s] | 손실 2.22
# | 에폭 1 |  반복 4181 / 9295 | 시간 239[s] | 손실 2.20
# | 에폭 1 |  반복 4201 / 9295 | 시간 240[s] | 손실 2.15
# | 에폭 1 |  반복 4221 / 9295 | 시간 241[s] | 손실 2.16
# | 에폭 1 |  반복 4241 / 9295 | 시간 242[s] | 손실 2.20
# | 에폭 1 |  반복 4261 / 9295 | 시간 243[s] | 손실 2.18
# | 에폭 1 |  반복 4281 / 9295 | 시간 245[s] | 손실 2.17
# | 에폭 1 |  반복 4301 / 9295 | 시간 246[s] | 손실 2.21
# | 에폭 1 |  반복 4321 / 9295 | 시간 247[s] | 손실 2.19
# | 에폭 1 |  반복 4341 / 9295 | 시간 248[s] | 손실 2.13
# | 에폭 1 |  반복 4361 / 9295 | 시간 249[s] | 손실 2.21
# | 에폭 1 |  반복 4381 / 9295 | 시간 250[s] | 손실 2.14
# | 에폭 1 |  반복 4401 / 9295 | 시간 252[s] | 손실 2.15
# | 에폭 1 |  반복 4421 / 9295 | 시간 253[s] | 손실 2.18
# | 에폭 1 |  반복 4441 / 9295 | 시간 254[s] | 손실 2.16
# | 에폭 1 |  반복 4461 / 9295 | 시간 255[s] | 손실 2.19
# | 에폭 1 |  반복 4481 / 9295 | 시간 256[s] | 손실 2.16
# | 에폭 1 |  반복 4501 / 9295 | 시간 258[s] | 손실 2.15
# | 에폭 1 |  반복 4521 / 9295 | 시간 259[s] | 손실 2.17
# | 에폭 1 |  반복 4541 / 9295 | 시간 260[s] | 손실 2.16
# | 에폭 1 |  반복 4561 / 9295 | 시간 262[s] | 손실 2.14
# | 에폭 1 |  반복 4581 / 9295 | 시간 263[s] | 손실 2.16
# | 에폭 1 |  반복 4601 / 9295 | 시간 264[s] | 손실 2.16
# | 에폭 1 |  반복 4621 / 9295 | 시간 265[s] | 손실 2.15
# | 에폭 1 |  반복 4641 / 9295 | 시간 266[s] | 손실 2.16
# | 에폭 1 |  반복 4661 / 9295 | 시간 267[s] | 손실 2.13
# | 에폭 1 |  반복 4681 / 9295 | 시간 268[s] | 손실 2.16
# | 에폭 1 |  반복 4701 / 9295 | 시간 270[s] | 손실 2.13
# | 에폭 1 |  반복 4721 / 9295 | 시간 271[s] | 손실 2.12
# | 에폭 1 |  반복 4741 / 9295 | 시간 272[s] | 손실 2.15
# | 에폭 1 |  반복 4761 / 9295 | 시간 273[s] | 손실 2.14
# | 에폭 1 |  반복 4781 / 9295 | 시간 274[s] | 손실 2.18
# | 에폭 1 |  반복 4801 / 9295 | 시간 275[s] | 손실 2.13
# | 에폭 1 |  반복 4821 / 9295 | 시간 276[s] | 손실 2.18
# | 에폭 1 |  반복 4841 / 9295 | 시간 278[s] | 손실 2.13
# | 에폭 1 |  반복 4861 / 9295 | 시간 279[s] | 손실 2.17
# | 에폭 1 |  반복 4881 / 9295 | 시간 280[s] | 손실 2.15
# | 에폭 1 |  반복 4901 / 9295 | 시간 281[s] | 손실 2.12
# | 에폭 1 |  반복 4921 / 9295 | 시간 282[s] | 손실 2.14
# | 에폭 1 |  반복 4941 / 9295 | 시간 283[s] | 손실 2.11
# | 에폭 1 |  반복 4961 / 9295 | 시간 284[s] | 손실 2.14
# | 에폭 1 |  반복 4981 / 9295 | 시간 285[s] | 손실 2.16
# | 에폭 1 |  반복 5001 / 9295 | 시간 287[s] | 손실 2.12
# | 에폭 1 |  반복 5021 / 9295 | 시간 288[s] | 손실 2.13
# | 에폭 1 |  반복 5041 / 9295 | 시간 289[s] | 손실 2.11
# | 에폭 1 |  반복 5061 / 9295 | 시간 290[s] | 손실 2.12
# | 에폭 1 |  반복 5081 / 9295 | 시간 291[s] | 손실 2.11
# | 에폭 1 |  반복 5101 / 9295 | 시간 292[s] | 손실 2.10
# | 에폭 1 |  반복 5121 / 9295 | 시간 294[s] | 손실 2.12
# | 에폭 1 |  반복 5141 / 9295 | 시간 295[s] | 손실 2.17
# | 에폭 1 |  반복 5161 / 9295 | 시간 296[s] | 손실 2.11
# | 에폭 1 |  반복 5181 / 9295 | 시간 297[s] | 손실 2.14
# | 에폭 1 |  반복 5201 / 9295 | 시간 298[s] | 손실 2.15
# | 에폭 1 |  반복 5221 / 9295 | 시간 299[s] | 손실 2.11
# | 에폭 1 |  반복 5241 / 9295 | 시간 300[s] | 손실 2.10
# | 에폭 1 |  반복 5261 / 9295 | 시간 302[s] | 손실 2.16
# | 에폭 1 |  반복 5281 / 9295 | 시간 303[s] | 손실 2.14
# | 에폭 1 |  반복 5301 / 9295 | 시간 304[s] | 손실 2.15
# | 에폭 1 |  반복 5321 / 9295 | 시간 305[s] | 손실 2.14
# | 에폭 1 |  반복 5341 / 9295 | 시간 306[s] | 손실 2.12
# | 에폭 1 |  반복 5361 / 9295 | 시간 307[s] | 손실 2.08
# | 에폭 1 |  반복 5381 / 9295 | 시간 309[s] | 손실 2.13
# | 에폭 1 |  반복 5401 / 9295 | 시간 310[s] | 손실 2.12
# | 에폭 1 |  반복 5421 / 9295 | 시간 311[s] | 손실 2.13
# | 에폭 1 |  반복 5441 / 9295 | 시간 312[s] | 손실 2.13
# | 에폭 1 |  반복 5461 / 9295 | 시간 313[s] | 손실 2.12
# | 에폭 1 |  반복 5481 / 9295 | 시간 314[s] | 손실 2.12
# | 에폭 1 |  반복 5501 / 9295 | 시간 315[s] | 손실 2.11
# | 에폭 1 |  반복 5521 / 9295 | 시간 317[s] | 손실 2.07
# | 에폭 1 |  반복 5541 / 9295 | 시간 318[s] | 손실 2.09
# | 에폭 1 |  반복 5561 / 9295 | 시간 319[s] | 손실 2.08
# | 에폭 1 |  반복 5581 / 9295 | 시간 320[s] | 손실 2.09
# | 에폭 1 |  반복 5601 / 9295 | 시간 321[s] | 손실 2.12
# | 에폭 1 |  반복 5621 / 9295 | 시간 322[s] | 손실 2.10
# | 에폭 1 |  반복 5641 / 9295 | 시간 324[s] | 손실 2.10
# | 에폭 1 |  반복 5661 / 9295 | 시간 325[s] | 손실 2.10
# | 에폭 1 |  반복 5681 / 9295 | 시간 326[s] | 손실 2.11
# | 에폭 1 |  반복 5701 / 9295 | 시간 328[s] | 손실 2.08
# | 에폭 1 |  반복 5721 / 9295 | 시간 329[s] | 손실 2.09
# | 에폭 1 |  반복 5741 / 9295 | 시간 330[s] | 손실 2.11
# | 에폭 1 |  반복 5761 / 9295 | 시간 332[s] | 손실 2.08
# | 에폭 1 |  반복 5781 / 9295 | 시간 333[s] | 손실 2.08
# | 에폭 1 |  반복 5801 / 9295 | 시간 334[s] | 손실 2.08
# | 에폭 1 |  반복 5821 / 9295 | 시간 335[s] | 손실 2.08
# | 에폭 1 |  반복 5841 / 9295 | 시간 337[s] | 손실 2.08
# | 에폭 1 |  반복 5861 / 9295 | 시간 338[s] | 손실 2.03
# | 에폭 1 |  반복 5881 / 9295 | 시간 339[s] | 손실 2.08
# | 에폭 1 |  반복 5901 / 9295 | 시간 340[s] | 손실 2.08
# | 에폭 1 |  반복 5921 / 9295 | 시간 341[s] | 손실 2.09
# | 에폭 1 |  반복 5941 / 9295 | 시간 343[s] | 손실 2.07
# | 에폭 1 |  반복 5961 / 9295 | 시간 344[s] | 손실 2.08
# | 에폭 1 |  반복 5981 / 9295 | 시간 345[s] | 손실 2.10
# | 에폭 1 |  반복 6001 / 9295 | 시간 346[s] | 손실 2.10
# | 에폭 1 |  반복 6021 / 9295 | 시간 347[s] | 손실 2.08
# | 에폭 1 |  반복 6041 / 9295 | 시간 348[s] | 손실 2.10
# | 에폭 1 |  반복 6061 / 9295 | 시간 349[s] | 손실 2.04
# | 에폭 1 |  반복 6081 / 9295 | 시간 351[s] | 손실 2.06
# | 에폭 1 |  반복 6101 / 9295 | 시간 352[s] | 손실 2.06
# | 에폭 1 |  반복 6121 / 9295 | 시간 353[s] | 손실 2.10
# | 에폭 1 |  반복 6141 / 9295 | 시간 354[s] | 손실 2.05
# | 에폭 1 |  반복 6161 / 9295 | 시간 355[s] | 손실 2.09
# | 에폭 1 |  반복 6181 / 9295 | 시간 356[s] | 손실 2.11
# | 에폭 1 |  반복 6201 / 9295 | 시간 357[s] | 손실 2.05
# | 에폭 1 |  반복 6221 / 9295 | 시간 358[s] | 손실 2.08
# | 에폭 1 |  반복 6241 / 9295 | 시간 359[s] | 손실 2.11
# | 에폭 1 |  반복 6261 / 9295 | 시간 361[s] | 손실 2.09
# | 에폭 1 |  반복 6281 / 9295 | 시간 362[s] | 손실 2.08
# | 에폭 1 |  반복 6301 / 9295 | 시간 363[s] | 손실 2.12
# | 에폭 1 |  반복 6321 / 9295 | 시간 364[s] | 손실 2.10
# | 에폭 1 |  반복 6341 / 9295 | 시간 365[s] | 손실 2.06
# | 에폭 1 |  반복 6361 / 9295 | 시간 366[s] | 손실 2.07
# | 에폭 1 |  반복 6381 / 9295 | 시간 367[s] | 손실 2.09
# | 에폭 1 |  반복 6401 / 9295 | 시간 368[s] | 손실 2.06
# | 에폭 1 |  반복 6421 / 9295 | 시간 369[s] | 손실 2.09
# | 에폭 1 |  반복 6441 / 9295 | 시간 371[s] | 손실 2.08
# | 에폭 1 |  반복 6461 / 9295 | 시간 372[s] | 손실 2.04
# | 에폭 1 |  반복 6481 / 9295 | 시간 373[s] | 손실 2.05
# | 에폭 1 |  반복 6501 / 9295 | 시간 374[s] | 손실 2.07
# | 에폭 1 |  반복 6521 / 9295 | 시간 375[s] | 손실 2.09
# | 에폭 1 |  반복 6541 / 9295 | 시간 376[s] | 손실 2.07
# | 에폭 1 |  반복 6561 / 9295 | 시간 377[s] | 손실 2.09
# | 에폭 1 |  반복 6581 / 9295 | 시간 378[s] | 손실 2.05
# | 에폭 1 |  반복 6601 / 9295 | 시간 379[s] | 손실 2.05
# | 에폭 1 |  반복 6621 / 9295 | 시간 381[s] | 손실 2.06
# | 에폭 1 |  반복 6641 / 9295 | 시간 382[s] | 손실 2.05
# | 에폭 1 |  반복 6661 / 9295 | 시간 383[s] | 손실 2.02
# | 에폭 1 |  반복 6681 / 9295 | 시간 384[s] | 손실 2.05
# | 에폭 1 |  반복 6701 / 9295 | 시간 385[s] | 손실 2.04
# | 에폭 1 |  반복 6721 / 9295 | 시간 386[s] | 손실 2.09
# | 에폭 1 |  반복 6741 / 9295 | 시간 387[s] | 손실 2.06
# | 에폭 1 |  반복 6761 / 9295 | 시간 388[s] | 손실 2.00
# | 에폭 1 |  반복 6781 / 9295 | 시간 389[s] | 손실 2.06
# | 에폭 1 |  반복 6801 / 9295 | 시간 391[s] | 손실 2.05
# | 에폭 1 |  반복 6821 / 9295 | 시간 392[s] | 손실 2.04
# | 에폭 1 |  반복 6841 / 9295 | 시간 393[s] | 손실 2.09
# | 에폭 1 |  반복 6861 / 9295 | 시간 394[s] | 손실 2.05
# | 에폭 1 |  반복 6881 / 9295 | 시간 395[s] | 손실 2.07
# | 에폭 1 |  반복 6901 / 9295 | 시간 396[s] | 손실 2.01
# | 에폭 1 |  반복 6921 / 9295 | 시간 397[s] | 손실 2.06
# | 에폭 1 |  반복 6941 / 9295 | 시간 398[s] | 손실 2.08
# | 에폭 1 |  반복 6961 / 9295 | 시간 399[s] | 손실 2.05
# | 에폭 1 |  반복 6981 / 9295 | 시간 400[s] | 손실 2.00
# | 에폭 1 |  반복 7001 / 9295 | 시간 402[s] | 손실 2.09
# | 에폭 1 |  반복 7021 / 9295 | 시간 403[s] | 손실 2.01
# | 에폭 1 |  반복 7041 / 9295 | 시간 404[s] | 손실 2.06
# | 에폭 1 |  반복 7061 / 9295 | 시간 405[s] | 손실 2.07
# | 에폭 1 |  반복 7081 / 9295 | 시간 406[s] | 손실 2.09
# | 에폭 1 |  반복 7101 / 9295 | 시간 407[s] | 손실 2.05
# | 에폭 1 |  반복 7121 / 9295 | 시간 408[s] | 손실 2.00
# | 에폭 1 |  반복 7141 / 9295 | 시간 409[s] | 손실 2.00
# | 에폭 1 |  반복 7161 / 9295 | 시간 411[s] | 손실 2.04
# | 에폭 1 |  반복 7181 / 9295 | 시간 412[s] | 손실 2.03
# | 에폭 1 |  반복 7201 / 9295 | 시간 413[s] | 손실 2.03
# | 에폭 1 |  반복 7221 / 9295 | 시간 414[s] | 손실 2.06
# | 에폭 1 |  반복 7241 / 9295 | 시간 415[s] | 손실 2.02
# | 에폭 1 |  반복 7261 / 9295 | 시간 416[s] | 손실 2.00
# | 에폭 1 |  반복 7281 / 9295 | 시간 417[s] | 손실 2.01
# | 에폭 1 |  반복 7301 / 9295 | 시간 418[s] | 손실 2.04
# | 에폭 1 |  반복 7321 / 9295 | 시간 420[s] | 손실 2.01
# | 에폭 1 |  반복 7341 / 9295 | 시간 421[s] | 손실 2.02
# | 에폭 1 |  반복 7361 / 9295 | 시간 422[s] | 손실 2.04
# | 에폭 1 |  반복 7381 / 9295 | 시간 423[s] | 손실 2.04
# | 에폭 1 |  반복 7401 / 9295 | 시간 424[s] | 손실 2.03
# | 에폭 1 |  반복 7421 / 9295 | 시간 425[s] | 손실 2.02
# | 에폭 1 |  반복 7441 / 9295 | 시간 426[s] | 손실 2.04
# | 에폭 1 |  반복 7461 / 9295 | 시간 428[s] | 손실 2.05
# | 에폭 1 |  반복 7481 / 9295 | 시간 429[s] | 손실 2.02
# | 에폭 1 |  반복 7501 / 9295 | 시간 430[s] | 손실 1.97
# | 에폭 1 |  반복 7521 / 9295 | 시간 431[s] | 손실 2.04
# | 에폭 1 |  반복 7541 / 9295 | 시간 432[s] | 손실 2.02
# | 에폭 1 |  반복 7561 / 9295 | 시간 433[s] | 손실 2.04
# | 에폭 1 |  반복 7581 / 9295 | 시간 434[s] | 손실 2.03
# | 에폭 1 |  반복 7601 / 9295 | 시간 435[s] | 손실 1.97
# | 에폭 1 |  반복 7621 / 9295 | 시간 437[s] | 손실 2.03
# | 에폭 1 |  반복 7641 / 9295 | 시간 438[s] | 손실 2.03
# | 에폭 1 |  반복 7661 / 9295 | 시간 439[s] | 손실 2.02
# | 에폭 1 |  반복 7681 / 9295 | 시간 440[s] | 손실 2.02
# | 에폭 1 |  반복 7701 / 9295 | 시간 441[s] | 손실 2.04
# | 에폭 1 |  반복 7721 / 9295 | 시간 442[s] | 손실 1.99
# | 에폭 1 |  반복 7741 / 9295 | 시간 443[s] | 손실 2.04
# | 에폭 1 |  반복 7761 / 9295 | 시간 444[s] | 손실 2.02
# | 에폭 1 |  반복 7781 / 9295 | 시간 446[s] | 손실 1.98
# | 에폭 1 |  반복 7801 / 9295 | 시간 447[s] | 손실 2.00
# | 에폭 1 |  반복 7821 / 9295 | 시간 448[s] | 손실 1.98
# | 에폭 1 |  반복 7841 / 9295 | 시간 449[s] | 손실 2.02
# | 에폭 1 |  반복 7861 / 9295 | 시간 450[s] | 손실 2.02
# | 에폭 1 |  반복 7881 / 9295 | 시간 451[s] | 손실 2.01
# | 에폭 1 |  반복 7901 / 9295 | 시간 452[s] | 손실 2.02
# | 에폭 1 |  반복 7921 / 9295 | 시간 453[s] | 손실 2.00
# | 에폭 1 |  반복 7941 / 9295 | 시간 455[s] | 손실 1.99
# | 에폭 1 |  반복 7961 / 9295 | 시간 456[s] | 손실 2.01
# | 에폭 1 |  반복 7981 / 9295 | 시간 457[s] | 손실 1.99
# | 에폭 1 |  반복 8001 / 9295 | 시간 458[s] | 손실 2.01
# | 에폭 1 |  반복 8021 / 9295 | 시간 459[s] | 손실 2.01
# | 에폭 1 |  반복 8041 / 9295 | 시간 460[s] | 손실 2.05
# | 에폭 1 |  반복 8061 / 9295 | 시간 461[s] | 손실 2.06
# | 에폭 1 |  반복 8081 / 9295 | 시간 463[s] | 손실 2.02
# | 에폭 1 |  반복 8101 / 9295 | 시간 464[s] | 손실 1.98
# | 에폭 1 |  반복 8121 / 9295 | 시간 465[s] | 손실 2.01
# | 에폭 1 |  반복 8141 / 9295 | 시간 466[s] | 손실 2.02
# | 에폭 1 |  반복 8161 / 9295 | 시간 467[s] | 손실 2.01
# | 에폭 1 |  반복 8181 / 9295 | 시간 469[s] | 손실 2.02
# | 에폭 1 |  반복 8201 / 9295 | 시간 470[s] | 손실 2.02
# | 에폭 1 |  반복 8221 / 9295 | 시간 471[s] | 손실 2.02
# | 에폭 1 |  반복 8241 / 9295 | 시간 472[s] | 손실 1.97
# | 에폭 1 |  반복 8261 / 9295 | 시간 473[s] | 손실 2.02
# | 에폭 1 |  반복 8281 / 9295 | 시간 474[s] | 손실 2.02
# | 에폭 1 |  반복 8301 / 9295 | 시간 476[s] | 손실 2.01
# | 에폭 1 |  반복 8321 / 9295 | 시간 477[s] | 손실 2.00
# | 에폭 1 |  반복 8341 / 9295 | 시간 478[s] | 손실 1.98
# | 에폭 1 |  반복 8361 / 9295 | 시간 480[s] | 손실 2.02
# | 에폭 1 |  반복 8381 / 9295 | 시간 481[s] | 손실 2.03
# | 에폭 1 |  반복 8401 / 9295 | 시간 482[s] | 손실 2.01
# | 에폭 1 |  반복 8421 / 9295 | 시간 483[s] | 손실 2.01
# | 에폭 1 |  반복 8441 / 9295 | 시간 485[s] | 손실 2.01
# | 에폭 1 |  반복 8461 / 9295 | 시간 486[s] | 손실 1.96
# | 에폭 1 |  반복 8481 / 9295 | 시간 487[s] | 손실 2.02
# | 에폭 1 |  반복 8501 / 9295 | 시간 489[s] | 손실 1.99
# | 에폭 1 |  반복 8521 / 9295 | 시간 490[s] | 손실 1.98
# | 에폭 1 |  반복 8541 / 9295 | 시간 491[s] | 손실 1.98
# | 에폭 1 |  반복 8561 / 9295 | 시간 492[s] | 손실 2.00
# | 에폭 1 |  반복 8581 / 9295 | 시간 494[s] | 손실 1.98
# | 에폭 1 |  반복 8601 / 9295 | 시간 495[s] | 손실 2.00
# | 에폭 1 |  반복 8621 / 9295 | 시간 496[s] | 손실 2.00
# | 에폭 1 |  반복 8641 / 9295 | 시간 497[s] | 손실 1.99
# | 에폭 1 |  반복 8661 / 9295 | 시간 499[s] | 손실 1.95
# | 에폭 1 |  반복 8681 / 9295 | 시간 500[s] | 손실 1.97
# | 에폭 1 |  반복 8701 / 9295 | 시간 501[s] | 손실 1.99
# | 에폭 1 |  반복 8721 / 9295 | 시간 503[s] | 손실 1.99
# | 에폭 1 |  반복 8741 / 9295 | 시간 504[s] | 손실 1.99
# | 에폭 1 |  반복 8761 / 9295 | 시간 505[s] | 손실 2.00
# | 에폭 1 |  반복 8781 / 9295 | 시간 506[s] | 손실 1.99
# | 에폭 1 |  반복 8801 / 9295 | 시간 508[s] | 손실 1.97
# | 에폭 1 |  반복 8821 / 9295 | 시간 509[s] | 손실 1.99
# | 에폭 1 |  반복 8841 / 9295 | 시간 510[s] | 손실 1.98
# | 에폭 1 |  반복 8861 / 9295 | 시간 511[s] | 손실 1.98
# | 에폭 1 |  반복 8881 / 9295 | 시간 513[s] | 손실 2.00
# | 에폭 1 |  반복 8901 / 9295 | 시간 514[s] | 손실 2.03
# | 에폭 1 |  반복 8921 / 9295 | 시간 515[s] | 손실 2.01
# | 에폭 1 |  반복 8941 / 9295 | 시간 516[s] | 손실 1.98
# | 에폭 1 |  반복 8961 / 9295 | 시간 517[s] | 손실 1.98
# | 에폭 1 |  반복 8981 / 9295 | 시간 518[s] | 손실 1.95
# | 에폭 1 |  반복 9001 / 9295 | 시간 520[s] | 손실 1.99
# | 에폭 1 |  반복 9021 / 9295 | 시간 521[s] | 손실 2.01
# | 에폭 1 |  반복 9041 / 9295 | 시간 522[s] | 손실 1.99
# | 에폭 1 |  반복 9061 / 9295 | 시간 523[s] | 손실 1.96
# | 에폭 1 |  반복 9081 / 9295 | 시간 524[s] | 손실 1.98
# | 에폭 1 |  반복 9101 / 9295 | 시간 525[s] | 손실 1.98
# | 에폭 1 |  반복 9121 / 9295 | 시간 527[s] | 손실 1.99
# | 에폭 1 |  반복 9141 / 9295 | 시간 528[s] | 손실 1.99
# | 에폭 1 |  반복 9161 / 9295 | 시간 529[s] | 손실 1.98
# | 에폭 1 |  반복 9181 / 9295 | 시간 530[s] | 손실 1.95
# | 에폭 1 |  반복 9201 / 9295 | 시간 531[s] | 손실 1.97
# | 에폭 1 |  반복 9221 / 9295 | 시간 532[s] | 손실 1.94
# | 에폭 1 |  반복 9241 / 9295 | 시간 533[s] | 손실 1.97
# | 에폭 1 |  반복 9261 / 9295 | 시간 534[s] | 손실 1.95
# | 에폭 1 |  반복 9281 / 9295 | 시간 535[s] | 손실 1.94
# | 에폭 2 |  반복 1 / 9295 | 시간 536[s] | 손실 1.99
# | 에폭 2 |  반복 21 / 9295 | 시간 537[s] | 손실 1.91
# | 에폭 2 |  반복 41 / 9295 | 시간 538[s] | 손실 1.93
# | 에폭 2 |  반복 61 / 9295 | 시간 539[s] | 손실 1.90
# | 에폭 2 |  반복 81 / 9295 | 시간 540[s] | 손실 1.89
# | 에폭 2 |  반복 101 / 9295 | 시간 541[s] | 손실 1.91
# | 에폭 2 |  반복 121 / 9295 | 시간 542[s] | 손실 1.96
# | 에폭 2 |  반복 141 / 9295 | 시간 543[s] | 손실 1.92
# | 에폭 2 |  반복 161 / 9295 | 시간 544[s] | 손실 1.89
# | 에폭 2 |  반복 181 / 9295 | 시간 545[s] | 손실 1.92
# | 에폭 2 |  반복 201 / 9295 | 시간 546[s] | 손실 1.90
# | 에폭 2 |  반복 221 / 9295 | 시간 547[s] | 손실 1.92
# | 에폭 2 |  반복 241 / 9295 | 시간 547[s] | 손실 1.94
# | 에폭 2 |  반복 261 / 9295 | 시간 548[s] | 손실 1.91
# | 에폭 2 |  반복 281 / 9295 | 시간 549[s] | 손실 1.91
# | 에폭 2 |  반복 301 / 9295 | 시간 550[s] | 손실 1.94
# | 에폭 2 |  반복 321 / 9295 | 시간 551[s] | 손실 1.90
# | 에폭 2 |  반복 341 / 9295 | 시간 552[s] | 손실 1.93
# | 에폭 2 |  반복 361 / 9295 | 시간 553[s] | 손실 1.90
# | 에폭 2 |  반복 381 / 9295 | 시간 554[s] | 손실 1.87
# | 에폭 2 |  반복 401 / 9295 | 시간 555[s] | 손실 1.90
# | 에폭 2 |  반복 421 / 9295 | 시간 556[s] | 손실 1.91
# | 에폭 2 |  반복 441 / 9295 | 시간 557[s] | 손실 1.87
# | 에폭 2 |  반복 461 / 9295 | 시간 558[s] | 손실 1.92
# | 에폭 2 |  반복 481 / 9295 | 시간 559[s] | 손실 1.90
# | 에폭 2 |  반복 501 / 9295 | 시간 560[s] | 손실 1.93
# | 에폭 2 |  반복 521 / 9295 | 시간 561[s] | 손실 1.92
# | 에폭 2 |  반복 541 / 9295 | 시간 562[s] | 손실 1.90
# | 에폭 2 |  반복 561 / 9295 | 시간 563[s] | 손실 1.90
# | 에폭 2 |  반복 581 / 9295 | 시간 564[s] | 손실 1.93
# | 에폭 2 |  반복 601 / 9295 | 시간 564[s] | 손실 1.89
# | 에폭 2 |  반복 621 / 9295 | 시간 565[s] | 손실 1.93
# | 에폭 2 |  반복 641 / 9295 | 시간 566[s] | 손실 1.87
# | 에폭 2 |  반복 661 / 9295 | 시간 567[s] | 손실 1.94
# | 에폭 2 |  반복 681 / 9295 | 시간 568[s] | 손실 1.88
# | 에폭 2 |  반복 701 / 9295 | 시간 569[s] | 손실 1.88
# | 에폭 2 |  반복 721 / 9295 | 시간 570[s] | 손실 1.86
# | 에폭 2 |  반복 741 / 9295 | 시간 571[s] | 손실 1.88
# | 에폭 2 |  반복 761 / 9295 | 시간 572[s] | 손실 1.88
# | 에폭 2 |  반복 781 / 9295 | 시간 573[s] | 손실 1.91
# | 에폭 2 |  반복 801 / 9295 | 시간 574[s] | 손실 1.90
# | 에폭 2 |  반복 821 / 9295 | 시간 575[s] | 손실 1.90
# | 에폭 2 |  반복 841 / 9295 | 시간 576[s] | 손실 1.88
# | 에폭 2 |  반복 861 / 9295 | 시간 576[s] | 손실 1.89
# | 에폭 2 |  반복 881 / 9295 | 시간 577[s] | 손실 1.88
# | 에폭 2 |  반복 901 / 9295 | 시간 578[s] | 손실 1.88
# | 에폭 2 |  반복 921 / 9295 | 시간 579[s] | 손실 1.91
# | 에폭 2 |  반복 941 / 9295 | 시간 580[s] | 손실 1.88
# | 에폭 2 |  반복 961 / 9295 | 시간 581[s] | 손실 1.87
# | 에폭 2 |  반복 981 / 9295 | 시간 582[s] | 손실 1.90
# | 에폭 2 |  반복 1001 / 9295 | 시간 583[s] | 손실 1.88
# | 에폭 2 |  반복 1021 / 9295 | 시간 584[s] | 손실 1.87
# | 에폭 2 |  반복 1041 / 9295 | 시간 585[s] | 손실 1.92
# | 에폭 2 |  반복 1061 / 9295 | 시간 586[s] | 손실 1.92
# | 에폭 2 |  반복 1081 / 9295 | 시간 587[s] | 손실 1.89
# | 에폭 2 |  반복 1101 / 9295 | 시간 588[s] | 손실 1.88
# | 에폭 2 |  반복 1121 / 9295 | 시간 589[s] | 손실 1.92
# | 에폭 2 |  반복 1141 / 9295 | 시간 590[s] | 손실 1.85
# | 에폭 2 |  반복 1161 / 9295 | 시간 591[s] | 손실 1.92
# | 에폭 2 |  반복 1181 / 9295 | 시간 593[s] | 손실 1.89
# | 에폭 2 |  반복 1201 / 9295 | 시간 594[s] | 손실 1.90
# | 에폭 2 |  반복 1221 / 9295 | 시간 595[s] | 손실 1.84
# | 에폭 2 |  반복 1241 / 9295 | 시간 596[s] | 손실 1.89
# | 에폭 2 |  반복 1261 / 9295 | 시간 597[s] | 손실 1.89
# | 에폭 2 |  반복 1281 / 9295 | 시간 598[s] | 손실 1.90
# | 에폭 2 |  반복 1301 / 9295 | 시간 599[s] | 손실 1.86
# | 에폭 2 |  반복 1321 / 9295 | 시간 599[s] | 손실 1.91
# | 에폭 2 |  반복 1341 / 9295 | 시간 600[s] | 손실 1.88
# | 에폭 2 |  반복 1361 / 9295 | 시간 601[s] | 손실 1.88
# | 에폭 2 |  반복 1381 / 9295 | 시간 602[s] | 손실 1.90
# | 에폭 2 |  반복 1401 / 9295 | 시간 603[s] | 손실 1.91
# | 에폭 2 |  반복 1421 / 9295 | 시간 604[s] | 손실 1.87
# | 에폭 2 |  반복 1441 / 9295 | 시간 605[s] | 손실 1.91
# | 에폭 2 |  반복 1461 / 9295 | 시간 606[s] | 손실 1.90
# | 에폭 2 |  반복 1481 / 9295 | 시간 607[s] | 손실 1.88
# | 에폭 2 |  반복 1501 / 9295 | 시간 608[s] | 손실 1.89
# | 에폭 2 |  반복 1521 / 9295 | 시간 609[s] | 손실 1.89
# | 에폭 2 |  반복 1541 / 9295 | 시간 610[s] | 손실 1.88
# | 에폭 2 |  반복 1561 / 9295 | 시간 611[s] | 손실 1.88
# | 에폭 2 |  반복 1581 / 9295 | 시간 612[s] | 손실 1.89
# | 에폭 2 |  반복 1601 / 9295 | 시간 613[s] | 손실 1.89
# | 에폭 2 |  반복 1621 / 9295 | 시간 613[s] | 손실 1.90
# | 에폭 2 |  반복 1641 / 9295 | 시간 614[s] | 손실 1.88
# | 에폭 2 |  반복 1661 / 9295 | 시간 615[s] | 손실 1.88
# | 에폭 2 |  반복 1681 / 9295 | 시간 616[s] | 손실 1.87
# | 에폭 2 |  반복 1701 / 9295 | 시간 617[s] | 손실 1.87
# | 에폭 2 |  반복 1721 / 9295 | 시간 618[s] | 손실 1.90
# | 에폭 2 |  반복 1741 / 9295 | 시간 619[s] | 손실 1.89
# | 에폭 2 |  반복 1761 / 9295 | 시간 620[s] | 손실 1.88
# | 에폭 2 |  반복 1781 / 9295 | 시간 621[s] | 손실 1.91
# | 에폭 2 |  반복 1801 / 9295 | 시간 622[s] | 손실 1.86
# | 에폭 2 |  반복 1821 / 9295 | 시간 623[s] | 손실 1.87
# | 에폭 2 |  반복 1841 / 9295 | 시간 624[s] | 손실 1.90
# | 에폭 2 |  반복 1861 / 9295 | 시간 625[s] | 손실 1.86
# | 에폭 2 |  반복 1881 / 9295 | 시간 626[s] | 손실 1.90
# | 에폭 2 |  반복 1901 / 9295 | 시간 627[s] | 손실 1.88
# | 에폭 2 |  반복 1921 / 9295 | 시간 628[s] | 손실 1.92
# | 에폭 2 |  반복 1941 / 9295 | 시간 630[s] | 손실 1.88
# | 에폭 2 |  반복 1961 / 9295 | 시간 631[s] | 손실 1.89
# | 에폭 2 |  반복 1981 / 9295 | 시간 632[s] | 손실 1.88
# | 에폭 2 |  반복 2001 / 9295 | 시간 633[s] | 손실 1.87
# | 에폭 2 |  반복 2021 / 9295 | 시간 634[s] | 손실 1.84
# | 에폭 2 |  반복 2041 / 9295 | 시간 635[s] | 손실 1.86
# | 에폭 2 |  반복 2061 / 9295 | 시간 636[s] | 손실 1.89
# | 에폭 2 |  반복 2081 / 9295 | 시간 637[s] | 손실 1.89
# | 에폭 2 |  반복 2101 / 9295 | 시간 638[s] | 손실 1.89
# | 에폭 2 |  반복 2121 / 9295 | 시간 639[s] | 손실 1.88
# | 에폭 2 |  반복 2141 / 9295 | 시간 640[s] | 손실 1.87
# | 에폭 2 |  반복 2161 / 9295 | 시간 641[s] | 손실 1.86
# | 에폭 2 |  반복 2181 / 9295 | 시간 642[s] | 손실 1.85
# | 에폭 2 |  반복 2201 / 9295 | 시간 643[s] | 손실 1.81
# | 에폭 2 |  반복 2221 / 9295 | 시간 645[s] | 손실 1.88
# | 에폭 2 |  반복 2241 / 9295 | 시간 646[s] | 손실 1.87
# | 에폭 2 |  반복 2261 / 9295 | 시간 647[s] | 손실 1.88
# | 에폭 2 |  반복 2281 / 9295 | 시간 648[s] | 손실 1.87
# | 에폭 2 |  반복 2301 / 9295 | 시간 649[s] | 손실 1.89
# | 에폭 2 |  반복 2321 / 9295 | 시간 650[s] | 손실 1.88
# | 에폭 2 |  반복 2341 / 9295 | 시간 651[s] | 손실 1.85
# | 에폭 2 |  반복 2361 / 9295 | 시간 652[s] | 손실 1.87
# | 에폭 2 |  반복 2381 / 9295 | 시간 653[s] | 손실 1.86
# | 에폭 2 |  반복 2401 / 9295 | 시간 654[s] | 손실 1.87
# | 에폭 2 |  반복 2421 / 9295 | 시간 655[s] | 손실 1.88
# | 에폭 2 |  반복 2441 / 9295 | 시간 657[s] | 손실 1.85
# | 에폭 2 |  반복 2461 / 9295 | 시간 658[s] | 손실 1.83
# | 에폭 2 |  반복 2481 / 9295 | 시간 659[s] | 손실 1.90
# | 에폭 2 |  반복 2501 / 9295 | 시간 660[s] | 손실 1.89
# | 에폭 2 |  반복 2521 / 9295 | 시간 661[s] | 손실 1.86
# | 에폭 2 |  반복 2541 / 9295 | 시간 662[s] | 손실 1.88
# | 에폭 2 |  반복 2561 / 9295 | 시간 663[s] | 손실 1.87
# | 에폭 2 |  반복 2581 / 9295 | 시간 664[s] | 손실 1.87
# | 에폭 2 |  반복 2601 / 9295 | 시간 665[s] | 손실 1.83
# | 에폭 2 |  반복 2621 / 9295 | 시간 666[s] | 손실 1.84
# | 에폭 2 |  반복 2641 / 9295 | 시간 667[s] | 손실 1.87
# | 에폭 2 |  반복 2661 / 9295 | 시간 668[s] | 손실 1.91
# | 에폭 2 |  반복 2681 / 9295 | 시간 669[s] | 손실 1.86
# | 에폭 2 |  반복 2701 / 9295 | 시간 670[s] | 손실 1.89
# | 에폭 2 |  반복 2721 / 9295 | 시간 671[s] | 손실 1.85
# | 에폭 2 |  반복 2741 / 9295 | 시간 673[s] | 손실 1.82
# | 에폭 2 |  반복 2761 / 9295 | 시간 674[s] | 손실 1.87
# | 에폭 2 |  반복 2781 / 9295 | 시간 675[s] | 손실 1.87
# | 에폭 2 |  반복 2801 / 9295 | 시간 676[s] | 손실 1.85
# | 에폭 2 |  반복 2821 / 9295 | 시간 677[s] | 손실 1.88
# | 에폭 2 |  반복 2841 / 9295 | 시간 678[s] | 손실 1.85
# | 에폭 2 |  반복 2861 / 9295 | 시간 679[s] | 손실 1.85
# | 에폭 2 |  반복 2881 / 9295 | 시간 680[s] | 손실 1.84
# | 에폭 2 |  반복 2901 / 9295 | 시간 681[s] | 손실 1.86
# | 에폭 2 |  반복 2921 / 9295 | 시간 682[s] | 손실 1.88
# | 에폭 2 |  반복 2941 / 9295 | 시간 684[s] | 손실 1.86
# | 에폭 2 |  반복 2961 / 9295 | 시간 685[s] | 손실 1.85
# | 에폭 2 |  반복 2981 / 9295 | 시간 686[s] | 손실 1.86
# | 에폭 2 |  반복 3001 / 9295 | 시간 687[s] | 손실 1.84
# | 에폭 2 |  반복 3021 / 9295 | 시간 688[s] | 손실 1.90
# | 에폭 2 |  반복 3041 / 9295 | 시간 689[s] | 손실 1.87
# | 에폭 2 |  반복 3061 / 9295 | 시간 690[s] | 손실 1.84
# | 에폭 2 |  반복 3081 / 9295 | 시간 691[s] | 손실 1.86
# | 에폭 2 |  반복 3101 / 9295 | 시간 692[s] | 손실 1.87
# | 에폭 2 |  반복 3121 / 9295 | 시간 693[s] | 손실 1.86
# | 에폭 2 |  반복 3141 / 9295 | 시간 694[s] | 손실 1.83
# | 에폭 2 |  반복 3161 / 9295 | 시간 695[s] | 손실 1.82
# | 에폭 2 |  반복 3181 / 9295 | 시간 696[s] | 손실 1.89
# | 에폭 2 |  반복 3201 / 9295 | 시간 697[s] | 손실 1.86
# | 에폭 2 |  반복 3221 / 9295 | 시간 698[s] | 손실 1.84
# | 에폭 2 |  반복 3241 / 9295 | 시간 699[s] | 손실 1.84
# | 에폭 2 |  반복 3261 / 9295 | 시간 700[s] | 손실 1.85
# | 에폭 2 |  반복 3281 / 9295 | 시간 701[s] | 손실 1.85
# | 에폭 2 |  반복 3301 / 9295 | 시간 702[s] | 손실 1.86
# | 에폭 2 |  반복 3321 / 9295 | 시간 703[s] | 손실 1.86
# | 에폭 2 |  반복 3341 / 9295 | 시간 704[s] | 손실 1.84
# | 에폭 2 |  반복 3361 / 9295 | 시간 705[s] | 손실 1.87
# | 에폭 2 |  반복 3381 / 9295 | 시간 706[s] | 손실 1.87
# | 에폭 2 |  반복 3401 / 9295 | 시간 707[s] | 손실 1.87
# | 에폭 2 |  반복 3421 / 9295 | 시간 708[s] | 손실 1.88
# | 에폭 2 |  반복 3441 / 9295 | 시간 709[s] | 손실 1.87
# | 에폭 2 |  반복 3461 / 9295 | 시간 710[s] | 손실 1.86
# | 에폭 2 |  반복 3481 / 9295 | 시간 711[s] | 손실 1.85
# | 에폭 2 |  반복 3501 / 9295 | 시간 712[s] | 손실 1.84
# | 에폭 2 |  반복 3521 / 9295 | 시간 713[s] | 손실 1.85
# | 에폭 2 |  반복 3541 / 9295 | 시간 714[s] | 손실 1.83
# | 에폭 2 |  반복 3561 / 9295 | 시간 715[s] | 손실 1.87
# | 에폭 2 |  반복 3581 / 9295 | 시간 715[s] | 손실 1.87
# | 에폭 2 |  반복 3601 / 9295 | 시간 716[s] | 손실 1.84
# | 에폭 2 |  반복 3621 / 9295 | 시간 717[s] | 손실 1.85
# | 에폭 2 |  반복 3641 / 9295 | 시간 718[s] | 손실 1.87
# | 에폭 2 |  반복 3661 / 9295 | 시간 719[s] | 손실 1.84
# | 에폭 2 |  반복 3681 / 9295 | 시간 720[s] | 손실 1.85
# | 에폭 2 |  반복 3701 / 9295 | 시간 721[s] | 손실 1.87
# | 에폭 2 |  반복 3721 / 9295 | 시간 722[s] | 손실 1.81
# | 에폭 2 |  반복 3741 / 9295 | 시간 723[s] | 손실 1.86
# | 에폭 2 |  반복 3761 / 9295 | 시간 724[s] | 손실 1.83
# | 에폭 2 |  반복 3781 / 9295 | 시간 725[s] | 손실 1.86
# | 에폭 2 |  반복 3801 / 9295 | 시간 726[s] | 손실 1.85
# | 에폭 2 |  반복 3821 / 9295 | 시간 727[s] | 손실 1.83
# | 에폭 2 |  반복 3841 / 9295 | 시간 728[s] | 손실 1.88
# | 에폭 2 |  반복 3861 / 9295 | 시간 728[s] | 손실 1.86
# | 에폭 2 |  반복 3881 / 9295 | 시간 729[s] | 손실 1.84
# | 에폭 2 |  반복 3901 / 9295 | 시간 730[s] | 손실 1.85
# | 에폭 2 |  반복 3921 / 9295 | 시간 731[s] | 손실 1.84
# | 에폭 2 |  반복 3941 / 9295 | 시간 732[s] | 손실 1.90
# | 에폭 2 |  반복 3961 / 9295 | 시간 733[s] | 손실 1.86
# | 에폭 2 |  반복 3981 / 9295 | 시간 734[s] | 손실 1.83
# | 에폭 2 |  반복 4001 / 9295 | 시간 735[s] | 손실 1.86
# | 에폭 2 |  반복 4021 / 9295 | 시간 736[s] | 손실 1.82
# | 에폭 2 |  반복 4041 / 9295 | 시간 737[s] | 손실 1.82
# | 에폭 2 |  반복 4061 / 9295 | 시간 738[s] | 손실 1.83
# | 에폭 2 |  반복 4081 / 9295 | 시간 739[s] | 손실 1.85
# | 에폭 2 |  반복 4101 / 9295 | 시간 740[s] | 손실 1.83
# | 에폭 2 |  반복 4121 / 9295 | 시간 741[s] | 손실 1.83
# | 에폭 2 |  반복 4141 / 9295 | 시간 742[s] | 손실 1.82
# | 에폭 2 |  반복 4161 / 9295 | 시간 742[s] | 손실 1.85
# | 에폭 2 |  반복 4181 / 9295 | 시간 743[s] | 손실 1.85
# | 에폭 2 |  반복 4201 / 9295 | 시간 744[s] | 손실 1.88
# | 에폭 2 |  반복 4221 / 9295 | 시간 745[s] | 손실 1.82
# | 에폭 2 |  반복 4241 / 9295 | 시간 746[s] | 손실 1.83
# | 에폭 2 |  반복 4261 / 9295 | 시간 747[s] | 손실 1.82
# | 에폭 2 |  반복 4281 / 9295 | 시간 748[s] | 손실 1.82
# | 에폭 2 |  반복 4301 / 9295 | 시간 749[s] | 손실 1.83
# | 에폭 2 |  반복 4321 / 9295 | 시간 750[s] | 손실 1.81
# | 에폭 2 |  반복 4341 / 9295 | 시간 751[s] | 손실 1.83
# | 에폭 2 |  반복 4361 / 9295 | 시간 752[s] | 손실 1.80
# | 에폭 2 |  반복 4381 / 9295 | 시간 753[s] | 손실 1.87
# | 에폭 2 |  반복 4401 / 9295 | 시간 753[s] | 손실 1.83
# | 에폭 2 |  반복 4421 / 9295 | 시간 754[s] | 손실 1.87
# | 에폭 2 |  반복 4441 / 9295 | 시간 755[s] | 손실 1.82
# | 에폭 2 |  반복 4461 / 9295 | 시간 756[s] | 손실 1.82
# | 에폭 2 |  반복 4481 / 9295 | 시간 757[s] | 손실 1.85
# | 에폭 2 |  반복 4501 / 9295 | 시간 758[s] | 손실 1.86
# | 에폭 2 |  반복 4521 / 9295 | 시간 759[s] | 손실 1.85
# | 에폭 2 |  반복 4541 / 9295 | 시간 760[s] | 손실 1.82
# | 에폭 2 |  반복 4561 / 9295 | 시간 761[s] | 손실 1.85
# | 에폭 2 |  반복 4581 / 9295 | 시간 762[s] | 손실 1.85
# | 에폭 2 |  반복 4601 / 9295 | 시간 763[s] | 손실 1.85
# | 에폭 2 |  반복 4621 / 9295 | 시간 764[s] | 손실 1.79
# | 에폭 2 |  반복 4641 / 9295 | 시간 764[s] | 손실 1.85
# | 에폭 2 |  반복 4661 / 9295 | 시간 765[s] | 손실 1.83
# | 에폭 2 |  반복 4681 / 9295 | 시간 766[s] | 손실 1.83
# | 에폭 2 |  반복 4701 / 9295 | 시간 767[s] | 손실 1.81
# | 에폭 2 |  반복 4721 / 9295 | 시간 768[s] | 손실 1.82
# | 에폭 2 |  반복 4741 / 9295 | 시간 769[s] | 손실 1.80
# | 에폭 2 |  반복 4761 / 9295 | 시간 770[s] | 손실 1.83
# | 에폭 2 |  반복 4781 / 9295 | 시간 771[s] | 손실 1.82
# | 에폭 2 |  반복 4801 / 9295 | 시간 772[s] | 손실 1.81
# | 에폭 2 |  반복 4821 / 9295 | 시간 773[s] | 손실 1.83
# | 에폭 2 |  반복 4841 / 9295 | 시간 773[s] | 손실 1.84
# | 에폭 2 |  반복 4861 / 9295 | 시간 774[s] | 손실 1.82
# | 에폭 2 |  반복 4881 / 9295 | 시간 775[s] | 손실 1.82
# | 에폭 2 |  반복 4901 / 9295 | 시간 776[s] | 손실 1.86
# | 에폭 2 |  반복 4921 / 9295 | 시간 777[s] | 손실 1.82
# | 에폭 2 |  반복 4941 / 9295 | 시간 778[s] | 손실 1.84
# | 에폭 2 |  반복 4961 / 9295 | 시간 779[s] | 손실 1.83
# | 에폭 2 |  반복 4981 / 9295 | 시간 780[s] | 손실 1.83
# | 에폭 2 |  반복 5001 / 9295 | 시간 781[s] | 손실 1.86
# | 에폭 2 |  반복 5021 / 9295 | 시간 782[s] | 손실 1.81
# | 에폭 2 |  반복 5041 / 9295 | 시간 782[s] | 손실 1.82
# | 에폭 2 |  반복 5061 / 9295 | 시간 783[s] | 손실 1.88
# | 에폭 2 |  반복 5081 / 9295 | 시간 784[s] | 손실 1.84
# | 에폭 2 |  반복 5101 / 9295 | 시간 785[s] | 손실 1.81
# | 에폭 2 |  반복 5121 / 9295 | 시간 786[s] | 손실 1.82
# | 에폭 2 |  반복 5141 / 9295 | 시간 787[s] | 손실 1.86
# | 에폭 2 |  반복 5161 / 9295 | 시간 788[s] | 손실 1.85
# | 에폭 2 |  반복 5181 / 9295 | 시간 789[s] | 손실 1.81
# | 에폭 2 |  반복 5201 / 9295 | 시간 790[s] | 손실 1.85
# | 에폭 2 |  반복 5221 / 9295 | 시간 791[s] | 손실 1.82
# | 에폭 2 |  반복 5241 / 9295 | 시간 792[s] | 손실 1.80
# | 에폭 2 |  반복 5261 / 9295 | 시간 793[s] | 손실 1.81
# | 에폭 2 |  반복 5281 / 9295 | 시간 794[s] | 손실 1.80
# | 에폭 2 |  반복 5301 / 9295 | 시간 795[s] | 손실 1.85
# | 에폭 2 |  반복 5321 / 9295 | 시간 797[s] | 손실 1.84
# | 에폭 2 |  반복 5341 / 9295 | 시간 798[s] | 손실 1.85
# | 에폭 2 |  반복 5361 / 9295 | 시간 800[s] | 손실 1.84
# | 에폭 2 |  반복 5381 / 9295 | 시간 801[s] | 손실 1.82
# | 에폭 2 |  반복 5401 / 9295 | 시간 802[s] | 손실 1.79
# | 에폭 2 |  반복 5421 / 9295 | 시간 802[s] | 손실 1.81
# | 에폭 2 |  반복 5441 / 9295 | 시간 803[s] | 손실 1.82
# | 에폭 2 |  반복 5461 / 9295 | 시간 804[s] | 손실 1.85
# | 에폭 2 |  반복 5481 / 9295 | 시간 805[s] | 손실 1.84
# | 에폭 2 |  반복 5501 / 9295 | 시간 806[s] | 손실 1.84
# | 에폭 2 |  반복 5521 / 9295 | 시간 807[s] | 손실 1.80
# | 에폭 2 |  반복 5541 / 9295 | 시간 808[s] | 손실 1.80
# | 에폭 2 |  반복 5561 / 9295 | 시간 809[s] | 손실 1.81
# | 에폭 2 |  반복 5581 / 9295 | 시간 810[s] | 손실 1.83
# | 에폭 2 |  반복 5601 / 9295 | 시간 811[s] | 손실 1.81
# | 에폭 2 |  반복 5621 / 9295 | 시간 812[s] | 손실 1.83
# | 에폭 2 |  반복 5641 / 9295 | 시간 813[s] | 손실 1.81
# | 에폭 2 |  반복 5661 / 9295 | 시간 813[s] | 손실 1.82
# | 에폭 2 |  반복 5681 / 9295 | 시간 814[s] | 손실 1.77
# | 에폭 2 |  반복 5701 / 9295 | 시간 815[s] | 손실 1.82
# | 에폭 2 |  반복 5721 / 9295 | 시간 816[s] | 손실 1.84
# | 에폭 2 |  반복 5741 / 9295 | 시간 817[s] | 손실 1.85
# | 에폭 2 |  반복 5761 / 9295 | 시간 818[s] | 손실 1.82
# | 에폭 2 |  반복 5781 / 9295 | 시간 819[s] | 손실 1.84
# | 에폭 2 |  반복 5801 / 9295 | 시간 820[s] | 손실 1.83
# | 에폭 2 |  반복 5821 / 9295 | 시간 821[s] | 손실 1.82
# | 에폭 2 |  반복 5841 / 9295 | 시간 822[s] | 손실 1.77
# | 에폭 2 |  반복 5861 / 9295 | 시간 823[s] | 손실 1.83
# | 에폭 2 |  반복 5881 / 9295 | 시간 824[s] | 손실 1.82
# | 에폭 2 |  반복 5901 / 9295 | 시간 825[s] | 손실 1.82
# | 에폭 2 |  반복 5921 / 9295 | 시간 826[s] | 손실 1.81
# | 에폭 2 |  반복 5941 / 9295 | 시간 827[s] | 손실 1.86
# | 에폭 2 |  반복 5961 / 9295 | 시간 828[s] | 손실 1.81
# | 에폭 2 |  반복 5981 / 9295 | 시간 829[s] | 손실 1.82
# | 에폭 2 |  반복 6001 / 9295 | 시간 829[s] | 손실 1.81
# | 에폭 2 |  반복 6021 / 9295 | 시간 830[s] | 손실 1.82
# | 에폭 2 |  반복 6041 / 9295 | 시간 831[s] | 손실 1.81
# | 에폭 2 |  반복 6061 / 9295 | 시간 832[s] | 손실 1.80
# | 에폭 2 |  반복 6081 / 9295 | 시간 833[s] | 손실 1.82
# | 에폭 2 |  반복 6101 / 9295 | 시간 834[s] | 손실 1.81
# | 에폭 2 |  반복 6121 / 9295 | 시간 835[s] | 손실 1.82
# | 에폭 2 |  반복 6141 / 9295 | 시간 836[s] | 손실 1.84
# | 에폭 2 |  반복 6161 / 9295 | 시간 837[s] | 손실 1.79
# | 에폭 2 |  반복 6181 / 9295 | 시간 838[s] | 손실 1.82
# | 에폭 2 |  반복 6201 / 9295 | 시간 839[s] | 손실 1.74
# | 에폭 2 |  반복 6221 / 9295 | 시간 839[s] | 손실 1.77
# | 에폭 2 |  반복 6241 / 9295 | 시간 840[s] | 손실 1.81
# | 에폭 2 |  반복 6261 / 9295 | 시간 841[s] | 손실 1.80
# | 에폭 2 |  반복 6281 / 9295 | 시간 842[s] | 손실 1.80
# | 에폭 2 |  반복 6301 / 9295 | 시간 843[s] | 손실 1.83
# | 에폭 2 |  반복 6321 / 9295 | 시간 844[s] | 손실 1.81
# | 에폭 2 |  반복 6341 / 9295 | 시간 845[s] | 손실 1.85
# | 에폭 2 |  반복 6361 / 9295 | 시간 846[s] | 손실 1.77
# | 에폭 2 |  반복 6381 / 9295 | 시간 847[s] | 손실 1.80
# | 에폭 2 |  반복 6401 / 9295 | 시간 848[s] | 손실 1.80
# | 에폭 2 |  반복 6421 / 9295 | 시간 849[s] | 손실 1.81
# | 에폭 2 |  반복 6441 / 9295 | 시간 850[s] | 손실 1.79
# | 에폭 2 |  반복 6461 / 9295 | 시간 851[s] | 손실 1.80
# | 에폭 2 |  반복 6481 / 9295 | 시간 851[s] | 손실 1.75
# | 에폭 2 |  반복 6501 / 9295 | 시간 852[s] | 손실 1.82
# | 에폭 2 |  반복 6521 / 9295 | 시간 853[s] | 손실 1.82
# | 에폭 2 |  반복 6541 / 9295 | 시간 854[s] | 손실 1.79
# | 에폭 2 |  반복 6561 / 9295 | 시간 855[s] | 손실 1.80
# | 에폭 2 |  반복 6581 / 9295 | 시간 856[s] | 손실 1.75
# | 에폭 2 |  반복 6601 / 9295 | 시간 857[s] | 손실 1.84
# | 에폭 2 |  반복 6621 / 9295 | 시간 858[s] | 손실 1.83
# | 에폭 2 |  반복 6641 / 9295 | 시간 859[s] | 손실 1.79
# | 에폭 2 |  반복 6661 / 9295 | 시간 860[s] | 손실 1.81
# | 에폭 2 |  반복 6681 / 9295 | 시간 861[s] | 손실 1.84
# | 에폭 2 |  반복 6701 / 9295 | 시간 861[s] | 손실 1.83
# | 에폭 2 |  반복 6721 / 9295 | 시간 862[s] | 손실 1.82
# | 에폭 2 |  반복 6741 / 9295 | 시간 863[s] | 손실 1.78
# | 에폭 2 |  반복 6761 / 9295 | 시간 864[s] | 손실 1.80
# | 에폭 2 |  반복 6781 / 9295 | 시간 865[s] | 손실 1.79
# | 에폭 2 |  반복 6801 / 9295 | 시간 866[s] | 손실 1.82
# | 에폭 2 |  반복 6821 / 9295 | 시간 867[s] | 손실 1.81
# | 에폭 2 |  반복 6841 / 9295 | 시간 868[s] | 손실 1.79
# | 에폭 2 |  반복 6861 / 9295 | 시간 869[s] | 손실 1.82
# | 에폭 2 |  반복 6881 / 9295 | 시간 870[s] | 손실 1.81
# | 에폭 2 |  반복 6901 / 9295 | 시간 870[s] | 손실 1.78
# | 에폭 2 |  반복 6921 / 9295 | 시간 871[s] | 손실 1.80
# | 에폭 2 |  반복 6941 / 9295 | 시간 872[s] | 손실 1.81
# | 에폭 2 |  반복 6961 / 9295 | 시간 873[s] | 손실 1.74
# | 에폭 2 |  반복 6981 / 9295 | 시간 874[s] | 손실 1.80
# | 에폭 2 |  반복 7001 / 9295 | 시간 875[s] | 손실 1.76
# | 에폭 2 |  반복 7021 / 9295 | 시간 876[s] | 손실 1.79
# | 에폭 2 |  반복 7041 / 9295 | 시간 877[s] | 손실 1.81
# | 에폭 2 |  반복 7061 / 9295 | 시간 878[s] | 손실 1.79
# | 에폭 2 |  반복 7081 / 9295 | 시간 879[s] | 손실 1.78
# | 에폭 2 |  반복 7101 / 9295 | 시간 879[s] | 손실 1.79
# | 에폭 2 |  반복 7121 / 9295 | 시간 880[s] | 손실 1.76
# | 에폭 2 |  반복 7141 / 9295 | 시간 881[s] | 손실 1.77
# | 에폭 2 |  반복 7161 / 9295 | 시간 882[s] | 손실 1.77
# | 에폭 2 |  반복 7181 / 9295 | 시간 883[s] | 손실 1.79
# | 에폭 2 |  반복 7201 / 9295 | 시간 884[s] | 손실 1.79
# | 에폭 2 |  반복 7221 / 9295 | 시간 885[s] | 손실 1.81
# | 에폭 2 |  반복 7241 / 9295 | 시간 886[s] | 손실 1.79
# | 에폭 2 |  반복 7261 / 9295 | 시간 887[s] | 손실 1.85
# | 에폭 2 |  반복 7281 / 9295 | 시간 888[s] | 손실 1.77
# | 에폭 2 |  반복 7301 / 9295 | 시간 889[s] | 손실 1.78
# | 에폭 2 |  반복 7321 / 9295 | 시간 889[s] | 손실 1.78
# | 에폭 2 |  반복 7341 / 9295 | 시간 890[s] | 손실 1.79
# | 에폭 2 |  반복 7361 / 9295 | 시간 891[s] | 손실 1.77
# | 에폭 2 |  반복 7381 / 9295 | 시간 892[s] | 손실 1.79
# | 에폭 2 |  반복 7401 / 9295 | 시간 893[s] | 손실 1.81
# | 에폭 2 |  반복 7421 / 9295 | 시간 894[s] | 손실 1.81
# | 에폭 2 |  반복 7441 / 9295 | 시간 895[s] | 손실 1.82
# | 에폭 2 |  반복 7461 / 9295 | 시간 896[s] | 손실 1.77
# | 에폭 2 |  반복 7481 / 9295 | 시간 897[s] | 손실 1.78
# | 에폭 2 |  반복 7501 / 9295 | 시간 897[s] | 손실 1.84
# | 에폭 2 |  반복 7521 / 9295 | 시간 898[s] | 손실 1.81
# | 에폭 2 |  반복 7541 / 9295 | 시간 899[s] | 손실 1.80
# | 에폭 2 |  반복 7561 / 9295 | 시간 900[s] | 손실 1.79
# | 에폭 2 |  반복 7581 / 9295 | 시간 901[s] | 손실 1.80
# | 에폭 2 |  반복 7601 / 9295 | 시간 902[s] | 손실 1.76
# | 에폭 2 |  반복 7621 / 9295 | 시간 903[s] | 손실 1.81
# | 에폭 2 |  반복 7641 / 9295 | 시간 904[s] | 손실 1.80
# | 에폭 2 |  반복 7661 / 9295 | 시간 905[s] | 손실 1.74
# | 에폭 2 |  반복 7681 / 9295 | 시간 906[s] | 손실 1.84
# | 에폭 2 |  반복 7701 / 9295 | 시간 907[s] | 손실 1.74
# | 에폭 2 |  반복 7721 / 9295 | 시간 908[s] | 손실 1.80
# | 에폭 2 |  반복 7741 / 9295 | 시간 908[s] | 손실 1.79
# | 에폭 2 |  반복 7761 / 9295 | 시간 909[s] | 손실 1.78
# | 에폭 2 |  반복 7781 / 9295 | 시간 910[s] | 손실 1.77
# | 에폭 2 |  반복 7801 / 9295 | 시간 911[s] | 손실 1.79
# | 에폭 2 |  반복 7821 / 9295 | 시간 912[s] | 손실 1.76
# | 에폭 2 |  반복 7841 / 9295 | 시간 913[s] | 손실 1.81
# | 에폭 2 |  반복 7861 / 9295 | 시간 914[s] | 손실 1.81
# | 에폭 2 |  반복 7881 / 9295 | 시간 915[s] | 손실 1.76
# | 에폭 2 |  반복 7901 / 9295 | 시간 916[s] | 손실 1.78
# | 에폭 2 |  반복 7921 / 9295 | 시간 917[s] | 손실 1.77
# | 에폭 2 |  반복 7941 / 9295 | 시간 918[s] | 손실 1.79
# | 에폭 2 |  반복 7961 / 9295 | 시간 919[s] | 손실 1.78
# | 에폭 2 |  반복 7981 / 9295 | 시간 919[s] | 손실 1.76
# | 에폭 2 |  반복 8001 / 9295 | 시간 920[s] | 손실 1.82
# | 에폭 2 |  반복 8021 / 9295 | 시간 921[s] | 손실 1.78
# | 에폭 2 |  반복 8041 / 9295 | 시간 922[s] | 손실 1.78
# | 에폭 2 |  반복 8061 / 9295 | 시간 923[s] | 손실 1.74
# | 에폭 2 |  반복 8081 / 9295 | 시간 924[s] | 손실 1.81
# | 에폭 2 |  반복 8101 / 9295 | 시간 925[s] | 손실 1.78
# | 에폭 2 |  반복 8121 / 9295 | 시간 926[s] | 손실 1.83
# | 에폭 2 |  반복 8141 / 9295 | 시간 927[s] | 손실 1.77
# | 에폭 2 |  반복 8161 / 9295 | 시간 928[s] | 손실 1.80
# | 에폭 2 |  반복 8181 / 9295 | 시간 929[s] | 손실 1.79
# | 에폭 2 |  반복 8201 / 9295 | 시간 930[s] | 손실 1.81
# | 에폭 2 |  반복 8221 / 9295 | 시간 931[s] | 손실 1.78
# | 에폭 2 |  반복 8241 / 9295 | 시간 931[s] | 손실 1.76
# | 에폭 2 |  반복 8261 / 9295 | 시간 932[s] | 손실 1.78
# | 에폭 2 |  반복 8281 / 9295 | 시간 933[s] | 손실 1.79
# | 에폭 2 |  반복 8301 / 9295 | 시간 934[s] | 손실 1.78
# | 에폭 2 |  반복 8321 / 9295 | 시간 935[s] | 손실 1.81
# | 에폭 2 |  반복 8341 / 9295 | 시간 936[s] | 손실 1.77
# | 에폭 2 |  반복 8361 / 9295 | 시간 937[s] | 손실 1.76
# | 에폭 2 |  반복 8381 / 9295 | 시간 938[s] | 손실 1.76
# | 에폭 2 |  반복 8401 / 9295 | 시간 939[s] | 손실 1.77
# | 에폭 2 |  반복 8421 / 9295 | 시간 940[s] | 손실 1.80
# | 에폭 2 |  반복 8441 / 9295 | 시간 940[s] | 손실 1.74
# | 에폭 2 |  반복 8461 / 9295 | 시간 941[s] | 손실 1.79
# | 에폭 2 |  반복 8481 / 9295 | 시간 942[s] | 손실 1.79
# | 에폭 2 |  반복 8501 / 9295 | 시간 943[s] | 손실 1.76
# | 에폭 2 |  반복 8521 / 9295 | 시간 944[s] | 손실 1.86
# | 에폭 2 |  반복 8541 / 9295 | 시간 945[s] | 손실 1.80
# | 에폭 2 |  반복 8561 / 9295 | 시간 946[s] | 손실 1.79
# | 에폭 2 |  반복 8581 / 9295 | 시간 947[s] | 손실 1.77
# | 에폭 2 |  반복 8601 / 9295 | 시간 948[s] | 손실 1.77
# | 에폭 2 |  반복 8621 / 9295 | 시간 948[s] | 손실 1.75
# | 에폭 2 |  반복 8641 / 9295 | 시간 949[s] | 손실 1.79
# | 에폭 2 |  반복 8661 / 9295 | 시간 950[s] | 손실 1.80
# | 에폭 2 |  반복 8681 / 9295 | 시간 951[s] | 손실 1.82
# | 에폭 2 |  반복 8701 / 9295 | 시간 952[s] | 손실 1.75
# | 에폭 2 |  반복 8721 / 9295 | 시간 953[s] | 손실 1.77
# | 에폭 2 |  반복 8741 / 9295 | 시간 954[s] | 손실 1.77
# | 에폭 2 |  반복 8761 / 9295 | 시간 955[s] | 손실 1.78
# | 에폭 2 |  반복 8781 / 9295 | 시간 956[s] | 손실 1.77
# | 에폭 2 |  반복 8801 / 9295 | 시간 957[s] | 손실 1.77
# | 에폭 2 |  반복 8821 / 9295 | 시간 958[s] | 손실 1.74
# | 에폭 2 |  반복 8841 / 9295 | 시간 959[s] | 손실 1.76
# | 에폭 2 |  반복 8861 / 9295 | 시간 960[s] | 손실 1.75
# | 에폭 2 |  반복 8881 / 9295 | 시간 961[s] | 손실 1.79
# | 에폭 2 |  반복 8901 / 9295 | 시간 961[s] | 손실 1.79
# | 에폭 2 |  반복 8921 / 9295 | 시간 962[s] | 손실 1.79
# | 에폭 2 |  반복 8941 / 9295 | 시간 963[s] | 손실 1.79
# | 에폭 2 |  반복 8961 / 9295 | 시간 964[s] | 손실 1.76
# | 에폭 2 |  반복 8981 / 9295 | 시간 965[s] | 손실 1.73
# | 에폭 2 |  반복 9001 / 9295 | 시간 966[s] | 손실 1.75
# | 에폭 2 |  반복 9021 / 9295 | 시간 967[s] | 손실 1.76
# | 에폭 2 |  반복 9041 / 9295 | 시간 968[s] | 손실 1.75
# | 에폭 2 |  반복 9061 / 9295 | 시간 969[s] | 손실 1.82
# | 에폭 2 |  반복 9081 / 9295 | 시간 970[s] | 손실 1.77
# | 에폭 2 |  반복 9101 / 9295 | 시간 971[s] | 손실 1.76
# | 에폭 2 |  반복 9121 / 9295 | 시간 972[s] | 손실 1.77
# | 에폭 2 |  반복 9141 / 9295 | 시간 972[s] | 손실 1.73
# | 에폭 2 |  반복 9161 / 9295 | 시간 973[s] | 손실 1.78
# | 에폭 2 |  반복 9181 / 9295 | 시간 974[s] | 손실 1.76
# | 에폭 2 |  반복 9201 / 9295 | 시간 975[s] | 손실 1.79
# | 에폭 2 |  반복 9221 / 9295 | 시간 976[s] | 손실 1.77
# | 에폭 2 |  반복 9241 / 9295 | 시간 977[s] | 손실 1.81
# | 에폭 2 |  반복 9261 / 9295 | 시간 978[s] | 손실 1.75
# | 에폭 2 |  반복 9281 / 9295 | 시간 979[s] | 손실 1.78
# | 에폭 3 |  반복 1 / 9295 | 시간 979[s] | 손실 1.79
# | 에폭 3 |  반복 21 / 9295 | 시간 980[s] | 손실 1.67
# | 에폭 3 |  반복 41 / 9295 | 시간 981[s] | 손실 1.71
# | 에폭 3 |  반복 61 / 9295 | 시간 982[s] | 손실 1.70
# | 에폭 3 |  반복 81 / 9295 | 시간 983[s] | 손실 1.70
# | 에폭 3 |  반복 101 / 9295 | 시간 984[s] | 손실 1.68
# | 에폭 3 |  반복 121 / 9295 | 시간 985[s] | 손실 1.68
# | 에폭 3 |  반복 141 / 9295 | 시간 986[s] | 손실 1.71
# | 에폭 3 |  반복 161 / 9295 | 시간 987[s] | 손실 1.66
# | 에폭 3 |  반복 181 / 9295 | 시간 988[s] | 손실 1.69
# | 에폭 3 |  반복 201 / 9295 | 시간 989[s] | 손실 1.66
# | 에폭 3 |  반복 221 / 9295 | 시간 989[s] | 손실 1.67
# | 에폭 3 |  반복 241 / 9295 | 시간 990[s] | 손실 1.67
# | 에폭 3 |  반복 261 / 9295 | 시간 991[s] | 손실 1.68
# | 에폭 3 |  반복 281 / 9295 | 시간 992[s] | 손실 1.72
# | 에폭 3 |  반복 301 / 9295 | 시간 993[s] | 손실 1.69
# | 에폭 3 |  반복 321 / 9295 | 시간 994[s] | 손실 1.67
# | 에폭 3 |  반복 341 / 9295 | 시간 995[s] | 손실 1.72
# | 에폭 3 |  반복 361 / 9295 | 시간 996[s] | 손실 1.66
# | 에폭 3 |  반복 381 / 9295 | 시간 997[s] | 손실 1.70
# | 에폭 3 |  반복 401 / 9295 | 시간 998[s] | 손실 1.67
# | 에폭 3 |  반복 421 / 9295 | 시간 999[s] | 손실 1.70
# | 에폭 3 |  반복 441 / 9295 | 시간 999[s] | 손실 1.66
# | 에폭 3 |  반복 461 / 9295 | 시간 1000[s] | 손실 1.69
# | 에폭 3 |  반복 481 / 9295 | 시간 1001[s] | 손실 1.67
# | 에폭 3 |  반복 501 / 9295 | 시간 1002[s] | 손실 1.69
# | 에폭 3 |  반복 521 / 9295 | 시간 1003[s] | 손실 1.66
# | 에폭 3 |  반복 541 / 9295 | 시간 1004[s] | 손실 1.71
# | 에폭 3 |  반복 561 / 9295 | 시간 1005[s] | 손실 1.67
# | 에폭 3 |  반복 581 / 9295 | 시간 1006[s] | 손실 1.69
# | 에폭 3 |  반복 601 / 9295 | 시간 1007[s] | 손실 1.71
# | 에폭 3 |  반복 621 / 9295 | 시간 1008[s] | 손실 1.69
# | 에폭 3 |  반복 641 / 9295 | 시간 1008[s] | 손실 1.68
# | 에폭 3 |  반복 661 / 9295 | 시간 1009[s] | 손실 1.65
# | 에폭 3 |  반복 681 / 9295 | 시간 1010[s] | 손실 1.67
# | 에폭 3 |  반복 701 / 9295 | 시간 1011[s] | 손실 1.70
# | 에폭 3 |  반복 721 / 9295 | 시간 1012[s] | 손실 1.71
# | 에폭 3 |  반복 741 / 9295 | 시간 1013[s] | 손실 1.65
# | 에폭 3 |  반복 761 / 9295 | 시간 1014[s] | 손실 1.69
# | 에폭 3 |  반복 781 / 9295 | 시간 1015[s] | 손실 1.68
# | 에폭 3 |  반복 801 / 9295 | 시간 1016[s] | 손실 1.68
# | 에폭 3 |  반복 821 / 9295 | 시간 1017[s] | 손실 1.64
# | 에폭 3 |  반복 841 / 9295 | 시간 1017[s] | 손실 1.67
# | 에폭 3 |  반복 861 / 9295 | 시간 1018[s] | 손실 1.71
# | 에폭 3 |  반복 881 / 9295 | 시간 1019[s] | 손실 1.74
# | 에폭 3 |  반복 901 / 9295 | 시간 1020[s] | 손실 1.65
# | 에폭 3 |  반복 921 / 9295 | 시간 1021[s] | 손실 1.69
# | 에폭 3 |  반복 941 / 9295 | 시간 1022[s] | 손실 1.66
# | 에폭 3 |  반복 961 / 9295 | 시간 1023[s] | 손실 1.71
# | 에폭 3 |  반복 981 / 9295 | 시간 1024[s] | 손실 1.67
# | 에폭 3 |  반복 1001 / 9295 | 시간 1025[s] | 손실 1.70
# | 에폭 3 |  반복 1021 / 9295 | 시간 1026[s] | 손실 1.72
# | 에폭 3 |  반복 1041 / 9295 | 시간 1026[s] | 손실 1.63
# | 에폭 3 |  반복 1061 / 9295 | 시간 1027[s] | 손실 1.69
# | 에폭 3 |  반복 1081 / 9295 | 시간 1028[s] | 손실 1.70
# | 에폭 3 |  반복 1101 / 9295 | 시간 1029[s] | 손실 1.69
# | 에폭 3 |  반복 1121 / 9295 | 시간 1030[s] | 손실 1.72
# | 에폭 3 |  반복 1141 / 9295 | 시간 1031[s] | 손실 1.71
# | 에폭 3 |  반복 1161 / 9295 | 시간 1032[s] | 손실 1.66
# | 에폭 3 |  반복 1181 / 9295 | 시간 1033[s] | 손실 1.71
# | 에폭 3 |  반복 1201 / 9295 | 시간 1034[s] | 손실 1.69
# | 에폭 3 |  반복 1221 / 9295 | 시간 1035[s] | 손실 1.68
# | 에폭 3 |  반복 1241 / 9295 | 시간 1035[s] | 손실 1.68
# | 에폭 3 |  반복 1261 / 9295 | 시간 1036[s] | 손실 1.74
# | 에폭 3 |  반복 1281 / 9295 | 시간 1037[s] | 손실 1.72
# | 에폭 3 |  반복 1301 / 9295 | 시간 1038[s] | 손실 1.67
# | 에폭 3 |  반복 1321 / 9295 | 시간 1039[s] | 손실 1.68
# | 에폭 3 |  반복 1341 / 9295 | 시간 1040[s] | 손실 1.68
# | 에폭 3 |  반복 1361 / 9295 | 시간 1041[s] | 손실 1.72
# | 에폭 3 |  반복 1381 / 9295 | 시간 1042[s] | 손실 1.65
# | 에폭 3 |  반복 1401 / 9295 | 시간 1043[s] | 손실 1.64
# | 에폭 3 |  반복 1421 / 9295 | 시간 1044[s] | 손실 1.68
# | 에폭 3 |  반복 1441 / 9295 | 시간 1045[s] | 손실 1.74
# | 에폭 3 |  반복 1461 / 9295 | 시간 1045[s] | 손실 1.67
# | 에폭 3 |  반복 1481 / 9295 | 시간 1046[s] | 손실 1.67
# | 에폭 3 |  반복 1501 / 9295 | 시간 1047[s] | 손실 1.70
# | 에폭 3 |  반복 1521 / 9295 | 시간 1048[s] | 손실 1.70
# | 에폭 3 |  반복 1541 / 9295 | 시간 1049[s] | 손실 1.71
# | 에폭 3 |  반복 1561 / 9295 | 시간 1050[s] | 손실 1.65
# | 에폭 3 |  반복 1581 / 9295 | 시간 1051[s] | 손실 1.68
# | 에폭 3 |  반복 1601 / 9295 | 시간 1052[s] | 손실 1.69
# | 에폭 3 |  반복 1621 / 9295 | 시간 1053[s] | 손실 1.67
# | 에폭 3 |  반복 1641 / 9295 | 시간 1054[s] | 손실 1.68
# | 에폭 3 |  반복 1661 / 9295 | 시간 1055[s] | 손실 1.69
# | 에폭 3 |  반복 1681 / 9295 | 시간 1055[s] | 손실 1.68
# | 에폭 3 |  반복 1701 / 9295 | 시간 1056[s] | 손실 1.69
# | 에폭 3 |  반복 1721 / 9295 | 시간 1057[s] | 손실 1.69
# | 에폭 3 |  반복 1741 / 9295 | 시간 1058[s] | 손실 1.67
# | 에폭 3 |  반복 1761 / 9295 | 시간 1059[s] | 손실 1.66
# | 에폭 3 |  반복 1781 / 9295 | 시간 1060[s] | 손실 1.67
# | 에폭 3 |  반복 1801 / 9295 | 시간 1061[s] | 손실 1.70
# | 에폭 3 |  반복 1821 / 9295 | 시간 1062[s] | 손실 1.68
# | 에폭 3 |  반복 1841 / 9295 | 시간 1063[s] | 손실 1.69
# | 에폭 3 |  반복 1861 / 9295 | 시간 1064[s] | 손실 1.70
# | 에폭 3 |  반복 1881 / 9295 | 시간 1064[s] | 손실 1.68
# ...
# | 에폭 10 |  반복 3161 / 9295 | 시간 4195[s] | 손실 1.23
# | 에폭 10 |  반복 3181 / 9295 | 시간 4195[s] | 손실 1.20
# | 에폭 10 |  반복 3201 / 9295 | 시간 4196[s] | 손실 1.18
# | 에폭 10 |  반복 3221 / 9295 | 시간 4197[s] | 손실 1.17
# | 에폭 10 |  반복 3241 / 9295 | 시간 4198[s] | 손실 1.23
# | 에폭 10 |  반복 3261 / 9295 | 시간 4199[s] | 손실 1.20
# | 에폭 10 |  반복 3281 / 9295 | 시간 4200[s] | 손실 1.21
# | 에폭 10 |  반복 3301 / 9295 | 시간 4201[s] | 손실 1.19
# | 에폭 10 |  반복 3321 / 9295 | 시간 4202[s] | 손실 1.22
# | 에폭 10 |  반복 3341 / 9295 | 시간 4203[s] | 손실 1.18
# | 에폭 10 |  반복 3361 / 9295 | 시간 4204[s] | 손실 1.19
# | 에폭 10 |  반복 3381 / 9295 | 시간 4205[s] | 손실 1.20
# | 에폭 10 |  반복 3401 / 9295 | 시간 4206[s] | 손실 1.22
# | 에폭 10 |  반복 3421 / 9295 | 시간 4207[s] | 손실 1.21
# | 에폭 10 |  반복 3441 / 9295 | 시간 4208[s] | 손실 1.21
# | 에폭 10 |  반복 3461 / 9295 | 시간 4208[s] | 손실 1.20
# | 에폭 10 |  반복 3481 / 9295 | 시간 4209[s] | 손실 1.21
# | 에폭 10 |  반복 3501 / 9295 | 시간 4210[s] | 손실 1.19
# | 에폭 10 |  반복 3521 / 9295 | 시간 4211[s] | 손실 1.19
# | 에폭 10 |  반복 3541 / 9295 | 시간 4212[s] | 손실 1.18
# | 에폭 10 |  반복 3561 / 9295 | 시간 4213[s] | 손실 1.24
# | 에폭 10 |  반복 3581 / 9295 | 시간 4214[s] | 손실 1.17
# | 에폭 10 |  반복 3601 / 9295 | 시간 4215[s] | 손실 1.20
# | 에폭 10 |  반복 3621 / 9295 | 시간 4216[s] | 손실 1.24
# | 에폭 10 |  반복 3641 / 9295 | 시간 4217[s] | 손실 1.24
# | 에폭 10 |  반복 3661 / 9295 | 시간 4218[s] | 손실 1.17
# | 에폭 10 |  반복 3681 / 9295 | 시간 4219[s] | 손실 1.23
# | 에폭 10 |  반복 3701 / 9295 | 시간 4220[s] | 손실 1.22
# | 에폭 10 |  반복 3721 / 9295 | 시간 4221[s] | 손실 1.18
# | 에폭 10 |  반복 3741 / 9295 | 시간 4222[s] | 손실 1.18
# | 에폭 10 |  반복 3761 / 9295 | 시간 4223[s] | 손실 1.23
# | 에폭 10 |  반복 3781 / 9295 | 시간 4223[s] | 손실 1.22
# | 에폭 10 |  반복 3801 / 9295 | 시간 4224[s] | 손실 1.17
# | 에폭 10 |  반복 3821 / 9295 | 시간 4225[s] | 손실 1.23
# | 에폭 10 |  반복 3841 / 9295 | 시간 4226[s] | 손실 1.18
# | 에폭 10 |  반복 3861 / 9295 | 시간 4227[s] | 손실 1.23
# | 에폭 10 |  반복 3881 / 9295 | 시간 4228[s] | 손실 1.22
# | 에폭 10 |  반복 3901 / 9295 | 시간 4229[s] | 손실 1.19
# | 에폭 10 |  반복 3921 / 9295 | 시간 4231[s] | 손실 1.22
# | 에폭 10 |  반복 3941 / 9295 | 시간 4232[s] | 손실 1.17
# | 에폭 10 |  반복 3961 / 9295 | 시간 4233[s] | 손실 1.18
# | 에폭 10 |  반복 3981 / 9295 | 시간 4234[s] | 손실 1.19
# | 에폭 10 |  반복 4001 / 9295 | 시간 4235[s] | 손실 1.21
# | 에폭 10 |  반복 4021 / 9295 | 시간 4236[s] | 손실 1.21
# | 에폭 10 |  반복 4041 / 9295 | 시간 4237[s] | 손실 1.20
# | 에폭 10 |  반복 4061 / 9295 | 시간 4238[s] | 손실 1.19
# | 에폭 10 |  반복 4081 / 9295 | 시간 4239[s] | 손실 1.22
# | 에폭 10 |  반복 4101 / 9295 | 시간 4240[s] | 손실 1.24
# | 에폭 10 |  반복 4121 / 9295 | 시간 4242[s] | 손실 1.19
# | 에폭 10 |  반복 4141 / 9295 | 시간 4243[s] | 손실 1.21
# | 에폭 10 |  반복 4161 / 9295 | 시간 4244[s] | 손실 1.23
# | 에폭 10 |  반복 4181 / 9295 | 시간 4245[s] | 손실 1.22
# | 에폭 10 |  반복 4201 / 9295 | 시간 4246[s] | 손실 1.25
# | 에폭 10 |  반복 4221 / 9295 | 시간 4247[s] | 손실 1.22
# | 에폭 10 |  반복 4241 / 9295 | 시간 4248[s] | 손실 1.20
# | 에폭 10 |  반복 4261 / 9295 | 시간 4250[s] | 손실 1.21
# | 에폭 10 |  반복 4281 / 9295 | 시간 4251[s] | 손실 1.21
# | 에폭 10 |  반복 4301 / 9295 | 시간 4252[s] | 손실 1.21
# | 에폭 10 |  반복 4321 / 9295 | 시간 4253[s] | 손실 1.18
# | 에폭 10 |  반복 4341 / 9295 | 시간 4254[s] | 손실 1.24
# | 에폭 10 |  반복 4361 / 9295 | 시간 4255[s] | 손실 1.22
# | 에폭 10 |  반복 4381 / 9295 | 시간 4256[s] | 손실 1.24
# | 에폭 10 |  반복 4401 / 9295 | 시간 4257[s] | 손실 1.19
# | 에폭 10 |  반복 4421 / 9295 | 시간 4258[s] | 손실 1.20
# | 에폭 10 |  반복 4441 / 9295 | 시간 4259[s] | 손실 1.26
# | 에폭 10 |  반복 4461 / 9295 | 시간 4260[s] | 손실 1.14
# | 에폭 10 |  반복 4481 / 9295 | 시간 4261[s] | 손실 1.20
# | 에폭 10 |  반복 4501 / 9295 | 시간 4263[s] | 손실 1.22
# | 에폭 10 |  반복 4521 / 9295 | 시간 4264[s] | 손실 1.23
# | 에폭 10 |  반복 4541 / 9295 | 시간 4265[s] | 손실 1.17
# | 에폭 10 |  반복 4561 / 9295 | 시간 4266[s] | 손실 1.23
# | 에폭 10 |  반복 4581 / 9295 | 시간 4267[s] | 손실 1.23
# | 에폭 10 |  반복 4601 / 9295 | 시간 4268[s] | 손실 1.14
# | 에폭 10 |  반복 4621 / 9295 | 시간 4269[s] | 손실 1.20
# | 에폭 10 |  반복 4641 / 9295 | 시간 4270[s] | 손실 1.20
# | 에폭 10 |  반복 4661 / 9295 | 시간 4271[s] | 손실 1.24
# | 에폭 10 |  반복 4681 / 9295 | 시간 4272[s] | 손실 1.19
# | 에폭 10 |  반복 4701 / 9295 | 시간 4273[s] | 손실 1.20
# | 에폭 10 |  반복 4721 / 9295 | 시간 4274[s] | 손실 1.17
# | 에폭 10 |  반복 4741 / 9295 | 시간 4275[s] | 손실 1.23
# | 에폭 10 |  반복 4761 / 9295 | 시간 4276[s] | 손실 1.20
# | 에폭 10 |  반복 4781 / 9295 | 시간 4277[s] | 손실 1.24
# | 에폭 10 |  반복 4801 / 9295 | 시간 4278[s] | 손실 1.16
# | 에폭 10 |  반복 4821 / 9295 | 시간 4279[s] | 손실 1.19
# | 에폭 10 |  반복 4841 / 9295 | 시간 4281[s] | 손실 1.23
# | 에폭 10 |  반복 4861 / 9295 | 시간 4282[s] | 손실 1.21
# | 에폭 10 |  반복 4881 / 9295 | 시간 4283[s] | 손실 1.21
# | 에폭 10 |  반복 4901 / 9295 | 시간 4284[s] | 손실 1.20
# | 에폭 10 |  반복 4921 / 9295 | 시간 4285[s] | 손실 1.22
# | 에폭 10 |  반복 4941 / 9295 | 시간 4286[s] | 손실 1.23
# | 에폭 10 |  반복 4961 / 9295 | 시간 4287[s] | 손실 1.20
# | 에폭 10 |  반복 4981 / 9295 | 시간 4288[s] | 손실 1.22
# | 에폭 10 |  반복 5001 / 9295 | 시간 4289[s] | 손실 1.25
# | 에폭 10 |  반복 5021 / 9295 | 시간 4290[s] | 손실 1.23
# | 에폭 10 |  반복 5041 / 9295 | 시간 4291[s] | 손실 1.23
# | 에폭 10 |  반복 5061 / 9295 | 시간 4292[s] | 손실 1.17
# | 에폭 10 |  반복 5081 / 9295 | 시간 4293[s] | 손실 1.22
# | 에폭 10 |  반복 5101 / 9295 | 시간 4294[s] | 손실 1.19
# | 에폭 10 |  반복 5121 / 9295 | 시간 4296[s] | 손실 1.22
# | 에폭 10 |  반복 5141 / 9295 | 시간 4297[s] | 손실 1.26
# | 에폭 10 |  반복 5161 / 9295 | 시간 4298[s] | 손실 1.18
# | 에폭 10 |  반복 5181 / 9295 | 시간 4299[s] | 손실 1.25
# | 에폭 10 |  반복 5201 / 9295 | 시간 4300[s] | 손실 1.17
# | 에폭 10 |  반복 5221 / 9295 | 시간 4301[s] | 손실 1.19
# | 에폭 10 |  반복 5241 / 9295 | 시간 4302[s] | 손실 1.20
# | 에폭 10 |  반복 5261 / 9295 | 시간 4303[s] | 손실 1.21
# | 에폭 10 |  반복 5281 / 9295 | 시간 4304[s] | 손실 1.23
# | 에폭 10 |  반복 5301 / 9295 | 시간 4305[s] | 손실 1.21
# | 에폭 10 |  반복 5321 / 9295 | 시간 4306[s] | 손실 1.23
# | 에폭 10 |  반복 5341 / 9295 | 시간 4307[s] | 손실 1.17
# | 에폭 10 |  반복 5361 / 9295 | 시간 4308[s] | 손실 1.21
# | 에폭 10 |  반복 5381 / 9295 | 시간 4309[s] | 손실 1.21
# | 에폭 10 |  반복 5401 / 9295 | 시간 4310[s] | 손실 1.22
# | 에폭 10 |  반복 5421 / 9295 | 시간 4311[s] | 손실 1.22
# | 에폭 10 |  반복 5441 / 9295 | 시간 4312[s] | 손실 1.26
# | 에폭 10 |  반복 5461 / 9295 | 시간 4313[s] | 손실 1.19
# | 에폭 10 |  반복 5481 / 9295 | 시간 4314[s] | 손실 1.22
# | 에폭 10 |  반복 5501 / 9295 | 시간 4316[s] | 손실 1.20
# | 에폭 10 |  반복 5521 / 9295 | 시간 4317[s] | 손실 1.22
# | 에폭 10 |  반복 5541 / 9295 | 시간 4318[s] | 손실 1.16
# | 에폭 10 |  반복 5561 / 9295 | 시간 4319[s] | 손실 1.20
# | 에폭 10 |  반복 5581 / 9295 | 시간 4320[s] | 손실 1.21
# | 에폭 10 |  반복 5601 / 9295 | 시간 4321[s] | 손실 1.24
# | 에폭 10 |  반복 5621 / 9295 | 시간 4322[s] | 손실 1.21
# | 에폭 10 |  반복 5641 / 9295 | 시간 4323[s] | 손실 1.21
# | 에폭 10 |  반복 5661 / 9295 | 시간 4324[s] | 손실 1.24
# | 에폭 10 |  반복 5681 / 9295 | 시간 4325[s] | 손실 1.20
# | 에폭 10 |  반복 5701 / 9295 | 시간 4326[s] | 손실 1.24
# | 에폭 10 |  반복 5721 / 9295 | 시간 4327[s] | 손실 1.26
# | 에폭 10 |  반복 5741 / 9295 | 시간 4328[s] | 손실 1.20
# | 에폭 10 |  반복 5761 / 9295 | 시간 4329[s] | 손실 1.21
# | 에폭 10 |  반복 5781 / 9295 | 시간 4330[s] | 손실 1.21
# | 에폭 10 |  반복 5801 / 9295 | 시간 4331[s] | 손실 1.20
# | 에폭 10 |  반복 5821 / 9295 | 시간 4332[s] | 손실 1.21
# | 에폭 10 |  반복 5841 / 9295 | 시간 4333[s] | 손실 1.27
# | 에폭 10 |  반복 5861 / 9295 | 시간 4334[s] | 손실 1.22
# | 에폭 10 |  반복 5881 / 9295 | 시간 4335[s] | 손실 1.22
# | 에폭 10 |  반복 5901 / 9295 | 시간 4336[s] | 손실 1.22
# | 에폭 10 |  반복 5921 / 9295 | 시간 4337[s] | 손실 1.17
# | 에폭 10 |  반복 5941 / 9295 | 시간 4338[s] | 손실 1.22
# | 에폭 10 |  반복 5961 / 9295 | 시간 4339[s] | 손실 1.25
# | 에폭 10 |  반복 5981 / 9295 | 시간 4340[s] | 손실 1.22
# | 에폭 10 |  반복 6001 / 9295 | 시간 4341[s] | 손실 1.20
# | 에폭 10 |  반복 6021 / 9295 | 시간 4342[s] | 손실 1.20
# | 에폭 10 |  반복 6041 / 9295 | 시간 4343[s] | 손실 1.20
# | 에폭 10 |  반복 6061 / 9295 | 시간 4344[s] | 손실 1.20
# | 에폭 10 |  반복 6081 / 9295 | 시간 4345[s] | 손실 1.21
# | 에폭 10 |  반복 6101 / 9295 | 시간 4346[s] | 손실 1.19
# | 에폭 10 |  반복 6121 / 9295 | 시간 4347[s] | 손실 1.20
# | 에폭 10 |  반복 6141 / 9295 | 시간 4348[s] | 손실 1.22
# | 에폭 10 |  반복 6161 / 9295 | 시간 4349[s] | 손실 1.21
# | 에폭 10 |  반복 6181 / 9295 | 시간 4349[s] | 손실 1.17
# | 에폭 10 |  반복 6201 / 9295 | 시간 4350[s] | 손실 1.21
# | 에폭 10 |  반복 6221 / 9295 | 시간 4351[s] | 손실 1.19
# | 에폭 10 |  반복 6241 / 9295 | 시간 4352[s] | 손실 1.20
# | 에폭 10 |  반복 6261 / 9295 | 시간 4353[s] | 손실 1.19
# | 에폭 10 |  반복 6281 / 9295 | 시간 4354[s] | 손실 1.23
# | 에폭 10 |  반복 6301 / 9295 | 시간 4355[s] | 손실 1.19
# | 에폭 10 |  반복 6321 / 9295 | 시간 4356[s] | 손실 1.19
# | 에폭 10 |  반복 6341 / 9295 | 시간 4357[s] | 손실 1.19
# | 에폭 10 |  반복 6361 / 9295 | 시간 4358[s] | 손실 1.23
# | 에폭 10 |  반복 6381 / 9295 | 시간 4359[s] | 손실 1.20
# | 에폭 10 |  반복 6401 / 9295 | 시간 4360[s] | 손실 1.23
# | 에폭 10 |  반복 6421 / 9295 | 시간 4361[s] | 손실 1.22
# | 에폭 10 |  반복 6441 / 9295 | 시간 4362[s] | 손실 1.22
# | 에폭 10 |  반복 6461 / 9295 | 시간 4363[s] | 손실 1.27
# | 에폭 10 |  반복 6481 / 9295 | 시간 4364[s] | 손실 1.23
# | 에폭 10 |  반복 6501 / 9295 | 시간 4365[s] | 손실 1.21
# | 에폭 10 |  반복 6521 / 9295 | 시간 4366[s] | 손실 1.22
# | 에폭 10 |  반복 6541 / 9295 | 시간 4367[s] | 손실 1.21
# | 에폭 10 |  반복 6561 / 9295 | 시간 4367[s] | 손실 1.19
# | 에폭 10 |  반복 6581 / 9295 | 시간 4368[s] | 손실 1.24
# | 에폭 10 |  반복 6601 / 9295 | 시간 4369[s] | 손실 1.22
# | 에폭 10 |  반복 6621 / 9295 | 시간 4370[s] | 손실 1.25
# | 에폭 10 |  반복 6641 / 9295 | 시간 4371[s] | 손실 1.20
# | 에폭 10 |  반복 6661 / 9295 | 시간 4372[s] | 손실 1.24
# | 에폭 10 |  반복 6681 / 9295 | 시간 4373[s] | 손실 1.22
# | 에폭 10 |  반복 6701 / 9295 | 시간 4374[s] | 손실 1.23
# | 에폭 10 |  반복 6721 / 9295 | 시간 4375[s] | 손실 1.19
# | 에폭 10 |  반복 6741 / 9295 | 시간 4376[s] | 손실 1.21
# | 에폭 10 |  반복 6761 / 9295 | 시간 4377[s] | 손실 1.27
# | 에폭 10 |  반복 6781 / 9295 | 시간 4378[s] | 손실 1.26
# | 에폭 10 |  반복 6801 / 9295 | 시간 4379[s] | 손실 1.21
# | 에폭 10 |  반복 6821 / 9295 | 시간 4380[s] | 손실 1.24
# | 에폭 10 |  반복 6841 / 9295 | 시간 4381[s] | 손실 1.23
# | 에폭 10 |  반복 6861 / 9295 | 시간 4382[s] | 손실 1.25
# | 에폭 10 |  반복 6881 / 9295 | 시간 4382[s] | 손실 1.24
# | 에폭 10 |  반복 6901 / 9295 | 시간 4383[s] | 손실 1.22
# | 에폭 10 |  반복 6921 / 9295 | 시간 4384[s] | 손실 1.20
# | 에폭 10 |  반복 6941 / 9295 | 시간 4385[s] | 손실 1.23
# | 에폭 10 |  반복 6961 / 9295 | 시간 4386[s] | 손실 1.23
# | 에폭 10 |  반복 6981 / 9295 | 시간 4387[s] | 손실 1.22
# | 에폭 10 |  반복 7001 / 9295 | 시간 4388[s] | 손실 1.24
# | 에폭 10 |  반복 7021 / 9295 | 시간 4389[s] | 손실 1.26
# | 에폭 10 |  반복 7041 / 9295 | 시간 4390[s] | 손실 1.23
# | 에폭 10 |  반복 7061 / 9295 | 시간 4391[s] | 손실 1.19
# | 에폭 10 |  반복 7081 / 9295 | 시간 4392[s] | 손실 1.25
# | 에폭 10 |  반복 7101 / 9295 | 시간 4393[s] | 손실 1.24
# | 에폭 10 |  반복 7121 / 9295 | 시간 4394[s] | 손실 1.26
# | 에폭 10 |  반복 7141 / 9295 | 시간 4395[s] | 손실 1.26
# | 에폭 10 |  반복 7161 / 9295 | 시간 4396[s] | 손실 1.18
# | 에폭 10 |  반복 7181 / 9295 | 시간 4397[s] | 손실 1.20
# | 에폭 10 |  반복 7201 / 9295 | 시간 4398[s] | 손실 1.22
# | 에폭 10 |  반복 7221 / 9295 | 시간 4399[s] | 손실 1.24
# | 에폭 10 |  반복 7241 / 9295 | 시간 4399[s] | 손실 1.26
# | 에폭 10 |  반복 7261 / 9295 | 시간 4400[s] | 손실 1.21
# | 에폭 10 |  반복 7281 / 9295 | 시간 4401[s] | 손실 1.20
# | 에폭 10 |  반복 7301 / 9295 | 시간 4402[s] | 손실 1.23
# | 에폭 10 |  반복 7321 / 9295 | 시간 4403[s] | 손실 1.23
# | 에폭 10 |  반복 7341 / 9295 | 시간 4404[s] | 손실 1.22
# | 에폭 10 |  반복 7361 / 9295 | 시간 4405[s] | 손실 1.21
# | 에폭 10 |  반복 7381 / 9295 | 시간 4406[s] | 손실 1.21
# | 에폭 10 |  반복 7401 / 9295 | 시간 4407[s] | 손실 1.22
# | 에폭 10 |  반복 7421 / 9295 | 시간 4408[s] | 손실 1.19
# | 에폭 10 |  반복 7441 / 9295 | 시간 4409[s] | 손실 1.22
# | 에폭 10 |  반복 7461 / 9295 | 시간 4410[s] | 손실 1.26
# | 에폭 10 |  반복 7481 / 9295 | 시간 4411[s] | 손실 1.23
# | 에폭 10 |  반복 7501 / 9295 | 시간 4412[s] | 손실 1.18
# | 에폭 10 |  반복 7521 / 9295 | 시간 4413[s] | 손실 1.26
# | 에폭 10 |  반복 7541 / 9295 | 시간 4414[s] | 손실 1.28
# | 에폭 10 |  반복 7561 / 9295 | 시간 4415[s] | 손실 1.22
# | 에폭 10 |  반복 7581 / 9295 | 시간 4416[s] | 손실 1.24
# | 에폭 10 |  반복 7601 / 9295 | 시간 4417[s] | 손실 1.23
# | 에폭 10 |  반복 7621 / 9295 | 시간 4418[s] | 손실 1.17
# | 에폭 10 |  반복 7641 / 9295 | 시간 4419[s] | 손실 1.24
# | 에폭 10 |  반복 7661 / 9295 | 시간 4420[s] | 손실 1.19
# | 에폭 10 |  반복 7681 / 9295 | 시간 4421[s] | 손실 1.23
# | 에폭 10 |  반복 7701 / 9295 | 시간 4422[s] | 손실 1.21
# | 에폭 10 |  반복 7721 / 9295 | 시간 4423[s] | 손실 1.20
# | 에폭 10 |  반복 7741 / 9295 | 시간 4424[s] | 손실 1.17
# | 에폭 10 |  반복 7761 / 9295 | 시간 4425[s] | 손실 1.23
# | 에폭 10 |  반복 7781 / 9295 | 시간 4426[s] | 손실 1.24
# | 에폭 10 |  반복 7801 / 9295 | 시간 4427[s] | 손실 1.23
# | 에폭 10 |  반복 7821 / 9295 | 시간 4427[s] | 손실 1.22
# | 에폭 10 |  반복 7841 / 9295 | 시간 4428[s] | 손실 1.22
# | 에폭 10 |  반복 7861 / 9295 | 시간 4429[s] | 손실 1.22
# | 에폭 10 |  반복 7881 / 9295 | 시간 4430[s] | 손실 1.26
# | 에폭 10 |  반복 7901 / 9295 | 시간 4431[s] | 손실 1.18
# | 에폭 10 |  반복 7921 / 9295 | 시간 4432[s] | 손실 1.23
# | 에폭 10 |  반복 7941 / 9295 | 시간 4433[s] | 손실 1.22
# | 에폭 10 |  반복 7961 / 9295 | 시간 4434[s] | 손실 1.22
# | 에폭 10 |  반복 7981 / 9295 | 시간 4435[s] | 손실 1.21
# | 에폭 10 |  반복 8001 / 9295 | 시간 4436[s] | 손실 1.21
# | 에폭 10 |  반복 8021 / 9295 | 시간 4437[s] | 손실 1.22
# | 에폭 10 |  반복 8041 / 9295 | 시간 4438[s] | 손실 1.24
# | 에폭 10 |  반복 8061 / 9295 | 시간 4440[s] | 손실 1.24
# | 에폭 10 |  반복 8081 / 9295 | 시간 4441[s] | 손실 1.21
# | 에폭 10 |  반복 8101 / 9295 | 시간 4442[s] | 손실 1.24
# | 에폭 10 |  반복 8121 / 9295 | 시간 4443[s] | 손실 1.22
# | 에폭 10 |  반복 8141 / 9295 | 시간 4444[s] | 손실 1.25
# | 에폭 10 |  반복 8161 / 9295 | 시간 4445[s] | 손실 1.23
# | 에폭 10 |  반복 8181 / 9295 | 시간 4446[s] | 손실 1.24
# | 에폭 10 |  반복 8201 / 9295 | 시간 4448[s] | 손실 1.22
# | 에폭 10 |  반복 8221 / 9295 | 시간 4449[s] | 손실 1.20
# | 에폭 10 |  반복 8241 / 9295 | 시간 4450[s] | 손실 1.19
# | 에폭 10 |  반복 8261 / 9295 | 시간 4451[s] | 손실 1.23
# | 에폭 10 |  반복 8281 / 9295 | 시간 4452[s] | 손실 1.22
# | 에폭 10 |  반복 8301 / 9295 | 시간 4453[s] | 손실 1.27
# | 에폭 10 |  반복 8321 / 9295 | 시간 4454[s] | 손실 1.20
# | 에폭 10 |  반복 8341 / 9295 | 시간 4455[s] | 손실 1.22
# | 에폭 10 |  반복 8361 / 9295 | 시간 4456[s] | 손실 1.25
# | 에폭 10 |  반복 8381 / 9295 | 시간 4458[s] | 손실 1.24
# | 에폭 10 |  반복 8401 / 9295 | 시간 4459[s] | 손실 1.18
# | 에폭 10 |  반복 8421 / 9295 | 시간 4460[s] | 손실 1.22
# | 에폭 10 |  반복 8441 / 9295 | 시간 4461[s] | 손실 1.24
# | 에폭 10 |  반복 8461 / 9295 | 시간 4462[s] | 손실 1.23
# | 에폭 10 |  반복 8481 / 9295 | 시간 4463[s] | 손실 1.28
# | 에폭 10 |  반복 8501 / 9295 | 시간 4464[s] | 손실 1.21
# | 에폭 10 |  반복 8521 / 9295 | 시간 4464[s] | 손실 1.23
# | 에폭 10 |  반복 8541 / 9295 | 시간 4465[s] | 손실 1.21
# | 에폭 10 |  반복 8561 / 9295 | 시간 4466[s] | 손실 1.21
# | 에폭 10 |  반복 8581 / 9295 | 시간 4467[s] | 손실 1.22
# | 에폭 10 |  반복 8601 / 9295 | 시간 4468[s] | 손실 1.19
# | 에폭 10 |  반복 8621 / 9295 | 시간 4469[s] | 손실 1.21
# | 에폭 10 |  반복 8641 / 9295 | 시간 4470[s] | 손실 1.18
# | 에폭 10 |  반복 8661 / 9295 | 시간 4471[s] | 손실 1.23
# | 에폭 10 |  반복 8681 / 9295 | 시간 4472[s] | 손실 1.22
# | 에폭 10 |  반복 8701 / 9295 | 시간 4473[s] | 손실 1.24
# | 에폭 10 |  반복 8721 / 9295 | 시간 4474[s] | 손실 1.20
# | 에폭 10 |  반복 8741 / 9295 | 시간 4475[s] | 손실 1.21
# | 에폭 10 |  반복 8761 / 9295 | 시간 4476[s] | 손실 1.19
# | 에폭 10 |  반복 8781 / 9295 | 시간 4477[s] | 손실 1.27
# | 에폭 10 |  반복 8801 / 9295 | 시간 4478[s] | 손실 1.25
# | 에폭 10 |  반복 8821 / 9295 | 시간 4478[s] | 손실 1.25
# | 에폭 10 |  반복 8841 / 9295 | 시간 4479[s] | 손실 1.22
# | 에폭 10 |  반복 8861 / 9295 | 시간 4480[s] | 손실 1.21
# | 에폭 10 |  반복 8881 / 9295 | 시간 4481[s] | 손실 1.21
# | 에폭 10 |  반복 8901 / 9295 | 시간 4482[s] | 손실 1.26
# | 에폭 10 |  반복 8921 / 9295 | 시간 4483[s] | 손실 1.21
# | 에폭 10 |  반복 8941 / 9295 | 시간 4484[s] | 손실 1.21
# | 에폭 10 |  반복 8961 / 9295 | 시간 4485[s] | 손실 1.24
# | 에폭 10 |  반복 8981 / 9295 | 시간 4486[s] | 손실 1.18
# | 에폭 10 |  반복 9001 / 9295 | 시간 4487[s] | 손실 1.19
# | 에폭 10 |  반복 9021 / 9295 | 시간 4488[s] | 손실 1.24
# | 에폭 10 |  반복 9041 / 9295 | 시간 4489[s] | 손실 1.22
# | 에폭 10 |  반복 9061 / 9295 | 시간 4490[s] | 손실 1.24
# | 에폭 10 |  반복 9081 / 9295 | 시간 4491[s] | 손실 1.25
# | 에폭 10 |  반복 9101 / 9295 | 시간 4492[s] | 손실 1.22
# | 에폭 10 |  반복 9121 / 9295 | 시간 4493[s] | 손실 1.23
# | 에폭 10 |  반복 9141 / 9295 | 시간 4493[s] | 손실 1.28
# | 에폭 10 |  반복 9161 / 9295 | 시간 4494[s] | 손실 1.22
# | 에폭 10 |  반복 9181 / 9295 | 시간 4495[s] | 손실 1.20
# | 에폭 10 |  반복 9201 / 9295 | 시간 4496[s] | 손실 1.25
# | 에폭 10 |  반복 9221 / 9295 | 시간 4497[s] | 손실 1.22
# | 에폭 10 |  반복 9241 / 9295 | 시간 4498[s] | 손실 1.25
# | 에폭 10 |  반복 9261 / 9295 | 시간 4499[s] | 손실 1.21
# | 에폭 10 |  반복 9281 / 9295 | 시간 4500[s] | 손실 1.24
# c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48152 (\N{HANGUL SYLLABLE BAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48373 (\N{HANGUL SYLLABLE BOG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49552 (\N{HANGUL SYLLABLE SON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 유추(analogy) 작업
print('-'*50)
print("추론 기반 기법 결과")
analogy('king', 'man', 'queen',  word_to_id, id_to_word, word_vecs)
analogy('take', 'took', 'go',  word_to_id, id_to_word, word_vecs)
analogy('car', 'cars', 'child',  word_to_id, id_to_word, word_vecs)
analogy('good', 'better', 'bad',  word_to_id, id_to_word, word_vecs)
# Out:
# --------------------------------------------------
# 추론 기반 기법 결과
#
# [analogy] king:man = queen:?
#  reason: 4.16910982131958
#  thing: 3.5434231758117676
#  respect: 3.3454971313476562
#  woman: 3.197848081588745
#  decade: 3.1147024631500244
#
# [analogy] take:took = go:?
#  ended: 3.5958752632141113
#  went: 3.234353542327881
#  lived: 3.114945888519287
#  goes: 3.0501818656921387
#  east: 2.9858169555664062
#
# [analogy] car:cars = child:?
#  cubic: 3.42816162109375
#  duties: 3.27427077293396
#  homes: 3.2662317752838135
#  rape: 3.264554262161255
#  children: 3.2632460594177246
#
# [analogy] good:better = bad:?
#  greater: 3.6844727993011475
#  less: 3.508070707321167
#  n't: 3.4903883934020996
#  outweigh: 2.9878413677215576
#  more: 2.9800236225128174
