# %%
# coding: utf-8
import sys
sys.path.append('C:/Users/KimDongyoung/Desktop/Github/my_git/mygit/DEEPLEARNING/밑바닥부터시작하는딥러닝2')
import numpy as np
import matplotlib.pyplot as plt
import sequence as sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq
from seq2seq import Seq2seq
from ch07.peeky_seq2seq import PeekySeq2seq

# %%
# 데이터셋 읽기
(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
char_to_id, id_to_char = sequence.get_vocab()

# 입력 반전 여부 설정 =============================================
is_reverse = False  # True
if is_reverse:
    x_train, x_test = x_train[:, ::-1], x_test[:, ::-1]
# ================================================================

# %%
# 하이퍼파라미터 설정
vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size_list = [64, 128, 256]  # 다양한 hidden_size 값
batch_size = 128
max_epoch = 25
max_grad = 5.0

results = {}

for hidden_size in hidden_size_list:
    print(f"Training with hidden_size={hidden_size}...")
    model = Seq2seq(vocab_size, wordvec_size, hidden_size)
    # model = PeekySeq2seq(vocab_size, wordvec_size, hidden_size)
    optimizer = Adam()
    trainer = Trainer(model, optimizer)

    acc_list = []
    for epoch in range(max_epoch):
        trainer.fit(x_train, t_train, max_epoch=1,
                    batch_size=batch_size, max_grad=max_grad)

        correct_num = 0
        for i in range(len(x_test)):
            question, correct = x_test[[i]], t_test[[i]]
            verbose = i < 10
            correct_num += eval_seq2seq(model, question, correct,
                                        id_to_char, verbose, is_reverse)

        acc = float(correct_num) / len(x_test)
        acc_list.append(acc)
        print(f'검증 정확도 %.3f%%' % (acc * 100))

    results[hidden_size] = acc_list
# Out:
# Training with hidden_size=64...
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 2.56
# | 에폭 1 |  반복 21 / 351 | 시간 0[s] | 손실 2.54
# | 에폭 1 |  반복 41 / 351 | 시간 0[s] | 손실 2.35
# | 에폭 1 |  반복 61 / 351 | 시간 1[s] | 손실 2.12
# | 에폭 1 |  반복 81 / 351 | 시간 1[s] | 손실 1.98
# | 에폭 1 |  반복 101 / 351 | 시간 2[s] | 손실 1.92
# | 에폭 1 |  반복 121 / 351 | 시간 2[s] | 손실 1.89
# | 에폭 1 |  반복 141 / 351 | 시간 2[s] | 손실 1.86
# | 에폭 1 |  반복 161 / 351 | 시간 3[s] | 손실 1.85
# | 에폭 1 |  반복 181 / 351 | 시간 3[s] | 손실 1.81
# | 에폭 1 |  반복 201 / 351 | 시간 4[s] | 손실 1.79
# | 에폭 1 |  반복 221 / 351 | 시간 4[s] | 손실 1.79
# | 에폭 1 |  반복 241 / 351 | 시간 4[s] | 손실 1.77
# | 에폭 1 |  반복 261 / 351 | 시간 5[s] | 손실 1.77
# | 에폭 1 |  반복 281 / 351 | 시간 5[s] | 손실 1.76
# | 에폭 1 |  반복 301 / 351 | 시간 6[s] | 손실 1.77
# | 에폭 1 |  반복 321 / 351 | 시간 6[s] | 손실 1.76
# | 에폭 1 |  반복 341 / 351 | 시간 6[s] | 손실 1.76
# Q 77+85
# T 162
# X 100
# ---
# Q 975+164
# T 1139
# X 1000
# ---
# Q 582+84
# T 666
# X 1003
# ---
# Q 8+155
# T 163
# X 100
# ---
# Q 367+55
# T 422
# X 1003
# ---
# Q 600+257
# T 857
# X 1000
# ---
# Q 761+292
# T 1053
# X 1000
# ---
# Q 830+597
# T 1427
# X 1000
# ---
# Q 26+838
# T 864
# X 100
# ---
# Q 143+93
# T 236
# X 100
# ---
# 검증 정확도 0.200%
# | 에폭 2 |  반복 1 / 351 | 시간 0[s] | 손실 1.76
# | 에폭 2 |  반복 21 / 351 | 시간 0[s] | 손실 1.75
# | 에폭 2 |  반복 41 / 351 | 시간 0[s] | 손실 1.75
# | 에폭 2 |  반복 61 / 351 | 시간 1[s] | 손실 1.75
# | 에폭 2 |  반복 81 / 351 | 시간 1[s] | 손실 1.74
# | 에폭 2 |  반복 101 / 351 | 시간 2[s] | 손실 1.74
# | 에폭 2 |  반복 121 / 351 | 시간 2[s] | 손실 1.74
# | 에폭 2 |  반복 141 / 351 | 시간 2[s] | 손실 1.74
# | 에폭 2 |  반복 161 / 351 | 시간 3[s] | 손실 1.73
# | 에폭 2 |  반복 181 / 351 | 시간 3[s] | 손실 1.73
# | 에폭 2 |  반복 201 / 351 | 시간 4[s] | 손실 1.73
# | 에폭 2 |  반복 221 / 351 | 시간 4[s] | 손실 1.73
# | 에폭 2 |  반복 241 / 351 | 시간 4[s] | 손실 1.72
# | 에폭 2 |  반복 261 / 351 | 시간 5[s] | 손실 1.72
# | 에폭 2 |  반복 281 / 351 | 시간 5[s] | 손실 1.72
# | 에폭 2 |  반복 301 / 351 | 시간 6[s] | 손실 1.71
# | 에폭 2 |  반복 321 / 351 | 시간 6[s] | 손실 1.71
# | 에폭 2 |  반복 341 / 351 | 시간 6[s] | 손실 1.71
# Q 77+85
# T 162
# X 100
# ---
# Q 975+164
# T 1139
# X 1022
# ---
# Q 582+84
# T 666
# X 1000
# ---
# Q 8+155
# T 163
# X 100
# ---
# Q 367+55
# T 422
# X 100
# ---
# Q 600+257
# T 857
# X 1022
# ---
# Q 761+292
# T 1053
# X 1022
# ---
# Q 830+597
# T 1427
# X 1022
# ---
# Q 26+838
# T 864
# X 100
# ---
# Q 143+93
# T 236
# X 622
# ---
# 검증 정확도 0.120%
# | 에폭 3 |  반복 1 / 351 | 시간 0[s] | 손실 1.71
# | 에폭 3 |  반복 21 / 351 | 시간 0[s] | 손실 1.70
# | 에폭 3 |  반복 41 / 351 | 시간 0[s] | 손실 1.70
# | 에폭 3 |  반복 61 / 351 | 시간 1[s] | 손실 1.69
# | 에폭 3 |  반복 81 / 351 | 시간 1[s] | 손실 1.69
# | 에폭 3 |  반복 101 / 351 | 시간 1[s] | 손실 1.68
# | 에폭 3 |  반복 121 / 351 | 시간 2[s] | 손실 1.68
# | 에폭 3 |  반복 141 / 351 | 시간 2[s] | 손실 1.67
# | 에폭 3 |  반복 161 / 351 | 시간 3[s] | 손실 1.66
# | 에폭 3 |  반복 181 / 351 | 시간 3[s] | 손실 1.66
# | 에폭 3 |  반복 201 / 351 | 시간 3[s] | 손실 1.65
# | 에폭 3 |  반복 221 / 351 | 시간 4[s] | 손실 1.64
# | 에폭 3 |  반복 241 / 351 | 시간 4[s] | 손실 1.63
# | 에폭 3 |  반복 261 / 351 | 시간 5[s] | 손실 1.62
# | 에폭 3 |  반복 281 / 351 | 시간 5[s] | 손실 1.61
# | 에폭 3 |  반복 301 / 351 | 시간 5[s] | 손실 1.61
# | 에폭 3 |  반복 321 / 351 | 시간 6[s] | 손실 1.60
# | 에폭 3 |  반복 341 / 351 | 시간 6[s] | 손실 1.59
# Q 77+85
# T 162
# X 101
# ---
# Q 975+164
# T 1139
# X 1100
# ---
# Q 582+84
# T 666
# X 694
# ---
# Q 8+155
# T 163
# X 218
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 992
# ---
# Q 761+292
# T 1053
# X 1010
# ---
# Q 830+597
# T 1427
# X 1266
# ---
# Q 26+838
# T 864
# X 894
# ---
# Q 143+93
# T 236
# X 422
# ---
# 검증 정확도 0.500%
# | 에폭 4 |  반복 1 / 351 | 시간 0[s] | 손실 1.57
# | 에폭 4 |  반복 21 / 351 | 시간 0[s] | 손실 1.57
# | 에폭 4 |  반복 41 / 351 | 시간 0[s] | 손실 1.58
# | 에폭 4 |  반복 61 / 351 | 시간 1[s] | 손실 1.56
# | 에폭 4 |  반복 81 / 351 | 시간 1[s] | 손실 1.56
# | 에폭 4 |  반복 101 / 351 | 시간 2[s] | 손실 1.55
# | 에폭 4 |  반복 121 / 351 | 시간 2[s] | 손실 1.55
# | 에폭 4 |  반복 141 / 351 | 시간 2[s] | 손실 1.54
# | 에폭 4 |  반복 161 / 351 | 시간 3[s] | 손실 1.53
# | 에폭 4 |  반복 181 / 351 | 시간 3[s] | 손실 1.53
# | 에폭 4 |  반복 201 / 351 | 시간 4[s] | 손실 1.52
# | 에폭 4 |  반복 221 / 351 | 시간 4[s] | 손실 1.51
# | 에폭 4 |  반복 241 / 351 | 시간 4[s] | 손실 1.51
# | 에폭 4 |  반복 261 / 351 | 시간 5[s] | 손실 1.50
# | 에폭 4 |  반복 281 / 351 | 시간 5[s] | 손실 1.49
# | 에폭 4 |  반복 301 / 351 | 시간 6[s] | 손실 1.49
# | 에폭 4 |  반복 321 / 351 | 시간 6[s] | 손실 1.48
# | 에폭 4 |  반복 341 / 351 | 시간 7[s] | 손실 1.47
# Q 77+85
# T 162
# X 100
# ---
# Q 975+164
# T 1139
# X 1100
# ---
# Q 582+84
# T 666
# X 600
# ---
# Q 8+155
# T 163
# X 103
# ---
# Q 367+55
# T 422
# X 482
# ---
# Q 600+257
# T 857
# X 801
# ---
# Q 761+292
# T 1053
# X 1010
# ---
# Q 830+597
# T 1427
# X 1200
# ---
# Q 26+838
# T 864
# X 898
# ---
# Q 143+93
# T 236
# X 332
# ---
# 검증 정확도 0.680%
# | 에폭 5 |  반복 1 / 351 | 시간 0[s] | 손실 1.47
# | 에폭 5 |  반복 21 / 351 | 시간 0[s] | 손실 1.46
# | 에폭 5 |  반복 41 / 351 | 시간 0[s] | 손실 1.46
# | 에폭 5 |  반복 61 / 351 | 시간 1[s] | 손실 1.45
# | 에폭 5 |  반복 81 / 351 | 시간 1[s] | 손실 1.45
# | 에폭 5 |  반복 101 / 351 | 시간 2[s] | 손실 1.44
# | 에폭 5 |  반복 121 / 351 | 시간 2[s] | 손실 1.44
# | 에폭 5 |  반복 141 / 351 | 시간 3[s] | 손실 1.43
# | 에폭 5 |  반복 161 / 351 | 시간 3[s] | 손실 1.42
# | 에폭 5 |  반복 181 / 351 | 시간 3[s] | 손실 1.42
# | 에폭 5 |  반복 201 / 351 | 시간 4[s] | 손실 1.41
# | 에폭 5 |  반복 221 / 351 | 시간 4[s] | 손실 1.41
# | 에폭 5 |  반복 241 / 351 | 시간 5[s] | 손실 1.40
# | 에폭 5 |  반복 261 / 351 | 시간 5[s] | 손실 1.39
# | 에폭 5 |  반복 281 / 351 | 시간 5[s] | 손실 1.39
# | 에폭 5 |  반복 301 / 351 | 시간 6[s] | 손실 1.38
# | 에폭 5 |  반복 321 / 351 | 시간 6[s] | 손실 1.38
# | 에폭 5 |  반복 341 / 351 | 시간 7[s] | 손실 1.37
# Q 77+85
# T 162
# X 101
# ---
# Q 975+164
# T 1139
# X 1120
# ---
# Q 582+84
# T 666
# X 613
# ---
# Q 8+155
# T 163
# X 116
# ---
# Q 367+55
# T 422
# X 421
# ---
# Q 600+257
# T 857
# X 810
# ---
# Q 761+292
# T 1053
# X 1021
# ---
# Q 830+597
# T 1427
# X 1406
# ---
# Q 26+838
# T 864
# X 934
# ---
# Q 143+93
# T 236
# X 325
# ---
# 검증 정확도 0.960%
# | 에폭 6 |  반복 1 / 351 | 시간 0[s] | 손실 1.36
# | 에폭 6 |  반복 21 / 351 | 시간 0[s] | 손실 1.36
# | 에폭 6 |  반복 41 / 351 | 시간 0[s] | 손실 1.35
# | 에폭 6 |  반복 61 / 351 | 시간 1[s] | 손실 1.35
# | 에폭 6 |  반복 81 / 351 | 시간 1[s] | 손실 1.35
# | 에폭 6 |  반복 101 / 351 | 시간 2[s] | 손실 1.35
# | 에폭 6 |  반복 121 / 351 | 시간 2[s] | 손실 1.33
# | 에폭 6 |  반복 141 / 351 | 시간 2[s] | 손실 1.33
# | 에폭 6 |  반복 161 / 351 | 시간 3[s] | 손실 1.33
# | 에폭 6 |  반복 181 / 351 | 시간 3[s] | 손실 1.33
# | 에폭 6 |  반복 201 / 351 | 시간 4[s] | 손실 1.32
# | 에폭 6 |  반복 221 / 351 | 시간 4[s] | 손실 1.32
# | 에폭 6 |  반복 241 / 351 | 시간 5[s] | 손실 1.31
# | 에폭 6 |  반복 261 / 351 | 시간 5[s] | 손실 1.31
# | 에폭 6 |  반복 281 / 351 | 시간 6[s] | 손실 1.30
# | 에폭 6 |  반복 301 / 351 | 시간 6[s] | 손실 1.30
# | 에폭 6 |  반복 321 / 351 | 시간 7[s] | 손실 1.30
# | 에폭 6 |  반복 341 / 351 | 시간 7[s] | 손실 1.29
# Q 77+85
# T 162
# X 110
# ---
# Q 975+164
# T 1139
# X 1147
# ---
# Q 582+84
# T 666
# X 722
# ---
# Q 8+155
# T 163
# X 173
# ---
# Q 367+55
# T 422
# X 440
# ---
# Q 600+257
# T 857
# X 893
# ---
# Q 761+292
# T 1053
# X 1020
# ---
# Q 830+597
# T 1427
# X 1479
# ---
# Q 26+838
# T 864
# X 875
# ---
# Q 143+93
# T 236
# X 207
# ---
# 검증 정확도 1.820%
# | 에폭 7 |  반복 1 / 351 | 시간 0[s] | 손실 1.27
# | 에폭 7 |  반복 21 / 351 | 시간 0[s] | 손실 1.28
# | 에폭 7 |  반복 41 / 351 | 시간 1[s] | 손실 1.28
# | 에폭 7 |  반복 61 / 351 | 시간 1[s] | 손실 1.28
# | 에폭 7 |  반복 81 / 351 | 시간 2[s] | 손실 1.27
# | 에폭 7 |  반복 101 / 351 | 시간 2[s] | 손실 1.26
# | 에폭 7 |  반복 121 / 351 | 시간 3[s] | 손실 1.27
# | 에폭 7 |  반복 141 / 351 | 시간 3[s] | 손실 1.26
# | 에폭 7 |  반복 161 / 351 | 시간 4[s] | 손실 1.26
# | 에폭 7 |  반복 181 / 351 | 시간 4[s] | 손실 1.25
# | 에폭 7 |  반복 201 / 351 | 시간 4[s] | 손실 1.25
# | 에폭 7 |  반복 221 / 351 | 시간 5[s] | 손실 1.25
# | 에폭 7 |  반복 241 / 351 | 시간 5[s] | 손실 1.24
# | 에폭 7 |  반복 261 / 351 | 시간 6[s] | 손실 1.23
# | 에폭 7 |  반복 281 / 351 | 시간 6[s] | 손실 1.23
# | 에폭 7 |  반복 301 / 351 | 시간 7[s] | 손실 1.23
# | 에폭 7 |  반복 321 / 351 | 시간 7[s] | 손실 1.23
# | 에폭 7 |  반복 341 / 351 | 시간 7[s] | 손실 1.23
# Q 77+85
# T 162
# X 148
# ---
# Q 975+164
# T 1139
# X 1169
# ---
# Q 582+84
# T 666
# X 690
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# X 430
# ---
# Q 600+257
# T 857
# X 854
# ---
# Q 761+292
# T 1053
# X 1063
# ---
# Q 830+597
# T 1427
# X 1408
# ---
# Q 26+838
# T 864
# X 890
# ---
# Q 143+93
# T 236
# X 239
# ---
# 검증 정확도 1.780%
# | 에폭 8 |  반복 1 / 351 | 시간 0[s] | 손실 1.24
# | 에폭 8 |  반복 21 / 351 | 시간 0[s] | 손실 1.22
# | 에폭 8 |  반복 41 / 351 | 시간 0[s] | 손실 1.21
# | 에폭 8 |  반복 61 / 351 | 시간 1[s] | 손실 1.22
# | 에폭 8 |  반복 81 / 351 | 시간 1[s] | 손실 1.21
# | 에폭 8 |  반복 101 / 351 | 시간 2[s] | 손실 1.20
# | 에폭 8 |  반복 121 / 351 | 시간 2[s] | 손실 1.20
# | 에폭 8 |  반복 141 / 351 | 시간 3[s] | 손실 1.20
# | 에폭 8 |  반복 161 / 351 | 시간 3[s] | 손실 1.19
# | 에폭 8 |  반복 181 / 351 | 시간 4[s] | 손실 1.19
# | 에폭 8 |  반복 201 / 351 | 시간 4[s] | 손실 1.19
# | 에폭 8 |  반복 221 / 351 | 시간 4[s] | 손실 1.18
# | 에폭 8 |  반복 241 / 351 | 시간 5[s] | 손실 1.18
# | 에폭 8 |  반복 261 / 351 | 시간 5[s] | 손실 1.18
# | 에폭 8 |  반복 281 / 351 | 시간 6[s] | 손실 1.17
# | 에폭 8 |  반복 301 / 351 | 시간 6[s] | 손실 1.17
# | 에폭 8 |  반복 321 / 351 | 시간 7[s] | 손실 1.17
# | 에폭 8 |  반복 341 / 351 | 시간 7[s] | 손실 1.17
# Q 77+85
# T 162
# X 154
# ---
# Q 975+164
# T 1139
# X 1163
# ---
# Q 582+84
# T 666
# X 650
# ---
# Q 8+155
# T 163
# X 156
# ---
# Q 367+55
# T 422
# X 430
# ---
# Q 600+257
# T 857
# X 816
# ---
# Q 761+292
# T 1053
# X 1027
# ---
# Q 830+597
# T 1427
# X 1408
# ---
# Q 26+838
# T 864
# X 829
# ---
# Q 143+93
# T 236
# X 209
# ---
# 검증 정확도 1.280%
# | 에폭 9 |  반복 1 / 351 | 시간 0[s] | 손실 1.19
# | 에폭 9 |  반복 21 / 351 | 시간 0[s] | 손실 1.17
# | 에폭 9 |  반복 41 / 351 | 시간 0[s] | 손실 1.16
# | 에폭 9 |  반복 61 / 351 | 시간 1[s] | 손실 1.15
# | 에폭 9 |  반복 81 / 351 | 시간 1[s] | 손실 1.16
# | 에폭 9 |  반복 101 / 351 | 시간 2[s] | 손실 1.16
# | 에폭 9 |  반복 121 / 351 | 시간 2[s] | 손실 1.16
# | 에폭 9 |  반복 141 / 351 | 시간 3[s] | 손실 1.15
# | 에폭 9 |  반복 161 / 351 | 시간 3[s] | 손실 1.15
# | 에폭 9 |  반복 181 / 351 | 시간 4[s] | 손실 1.15
# | 에폭 9 |  반복 201 / 351 | 시간 4[s] | 손실 1.14
# | 에폭 9 |  반복 221 / 351 | 시간 4[s] | 손실 1.13
# | 에폭 9 |  반복 241 / 351 | 시간 5[s] | 손실 1.14
# | 에폭 9 |  반복 261 / 351 | 시간 5[s] | 손실 1.14
# | 에폭 9 |  반복 281 / 351 | 시간 6[s] | 손실 1.13
# | 에폭 9 |  반복 301 / 351 | 시간 6[s] | 손실 1.13
# | 에폭 9 |  반복 321 / 351 | 시간 7[s] | 손실 1.13
# | 에폭 9 |  반복 341 / 351 | 시간 7[s] | 손실 1.13
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# X 1127
# ---
# Q 582+84
# T 666
# X 662
# ---
# Q 8+155
# T 163
# X 171
# ---
# Q 367+55
# T 422
# X 432
# ---
# Q 600+257
# T 857
# X 851
# ---
# Q 761+292
# T 1053
# X 1027
# ---
# Q 830+597
# T 1427
# X 1442
# ---
# Q 26+838
# T 864
# X 855
# ---
# Q 143+93
# T 236
# X 242
# ---
# 검증 정확도 3.260%
# | 에폭 10 |  반복 1 / 351 | 시간 0[s] | 손실 1.12
# | 에폭 10 |  반복 21 / 351 | 시간 0[s] | 손실 1.11
# | 에폭 10 |  반복 41 / 351 | 시간 0[s] | 손실 1.11
# | 에폭 10 |  반복 61 / 351 | 시간 1[s] | 손실 1.11
# | 에폭 10 |  반복 81 / 351 | 시간 1[s] | 손실 1.11
# | 에폭 10 |  반복 101 / 351 | 시간 2[s] | 손실 1.13
# | 에폭 10 |  반복 121 / 351 | 시간 2[s] | 손실 1.13
# | 에폭 10 |  반복 141 / 351 | 시간 3[s] | 손실 1.11
# | 에폭 10 |  반복 161 / 351 | 시간 3[s] | 손실 1.10
# | 에폭 10 |  반복 181 / 351 | 시간 4[s] | 손실 1.10
# | 에폭 10 |  반복 201 / 351 | 시간 4[s] | 손실 1.11
# | 에폭 10 |  반복 221 / 351 | 시간 4[s] | 손실 1.09
# | 에폭 10 |  반복 241 / 351 | 시간 5[s] | 손실 1.09
# | 에폭 10 |  반복 261 / 351 | 시간 5[s] | 손실 1.09
# | 에폭 10 |  반복 281 / 351 | 시간 6[s] | 손실 1.09
# | 에폭 10 |  반복 301 / 351 | 시간 6[s] | 손실 1.08
# | 에폭 10 |  반복 321 / 351 | 시간 7[s] | 손실 1.08
# | 에폭 10 |  반복 341 / 351 | 시간 7[s] | 손실 1.09
# Q 77+85
# T 162
# X 153
# ---
# Q 975+164
# T 1139
# X 1121
# ---
# Q 582+84
# T 666
# X 681
# ---
# Q 8+155
# T 163
# X 153
# ---
# Q 367+55
# T 422
# X 430
# ---
# Q 600+257
# T 857
# X 859
# ---
# Q 761+292
# T 1053
# X 1027
# ---
# Q 830+597
# T 1427
# X 1405
# ---
# Q 26+838
# T 864
# X 859
# ---
# Q 143+93
# T 236
# X 249
# ---
# 검증 정확도 3.640%
# | 에폭 11 |  반복 1 / 351 | 시간 0[s] | 손실 1.10
# | 에폭 11 |  반복 21 / 351 | 시간 0[s] | 손실 1.08
# | 에폭 11 |  반복 41 / 351 | 시간 1[s] | 손실 1.08
# | 에폭 11 |  반복 61 / 351 | 시간 1[s] | 손실 1.08
# | 에폭 11 |  반복 81 / 351 | 시간 2[s] | 손실 1.08
# | 에폭 11 |  반복 101 / 351 | 시간 2[s] | 손실 1.08
# | 에폭 11 |  반복 121 / 351 | 시간 3[s] | 손실 1.08
# | 에폭 11 |  반복 141 / 351 | 시간 3[s] | 손실 1.07
# | 에폭 11 |  반복 161 / 351 | 시간 4[s] | 손실 1.08
# | 에폭 11 |  반복 181 / 351 | 시간 4[s] | 손실 1.07
# | 에폭 11 |  반복 201 / 351 | 시간 5[s] | 손실 1.07
# | 에폭 11 |  반복 221 / 351 | 시간 5[s] | 손실 1.06
# | 에폭 11 |  반복 241 / 351 | 시간 6[s] | 손실 1.07
# | 에폭 11 |  반복 261 / 351 | 시간 6[s] | 손실 1.06
# | 에폭 11 |  반복 281 / 351 | 시간 7[s] | 손실 1.06
# | 에폭 11 |  반복 301 / 351 | 시간 7[s] | 손실 1.08
# | 에폭 11 |  반복 321 / 351 | 시간 7[s] | 손실 1.08
# | 에폭 11 |  반복 341 / 351 | 시간 8[s] | 손실 1.04
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# X 1147
# ---
# Q 582+84
# T 666
# X 673
# ---
# Q 8+155
# T 163
# X 173
# ---
# Q 367+55
# T 422
# X 433
# ---
# Q 600+257
# T 857
# X 859
# ---
# Q 761+292
# T 1053
# X 1039
# ---
# Q 830+597
# T 1427
# X 1417
# ---
# Q 26+838
# T 864
# X 865
# ---
# Q 143+93
# T 236
# X 210
# ---
# 검증 정확도 3.440%
# | 에폭 12 |  반복 1 / 351 | 시간 0[s] | 손실 1.04
# | 에폭 12 |  반복 21 / 351 | 시간 0[s] | 손실 1.05
# | 에폭 12 |  반복 41 / 351 | 시간 0[s] | 손실 1.06
# | 에폭 12 |  반복 61 / 351 | 시간 1[s] | 손실 1.05
# | 에폭 12 |  반복 81 / 351 | 시간 1[s] | 손실 1.06
# | 에폭 12 |  반복 101 / 351 | 시간 2[s] | 손실 1.06
# | 에폭 12 |  반복 121 / 351 | 시간 2[s] | 손실 1.04
# | 에폭 12 |  반복 141 / 351 | 시간 3[s] | 손실 1.04
# | 에폭 12 |  반복 161 / 351 | 시간 3[s] | 손실 1.04
# | 에폭 12 |  반복 181 / 351 | 시간 3[s] | 손실 1.04
# | 에폭 12 |  반복 201 / 351 | 시간 4[s] | 손실 1.04
# | 에폭 12 |  반복 221 / 351 | 시간 4[s] | 손실 1.04
# | 에폭 12 |  반복 241 / 351 | 시간 5[s] | 손실 1.04
# | 에폭 12 |  반복 261 / 351 | 시간 5[s] | 손실 1.04
# | 에폭 12 |  반복 281 / 351 | 시간 6[s] | 손실 1.05
# | 에폭 12 |  반복 301 / 351 | 시간 6[s] | 손실 1.05
# | 에폭 12 |  반복 321 / 351 | 시간 7[s] | 손실 1.04
# | 에폭 12 |  반복 341 / 351 | 시간 7[s] | 손실 1.03
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# X 1146
# ---
# Q 582+84
# T 666
# X 656
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# X 406
# ---
# Q 600+257
# T 857
# X 846
# ---
# Q 761+292
# T 1053
# X 1016
# ---
# Q 830+597
# T 1427
# X 1407
# ---
# Q 26+838
# T 864
# X 853
# ---
# Q 143+93
# T 236
# X 209
# ---
# 검증 정확도 2.800%
# | 에폭 13 |  반복 1 / 351 | 시간 0[s] | 손실 1.03
# | 에폭 13 |  반복 21 / 351 | 시간 0[s] | 손실 1.05
# | 에폭 13 |  반복 41 / 351 | 시간 0[s] | 손실 1.04
# | 에폭 13 |  반복 61 / 351 | 시간 1[s] | 손실 1.04
# | 에폭 13 |  반복 81 / 351 | 시간 1[s] | 손실 1.03
# | 에폭 13 |  반복 101 / 351 | 시간 2[s] | 손실 1.02
# | 에폭 13 |  반복 121 / 351 | 시간 2[s] | 손실 1.02
# | 에폭 13 |  반복 141 / 351 | 시간 3[s] | 손실 1.04
# | 에폭 13 |  반복 161 / 351 | 시간 3[s] | 손실 1.04
# | 에폭 13 |  반복 181 / 351 | 시간 3[s] | 손실 1.04
# | 에폭 13 |  반복 201 / 351 | 시간 4[s] | 손실 1.04
# | 에폭 13 |  반복 221 / 351 | 시간 4[s] | 손실 1.02
# | 에폭 13 |  반복 241 / 351 | 시간 5[s] | 손실 1.03
# | 에폭 13 |  반복 261 / 351 | 시간 5[s] | 손실 1.03
# | 에폭 13 |  반복 281 / 351 | 시간 6[s] | 손실 1.03
# | 에폭 13 |  반복 301 / 351 | 시간 6[s] | 손실 1.01
# | 에폭 13 |  반복 321 / 351 | 시간 7[s] | 손실 1.01
# | 에폭 13 |  반복 341 / 351 | 시간 7[s] | 손실 1.01
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# X 1149
# ---
# Q 582+84
# T 666
# X 676
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# X 430
# ---
# Q 600+257
# T 857
# X 873
# ---
# Q 761+292
# T 1053
# X 1060
# ---
# Q 830+597
# T 1427
# X 1440
# ---
# Q 26+838
# T 864
# X 859
# ---
# Q 143+93
# T 236
# X 209
# ---
# 검증 정확도 4.160%
# | 에폭 14 |  반복 1 / 351 | 시간 0[s] | 손실 1.01
# | 에폭 14 |  반복 21 / 351 | 시간 0[s] | 손실 1.02
# | 에폭 14 |  반복 41 / 351 | 시간 0[s] | 손실 1.01
# | 에폭 14 |  반복 61 / 351 | 시간 1[s] | 손실 1.01
# | 에폭 14 |  반복 81 / 351 | 시간 1[s] | 손실 1.01
# | 에폭 14 |  반복 101 / 351 | 시간 2[s] | 손실 1.01
# | 에폭 14 |  반복 121 / 351 | 시간 2[s] | 손실 1.00
# | 에폭 14 |  반복 141 / 351 | 시간 2[s] | 손실 1.00
# | 에폭 14 |  반복 161 / 351 | 시간 3[s] | 손실 1.00
# | 에폭 14 |  반복 181 / 351 | 시간 3[s] | 손실 1.00
# | 에폭 14 |  반복 201 / 351 | 시간 4[s] | 손실 1.03
# | 에폭 14 |  반복 221 / 351 | 시간 4[s] | 손실 1.01
# | 에폭 14 |  반복 241 / 351 | 시간 4[s] | 손실 1.00
# | 에폭 14 |  반복 261 / 351 | 시간 5[s] | 손실 1.02
# | 에폭 14 |  반복 281 / 351 | 시간 5[s] | 손실 1.01
# | 에폭 14 |  반복 301 / 351 | 시간 6[s] | 손실 1.00
# | 에폭 14 |  반복 321 / 351 | 시간 6[s] | 손실 0.99
# | 에폭 14 |  반복 341 / 351 | 시간 6[s] | 손실 0.99
# Q 77+85
# T 162
# X 155
# ---
# Q 975+164
# T 1139
# X 1149
# ---
# Q 582+84
# T 666
# X 668
# ---
# Q 8+155
# T 163
# X 176
# ---
# Q 367+55
# T 422
# X 435
# ---
# Q 600+257
# T 857
# X 869
# ---
# Q 761+292
# T 1053
# X 1066
# ---
# Q 830+597
# T 1427
# X 1409
# ---
# Q 26+838
# T 864
# X 869
# ---
# Q 143+93
# T 236
# X 228
# ---
# 검증 정확도 4.320%
# | 에폭 15 |  반복 1 / 351 | 시간 0[s] | 손실 1.02
# | 에폭 15 |  반복 21 / 351 | 시간 0[s] | 손실 1.00
# | 에폭 15 |  반복 41 / 351 | 시간 0[s] | 손실 1.00
# | 에폭 15 |  반복 61 / 351 | 시간 1[s] | 손실 0.99
# | 에폭 15 |  반복 81 / 351 | 시간 1[s] | 손실 0.99
# | 에폭 15 |  반복 101 / 351 | 시간 2[s] | 손실 0.99
# | 에폭 15 |  반복 121 / 351 | 시간 2[s] | 손실 1.00
# | 에폭 15 |  반복 141 / 351 | 시간 2[s] | 손실 0.99
# | 에폭 15 |  반복 161 / 351 | 시간 3[s] | 손실 0.98
# | 에폭 15 |  반복 181 / 351 | 시간 3[s] | 손실 1.00
# | 에폭 15 |  반복 201 / 351 | 시간 4[s] | 손실 0.99
# | 에폭 15 |  반복 221 / 351 | 시간 4[s] | 손실 1.00
# | 에폭 15 |  반복 241 / 351 | 시간 4[s] | 손실 0.99
# | 에폭 15 |  반복 261 / 351 | 시간 5[s] | 손실 0.98
# | 에폭 15 |  반복 281 / 351 | 시간 5[s] | 손실 0.97
# | 에폭 15 |  반복 301 / 351 | 시간 6[s] | 손실 0.97
# | 에폭 15 |  반복 321 / 351 | 시간 6[s] | 손실 0.99
# | 에폭 15 |  반복 341 / 351 | 시간 6[s] | 손실 1.00
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# X 1127
# ---
# Q 582+84
# T 666
# X 682
# ---
# Q 8+155
# T 163
# X 170
# ---
# Q 367+55
# T 422
# X 431
# ---
# Q 600+257
# T 857
# X 892
# ---
# Q 761+292
# T 1053
# X 1063
# ---
# Q 830+597
# T 1427
# X 1418
# ---
# Q 26+838
# T 864
# X 870
# ---
# Q 143+93
# T 236
# X 240
# ---
# 검증 정확도 3.820%
# | 에폭 16 |  반복 1 / 351 | 시간 0[s] | 손실 1.00
# | 에폭 16 |  반복 21 / 351 | 시간 0[s] | 손실 0.98
# | 에폭 16 |  반복 41 / 351 | 시간 0[s] | 손실 0.99
# | 에폭 16 |  반복 61 / 351 | 시간 1[s] | 손실 0.99
# | 에폭 16 |  반복 81 / 351 | 시간 1[s] | 손실 0.97
# | 에폭 16 |  반복 101 / 351 | 시간 2[s] | 손실 0.97
# | 에폭 16 |  반복 121 / 351 | 시간 2[s] | 손실 0.98
# | 에폭 16 |  반복 141 / 351 | 시간 2[s] | 손실 0.97
# | 에폭 16 |  반복 161 / 351 | 시간 3[s] | 손실 0.98
# | 에폭 16 |  반복 181 / 351 | 시간 3[s] | 손실 0.99
# | 에폭 16 |  반복 201 / 351 | 시간 4[s] | 손실 0.99
# | 에폭 16 |  반복 221 / 351 | 시간 4[s] | 손실 0.99
# | 에폭 16 |  반복 241 / 351 | 시간 4[s] | 손실 1.04
# | 에폭 16 |  반복 261 / 351 | 시간 5[s] | 손실 1.02
# | 에폭 16 |  반복 281 / 351 | 시간 5[s] | 손실 1.02
# | 에폭 16 |  반복 301 / 351 | 시간 6[s] | 손실 1.03
# | 에폭 16 |  반복 321 / 351 | 시간 6[s] | 손실 0.97
# | 에폭 16 |  반복 341 / 351 | 시간 6[s] | 손실 0.97
# Q 77+85
# T 162
# X 158
# ---
# Q 975+164
# T 1139
# X 1145
# ---
# Q 582+84
# T 666
# X 672
# ---
# Q 8+155
# T 163
# X 172
# ---
# Q 367+55
# T 422
# X 431
# ---
# Q 600+257
# T 857
# X 859
# ---
# Q 761+292
# T 1053
# X 1039
# ---
# Q 830+597
# T 1427
# X 1405
# ---
# Q 26+838
# T 864
# X 858
# ---
# Q 143+93
# T 236
# X 239
# ---
# 검증 정확도 5.360%
# | 에폭 17 |  반복 1 / 351 | 시간 0[s] | 손실 0.96
# | 에폭 17 |  반복 21 / 351 | 시간 0[s] | 손실 0.97
# | 에폭 17 |  반복 41 / 351 | 시간 0[s] | 손실 0.95
# | 에폭 17 |  반복 61 / 351 | 시간 1[s] | 손실 0.96
# | 에폭 17 |  반복 81 / 351 | 시간 1[s] | 손실 0.96
# | 에폭 17 |  반복 101 / 351 | 시간 2[s] | 손실 0.97
# | 에폭 17 |  반복 121 / 351 | 시간 2[s] | 손실 0.96
# | 에폭 17 |  반복 141 / 351 | 시간 2[s] | 손실 0.97
# | 에폭 17 |  반복 161 / 351 | 시간 3[s] | 손실 0.98
# | 에폭 17 |  반복 181 / 351 | 시간 3[s] | 손실 0.96
# | 에폭 17 |  반복 201 / 351 | 시간 4[s] | 손실 0.99
# | 에폭 17 |  반복 221 / 351 | 시간 4[s] | 손실 1.00
# | 에폭 17 |  반복 241 / 351 | 시간 5[s] | 손실 0.97
# | 에폭 17 |  반복 261 / 351 | 시간 5[s] | 손실 0.97
# | 에폭 17 |  반복 281 / 351 | 시간 5[s] | 손실 0.97
# | 에폭 17 |  반복 301 / 351 | 시간 6[s] | 손실 0.97
# | 에폭 17 |  반복 321 / 351 | 시간 6[s] | 손실 0.96
# | 에폭 17 |  반복 341 / 351 | 시간 7[s] | 손실 0.95
# Q 77+85
# T 162
# X 161
# ---
# Q 975+164
# T 1139
# X 1144
# ---
# Q 582+84
# T 666
# X 672
# ---
# Q 8+155
# T 163
# X 171
# ---
# Q 367+55
# T 422
# X 431
# ---
# Q 600+257
# T 857
# X 849
# ---
# Q 761+292
# T 1053
# X 1039
# ---
# Q 830+597
# T 1427
# X 1405
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 240
# ---
# 검증 정확도 5.360%
# | 에폭 18 |  반복 1 / 351 | 시간 0[s] | 손실 0.93
# | 에폭 18 |  반복 21 / 351 | 시간 0[s] | 손실 0.96
# | 에폭 18 |  반복 41 / 351 | 시간 0[s] | 손실 0.94
# | 에폭 18 |  반복 61 / 351 | 시간 1[s] | 손실 0.96
# | 에폭 18 |  반복 81 / 351 | 시간 1[s] | 손실 0.97
# | 에폭 18 |  반복 101 / 351 | 시간 2[s] | 손실 0.94
# | 에폭 18 |  반복 121 / 351 | 시간 2[s] | 손실 0.95
# | 에폭 18 |  반복 141 / 351 | 시간 2[s] | 손실 0.94
# | 에폭 18 |  반복 161 / 351 | 시간 3[s] | 손실 0.94
# | 에폭 18 |  반복 181 / 351 | 시간 3[s] | 손실 0.96
# | 에폭 18 |  반복 201 / 351 | 시간 4[s] | 손실 0.96
# | 에폭 18 |  반복 221 / 351 | 시간 4[s] | 손실 0.96
# | 에폭 18 |  반복 241 / 351 | 시간 5[s] | 손실 0.96
# | 에폭 18 |  반복 261 / 351 | 시간 5[s] | 손실 0.95
# | 에폭 18 |  반복 281 / 351 | 시간 5[s] | 손실 0.94
# | 에폭 18 |  반복 301 / 351 | 시간 6[s] | 손실 0.97
# | 에폭 18 |  반복 321 / 351 | 시간 6[s] | 손실 0.94
# | 에폭 18 |  반복 341 / 351 | 시간 7[s] | 손실 0.94
# Q 77+85
# T 162
# X 157
# ---
# Q 975+164
# T 1139
# X 1127
# ---
# Q 582+84
# T 666
# X 671
# ---
# Q 8+155
# T 163
# X 171
# ---
# Q 367+55
# T 422
# X 431
# ---
# Q 600+257
# T 857
# X 873
# ---
# Q 761+292
# T 1053
# X 1055
# ---
# Q 830+597
# T 1427
# X 1421
# ---
# Q 26+838
# T 864
# X 859
# ---
# Q 143+93
# T 236
# X 227
# ---
# 검증 정확도 6.460%
# | 에폭 19 |  반복 1 / 351 | 시간 0[s] | 손실 0.93
# | 에폭 19 |  반복 21 / 351 | 시간 0[s] | 손실 0.96
# | 에폭 19 |  반복 41 / 351 | 시간 0[s] | 손실 0.95
# | 에폭 19 |  반복 61 / 351 | 시간 1[s] | 손실 0.94
# | 에폭 19 |  반복 81 / 351 | 시간 1[s] | 손실 0.95
# | 에폭 19 |  반복 101 / 351 | 시간 2[s] | 손실 0.94
# | 에폭 19 |  반복 121 / 351 | 시간 2[s] | 손실 0.94
# | 에폭 19 |  반복 141 / 351 | 시간 2[s] | 손실 0.95
# | 에폭 19 |  반복 161 / 351 | 시간 3[s] | 손실 0.95
# | 에폭 19 |  반복 181 / 351 | 시간 3[s] | 손실 0.93
# | 에폭 19 |  반복 201 / 351 | 시간 4[s] | 손실 0.93
# | 에폭 19 |  반복 221 / 351 | 시간 4[s] | 손실 0.93
# | 에폭 19 |  반복 241 / 351 | 시간 4[s] | 손실 0.94
# | 에폭 19 |  반복 261 / 351 | 시간 5[s] | 손실 0.92
# | 에폭 19 |  반복 281 / 351 | 시간 5[s] | 손실 0.94
# | 에폭 19 |  반복 301 / 351 | 시간 6[s] | 손실 0.94
# | 에폭 19 |  반복 321 / 351 | 시간 6[s] | 손실 0.93
# | 에폭 19 |  반복 341 / 351 | 시간 7[s] | 손실 0.93
# Q 77+85
# T 162
# X 157
# ---
# Q 975+164
# T 1139
# X 1127
# ---
# Q 582+84
# T 666
# X 657
# ---
# Q 8+155
# T 163
# X 171
# ---
# Q 367+55
# T 422
# X 431
# ---
# Q 600+257
# T 857
# X 849
# ---
# Q 761+292
# T 1053
# X 1039
# ---
# Q 830+597
# T 1427
# X 1399
# ---
# Q 26+838
# T 864
# X 857
# ---
# Q 143+93
# T 236
# X 235
# ---
# 검증 정확도 4.920%
# | 에폭 20 |  반복 1 / 351 | 시간 0[s] | 손실 0.96
# | 에폭 20 |  반복 21 / 351 | 시간 0[s] | 손실 0.92
# | 에폭 20 |  반복 41 / 351 | 시간 0[s] | 손실 0.92
# | 에폭 20 |  반복 61 / 351 | 시간 1[s] | 손실 0.94
# | 에폭 20 |  반복 81 / 351 | 시간 1[s] | 손실 0.93
# | 에폭 20 |  반복 101 / 351 | 시간 2[s] | 손실 0.93
# | 에폭 20 |  반복 121 / 351 | 시간 2[s] | 손실 0.92
# | 에폭 20 |  반복 141 / 351 | 시간 2[s] | 손실 0.92
# | 에폭 20 |  반복 161 / 351 | 시간 3[s] | 손실 0.94
# | 에폭 20 |  반복 181 / 351 | 시간 3[s] | 손실 0.95
# | 에폭 20 |  반복 201 / 351 | 시간 4[s] | 손실 0.94
# | 에폭 20 |  반복 221 / 351 | 시간 4[s] | 손실 0.93
# | 에폭 20 |  반복 241 / 351 | 시간 4[s] | 손실 0.93
# | 에폭 20 |  반복 261 / 351 | 시간 5[s] | 손실 0.94
# | 에폭 20 |  반복 281 / 351 | 시간 5[s] | 손실 0.93
# | 에폭 20 |  반복 301 / 351 | 시간 6[s] | 손실 0.93
# | 에폭 20 |  반복 321 / 351 | 시간 6[s] | 손실 0.93
# | 에폭 20 |  반복 341 / 351 | 시간 7[s] | 손실 0.92
# Q 77+85
# T 162
# X 160
# ---
# Q 975+164
# T 1139
# X 1145
# ---
# Q 582+84
# T 666
# X 655
# ---
# Q 8+155
# T 163
# X 170
# ---
# Q 367+55
# T 422
# X 415
# ---
# Q 600+257
# T 857
# X 841
# ---
# Q 761+292
# T 1053
# X 1039
# ---
# Q 830+597
# T 1427
# X 1405
# ---
# Q 26+838
# T 864
# X 851
# ---
# Q 143+93
# T 236
# X 235
# ---
# 검증 정확도 5.220%
# | 에폭 21 |  반복 1 / 351 | 시간 0[s] | 손실 0.93
# | 에폭 21 |  반복 21 / 351 | 시간 0[s] | 손실 0.92
# | 에폭 21 |  반복 41 / 351 | 시간 0[s] | 손실 0.92
# | 에폭 21 |  반복 61 / 351 | 시간 1[s] | 손실 0.92
# | 에폭 21 |  반복 81 / 351 | 시간 1[s] | 손실 0.92
# | 에폭 21 |  반복 101 / 351 | 시간 1[s] | 손실 0.92
# | 에폭 21 |  반복 121 / 351 | 시간 2[s] | 손실 0.92
# | 에폭 21 |  반복 141 / 351 | 시간 2[s] | 손실 0.92
# | 에폭 21 |  반복 161 / 351 | 시간 3[s] | 손실 0.90
# | 에폭 21 |  반복 181 / 351 | 시간 3[s] | 손실 0.91
# | 에폭 21 |  반복 201 / 351 | 시간 3[s] | 손실 0.93
# | 에폭 21 |  반복 221 / 351 | 시간 4[s] | 손실 0.92
# | 에폭 21 |  반복 241 / 351 | 시간 4[s] | 손실 0.95
# | 에폭 21 |  반복 261 / 351 | 시간 5[s] | 손실 0.92
# | 에폭 21 |  반복 281 / 351 | 시간 5[s] | 손실 0.92
# | 에폭 21 |  반복 301 / 351 | 시간 5[s] | 손실 0.93
# | 에폭 21 |  반복 321 / 351 | 시간 6[s] | 손실 0.92
# | 에폭 21 |  반복 341 / 351 | 시간 6[s] | 손실 0.91
# Q 77+85
# T 162
# X 157
# ---
# Q 975+164
# T 1139
# X 1127
# ---
# Q 582+84
# T 666
# X 677
# ---
# Q 8+155
# T 163
# X 171
# ---
# Q 367+55
# T 422
# X 431
# ---
# Q 600+257
# T 857
# X 871
# ---
# Q 761+292
# T 1053
# X 1039
# ---
# Q 830+597
# T 1427
# X 1407
# ---
# Q 26+838
# T 864
# X 860
# ---
# Q 143+93
# T 236
# X 238
# ---
# 검증 정확도 5.100%
# | 에폭 22 |  반복 1 / 351 | 시간 0[s] | 손실 0.92
# | 에폭 22 |  반복 21 / 351 | 시간 0[s] | 손실 0.93
# | 에폭 22 |  반복 41 / 351 | 시간 0[s] | 손실 0.91
# | 에폭 22 |  반복 61 / 351 | 시간 1[s] | 손실 0.92
# | 에폭 22 |  반복 81 / 351 | 시간 1[s] | 손실 0.92
# | 에폭 22 |  반복 101 / 351 | 시간 2[s] | 손실 0.91
# | 에폭 22 |  반복 121 / 351 | 시간 2[s] | 손실 0.92
# | 에폭 22 |  반복 141 / 351 | 시간 3[s] | 손실 0.92
# | 에폭 22 |  반복 161 / 351 | 시간 3[s] | 손실 0.92
# | 에폭 22 |  반복 181 / 351 | 시간 3[s] | 손실 0.92
# | 에폭 22 |  반복 201 / 351 | 시간 4[s] | 손실 0.91
# | 에폭 22 |  반복 221 / 351 | 시간 4[s] | 손실 0.90
# | 에폭 22 |  반복 241 / 351 | 시간 5[s] | 손실 0.91
# | 에폭 22 |  반복 261 / 351 | 시간 5[s] | 손실 0.90
# | 에폭 22 |  반복 281 / 351 | 시간 5[s] | 손실 0.92
# | 에폭 22 |  반복 301 / 351 | 시간 6[s] | 손실 0.90
# | 에폭 22 |  반복 321 / 351 | 시간 6[s] | 손실 0.90
# | 에폭 22 |  반복 341 / 351 | 시간 7[s] | 손실 0.90
# Q 77+85
# T 162
# X 160
# ---
# Q 975+164
# T 1139
# X 1140
# ---
# Q 582+84
# T 666
# X 667
# ---
# Q 8+155
# T 163
# X 170
# ---
# Q 367+55
# T 422
# X 421
# ---
# Q 600+257
# T 857
# X 854
# ---
# Q 761+292
# T 1053
# X 1054
# ---
# Q 830+597
# T 1427
# X 1418
# ---
# Q 26+838
# T 864
# X 857
# ---
# Q 143+93
# T 236
# X 235
# ---
# 검증 정확도 8.680%
# | 에폭 23 |  반복 1 / 351 | 시간 0[s] | 손실 0.89
# | 에폭 23 |  반복 21 / 351 | 시간 0[s] | 손실 0.90
# | 에폭 23 |  반복 41 / 351 | 시간 0[s] | 손실 0.89
# | 에폭 23 |  반복 61 / 351 | 시간 1[s] | 손실 0.89
# | 에폭 23 |  반복 81 / 351 | 시간 1[s] | 손실 0.91
# | 에폭 23 |  반복 101 / 351 | 시간 2[s] | 손실 0.89
# | 에폭 23 |  반복 121 / 351 | 시간 2[s] | 손실 0.93
# | 에폭 23 |  반복 141 / 351 | 시간 3[s] | 손실 0.92
# | 에폭 23 |  반복 161 / 351 | 시간 3[s] | 손실 0.91
# | 에폭 23 |  반복 181 / 351 | 시간 4[s] | 손실 0.90
# | 에폭 23 |  반복 201 / 351 | 시간 4[s] | 손실 0.89
# | 에폭 23 |  반복 221 / 351 | 시간 5[s] | 손실 0.89
# | 에폭 23 |  반복 241 / 351 | 시간 5[s] | 손실 0.89
# | 에폭 23 |  반복 261 / 351 | 시간 6[s] | 손실 0.91
# | 에폭 23 |  반복 281 / 351 | 시간 6[s] | 손실 0.95
# | 에폭 23 |  반복 301 / 351 | 시간 7[s] | 손실 0.93
# | 에폭 23 |  반복 321 / 351 | 시간 7[s] | 손실 0.89
# | 에폭 23 |  반복 341 / 351 | 시간 8[s] | 손실 0.93
# Q 77+85
# T 162
# X 157
# ---
# Q 975+164
# T 1139
# X 1143
# ---
# Q 582+84
# T 666
# X 672
# ---
# Q 8+155
# T 163
# X 161
# ---
# Q 367+55
# T 422
# X 419
# ---
# Q 600+257
# T 857
# X 871
# ---
# Q 761+292
# T 1053
# X 1055
# ---
# Q 830+597
# T 1427
# X 1415
# ---
# Q 26+838
# T 864
# X 858
# ---
# Q 143+93
# T 236
# X 225
# ---
# 검증 정확도 7.540%
# | 에폭 24 |  반복 1 / 351 | 시간 0[s] | 손실 0.92
# | 에폭 24 |  반복 21 / 351 | 시간 0[s] | 손실 0.91
# | 에폭 24 |  반복 41 / 351 | 시간 0[s] | 손실 0.91
# | 에폭 24 |  반복 61 / 351 | 시간 1[s] | 손실 0.90
# | 에폭 24 |  반복 81 / 351 | 시간 1[s] | 손실 0.90
# | 에폭 24 |  반복 101 / 351 | 시간 2[s] | 손실 0.90
# | 에폭 24 |  반복 121 / 351 | 시간 2[s] | 손실 0.90
# | 에폭 24 |  반복 141 / 351 | 시간 3[s] | 손실 0.91
# | 에폭 24 |  반복 161 / 351 | 시간 3[s] | 손실 0.90
# | 에폭 24 |  반복 181 / 351 | 시간 3[s] | 손실 0.91
# | 에폭 24 |  반복 201 / 351 | 시간 4[s] | 손실 0.88
# | 에폭 24 |  반복 221 / 351 | 시간 4[s] | 손실 0.88
# | 에폭 24 |  반복 241 / 351 | 시간 5[s] | 손실 0.87
# | 에폭 24 |  반복 261 / 351 | 시간 5[s] | 손실 0.88
# | 에폭 24 |  반복 281 / 351 | 시간 6[s] | 손실 0.88
# | 에폭 24 |  반복 301 / 351 | 시간 6[s] | 손실 0.90
# | 에폭 24 |  반복 321 / 351 | 시간 7[s] | 손실 0.88
# | 에폭 24 |  반복 341 / 351 | 시간 7[s] | 손실 0.89
# Q 77+85
# T 162
# X 159
# ---
# Q 975+164
# T 1139
# X 1143
# ---
# Q 582+84
# T 666
# X 669
# ---
# Q 8+155
# T 163
# X 161
# ---
# Q 367+55
# T 422
# X 418
# ---
# Q 600+257
# T 857
# X 860
# ---
# Q 761+292
# T 1053
# X 1048
# ---
# Q 830+597
# T 1427
# X 1418
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 228
# ---
# 검증 정확도 7.260%
# | 에폭 25 |  반복 1 / 351 | 시간 0[s] | 손실 0.90
# | 에폭 25 |  반복 21 / 351 | 시간 0[s] | 손실 0.87
# | 에폭 25 |  반복 41 / 351 | 시간 0[s] | 손실 0.88
# | 에폭 25 |  반복 61 / 351 | 시간 1[s] | 손실 0.88
# | 에폭 25 |  반복 81 / 351 | 시간 1[s] | 손실 0.90
# | 에폭 25 |  반복 101 / 351 | 시간 2[s] | 손실 0.89
# | 에폭 25 |  반복 121 / 351 | 시간 2[s] | 손실 0.89
# | 에폭 25 |  반복 141 / 351 | 시간 3[s] | 손실 0.87
# | 에폭 25 |  반복 161 / 351 | 시간 3[s] | 손실 0.88
# | 에폭 25 |  반복 181 / 351 | 시간 4[s] | 손실 0.90
# | 에폭 25 |  반복 201 / 351 | 시간 4[s] | 손실 0.90
# | 에폭 25 |  반복 221 / 351 | 시간 5[s] | 손실 0.90
# | 에폭 25 |  반복 241 / 351 | 시간 5[s] | 손실 0.96
# | 에폭 25 |  반복 261 / 351 | 시간 5[s] | 손실 0.96
# | 에폭 25 |  반복 281 / 351 | 시간 6[s] | 손실 0.94
# | 에폭 25 |  반복 301 / 351 | 시간 6[s] | 손실 0.94
# | 에폭 25 |  반복 321 / 351 | 시간 7[s] | 손실 0.94
# | 에폭 25 |  반복 341 / 351 | 시간 7[s] | 손실 0.94
# Q 77+85
# T 162
# X 160
# ---
# Q 975+164
# T 1139
# X 1143
# ---
# Q 582+84
# T 666
# X 676
# ---
# Q 8+155
# T 163
# X 160
# ---
# Q 367+55
# T 422
# X 419
# ---
# Q 600+257
# T 857
# X 871
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# X 1418
# ---
# Q 26+838
# T 864
# X 867
# ---
# Q 143+93
# T 236
# X 227
# ---
# 검증 정확도 6.800%
# Training with hidden_size=128...
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 2.56
# | 에폭 1 |  반복 21 / 351 | 시간 0[s] | 손실 2.52
# | 에폭 1 |  반복 41 / 351 | 시간 1[s] | 손실 2.17
# | 에폭 1 |  반복 61 / 351 | 시간 2[s] | 손실 1.97
# | 에폭 1 |  반복 81 / 351 | 시간 3[s] | 손실 1.90
# | 에폭 1 |  반복 101 / 351 | 시간 3[s] | 손실 1.86
# | 에폭 1 |  반복 121 / 351 | 시간 4[s] | 손실 1.85
# | 에폭 1 |  반복 141 / 351 | 시간 5[s] | 손실 1.81
# | 에폭 1 |  반복 161 / 351 | 시간 6[s] | 손실 1.79
# | 에폭 1 |  반복 181 / 351 | 시간 6[s] | 손실 1.77
# | 에폭 1 |  반복 201 / 351 | 시간 7[s] | 손실 1.77
# | 에폭 1 |  반복 221 / 351 | 시간 8[s] | 손실 1.76
# | 에폭 1 |  반복 241 / 351 | 시간 9[s] | 손실 1.76
# | 에폭 1 |  반복 261 / 351 | 시간 10[s] | 손실 1.75
# | 에폭 1 |  반복 281 / 351 | 시간 10[s] | 손실 1.75
# | 에폭 1 |  반복 301 / 351 | 시간 11[s] | 손실 1.74
# | 에폭 1 |  반복 321 / 351 | 시간 12[s] | 손실 1.74
# | 에폭 1 |  반복 341 / 351 | 시간 13[s] | 손실 1.73
# Q 77+85
# T 162
# X 100
# ---
# Q 975+164
# T 1139
# X 1000
# ---
# Q 582+84
# T 666
# X 1003
# ---
# Q 8+155
# T 163
# X 100
# ---
# Q 367+55
# T 422
# X 100
# ---
# Q 600+257
# T 857
# X 1003
# ---
# Q 761+292
# T 1053
# X 1003
# ---
# Q 830+597
# T 1427
# X 1000
# ---
# Q 26+838
# T 864
# X 100
# ---
# Q 143+93
# T 236
# X 100
# ---
# 검증 정확도 0.200%
# | 에폭 2 |  반복 1 / 351 | 시간 0[s] | 손실 1.71
# | 에폭 2 |  반복 21 / 351 | 시간 0[s] | 손실 1.72
# | 에폭 2 |  반복 41 / 351 | 시간 1[s] | 손실 1.72
# | 에폭 2 |  반복 61 / 351 | 시간 2[s] | 손실 1.71
# | 에폭 2 |  반복 81 / 351 | 시간 2[s] | 손실 1.71
# | 에폭 2 |  반복 101 / 351 | 시간 3[s] | 손실 1.71
# | 에폭 2 |  반복 121 / 351 | 시간 4[s] | 손실 1.71
# | 에폭 2 |  반복 141 / 351 | 시간 5[s] | 손실 1.70
# | 에폭 2 |  반복 161 / 351 | 시간 5[s] | 손실 1.69
# | 에폭 2 |  반복 181 / 351 | 시간 6[s] | 손실 1.69
# | 에폭 2 |  반복 201 / 351 | 시간 7[s] | 손실 1.69
# | 에폭 2 |  반복 221 / 351 | 시간 8[s] | 손실 1.68
# | 에폭 2 |  반복 241 / 351 | 시간 8[s] | 손실 1.67
# | 에폭 2 |  반복 261 / 351 | 시간 9[s] | 손실 1.66
# | 에폭 2 |  반복 281 / 351 | 시간 10[s] | 손실 1.66
# | 에폭 2 |  반복 301 / 351 | 시간 11[s] | 손실 1.65
# | 에폭 2 |  반복 321 / 351 | 시간 11[s] | 손실 1.66
# | 에폭 2 |  반복 341 / 351 | 시간 12[s] | 손실 1.64
# Q 77+85
# T 162
# X 100
# ---
# Q 975+164
# T 1139
# X 1444
# ---
# Q 582+84
# T 666
# X 602
# ---
# Q 8+155
# T 163
# X 100
# ---
# Q 367+55
# T 422
# X 322
# ---
# Q 600+257
# T 857
# X 1022
# ---
# Q 761+292
# T 1053
# X 1222
# ---
# Q 830+597
# T 1427
# X 1226
# ---
# Q 26+838
# T 864
# X 622
# ---
# Q 143+93
# T 236
# X 322
# ---
# 검증 정확도 0.320%
# | 에폭 3 |  반복 1 / 351 | 시간 0[s] | 손실 1.61
# | 에폭 3 |  반복 21 / 351 | 시간 0[s] | 손실 1.63
# | 에폭 3 |  반복 41 / 351 | 시간 1[s] | 손실 1.61
# | 에폭 3 |  반복 61 / 351 | 시간 2[s] | 손실 1.60
# | 에폭 3 |  반복 81 / 351 | 시간 3[s] | 손실 1.59
# | 에폭 3 |  반복 101 / 351 | 시간 3[s] | 손실 1.58
# | 에폭 3 |  반복 121 / 351 | 시간 4[s] | 손실 1.56
# | 에폭 3 |  반복 141 / 351 | 시간 5[s] | 손실 1.55
# | 에폭 3 |  반복 161 / 351 | 시간 6[s] | 손실 1.55
# | 에폭 3 |  반복 181 / 351 | 시간 6[s] | 손실 1.53
# | 에폭 3 |  반복 201 / 351 | 시간 7[s] | 손실 1.51
# | 에폭 3 |  반복 221 / 351 | 시간 8[s] | 손실 1.51
# | 에폭 3 |  반복 241 / 351 | 시간 9[s] | 손실 1.50
# | 에폭 3 |  반복 261 / 351 | 시간 9[s] | 손실 1.48
# | 에폭 3 |  반복 281 / 351 | 시간 10[s] | 손실 1.47
# | 에폭 3 |  반복 301 / 351 | 시간 11[s] | 손실 1.46
# | 에폭 3 |  반복 321 / 351 | 시간 12[s] | 손실 1.45
# | 에폭 3 |  반복 341 / 351 | 시간 13[s] | 손실 1.44
# Q 77+85
# T 162
# X 103
# ---
# Q 975+164
# T 1139
# X 1363
# ---
# Q 582+84
# T 666
# X 736
# ---
# Q 8+155
# T 163
# X 226
# ---
# Q 367+55
# T 422
# X 463
# ---
# Q 600+257
# T 857
# X 866
# ---
# Q 761+292
# T 1053
# X 1026
# ---
# Q 830+597
# T 1427
# X 1573
# ---
# Q 26+838
# T 864
# X 903
# ---
# Q 143+93
# T 236
# X 303
# ---
# 검증 정확도 0.900%
# | 에폭 4 |  반복 1 / 351 | 시간 0[s] | 손실 1.41
# | 에폭 4 |  반복 21 / 351 | 시간 0[s] | 손실 1.42
# | 에폭 4 |  반복 41 / 351 | 시간 1[s] | 손실 1.41
# | 에폭 4 |  반복 61 / 351 | 시간 2[s] | 손실 1.40
# | 에폭 4 |  반복 81 / 351 | 시간 3[s] | 손실 1.40
# | 에폭 4 |  반복 101 / 351 | 시간 3[s] | 손실 1.38
# | 에폭 4 |  반복 121 / 351 | 시간 4[s] | 손실 1.37
# | 에폭 4 |  반복 141 / 351 | 시간 5[s] | 손실 1.36
# | 에폭 4 |  반복 161 / 351 | 시간 6[s] | 손실 1.36
# | 에폭 4 |  반복 181 / 351 | 시간 6[s] | 손실 1.34
# | 에폭 4 |  반복 201 / 351 | 시간 7[s] | 손실 1.34
# | 에폭 4 |  반복 221 / 351 | 시간 8[s] | 손실 1.33
# | 에폭 4 |  반복 241 / 351 | 시간 8[s] | 손실 1.32
# | 에폭 4 |  반복 261 / 351 | 시간 9[s] | 손실 1.30
# | 에폭 4 |  반복 281 / 351 | 시간 10[s] | 손실 1.30
# | 에폭 4 |  반복 301 / 351 | 시간 10[s] | 손실 1.29
# | 에폭 4 |  반복 321 / 351 | 시간 11[s] | 손실 1.29
# | 에폭 4 |  반복 341 / 351 | 시간 12[s] | 손실 1.28
# Q 77+85
# T 162
# X 167
# ---
# Q 975+164
# T 1139
# X 1171
# ---
# Q 582+84
# T 666
# X 737
# ---
# Q 8+155
# T 163
# X 187
# ---
# Q 367+55
# T 422
# X 477
# ---
# Q 600+257
# T 857
# X 877
# ---
# Q 761+292
# T 1053
# X 1067
# ---
# Q 830+597
# T 1427
# X 1507
# ---
# Q 26+838
# T 864
# X 877
# ---
# Q 143+93
# T 236
# X 257
# ---
# 검증 정확도 1.520%
# | 에폭 5 |  반복 1 / 351 | 시간 0[s] | 손실 1.26
# | 에폭 5 |  반복 21 / 351 | 시간 0[s] | 손실 1.27
# | 에폭 5 |  반복 41 / 351 | 시간 1[s] | 손실 1.25
# | 에폭 5 |  반복 61 / 351 | 시간 2[s] | 손실 1.26
# | 에폭 5 |  반복 81 / 351 | 시간 2[s] | 손실 1.24
# | 에폭 5 |  반복 101 / 351 | 시간 3[s] | 손실 1.24
# | 에폭 5 |  반복 121 / 351 | 시간 4[s] | 손실 1.23
# | 에폭 5 |  반복 141 / 351 | 시간 4[s] | 손실 1.23
# | 에폭 5 |  반복 161 / 351 | 시간 5[s] | 손실 1.21
# | 에폭 5 |  반복 181 / 351 | 시간 6[s] | 손실 1.21
# | 에폭 5 |  반복 201 / 351 | 시간 7[s] | 손실 1.21
# | 에폭 5 |  반복 221 / 351 | 시간 7[s] | 손실 1.20
# | 에폭 5 |  반복 241 / 351 | 시간 8[s] | 손실 1.20
# | 에폭 5 |  반복 261 / 351 | 시간 9[s] | 손실 1.18
# | 에폭 5 |  반복 281 / 351 | 시간 9[s] | 손실 1.18
# | 에폭 5 |  반복 301 / 351 | 시간 10[s] | 손실 1.17
# | 에폭 5 |  반복 321 / 351 | 시간 11[s] | 손실 1.17
# | 에폭 5 |  반복 341 / 351 | 시간 11[s] | 손실 1.17
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# X 1159
# ---
# Q 582+84
# T 666
# X 651
# ---
# Q 8+155
# T 163
# X 154
# ---
# Q 367+55
# T 422
# X 402
# ---
# Q 600+257
# T 857
# X 849
# ---
# Q 761+292
# T 1053
# X 1069
# ---
# Q 830+597
# T 1427
# X 1419
# ---
# Q 26+838
# T 864
# X 872
# ---
# Q 143+93
# T 236
# X 207
# ---
# 검증 정확도 2.140%
# | 에폭 6 |  반복 1 / 351 | 시간 0[s] | 손실 1.16
# | 에폭 6 |  반복 21 / 351 | 시간 0[s] | 손실 1.16
# | 에폭 6 |  반복 41 / 351 | 시간 1[s] | 손실 1.15
# | 에폭 6 |  반복 61 / 351 | 시간 2[s] | 손실 1.14
# | 에폭 6 |  반복 81 / 351 | 시간 2[s] | 손실 1.14
# | 에폭 6 |  반복 101 / 351 | 시간 3[s] | 손실 1.14
# | 에폭 6 |  반복 121 / 351 | 시간 4[s] | 손실 1.14
# | 에폭 6 |  반복 141 / 351 | 시간 5[s] | 손실 1.13
# | 에폭 6 |  반복 161 / 351 | 시간 5[s] | 손실 1.13
# | 에폭 6 |  반복 181 / 351 | 시간 6[s] | 손실 1.12
# | 에폭 6 |  반복 201 / 351 | 시간 7[s] | 손실 1.11
# | 에폭 6 |  반복 221 / 351 | 시간 7[s] | 손실 1.12
# | 에폭 6 |  반복 241 / 351 | 시간 8[s] | 손실 1.11
# | 에폭 6 |  반복 261 / 351 | 시간 9[s] | 손실 1.10
# | 에폭 6 |  반복 281 / 351 | 시간 9[s] | 손실 1.10
# | 에폭 6 |  반복 301 / 351 | 시간 10[s] | 손실 1.11
# | 에폭 6 |  반복 321 / 351 | 시간 11[s] | 손실 1.10
# | 에폭 6 |  반복 341 / 351 | 시간 11[s] | 손실 1.09
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# X 1143
# ---
# Q 582+84
# T 666
# X 659
# ---
# Q 8+155
# T 163
# X 173
# ---
# Q 367+55
# T 422
# X 403
# ---
# Q 600+257
# T 857
# X 859
# ---
# Q 761+292
# T 1053
# X 1079
# ---
# Q 830+597
# T 1427
# X 1441
# ---
# Q 26+838
# T 864
# X 859
# ---
# Q 143+93
# T 236
# X 207
# ---
# 검증 정확도 3.480%
# | 에폭 7 |  반복 1 / 351 | 시간 0[s] | 손실 1.08
# | 에폭 7 |  반복 21 / 351 | 시간 0[s] | 손실 1.08
# | 에폭 7 |  반복 41 / 351 | 시간 1[s] | 손실 1.08
# | 에폭 7 |  반복 61 / 351 | 시간 2[s] | 손실 1.07
# | 에폭 7 |  반복 81 / 351 | 시간 3[s] | 손실 1.07
# | 에폭 7 |  반복 101 / 351 | 시간 3[s] | 손실 1.07
# | 에폭 7 |  반복 121 / 351 | 시간 4[s] | 손실 1.07
# | 에폭 7 |  반복 141 / 351 | 시간 5[s] | 손실 1.06
# | 에폭 7 |  반복 161 / 351 | 시간 5[s] | 손실 1.06
# | 에폭 7 |  반복 181 / 351 | 시간 6[s] | 손실 1.05
# | 에폭 7 |  반복 201 / 351 | 시간 7[s] | 손실 1.05
# | 에폭 7 |  반복 221 / 351 | 시간 7[s] | 손실 1.04
# | 에폭 7 |  반복 241 / 351 | 시간 8[s] | 손실 1.06
# | 에폭 7 |  반복 261 / 351 | 시간 9[s] | 손실 1.05
# | 에폭 7 |  반복 281 / 351 | 시간 9[s] | 손실 1.04
# | 에폭 7 |  반복 301 / 351 | 시간 10[s] | 손실 1.05
# | 에폭 7 |  반복 321 / 351 | 시간 11[s] | 손실 1.03
# | 에폭 7 |  반복 341 / 351 | 시간 11[s] | 손실 1.03
# Q 77+85
# T 162
# X 160
# ---
# Q 975+164
# T 1139
# X 1118
# ---
# Q 582+84
# T 666
# X 658
# ---
# Q 8+155
# T 163
# X 173
# ---
# Q 367+55
# T 422
# X 403
# ---
# Q 600+257
# T 857
# X 858
# ---
# Q 761+292
# T 1053
# X 1073
# ---
# Q 830+597
# T 1427
# X 1440
# ---
# Q 26+838
# T 864
# X 880
# ---
# Q 143+93
# T 236
# X 208
# ---
# 검증 정확도 3.800%
# | 에폭 8 |  반복 1 / 351 | 시간 0[s] | 손실 1.00
# | 에폭 8 |  반복 21 / 351 | 시간 0[s] | 손실 1.02
# | 에폭 8 |  반복 41 / 351 | 시간 1[s] | 손실 1.04
# | 에폭 8 |  반복 61 / 351 | 시간 2[s] | 손실 1.03
# | 에폭 8 |  반복 81 / 351 | 시간 2[s] | 손실 1.02
# | 에폭 8 |  반복 101 / 351 | 시간 3[s] | 손실 1.02
# | 에폭 8 |  반복 121 / 351 | 시간 4[s] | 손실 1.02
# | 에폭 8 |  반복 141 / 351 | 시간 5[s] | 손실 1.02
# | 에폭 8 |  반복 161 / 351 | 시간 5[s] | 손실 1.02
# | 에폭 8 |  반복 181 / 351 | 시간 6[s] | 손실 1.00
# | 에폭 8 |  반복 201 / 351 | 시간 7[s] | 손실 1.00
# | 에폭 8 |  반복 221 / 351 | 시간 8[s] | 손실 1.00
# | 에폭 8 |  반복 241 / 351 | 시간 8[s] | 손실 0.99
# | 에폭 8 |  반복 261 / 351 | 시간 9[s] | 손실 1.00
# | 에폭 8 |  반복 281 / 351 | 시간 10[s] | 손실 1.00
# | 에폭 8 |  반복 301 / 351 | 시간 10[s] | 손실 0.99
# | 에폭 8 |  반복 321 / 351 | 시간 11[s] | 손실 0.99
# | 에폭 8 |  반복 341 / 351 | 시간 12[s] | 손실 0.99
# Q 77+85
# T 162
# X 166
# ---
# Q 975+164
# T 1139
# X 1166
# ---
# Q 582+84
# T 666
# X 680
# ---
# Q 8+155
# T 163
# X 166
# ---
# Q 367+55
# T 422
# X 426
# ---
# Q 600+257
# T 857
# X 861
# ---
# Q 761+292
# T 1053
# X 1066
# ---
# Q 830+597
# T 1427
# X 1415
# ---
# Q 26+838
# T 864
# X 882
# ---
# Q 143+93
# T 236
# X 246
# ---
# 검증 정확도 5.020%
# | 에폭 9 |  반복 1 / 351 | 시간 0[s] | 손실 0.97
# | 에폭 9 |  반복 21 / 351 | 시간 0[s] | 손실 0.99
# | 에폭 9 |  반복 41 / 351 | 시간 1[s] | 손실 0.99
# | 에폭 9 |  반복 61 / 351 | 시간 2[s] | 손실 1.00
# | 에폭 9 |  반복 81 / 351 | 시간 2[s] | 손실 0.99
# | 에폭 9 |  반복 101 / 351 | 시간 3[s] | 손실 0.99
# | 에폭 9 |  반복 121 / 351 | 시간 4[s] | 손실 0.97
# | 에폭 9 |  반복 141 / 351 | 시간 4[s] | 손실 0.98
# | 에폭 9 |  반복 161 / 351 | 시간 5[s] | 손실 0.98
# | 에폭 9 |  반복 181 / 351 | 시간 6[s] | 손실 0.96
# | 에폭 9 |  반복 201 / 351 | 시간 6[s] | 손실 0.97
# | 에폭 9 |  반복 221 / 351 | 시간 7[s] | 손실 0.96
# | 에폭 9 |  반복 241 / 351 | 시간 8[s] | 손실 0.98
# | 에폭 9 |  반복 261 / 351 | 시간 8[s] | 손실 0.97
# | 에폭 9 |  반복 281 / 351 | 시간 9[s] | 손실 0.96
# | 에폭 9 |  반복 301 / 351 | 시간 10[s] | 손실 0.97
# | 에폭 9 |  반복 321 / 351 | 시간 10[s] | 손실 0.96
# | 에폭 9 |  반복 341 / 351 | 시간 11[s] | 손실 0.96
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# X 1160
# ---
# Q 582+84
# T 666
# X 680
# ---
# Q 8+155
# T 163
# X 168
# ---
# Q 367+55
# T 422
# X 413
# ---
# Q 600+257
# T 857
# X 851
# ---
# Q 761+292
# T 1053
# X 1063
# ---
# Q 830+597
# T 1427
# X 1441
# ---
# Q 26+838
# T 864
# X 872
# ---
# Q 143+93
# T 236
# X 238
# ---
# 검증 정확도 5.120%
# | 에폭 10 |  반복 1 / 351 | 시간 0[s] | 손실 0.93
# | 에폭 10 |  반복 21 / 351 | 시간 0[s] | 손실 0.94
# | 에폭 10 |  반복 41 / 351 | 시간 1[s] | 손실 0.94
# | 에폭 10 |  반복 61 / 351 | 시간 2[s] | 손실 0.95
# | 에폭 10 |  반복 81 / 351 | 시간 2[s] | 손실 0.95
# | 에폭 10 |  반복 101 / 351 | 시간 3[s] | 손실 0.95
# | 에폭 10 |  반복 121 / 351 | 시간 4[s] | 손실 0.93
# | 에폭 10 |  반복 141 / 351 | 시간 5[s] | 손실 0.94
# | 에폭 10 |  반복 161 / 351 | 시간 5[s] | 손실 0.94
# | 에폭 10 |  반복 181 / 351 | 시간 6[s] | 손실 0.95
# | 에폭 10 |  반복 201 / 351 | 시간 7[s] | 손실 0.93
# | 에폭 10 |  반복 221 / 351 | 시간 8[s] | 손실 0.93
# | 에폭 10 |  반복 241 / 351 | 시간 8[s] | 손실 0.94
# | 에폭 10 |  반복 261 / 351 | 시간 9[s] | 손실 0.93
# | 에폭 10 |  반복 281 / 351 | 시간 10[s] | 손실 0.93
# | 에폭 10 |  반복 301 / 351 | 시간 11[s] | 손실 0.93
# | 에폭 10 |  반복 321 / 351 | 시간 12[s] | 손실 0.94
# | 에폭 10 |  반복 341 / 351 | 시간 13[s] | 손실 0.93
# Q 77+85
# T 162
# X 164
# ---
# Q 975+164
# T 1139
# X 1149
# ---
# Q 582+84
# T 666
# X 661
# ---
# Q 8+155
# T 163
# X 164
# ---
# Q 367+55
# T 422
# X 414
# ---
# Q 600+257
# T 857
# X 851
# ---
# Q 761+292
# T 1053
# X 1049
# ---
# Q 830+597
# T 1427
# X 1409
# ---
# Q 26+838
# T 864
# X 868
# ---
# Q 143+93
# T 236
# O 236
# ---
# 검증 정확도 6.960%
# | 에폭 11 |  반복 1 / 351 | 시간 0[s] | 손실 0.92
# | 에폭 11 |  반복 21 / 351 | 시간 0[s] | 손실 0.92
# | 에폭 11 |  반복 41 / 351 | 시간 1[s] | 손실 0.93
# | 에폭 11 |  반복 61 / 351 | 시간 2[s] | 손실 0.92
# | 에폭 11 |  반복 81 / 351 | 시간 3[s] | 손실 0.92
# | 에폭 11 |  반복 101 / 351 | 시간 3[s] | 손실 0.91
# | 에폭 11 |  반복 121 / 351 | 시간 4[s] | 손실 0.91
# | 에폭 11 |  반복 141 / 351 | 시간 5[s] | 손실 0.92
# | 에폭 11 |  반복 161 / 351 | 시간 6[s] | 손실 0.92
# | 에폭 11 |  반복 181 / 351 | 시간 6[s] | 손실 0.91
# | 에폭 11 |  반복 201 / 351 | 시간 7[s] | 손실 0.92
# | 에폭 11 |  반복 221 / 351 | 시간 8[s] | 손실 0.93
# | 에폭 11 |  반복 241 / 351 | 시간 8[s] | 손실 0.94
# | 에폭 11 |  반복 261 / 351 | 시간 9[s] | 손실 0.89
# | 에폭 11 |  반복 281 / 351 | 시간 10[s] | 손실 0.91
# | 에폭 11 |  반복 301 / 351 | 시간 11[s] | 손실 0.91
# | 에폭 11 |  반복 321 / 351 | 시간 12[s] | 손실 0.91
# | 에폭 11 |  반복 341 / 351 | 시간 12[s] | 손실 0.90
# Q 77+85
# T 162
# X 165
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# X 670
# ---
# Q 8+155
# T 163
# X 165
# ---
# Q 367+55
# T 422
# X 409
# ---
# Q 600+257
# T 857
# X 851
# ---
# Q 761+292
# T 1053
# X 1059
# ---
# Q 830+597
# T 1427
# X 1409
# ---
# Q 26+838
# T 864
# X 869
# ---
# Q 143+93
# T 236
# X 241
# ---
# 검증 정확도 7.700%
# | 에폭 12 |  반복 1 / 351 | 시간 0[s] | 손실 0.88
# | 에폭 12 |  반복 21 / 351 | 시간 0[s] | 손실 0.88
# | 에폭 12 |  반복 41 / 351 | 시간 1[s] | 손실 0.89
# | 에폭 12 |  반복 61 / 351 | 시간 2[s] | 손실 0.89
# | 에폭 12 |  반복 81 / 351 | 시간 2[s] | 손실 0.93
# | 에폭 12 |  반복 101 / 351 | 시간 3[s] | 손실 0.92
# | 에폭 12 |  반복 121 / 351 | 시간 4[s] | 손실 0.93
# | 에폭 12 |  반복 141 / 351 | 시간 5[s] | 손실 0.92
# | 에폭 12 |  반복 161 / 351 | 시간 6[s] | 손실 0.90
# | 에폭 12 |  반복 181 / 351 | 시간 6[s] | 손실 0.88
# | 에폭 12 |  반복 201 / 351 | 시간 7[s] | 손실 0.87
# | 에폭 12 |  반복 221 / 351 | 시간 8[s] | 손실 0.88
# | 에폭 12 |  반복 241 / 351 | 시간 9[s] | 손실 0.88
# | 에폭 12 |  반복 261 / 351 | 시간 9[s] | 손실 0.91
# | 에폭 12 |  반복 281 / 351 | 시간 10[s] | 손실 0.89
# | 에폭 12 |  반복 301 / 351 | 시간 11[s] | 손실 0.87
# | 에폭 12 |  반복 321 / 351 | 시간 11[s] | 손실 0.89
# | 에폭 12 |  반복 341 / 351 | 시간 12[s] | 손실 0.87
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# X 673
# ---
# Q 8+155
# T 163
# X 165
# ---
# Q 367+55
# T 422
# X 419
# ---
# Q 600+257
# T 857
# X 851
# ---
# Q 761+292
# T 1053
# X 1039
# ---
# Q 830+597
# T 1427
# X 1419
# ---
# Q 26+838
# T 864
# X 867
# ---
# Q 143+93
# T 236
# X 239
# ---
# 검증 정확도 8.300%
# | 에폭 13 |  반복 1 / 351 | 시간 0[s] | 손실 0.85
# | 에폭 13 |  반복 21 / 351 | 시간 0[s] | 손실 0.88
# | 에폭 13 |  반복 41 / 351 | 시간 1[s] | 손실 0.87
# | 에폭 13 |  반복 61 / 351 | 시간 2[s] | 손실 0.87
# | 에폭 13 |  반복 81 / 351 | 시간 2[s] | 손실 0.86
# | 에폭 13 |  반복 101 / 351 | 시간 3[s] | 손실 0.85
# | 에폭 13 |  반복 121 / 351 | 시간 4[s] | 손실 0.86
# | 에폭 13 |  반복 141 / 351 | 시간 5[s] | 손실 0.86
# | 에폭 13 |  반복 161 / 351 | 시간 5[s] | 손실 0.86
# | 에폭 13 |  반복 181 / 351 | 시간 6[s] | 손실 0.86
# | 에폭 13 |  반복 201 / 351 | 시간 7[s] | 손실 0.84
# | 에폭 13 |  반복 221 / 351 | 시간 8[s] | 손실 0.85
# | 에폭 13 |  반복 241 / 351 | 시간 8[s] | 손실 0.85
# | 에폭 13 |  반복 261 / 351 | 시간 9[s] | 손실 0.87
# | 에폭 13 |  반복 281 / 351 | 시간 10[s] | 손실 0.85
# | 에폭 13 |  반복 301 / 351 | 시간 11[s] | 손실 0.84
# | 에폭 13 |  반복 321 / 351 | 시간 11[s] | 손실 0.85
# | 에폭 13 |  반복 341 / 351 | 시간 12[s] | 손실 0.85
# Q 77+85
# T 162
# X 160
# ---
# Q 975+164
# T 1139
# X 1135
# ---
# Q 582+84
# T 666
# X 665
# ---
# Q 8+155
# T 163
# X 165
# ---
# Q 367+55
# T 422
# X 415
# ---
# Q 600+257
# T 857
# X 855
# ---
# Q 761+292
# T 1053
# X 1056
# ---
# Q 830+597
# T 1427
# X 1409
# ---
# Q 26+838
# T 864
# X 869
# ---
# Q 143+93
# T 236
# X 235
# ---
# 검증 정확도 8.900%
# | 에폭 14 |  반복 1 / 351 | 시간 0[s] | 손실 0.83
# | 에폭 14 |  반복 21 / 351 | 시간 0[s] | 손실 0.84
# | 에폭 14 |  반복 41 / 351 | 시간 1[s] | 손실 0.84
# | 에폭 14 |  반복 61 / 351 | 시간 2[s] | 손실 0.84
# | 에폭 14 |  반복 81 / 351 | 시간 2[s] | 손실 0.86
# | 에폭 14 |  반복 101 / 351 | 시간 3[s] | 손실 0.90
# | 에폭 14 |  반복 121 / 351 | 시간 4[s] | 손실 0.84
# | 에폭 14 |  반복 141 / 351 | 시간 5[s] | 손실 0.83
# | 에폭 14 |  반복 161 / 351 | 시간 5[s] | 손실 0.83
# | 에폭 14 |  반복 181 / 351 | 시간 6[s] | 손실 0.83
# | 에폭 14 |  반복 201 / 351 | 시간 7[s] | 손실 0.83
# | 에폭 14 |  반복 221 / 351 | 시간 8[s] | 손실 0.81
# | 에폭 14 |  반복 241 / 351 | 시간 8[s] | 손실 0.85
# | 에폭 14 |  반복 261 / 351 | 시간 9[s] | 손실 0.87
# | 에폭 14 |  반복 281 / 351 | 시간 10[s] | 손실 0.85
# | 에폭 14 |  반복 301 / 351 | 시간 10[s] | 손실 0.85
# | 에폭 14 |  반복 321 / 351 | 시간 11[s] | 손실 0.85
# | 에폭 14 |  반복 341 / 351 | 시간 12[s] | 손실 0.82
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1145
# ---
# Q 582+84
# T 666
# X 674
# ---
# Q 8+155
# T 163
# X 173
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 850
# ---
# Q 761+292
# T 1053
# X 1047
# ---
# Q 830+597
# T 1427
# X 1409
# ---
# Q 26+838
# T 864
# X 867
# ---
# Q 143+93
# T 236
# X 229
# ---
# 검증 정확도 9.080%
# | 에폭 15 |  반복 1 / 351 | 시간 0[s] | 손실 0.82
# | 에폭 15 |  반복 21 / 351 | 시간 0[s] | 손실 0.82
# | 에폭 15 |  반복 41 / 351 | 시간 1[s] | 손실 0.82
# | 에폭 15 |  반복 61 / 351 | 시간 2[s] | 손실 0.83
# | 에폭 15 |  반복 81 / 351 | 시간 2[s] | 손실 0.83
# | 에폭 15 |  반복 101 / 351 | 시간 3[s] | 손실 0.82
# | 에폭 15 |  반복 121 / 351 | 시간 4[s] | 손실 0.85
# | 에폭 15 |  반복 141 / 351 | 시간 5[s] | 손실 0.82
# | 에폭 15 |  반복 161 / 351 | 시간 5[s] | 손실 0.80
# | 에폭 15 |  반복 181 / 351 | 시간 6[s] | 손실 0.84
# | 에폭 15 |  반복 201 / 351 | 시간 7[s] | 손실 0.83
# | 에폭 15 |  반복 221 / 351 | 시간 8[s] | 손실 0.81
# | 에폭 15 |  반복 241 / 351 | 시간 8[s] | 손실 0.81
# | 에폭 15 |  반복 261 / 351 | 시간 9[s] | 손실 0.84
# | 에폭 15 |  반복 281 / 351 | 시간 10[s] | 손실 0.84
# | 에폭 15 |  반복 301 / 351 | 시간 10[s] | 손실 0.81
# | 에폭 15 |  반복 321 / 351 | 시간 11[s] | 손실 0.80
# | 에폭 15 |  반복 341 / 351 | 시간 12[s] | 손실 0.79
# Q 77+85
# T 162
# X 164
# ---
# Q 975+164
# T 1139
# X 1149
# ---
# Q 582+84
# T 666
# X 659
# ---
# Q 8+155
# T 163
# X 167
# ---
# Q 367+55
# T 422
# X 424
# ---
# Q 600+257
# T 857
# X 851
# ---
# Q 761+292
# T 1053
# X 1049
# ---
# Q 830+597
# T 1427
# X 1409
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 239
# ---
# 검증 정확도 10.700%
# | 에폭 16 |  반복 1 / 351 | 시간 0[s] | 손실 0.78
# | 에폭 16 |  반복 21 / 351 | 시간 0[s] | 손실 0.80
# | 에폭 16 |  반복 41 / 351 | 시간 1[s] | 손실 0.82
# | 에폭 16 |  반복 61 / 351 | 시간 2[s] | 손실 0.81
# | 에폭 16 |  반복 81 / 351 | 시간 2[s] | 손실 0.79
# | 에폭 16 |  반복 101 / 351 | 시간 3[s] | 손실 0.80
# | 에폭 16 |  반복 121 / 351 | 시간 4[s] | 손실 0.79
# | 에폭 16 |  반복 141 / 351 | 시간 4[s] | 손실 0.79
# | 에폭 16 |  반복 161 / 351 | 시간 5[s] | 손실 0.80
# | 에폭 16 |  반복 181 / 351 | 시간 6[s] | 손실 0.79
# | 에폭 16 |  반복 201 / 351 | 시간 6[s] | 손실 0.81
# | 에폭 16 |  반복 221 / 351 | 시간 7[s] | 손실 0.79
# | 에폭 16 |  반복 241 / 351 | 시간 8[s] | 손실 0.80
# | 에폭 16 |  반복 261 / 351 | 시간 9[s] | 손실 0.80
# | 에폭 16 |  반복 281 / 351 | 시간 9[s] | 손실 0.79
# | 에폭 16 |  반복 301 / 351 | 시간 10[s] | 손실 0.80
# | 에폭 16 |  반복 321 / 351 | 시간 11[s] | 손실 0.79
# | 에폭 16 |  반복 341 / 351 | 시간 11[s] | 손실 0.77
# Q 77+85
# T 162
# X 164
# ---
# Q 975+164
# T 1139
# X 1144
# ---
# Q 582+84
# T 666
# X 659
# ---
# Q 8+155
# T 163
# X 164
# ---
# Q 367+55
# T 422
# X 419
# ---
# Q 600+257
# T 857
# X 874
# ---
# Q 761+292
# T 1053
# X 1059
# ---
# Q 830+597
# T 1427
# X 1440
# ---
# Q 26+838
# T 864
# X 869
# ---
# Q 143+93
# T 236
# X 240
# ---
# 검증 정확도 9.080%
# | 에폭 17 |  반복 1 / 351 | 시간 0[s] | 손실 0.77
# | 에폭 17 |  반복 21 / 351 | 시간 0[s] | 손실 0.79
# | 에폭 17 |  반복 41 / 351 | 시간 1[s] | 손실 0.77
# | 에폭 17 |  반복 61 / 351 | 시간 2[s] | 손실 0.77
# | 에폭 17 |  반복 81 / 351 | 시간 2[s] | 손실 0.76
# | 에폭 17 |  반복 101 / 351 | 시간 3[s] | 손실 0.78
# | 에폭 17 |  반복 121 / 351 | 시간 4[s] | 손실 0.80
# | 에폭 17 |  반복 141 / 351 | 시간 4[s] | 손실 0.79
# | 에폭 17 |  반복 161 / 351 | 시간 5[s] | 손실 0.76
# | 에폭 17 |  반복 181 / 351 | 시간 6[s] | 손실 0.77
# | 에폭 17 |  반복 201 / 351 | 시간 6[s] | 손실 0.76
# | 에폭 17 |  반복 221 / 351 | 시간 7[s] | 손실 0.75
# | 에폭 17 |  반복 241 / 351 | 시간 8[s] | 손실 0.75
# | 에폭 17 |  반복 261 / 351 | 시간 8[s] | 손실 0.80
# | 에폭 17 |  반복 281 / 351 | 시간 9[s] | 손실 0.80
# | 에폭 17 |  반복 301 / 351 | 시간 10[s] | 손실 0.77
# | 에폭 17 |  반복 321 / 351 | 시간 11[s] | 손실 0.74
# | 에폭 17 |  반복 341 / 351 | 시간 11[s] | 손실 0.75
# Q 77+85
# T 162
# X 160
# ---
# Q 975+164
# T 1139
# X 1125
# ---
# Q 582+84
# T 666
# X 658
# ---
# Q 8+155
# T 163
# X 164
# ---
# Q 367+55
# T 422
# X 420
# ---
# Q 600+257
# T 857
# X 840
# ---
# Q 761+292
# T 1053
# X 1035
# ---
# Q 830+597
# T 1427
# X 1409
# ---
# Q 26+838
# T 864
# X 860
# ---
# Q 143+93
# T 236
# X 240
# ---
# 검증 정확도 8.160%
# | 에폭 18 |  반복 1 / 351 | 시간 0[s] | 손실 0.78
# | 에폭 18 |  반복 21 / 351 | 시간 0[s] | 손실 0.74
# | 에폭 18 |  반복 41 / 351 | 시간 1[s] | 손실 0.79
# | 에폭 18 |  반복 61 / 351 | 시간 2[s] | 손실 0.77
# | 에폭 18 |  반복 81 / 351 | 시간 2[s] | 손실 0.75
# | 에폭 18 |  반복 101 / 351 | 시간 3[s] | 손실 0.79
# | 에폭 18 |  반복 121 / 351 | 시간 4[s] | 손실 0.77
# | 에폭 18 |  반복 141 / 351 | 시간 4[s] | 손실 0.77
# | 에폭 18 |  반복 161 / 351 | 시간 5[s] | 손실 0.75
# | 에폭 18 |  반복 181 / 351 | 시간 6[s] | 손실 0.75
# | 에폭 18 |  반복 201 / 351 | 시간 6[s] | 손실 0.76
# | 에폭 18 |  반복 221 / 351 | 시간 7[s] | 손실 0.77
# | 에폭 18 |  반복 241 / 351 | 시간 8[s] | 손실 0.77
# | 에폭 18 |  반복 261 / 351 | 시간 8[s] | 손실 0.77
# | 에폭 18 |  반복 281 / 351 | 시간 9[s] | 손실 0.72
# | 에폭 18 |  반복 301 / 351 | 시간 10[s] | 손실 0.74
# | 에폭 18 |  반복 321 / 351 | 시간 11[s] | 손실 0.76
# | 에폭 18 |  반복 341 / 351 | 시간 11[s] | 손실 0.75
# Q 77+85
# T 162
# X 161
# ---
# Q 975+164
# T 1139
# X 1149
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# X 425
# ---
# Q 600+257
# T 857
# X 851
# ---
# Q 761+292
# T 1053
# X 1059
# ---
# Q 830+597
# T 1427
# X 1415
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 235
# ---
# 검증 정확도 14.160%
# | 에폭 19 |  반복 1 / 351 | 시간 0[s] | 손실 0.73
# | 에폭 19 |  반복 21 / 351 | 시간 0[s] | 손실 0.74
# | 에폭 19 |  반복 41 / 351 | 시간 1[s] | 손실 0.75
# | 에폭 19 |  반복 61 / 351 | 시간 2[s] | 손실 0.73
# | 에폭 19 |  반복 81 / 351 | 시간 2[s] | 손실 0.72
# | 에폭 19 |  반복 101 / 351 | 시간 3[s] | 손실 0.75
# | 에폭 19 |  반복 121 / 351 | 시간 4[s] | 손실 0.72
# | 에폭 19 |  반복 141 / 351 | 시간 4[s] | 손실 0.74
# | 에폭 19 |  반복 161 / 351 | 시간 5[s] | 손실 0.71
# | 에폭 19 |  반복 181 / 351 | 시간 6[s] | 손실 0.73
# | 에폭 19 |  반복 201 / 351 | 시간 6[s] | 손실 0.73
# | 에폭 19 |  반복 221 / 351 | 시간 7[s] | 손실 0.72
# | 에폭 19 |  반복 241 / 351 | 시간 8[s] | 손실 0.71
# | 에폭 19 |  반복 261 / 351 | 시간 9[s] | 손실 0.72
# | 에폭 19 |  반복 281 / 351 | 시간 9[s] | 손실 0.76
# | 에폭 19 |  반복 301 / 351 | 시간 10[s] | 손실 0.75
# | 에폭 19 |  반복 321 / 351 | 시간 11[s] | 손실 0.75
# | 에폭 19 |  반복 341 / 351 | 시간 11[s] | 손실 0.75
# Q 77+85
# T 162
# X 161
# ---
# Q 975+164
# T 1139
# X 1138
# ---
# Q 582+84
# T 666
# X 658
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# X 418
# ---
# Q 600+257
# T 857
# X 850
# ---
# Q 761+292
# T 1053
# X 1051
# ---
# Q 830+597
# T 1427
# X 1415
# ---
# Q 26+838
# T 864
# X 860
# ---
# Q 143+93
# T 236
# X 235
# ---
# 검증 정확도 12.040%
# | 에폭 20 |  반복 1 / 351 | 시간 0[s] | 손실 0.72
# | 에폭 20 |  반복 21 / 351 | 시간 0[s] | 손실 0.73
# | 에폭 20 |  반복 41 / 351 | 시간 1[s] | 손실 0.75
# | 에폭 20 |  반복 61 / 351 | 시간 1[s] | 손실 0.71
# | 에폭 20 |  반복 81 / 351 | 시간 2[s] | 손실 0.72
# | 에폭 20 |  반복 101 / 351 | 시간 2[s] | 손실 0.73
# | 에폭 20 |  반복 121 / 351 | 시간 3[s] | 손실 0.72
# | 에폭 20 |  반복 141 / 351 | 시간 3[s] | 손실 0.73
# | 에폭 20 |  반복 161 / 351 | 시간 4[s] | 손실 0.73
# | 에폭 20 |  반복 181 / 351 | 시간 4[s] | 손실 0.71
# | 에폭 20 |  반복 201 / 351 | 시간 5[s] | 손실 0.75
# | 에폭 20 |  반복 221 / 351 | 시간 5[s] | 손실 0.77
# | 에폭 20 |  반복 241 / 351 | 시간 6[s] | 손실 0.72
# | 에폭 20 |  반복 261 / 351 | 시간 6[s] | 손실 0.71
# | 에폭 20 |  반복 281 / 351 | 시간 7[s] | 손실 0.71
# ...
# | 에폭 11 |  반복 181 / 351 | 시간 10[s] | 손실 0.74
# | 에폭 11 |  반복 201 / 351 | 시간 11[s] | 손실 0.82
# | 에폭 11 |  반복 221 / 351 | 시간 12[s] | 손실 0.78
# | 에폭 11 |  반복 241 / 351 | 시간 13[s] | 손실 0.73
# | 에폭 11 |  반복 261 / 351 | 시간 14[s] | 손실 0.74
# | 에폭 11 |  반복 281 / 351 | 시간 16[s] | 손실 0.74
# | 에폭 11 |  반복 301 / 351 | 시간 17[s] | 손실 0.78
# | 에폭 11 |  반복 321 / 351 | 시간 18[s] | 손실 0.79
# | 에폭 11 |  반복 341 / 351 | 시간 19[s] | 손실 0.77
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1136
# ---
# Q 582+84
# T 666
# X 665
# ---
# Q 8+155
# T 163
# X 157
# ---
# Q 367+55
# T 422
# X 416
# ---
# Q 600+257
# T 857
# X 842
# ---
# Q 761+292
# T 1053
# X 1059
# ---
# Q 830+597
# T 1427
# X 1441
# ---
# Q 26+838
# T 864
# X 856
# ---
# Q 143+93
# T 236
# X 230
# ---
# 검증 정확도 6.000%
# | 에폭 12 |  반복 1 / 351 | 시간 0[s] | 손실 0.78
# | 에폭 12 |  반복 21 / 351 | 시간 1[s] | 손실 0.77
# | 에폭 12 |  반복 41 / 351 | 시간 2[s] | 손실 0.76
# | 에폭 12 |  반복 61 / 351 | 시간 3[s] | 손실 0.74
# | 에폭 12 |  반복 81 / 351 | 시간 4[s] | 손실 0.74
# | 에폭 12 |  반복 101 / 351 | 시간 5[s] | 손실 0.75
# | 에폭 12 |  반복 121 / 351 | 시간 6[s] | 손실 0.74
# | 에폭 12 |  반복 141 / 351 | 시간 7[s] | 손실 0.72
# | 에폭 12 |  반복 161 / 351 | 시간 9[s] | 손실 0.71
# | 에폭 12 |  반복 181 / 351 | 시간 10[s] | 손실 0.70
# | 에폭 12 |  반복 201 / 351 | 시간 11[s] | 손실 0.71
# | 에폭 12 |  반복 221 / 351 | 시간 12[s] | 손실 0.71
# | 에폭 12 |  반복 241 / 351 | 시간 13[s] | 손실 0.71
# | 에폭 12 |  반복 261 / 351 | 시간 14[s] | 손실 0.71
# | 에폭 12 |  반복 281 / 351 | 시간 15[s] | 손실 0.70
# | 에폭 12 |  반복 301 / 351 | 시간 16[s] | 손실 0.70
# | 에폭 12 |  반복 321 / 351 | 시간 17[s] | 손실 0.71
# | 에폭 12 |  반복 341 / 351 | 시간 18[s] | 손실 0.73
# Q 77+85
# T 162
# X 164
# ---
# Q 975+164
# T 1139
# X 1136
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 171
# ---
# Q 367+55
# T 422
# X 423
# ---
# Q 600+257
# T 857
# X 867
# ---
# Q 761+292
# T 1053
# X 1083
# ---
# Q 830+597
# T 1427
# X 1463
# ---
# Q 26+838
# T 864
# X 872
# ---
# Q 143+93
# T 236
# X 237
# ---
# 검증 정확도 3.900%
# | 에폭 13 |  반복 1 / 351 | 시간 0[s] | 손실 0.94
# | 에폭 13 |  반복 21 / 351 | 시간 1[s] | 손실 0.81
# | 에폭 13 |  반복 41 / 351 | 시간 2[s] | 손실 0.72
# | 에폭 13 |  반복 61 / 351 | 시간 3[s] | 손실 0.67
# | 에폭 13 |  반복 81 / 351 | 시간 4[s] | 손실 0.68
# | 에폭 13 |  반복 101 / 351 | 시간 5[s] | 손실 0.68
# | 에폭 13 |  반복 121 / 351 | 시간 6[s] | 손실 0.70
# | 에폭 13 |  반복 141 / 351 | 시간 7[s] | 손실 0.70
# | 에폭 13 |  반복 161 / 351 | 시간 8[s] | 손실 0.70
# | 에폭 13 |  반복 181 / 351 | 시간 10[s] | 손실 0.68
# | 에폭 13 |  반복 201 / 351 | 시간 11[s] | 손실 0.69
# | 에폭 13 |  반복 221 / 351 | 시간 12[s] | 손실 0.66
# | 에폭 13 |  반복 241 / 351 | 시간 13[s] | 손실 0.69
# | 에폭 13 |  반복 261 / 351 | 시간 14[s] | 손실 0.66
# | 에폭 13 |  반복 281 / 351 | 시간 15[s] | 손실 0.65
# | 에폭 13 |  반복 301 / 351 | 시간 16[s] | 손실 0.67
# | 에폭 13 |  반복 321 / 351 | 시간 18[s] | 손실 0.71
# | 에폭 13 |  반복 341 / 351 | 시간 19[s] | 손실 0.64
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1149
# ---
# Q 582+84
# T 666
# X 665
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# X 420
# ---
# Q 600+257
# T 857
# X 859
# ---
# Q 761+292
# T 1053
# X 1049
# ---
# Q 830+597
# T 1427
# X 1441
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 234
# ---
# 검증 정확도 16.820%
# | 에폭 14 |  반복 1 / 351 | 시간 0[s] | 손실 0.60
# | 에폭 14 |  반복 21 / 351 | 시간 1[s] | 손실 0.66
# | 에폭 14 |  반복 41 / 351 | 시간 2[s] | 손실 0.69
# | 에폭 14 |  반복 61 / 351 | 시간 4[s] | 손실 0.66
# | 에폭 14 |  반복 81 / 351 | 시간 5[s] | 손실 0.66
# | 에폭 14 |  반복 101 / 351 | 시간 7[s] | 손실 0.65
# | 에폭 14 |  반복 121 / 351 | 시간 8[s] | 손실 0.67
# | 에폭 14 |  반복 141 / 351 | 시간 9[s] | 손실 0.64
# | 에폭 14 |  반복 161 / 351 | 시간 11[s] | 손실 0.63
# | 에폭 14 |  반복 181 / 351 | 시간 12[s] | 손실 0.64
# | 에폭 14 |  반복 201 / 351 | 시간 14[s] | 손실 0.67
# | 에폭 14 |  반복 221 / 351 | 시간 15[s] | 손실 0.68
# | 에폭 14 |  반복 241 / 351 | 시간 17[s] | 손실 0.68
# | 에폭 14 |  반복 261 / 351 | 시간 18[s] | 손실 0.65
# | 에폭 14 |  반복 281 / 351 | 시간 20[s] | 손실 0.64
# | 에폭 14 |  반복 301 / 351 | 시간 21[s] | 손실 0.64
# | 에폭 14 |  반복 321 / 351 | 시간 23[s] | 손실 0.63
# | 에폭 14 |  반복 341 / 351 | 시간 24[s] | 손실 0.64
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1149
# ---
# Q 582+84
# T 666
# X 665
# ---
# Q 8+155
# T 163
# X 169
# ---
# Q 367+55
# T 422
# X 423
# ---
# Q 600+257
# T 857
# X 854
# ---
# Q 761+292
# T 1053
# X 1049
# ---
# Q 830+597
# T 1427
# X 1441
# ---
# Q 26+838
# T 864
# X 868
# ---
# Q 143+93
# T 236
# X 239
# ---
# 검증 정확도 12.820%
# | 에폭 15 |  반복 1 / 351 | 시간 0[s] | 손실 0.68
# | 에폭 15 |  반복 21 / 351 | 시간 1[s] | 손실 0.62
# | 에폭 15 |  반복 41 / 351 | 시간 2[s] | 손실 0.63
# | 에폭 15 |  반복 61 / 351 | 시간 4[s] | 손실 0.68
# | 에폭 15 |  반복 81 / 351 | 시간 5[s] | 손실 0.64
# | 에폭 15 |  반복 101 / 351 | 시간 6[s] | 손실 0.63
# | 에폭 15 |  반복 121 / 351 | 시간 8[s] | 손실 0.62
# | 에폭 15 |  반복 141 / 351 | 시간 9[s] | 손실 0.62
# | 에폭 15 |  반복 161 / 351 | 시간 10[s] | 손실 0.63
# | 에폭 15 |  반복 181 / 351 | 시간 11[s] | 손실 0.62
# | 에폭 15 |  반복 201 / 351 | 시간 13[s] | 손실 0.64
# | 에폭 15 |  반복 221 / 351 | 시간 14[s] | 손실 0.60
# | 에폭 15 |  반복 241 / 351 | 시간 15[s] | 손실 0.60
# | 에폭 15 |  반복 261 / 351 | 시간 17[s] | 손실 0.63
# | 에폭 15 |  반복 281 / 351 | 시간 18[s] | 손실 0.61
# | 에폭 15 |  반복 301 / 351 | 시간 19[s] | 손실 0.61
# | 에폭 15 |  반복 321 / 351 | 시간 20[s] | 손실 0.63
# | 에폭 15 |  반복 341 / 351 | 시간 22[s] | 손실 0.62
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 844
# ---
# Q 761+292
# T 1053
# X 1051
# ---
# Q 830+597
# T 1427
# X 1420
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 237
# ---
# 검증 정확도 18.920%
# | 에폭 16 |  반복 1 / 351 | 시간 0[s] | 손실 0.60
# | 에폭 16 |  반복 21 / 351 | 시간 1[s] | 손실 0.59
# | 에폭 16 |  반복 41 / 351 | 시간 2[s] | 손실 0.59
# | 에폭 16 |  반복 61 / 351 | 시간 4[s] | 손실 0.58
# | 에폭 16 |  반복 81 / 351 | 시간 5[s] | 손실 0.58
# | 에폭 16 |  반복 101 / 351 | 시간 6[s] | 손실 0.60
# | 에폭 16 |  반복 121 / 351 | 시간 7[s] | 손실 0.59
# | 에폭 16 |  반복 141 / 351 | 시간 9[s] | 손실 0.58
# | 에폭 16 |  반복 161 / 351 | 시간 10[s] | 손실 0.59
# | 에폭 16 |  반복 181 / 351 | 시간 12[s] | 손실 0.59
# | 에폭 16 |  반복 201 / 351 | 시간 13[s] | 손실 0.59
# | 에폭 16 |  반복 221 / 351 | 시간 14[s] | 손실 0.59
# | 에폭 16 |  반복 241 / 351 | 시간 16[s] | 손실 0.63
# | 에폭 16 |  반복 261 / 351 | 시간 17[s] | 손실 0.63
# | 에폭 16 |  반복 281 / 351 | 시간 18[s] | 손실 0.61
# | 에폭 16 |  반복 301 / 351 | 시간 19[s] | 손실 0.58
# | 에폭 16 |  반복 321 / 351 | 시간 21[s] | 손실 0.57
# | 에폭 16 |  반복 341 / 351 | 시간 22[s] | 손실 0.57
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# X 1136
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# X 421
# ---
# Q 600+257
# T 857
# X 849
# ---
# Q 761+292
# T 1053
# X 1054
# ---
# Q 830+597
# T 1427
# X 1424
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 233
# ---
# 검증 정확도 15.440%
# | 에폭 17 |  반복 1 / 351 | 시간 0[s] | 손실 0.63
# | 에폭 17 |  반복 21 / 351 | 시간 1[s] | 손실 0.59
# | 에폭 17 |  반복 41 / 351 | 시간 3[s] | 손실 0.59
# | 에폭 17 |  반복 61 / 351 | 시간 4[s] | 손실 0.56
# | 에폭 17 |  반복 81 / 351 | 시간 6[s] | 손실 0.57
# | 에폭 17 |  반복 101 / 351 | 시간 7[s] | 손실 0.61
# | 에폭 17 |  반복 121 / 351 | 시간 9[s] | 손실 0.57
# | 에폭 17 |  반복 141 / 351 | 시간 10[s] | 손실 0.55
# | 에폭 17 |  반복 161 / 351 | 시간 11[s] | 손실 0.55
# | 에폭 17 |  반복 181 / 351 | 시간 13[s] | 손실 0.54
# | 에폭 17 |  반복 201 / 351 | 시간 14[s] | 손실 0.58
# | 에폭 17 |  반복 221 / 351 | 시간 16[s] | 손실 0.57
# | 에폭 17 |  반복 241 / 351 | 시간 18[s] | 손실 0.56
# | 에폭 17 |  반복 261 / 351 | 시간 19[s] | 손실 0.59
# | 에폭 17 |  반복 281 / 351 | 시간 21[s] | 손실 0.55
# | 에폭 17 |  반복 301 / 351 | 시간 22[s] | 손실 0.54
# | 에폭 17 |  반복 321 / 351 | 시간 24[s] | 손실 0.56
# | 에폭 17 |  반복 341 / 351 | 시간 25[s] | 손실 0.58
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# X 667
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# X 423
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# X 1431
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 239
# ---
# 검증 정확도 21.880%
# | 에폭 18 |  반복 1 / 351 | 시간 0[s] | 손실 0.55
# | 에폭 18 |  반복 21 / 351 | 시간 1[s] | 손실 0.55
# | 에폭 18 |  반복 41 / 351 | 시간 2[s] | 손실 0.55
# | 에폭 18 |  반복 61 / 351 | 시간 4[s] | 손실 0.58
# | 에폭 18 |  반복 81 / 351 | 시간 5[s] | 손실 0.60
# | 에폭 18 |  반복 101 / 351 | 시간 6[s] | 손실 0.57
# | 에폭 18 |  반복 121 / 351 | 시간 7[s] | 손실 0.55
# | 에폭 18 |  반복 141 / 351 | 시간 8[s] | 손실 0.53
# | 에폭 18 |  반복 161 / 351 | 시간 10[s] | 손실 0.53
# | 에폭 18 |  반복 181 / 351 | 시간 11[s] | 손실 0.56
# | 에폭 18 |  반복 201 / 351 | 시간 12[s] | 손실 0.55
# | 에폭 18 |  반복 221 / 351 | 시간 13[s] | 손실 0.54
# | 에폭 18 |  반복 241 / 351 | 시간 14[s] | 손실 0.52
# | 에폭 18 |  반복 261 / 351 | 시간 15[s] | 손실 0.51
# | 에폭 18 |  반복 281 / 351 | 시간 16[s] | 손실 0.51
# | 에폭 18 |  반복 301 / 351 | 시간 17[s] | 손실 0.54
# | 에폭 18 |  반복 321 / 351 | 시간 18[s] | 손실 0.54
# | 에폭 18 |  반복 341 / 351 | 시간 19[s] | 손실 0.55
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# X 420
# ---
# Q 600+257
# T 857
# X 854
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# X 1424
# ---
# Q 26+838
# T 864
# X 865
# ---
# Q 143+93
# T 236
# X 233
# ---
# 검증 정확도 24.740%
# | 에폭 19 |  반복 1 / 351 | 시간 0[s] | 손실 0.53
# | 에폭 19 |  반복 21 / 351 | 시간 1[s] | 손실 0.54
# | 에폭 19 |  반복 41 / 351 | 시간 2[s] | 손실 0.54
# | 에폭 19 |  반복 61 / 351 | 시간 3[s] | 손실 0.51
# | 에폭 19 |  반복 81 / 351 | 시간 5[s] | 손실 0.51
# | 에폭 19 |  반복 101 / 351 | 시간 6[s] | 손실 0.52
# | 에폭 19 |  반복 121 / 351 | 시간 8[s] | 손실 0.51
# | 에폭 19 |  반복 141 / 351 | 시간 9[s] | 손실 0.52
# | 에폭 19 |  반복 161 / 351 | 시간 10[s] | 손실 0.51
# | 에폭 19 |  반복 181 / 351 | 시간 12[s] | 손실 0.50
# | 에폭 19 |  반복 201 / 351 | 시간 13[s] | 손실 0.50
# | 에폭 19 |  반복 221 / 351 | 시간 14[s] | 손실 0.58
# | 에폭 19 |  반복 241 / 351 | 시간 15[s] | 손실 0.52
# | 에폭 19 |  반복 261 / 351 | 시간 17[s] | 손실 0.52
# | 에폭 19 |  반복 281 / 351 | 시간 18[s] | 손실 0.52
# | 에폭 19 |  반복 301 / 351 | 시간 19[s] | 손실 0.52
# | 에폭 19 |  반복 321 / 351 | 시간 20[s] | 손실 0.54
# | 에폭 19 |  반복 341 / 351 | 시간 21[s] | 손실 0.57
# Q 77+85
# T 162
# X 161
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# X 423
# ---
# Q 600+257
# T 857
# X 859
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# X 1425
# ---
# Q 26+838
# T 864
# X 865
# ---
# Q 143+93
# T 236
# O 236
# ---
# 검증 정확도 24.860%
# | 에폭 20 |  반복 1 / 351 | 시간 0[s] | 손실 0.52
# | 에폭 20 |  반복 21 / 351 | 시간 1[s] | 손실 0.51
# | 에폭 20 |  반복 41 / 351 | 시간 2[s] | 손실 0.48
# | 에폭 20 |  반복 61 / 351 | 시간 3[s] | 손실 0.48
# | 에폭 20 |  반복 81 / 351 | 시간 4[s] | 손실 0.49
# | 에폭 20 |  반복 101 / 351 | 시간 5[s] | 손실 0.51
# | 에폭 20 |  반복 121 / 351 | 시간 6[s] | 손실 0.49
# | 에폭 20 |  반복 141 / 351 | 시간 7[s] | 손실 0.51
# | 에폭 20 |  반복 161 / 351 | 시간 8[s] | 손실 0.51
# | 에폭 20 |  반복 181 / 351 | 시간 10[s] | 손실 0.55
# | 에폭 20 |  반복 201 / 351 | 시간 11[s] | 손실 0.54
# | 에폭 20 |  반복 221 / 351 | 시간 12[s] | 손실 0.51
# | 에폭 20 |  반복 241 / 351 | 시간 13[s] | 손실 0.51
# | 에폭 20 |  반복 261 / 351 | 시간 14[s] | 손실 0.48
# | 에폭 20 |  반복 281 / 351 | 시간 15[s] | 손실 0.48
# | 에폭 20 |  반복 301 / 351 | 시간 16[s] | 손실 0.52
# | 에폭 20 |  반복 321 / 351 | 시간 17[s] | 손실 0.52
# | 에폭 20 |  반복 341 / 351 | 시간 18[s] | 손실 0.51
# Q 77+85
# T 162
# X 160
# ---
# Q 975+164
# T 1139
# X 1138
# ---
# Q 582+84
# T 666
# X 665
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 852
# ---
# Q 761+292
# T 1053
# X 1044
# ---
# Q 830+597
# T 1427
# X 1425
# ---
# Q 26+838
# T 864
# X 862
# ---
# Q 143+93
# T 236
# X 235
# ---
# 검증 정확도 26.940%
# | 에폭 21 |  반복 1 / 351 | 시간 0[s] | 손실 0.46
# | 에폭 21 |  반복 21 / 351 | 시간 1[s] | 손실 0.50
# | 에폭 21 |  반복 41 / 351 | 시간 2[s] | 손실 0.47
# | 에폭 21 |  반복 61 / 351 | 시간 3[s] | 손실 0.48
# | 에폭 21 |  반복 81 / 351 | 시간 4[s] | 손실 0.50
# | 에폭 21 |  반복 101 / 351 | 시간 6[s] | 손실 0.50
# | 에폭 21 |  반복 121 / 351 | 시간 7[s] | 손실 0.49
# | 에폭 21 |  반복 141 / 351 | 시간 8[s] | 손실 0.47
# | 에폭 21 |  반복 161 / 351 | 시간 9[s] | 손실 0.46
# | 에폭 21 |  반복 181 / 351 | 시간 11[s] | 손실 0.46
# | 에폭 21 |  반복 201 / 351 | 시간 12[s] | 손실 0.45
# | 에폭 21 |  반복 221 / 351 | 시간 13[s] | 손실 0.46
# | 에폭 21 |  반복 241 / 351 | 시간 14[s] | 손실 0.47
# | 에폭 21 |  반복 261 / 351 | 시간 15[s] | 손실 0.48
# | 에폭 21 |  반복 281 / 351 | 시간 17[s] | 손실 0.46
# | 에폭 21 |  반복 301 / 351 | 시간 18[s] | 손실 0.48
# | 에폭 21 |  반복 321 / 351 | 시간 19[s] | 손실 0.47
# | 에폭 21 |  반복 341 / 351 | 시간 20[s] | 손실 0.46
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# X 667
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# X 421
# ---
# Q 600+257
# T 857
# X 854
# ---
# Q 761+292
# T 1053
# X 1048
# ---
# Q 830+597
# T 1427
# X 1425
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 234
# ---
# 검증 정확도 30.220%
# | 에폭 22 |  반복 1 / 351 | 시간 0[s] | 손실 0.46
# | 에폭 22 |  반복 21 / 351 | 시간 1[s] | 손실 0.47
# | 에폭 22 |  반복 41 / 351 | 시간 2[s] | 손실 0.48
# | 에폭 22 |  반복 61 / 351 | 시간 3[s] | 손실 0.45
# | 에폭 22 |  반복 81 / 351 | 시간 4[s] | 손실 0.45
# | 에폭 22 |  반복 101 / 351 | 시간 5[s] | 손실 0.45
# | 에폭 22 |  반복 121 / 351 | 시간 6[s] | 손실 0.46
# | 에폭 22 |  반복 141 / 351 | 시간 7[s] | 손실 0.47
# | 에폭 22 |  반복 161 / 351 | 시간 8[s] | 손실 0.52
# | 에폭 22 |  반복 181 / 351 | 시간 9[s] | 손실 0.47
# | 에폭 22 |  반복 201 / 351 | 시간 10[s] | 손실 0.45
# | 에폭 22 |  반복 221 / 351 | 시간 11[s] | 손실 0.48
# | 에폭 22 |  반복 241 / 351 | 시간 13[s] | 손실 0.46
# | 에폭 22 |  반복 261 / 351 | 시간 14[s] | 손실 0.48
# | 에폭 22 |  반복 281 / 351 | 시간 15[s] | 손실 0.44
# | 에폭 22 |  반복 301 / 351 | 시간 16[s] | 손실 0.44
# | 에폭 22 |  반복 321 / 351 | 시간 17[s] | 손실 0.43
# | 에폭 22 |  반복 341 / 351 | 시간 18[s] | 손실 0.45
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1136
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 859
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# X 1426
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# 검증 정확도 28.660%
# | 에폭 23 |  반복 1 / 351 | 시간 0[s] | 손실 0.43
# | 에폭 23 |  반복 21 / 351 | 시간 1[s] | 손실 0.42
# | 에폭 23 |  반복 41 / 351 | 시간 2[s] | 손실 0.44
# | 에폭 23 |  반복 61 / 351 | 시간 3[s] | 손실 0.43
# | 에폭 23 |  반복 81 / 351 | 시간 4[s] | 손실 0.45
# | 에폭 23 |  반복 101 / 351 | 시간 5[s] | 손실 0.49
# | 에폭 23 |  반복 121 / 351 | 시간 6[s] | 손실 0.47
# | 에폭 23 |  반복 141 / 351 | 시간 7[s] | 손실 0.42
# | 에폭 23 |  반복 161 / 351 | 시간 8[s] | 손실 0.44
# | 에폭 23 |  반복 181 / 351 | 시간 10[s] | 손실 0.48
# | 에폭 23 |  반복 201 / 351 | 시간 11[s] | 손실 0.47
# | 에폭 23 |  반복 221 / 351 | 시간 12[s] | 손실 0.50
# | 에폭 23 |  반복 241 / 351 | 시간 13[s] | 손실 0.49
# | 에폭 23 |  반복 261 / 351 | 시간 14[s] | 손실 0.44
# | 에폭 23 |  반복 281 / 351 | 시간 15[s] | 손실 0.42
# | 에폭 23 |  반복 301 / 351 | 시간 16[s] | 손실 0.41
# | 에폭 23 |  반복 321 / 351 | 시간 17[s] | 손실 0.44
# | 에폭 23 |  반복 341 / 351 | 시간 18[s] | 손실 0.44
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# X 665
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# X 421
# ---
# Q 600+257
# T 857
# X 856
# ---
# Q 761+292
# T 1053
# X 1051
# ---
# Q 830+597
# T 1427
# X 1428
# ---
# Q 26+838
# T 864
# X 865
# ---
# Q 143+93
# T 236
# X 238
# ---
# 검증 정확도 34.100%
# | 에폭 24 |  반복 1 / 351 | 시간 0[s] | 손실 0.42
# | 에폭 24 |  반복 21 / 351 | 시간 1[s] | 손실 0.47
# | 에폭 24 |  반복 41 / 351 | 시간 2[s] | 손실 0.46
# | 에폭 24 |  반복 61 / 351 | 시간 4[s] | 손실 0.42
# | 에폭 24 |  반복 81 / 351 | 시간 5[s] | 손실 0.42
# | 에폭 24 |  반복 101 / 351 | 시간 6[s] | 손실 0.42
# | 에폭 24 |  반복 121 / 351 | 시간 8[s] | 손실 0.45
# | 에폭 24 |  반복 141 / 351 | 시간 9[s] | 손실 0.47
# | 에폭 24 |  반복 161 / 351 | 시간 11[s] | 손실 0.44
# | 에폭 24 |  반복 181 / 351 | 시간 12[s] | 손실 0.46
# | 에폭 24 |  반복 201 / 351 | 시간 13[s] | 손실 0.41
# | 에폭 24 |  반복 221 / 351 | 시간 15[s] | 손실 0.40
# | 에폭 24 |  반복 241 / 351 | 시간 16[s] | 손실 0.41
# | 에폭 24 |  반복 261 / 351 | 시간 18[s] | 손실 0.44
# | 에폭 24 |  반복 281 / 351 | 시간 19[s] | 손실 0.47
# | 에폭 24 |  반복 301 / 351 | 시간 20[s] | 손실 0.42
# | 에폭 24 |  반복 321 / 351 | 시간 22[s] | 손실 0.41
# | 에폭 24 |  반복 341 / 351 | 시간 23[s] | 손실 0.41
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# X 1143
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 161
# ---
# Q 367+55
# T 422
# X 421
# ---
# Q 600+257
# T 857
# X 859
# ---
# Q 761+292
# T 1053
# X 1054
# ---
# Q 830+597
# T 1427
# X 1431
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 238
# ---
# 검증 정확도 34.340%
# | 에폭 25 |  반복 1 / 351 | 시간 0[s] | 손실 0.43
# | 에폭 25 |  반복 21 / 351 | 시간 1[s] | 손실 0.43
# | 에폭 25 |  반복 41 / 351 | 시간 2[s] | 손실 0.45
# | 에폭 25 |  반복 61 / 351 | 시간 3[s] | 손실 0.43
# | 에폭 25 |  반복 81 / 351 | 시간 5[s] | 손실 0.39
# | 에폭 25 |  반복 101 / 351 | 시간 6[s] | 손실 0.41
# | 에폭 25 |  반복 121 / 351 | 시간 7[s] | 손실 0.42
# | 에폭 25 |  반복 141 / 351 | 시간 9[s] | 손실 0.44
# | 에폭 25 |  반복 161 / 351 | 시간 10[s] | 손실 0.42
# | 에폭 25 |  반복 181 / 351 | 시간 11[s] | 손실 0.43
# | 에폭 25 |  반복 201 / 351 | 시간 12[s] | 손실 0.41
# | 에폭 25 |  반복 221 / 351 | 시간 13[s] | 손실 0.41
# | 에폭 25 |  반복 241 / 351 | 시간 14[s] | 손실 0.46
# | 에폭 25 |  반복 261 / 351 | 시간 16[s] | 손실 0.43
# | 에폭 25 |  반복 281 / 351 | 시간 17[s] | 손실 0.38
# | 에폭 25 |  반복 301 / 351 | 시간 18[s] | 손실 0.40
# | 에폭 25 |  반복 321 / 351 | 시간 19[s] | 손실 0.44
# | 에폭 25 |  반복 341 / 351 | 시간 20[s] | 손실 0.39
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# X 1140
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# X 423
# ---
# Q 600+257
# T 857
# X 858
# ---
# Q 761+292
# T 1053
# X 1054
# ---
# Q 830+597
# T 1427
# X 1428
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 235
# ---
# 검증 정확도 36.840%

# %%
# 그래프 그리기
plt.figure(figsize=(12, 8))
for hidden_size, acc_list in results.items():
    x = np.arange(len(acc_list))
    plt.plot(x, acc_list, marker='o', label=f'hidden_size={hidden_size}')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim(0, 1.0)
plt.legend()
plt.show()
