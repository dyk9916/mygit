# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('C:/Users/KimDongyoung/Desktop/my_git/mygit/NH투자증권/질문리스트.csv')

# %%
df1
# Out:
#                                질문                       답변고려사항
# 0             ETF에 대해 얼마나 알고계신가요?                ETF에 대한 기초 정보
# 1  ETF 투자에서 중요한 요소가 무엇이라고 생각하시나요?        중요시여기는 요소를 고려한 ETF 추천
# 2               투자의 목표가 어떻게 되시나요?    목표에 맞는 ETF 추천(장/단기 투자 구분)
# 3          본인의 투자 성향을 어떻게 생각하시나요?               위험감수성향(변동성) 파악
# 4              선호하는 투자 방식이 있으신가요?     분산투자 및 위험감수성향 고려한 ETF 추천
# 5                투자 경험이 어떻게 되시나요?            중요시여기는 요소의 중요도 증가
# 6                    시드 머니를 적어주세요  종목 종가와 투자성향을 고려하여 투자 가이드 생성
# 7           선호하는 투자 기간이 어떻게 되시나요?                   장/단기 투자 구분
# 8                 관심있는 섹터가 있으신가요?          관심있는 섹터를 포함한 ETF 추천
# 9                  배당 수익을 중시하시나요?               배당금이 높은 ETF 추천

# %%
from langchain.chat_models import ChatOpenAI
# Out:
# c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain\chat_models\__init__.py:25: LangChainDeprecationWarning: As of langchain-core 0.3.0, LangChain uses pydantic v2 internally. The langchain_core.pydantic_v1 module was a compatibility shim for pydantic v1, and should no longer be used. Please update the code to import from Pydantic directly.
#
# For example, replace imports like: `from langchain_core.pydantic_v1 import BaseModel`
# with: `from pydantic import BaseModel`
# or the v1 compatibility namespace if you are working in a code base that has not been fully upgraded to pydantic 2 yet. 	from pydantic.v1 import BaseModel
#
#   from langchain.chat_models.base import init_chat_model
# c:\Users\KimDongyoung\AppData\Local\Programs\Python\Python312\Lib\site-packages\pydantic\_internal\_config.py:341: UserWarning: Valid config keys have changed in V2:
# * 'allow_population_by_field_name' has been renamed to 'populate_by_name'
#   warnings.warn(message, UserWarning)
