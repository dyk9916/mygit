# %%
# 필요한 패키지 설치
# !pip install plotly
# !pip install pywaffle
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import plotly.express as px
from pywaffle import Waffle
plt.rcParams['figure.dpi'] = 300
# Out:
# Requirement already satisfied: plotly in c:\users\kimdongyoung\appdata\local\programs\python\python312\lib\site-packages (5.23.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\kimdongyoung\appdata\local\programs\python\python312\lib\site-packages (from plotly) (8.5.0)
# Requirement already satisfied: packaging in c:\users\kimdongyoung\appdata\local\programs\python\python312\lib\site-packages (from plotly) (24.1)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pywaffle in c:\users\kimdongyoung\appdata\local\programs\python\python312\lib\site-packages (1.1.1)
# Requirement already satisfied: fontawesomefree in c:\users\kimdongyoung\appdata\local\programs\python\python312\lib\site-packages (from pywaffle) (6.6.0)
# Requirement already satisfied: matplotlib in c:\users\kimdongyoung\appdata\local\programs\python\python312\lib\site-packages (from pywaffle) (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kimdongyoung\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->pywaffle) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\kimdongyoung\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->pywaffle) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kimdongyoung\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->pywaffle) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kimdongyoung\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->pywaffle) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\kimdongyoung\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->pywaffle) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\kimdongyoung\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->pywaffle) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\kimdongyoung\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->pywaffle) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kimdongyoung\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->pywaffle) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kimdongyoung\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->pywaffle) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\kimdongyoung\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->pywaffle) (1.16.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("fivethirtyeight/uber-pickups-in-new-york-city")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.10)
# Path to dataset files: C:\Users\KimDongyoung\.cache\kagglehub\datasets\fivethirtyeight\uber-pickups-in-new-york-city\versions\2

# %%
df = pd.read_csv("C:/Users/KimDongyoung/.cache/kagglehub/datasets/fivethirtyeight/uber-pickups-in-new-york-city/versions/2/uber-raw-data-sep14.csv")

# 데이터 샘플 확인
df.head()
# Out:
#           Date/Time      Lat      Lon    Base
# 0  9/1/2014 0:01:00  40.2201 -74.0021  B02512
# 1  9/1/2014 0:01:00  40.7500 -74.0027  B02512
# 2  9/1/2014 0:03:00  40.7559 -73.9864  B02512
# 3  9/1/2014 0:06:00  40.7450 -73.9889  B02512
# 4  9/1/2014 0:11:00  40.8145 -73.9444  B02512

# %%
# Date/Time 컬럼을 datetime 형식으로 변환
df['Date/Time'] = pd.to_datetime(df['Date/Time'])

# 날짜와 시간을 각각 분리하여 새로운 컬럼 생성
df['Date'] = df['Date/Time'].dt.date
df['Time'] = df['Date/Time'].dt.time

# 결과 확인
df = df.drop('Date/Time', axis=1)

# %%
# Date 컬럼을 datetime 형식으로 변환
df['Date'] = pd.to_datetime(df['Date'])

# Time 컬럼을 datetime 형식으로 변환
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028136 entries, 0 to 1028135
# Data columns (total 5 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   Lat     1028136 non-null  float64
#  1   Lon     1028136 non-null  float64
#  2   Base    1028136 non-null  object
#  3   Date    1028136 non-null  datetime64[ns]
#  4   Time    1028136 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), object(1)
# memory usage: 39.2+ MB

# %%
# 각 컬럼의 속성 및 결측치 확인
df.info()
# 각 컬럼의 통계치 확인
df.describe()
# 각 컬럼의 왜도 확인
df.skew(numeric_only  = True)
# 각 컬럼의 첨도 확인
df.kurtosis(numeric_only = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028136 entries, 0 to 1028135
# Data columns (total 5 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   Lat     1028136 non-null  float64
#  1   Lon     1028136 non-null  float64
#  2   Base    1028136 non-null  object
#  3   Date    1028136 non-null  datetime64[ns]
#  4   Time    1028136 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), object(1)
# memory usage: 39.2+ MB
# Lat    10.180041
# Lon    27.924359
# dtype: float64

# %%
# hour, day_of_week 컬럼 생성
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S')
df['hour'] = df['Time'].dt.hour
df['day_of_week'] = df['Date'].dt.day_name()

# %% [markdown]
# 시각화 실습

# %%
# 시간대별 탑승 수 추이

# 시간대별 탑승 수 집계
hourly_rides = df.groupby('hour').size() # hour을 기준으로 그룹화하여 사이즈 계산

plt.figure(figsize=(10, 6))
hourly_rides.plot(kind='line', marker='o')
plt.title('Hourly Uber Pickups', fontsize=14)
plt.xlabel('Hour of Day', fontsize=12)
plt.ylabel('Number of Rides', fontsize=12)
plt.grid(True)
plt.xticks(range(0, 24))
plt.show()

# %%
# 요일별 탑승 수 집계
rides_by_day = df['day_of_week'].value_counts()

# 요일 순서 정렬
rides_by_day = rides_by_day.reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])

# 히스토그램 시각화
plt.figure(figsize=(10, 6))
rides_by_day.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Pickups by Day of the Week', fontsize=14)
plt.xlabel('Day of the Week', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# hour와 day_of_week 컬럼을 기준으로 탑승 수 집계
heatmap_data = df.groupby(['day_of_week', 'hour']).size().unstack()

# 히트맵 시각화
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, cmap='YlGnBu', annot=False, fmt='d', cbar_kws={'label': 'Number of Rides'})
plt.title('Heatmap of Uber Pickups by Hour and Day of the Week', fontsize=14)
plt.xlabel('Day of the Week', fontsize=12)
plt.ylabel('Hour of Day', fontsize=12)
plt.show()

# %%
# 요일별 탑승 수 방사형 차트
categories = rides_by_day.index
values = rides_by_day.values

# 카테고리를 닫아 방사형 차트를 완성형으로 만듦
categories = list(categories) + [categories[0]]
values = list(values) + [values[0]]

# 각 카테고리에 대한 각도 계산
angles = np.linspace(0, 2 * np.pi, len(categories), endpoint=True)


# 방사형 차트 생성
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw={'polar': True})
ax.plot(angles, values, marker='o', label='Rides by Day')
ax.fill(angles, values, alpha=0.25)

# 카테고리 레이블 설정
ax.set_xticks(angles)
ax.set_xticklabels(categories)

# 제목 및 범례 추가
plt.title('Uber Pickups by Day of the Week (Radar Chart)', fontsize=14)
plt.legend(loc='upper right', bbox_to_anchor=(1.1, 1.1))
plt.show()

# %%
# 요일별 색상 설정
colors = ['red', 'orange', 'yellow', 'green', 'blue', 'purple', 'pink']

# 방사형 차트 생성
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw={'polar': True})

# 요일별로 색상 적용
for i in range(len(categories) - 1):  # 마지막 카테고리는 반복을 닫기 위한 것이므로 제외
  ax.fill(angles[i:i+2], values[i:i+2], color=colors[i], alpha=0.5, label=categories[i])
  ax.plot(angles[i:i+2], values[i:i+2], color=colors[i], marker='o')

# 카테고리 레이블 설정
ax.set_xticks(angles)
ax.set_xticklabels(categories)

# 제목 및 범례 추가
plt.title('Uber Pickups by Day of the Week (Radar Chart)', fontsize=14)
plt.legend(loc='upper right', bbox_to_anchor=(1.1, 1.1))
plt.show()
